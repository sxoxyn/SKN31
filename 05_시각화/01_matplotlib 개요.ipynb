# %% [markdown]
# # 데이터 시각화의 개념 및 필요성
#
# ## 데이터 시각화
# - 데이터의 분석 결과를 쉽게 이해하고 판단할 수 있도록 데이터를 시각적으로 표현하여 전달하기 위한 과정을 말한다.
#
# ## 필요성
# - 많은 양의 데이터를 한눈에 파악할 수 있다. 시각적 요소를 활용해 데이터를 요약한다.
# - 데이터 분석에 대한 전문적 지식이 없더라도 누구나 해당 데이터를 인지하고 활용할 수있게한다.
#     - 사람이 감각기관을 통해 획득하는 정보의 80%는 시각에 의한 것이다.
#     - 시각적인 입력은 다른 어떤 방법보다 빠르고 쉽게 사람이 이해할 수 있다.
#     - 시각화 형태, 요소, 위치, 색등을 기반으로 패턴이나 다양한 인사이트(의미있는 정보)를 도출 및 표현할 수 있다.
# - 단순한 데이터 요약, 통계분석 결과보다 정확한 데이터 분석결과를 도출할 수있다.
#     - 데이터의 패턴이나 추세, 데이터간 비교등 표(Table)로 쉽게 인식 할 수 없는 것들을 시각적으로 쉽게 확인할 수 있다.
# - [앤스컴 4분할 그래프(Anscombe's quartet)의 예](https://ko.wikipedia.org/wiki/%EC%95%A4%EC%8A%A4%EC%BB%B4_%EC%BD%B0%EB%A5%B4%ED%85%9F)
#     - 시각화의 중요성을 나타내는 예.
#     - 4개의 데이터셋은 평균, 표준편차, 상관계수 등의 통계량이 거의 일치한다. 그래서 통계량적으로는 같은 데이터셋이다.
#     - 그러나 시각화해서 그래프를 그려보면 전혀 다른 데이터 셋이다.
# # 대표적 파이썬 시각화 라이브러리
# - matplotlib
# - seaborn
# - pandas
# - plotly
# - folium
#
# + 무슨 그래프를 언제 그려야 하는지(어떨 때 어떤 그래프를 써야 하는지) 알고 있어야 함!

# %% [markdown]
# #  Matplotlib
# - 데이터의 시각화를 위한 파이썬 패키지
# - 2차원 그래프를 위한 패키지이나 확장 API들을 이용해 3D 그래프등 다양한 형식의 시각화를 지원
# - 파이썬 기반의 다른 시각화 패키지의 기본이 된다.
#     - 'Seaborn, Pandas 등이 Matplotlib를 기반'으로 사용한다.
# - https://matplotlib.org
#
# ## 설치
# - `pip install matplotlib`
# - 설치 디렉토리 확인 : 'uv pip show matplotlib'
#
# > ### 한글 처리
# > matplotlib의 기본 폰트는 한글을 지원하지 않는다. matplotlib의 폰트 설정을 변경해야 한다.
# >
# > - matplotlib 설정파일에서 변경
# >   - `파이썬설치경로\Lib\site-packages\matplotlib\mpl-data\matplotlibrc`
# >     - `font.famliy` 를 설치된 폰트 중 한글 지원 폰트로 변경. `font.family: Malgun gothic`
# >     - `axes.unicode_minus` 를 `False` 로 변경. `axes.unicode_minus: False` (한글로 바꿨을 때 음수 기호 안 깨지게 하기 위함)
# >      - 두 가지가 짝!
# >   - matplotlib 설치한 뒤 한번만 하면 된다.
# > - Code로 변경
# >   - Application 이 실행하는 동안만 적용된다.
# >   ```python
# >   import matplotlib.pyplot as plt
# >
# >   plt.rcParams["font.family"] = "malgun gothic"
# >   plt.rcParams['axes.unicode_minus'] = False
# >   ```
# >
# > - matplotlib  설정변경
# >   - 이 외에 그래프와 관련된 설정들은 위의 두가지 방법으로 변경할 수 있다.
# >   - 항상 적용될 설정 변경은 **설정파일**에서 변경한다.
# >   - 현재 application에만 적용할 설정 변경은 **Code를 이용**해 변경한다.

# %%
# matplotlib 설정파일 (matplotlibrc 경로 조회)
import  matplotlib as mpl
print(mpl.matplotlib_fname())
# Out:
# c:\Documents\SKN31\05_시각화\.venv\Lib\site-packages\matplotlib\mpl-data\matplotlibrc

# %%
# 설치된 폰트 경로 조회
import matplotlib.font_manager as fm
from pprint import pprint

font_list = fm.findSystemFonts(fontpaths=None, fontext='ttf') #ttf, otf
pprint(font_list)
# Out:
# ['C:\\Windows\\Fonts\\segoeprb.ttf',
#  'C:\\Windows\\Fonts\\trebucbi.ttf',
#  'C:\\Windows\\Fonts\\malgunbd.ttf',
#  'C:\\Windows\\Fonts\\phagspa.ttf',
#  'C:\\Windows\\Fonts\\javatext.ttf',
#  'C:\\Windows\\Fonts\\SegUIVar.ttf',
#  'C:\\Windows\\Fonts\\couri.ttf',
#  'C:\\Windows\\Fonts\\SegoeIcons.ttf',
#  'C:\\Windows\\Fonts\\Candaral.ttf',
#  'C:\\Windows\\Fonts\\constani.ttf',
#  'C:\\Windows\\Fonts\\LeelUIsl.ttf',
#  'C:\\Windows\\Fonts\\calibriz.ttf',
#  'C:\\Windows\\Fonts\\tahoma.ttf',
#  'C:\\Windows\\Fonts\\segoeuil.ttf',
#  'C:\\Windows\\Fonts\\YuGothL.ttc',
#  'C:\\Windows\\Fonts\\Gabriola.ttf',
#  'C:\\Windows\\Fonts\\times.ttf',
#  'C:\\Windows\\Fonts\\trebucbd.ttf',
#  'C:\\Windows\\Fonts\\segoeuiz.ttf',
#  'C:\\Windows\\Fonts\\seguisym.ttf',
#  'C:\\Windows\\Fonts\\NotoSansKR-VF.ttf',
#  'C:\\Windows\\Fonts\\verdanab.ttf',
#  'C:\\Windows\\Fonts\\malgun.ttf',
#  'C:\\Windows\\Fonts\\malgunsl.ttf',
#  'C:\\Windows\\Fonts\\taileb.ttf',
#  'C:\\Windows\\Fonts\\timesi.ttf',
#  'C:\\Windows\\Fonts\\verdana.ttf',
#  'C:\\Windows\\Fonts\\calibri.ttf',
#  'C:\\Windows\\Fonts\\seguibli.ttf',
#  'C:\\Windows\\Fonts\\gadugib.ttf',
#  'C:\\Windows\\Fonts\\palai.ttf',
#  'C:\\Windows\\Fonts\\segmdl2.ttf',
#  'C:\\Windows\\Fonts\\consolab.ttf',
#  'C:\\Windows\\Fonts\\mmrtextb.ttf',
#  'C:\\Windows\\Fonts\\verdanai.ttf',
#  'C:\\Windows\\Fonts\\SitkaVF-Italic.ttf',
#  'C:\\Windows\\Fonts\\comicz.ttf',
#  'C:\\Windows\\Fonts\\tahomabd.ttf',
#  'C:\\Windows\\Fonts\\comici.ttf',
#  'C:\\Windows\\Fonts\\timesbd.ttf',
#  'C:\\Windows\\Fonts\\trebuc.ttf',
#  'C:\\Windows\\Fonts\\LeelawUI.ttf',
#  'C:\\Windows\\Fonts\\seguili.ttf',
#  'C:\\Windows\\Fonts\\corbell.ttf',
#  'C:\\Windows\\Fonts\\comicbd.ttf',
#  'C:\\Windows\\Fonts\\arialbi.ttf',
#  'C:\\Windows\\Fonts\\trebucit.ttf',
#  'C:\\Windows\\Fonts\\consola.ttf',
#  'C:\\Windows\\Fonts\\msyi.ttf',
#  'C:\\Windows\\Fonts\\mvboli.ttf',
#  'C:\\Windows\\Fonts\\msyhl.ttc',
#  'C:\\Windows\\Fonts\\SimsunExtG.ttf',
#  'C:\\Windows\\Fonts\\mingliub.ttc',
#  'C:\\Windows\\Fonts\\cambria.ttc',
#  'C:\\Windows\\Fonts\\corbelz.ttf',
#  'C:\\Windows\\Fonts\\seguisli.ttf',
#  'C:\\Windows\\Fonts\\YuGothM.ttc',
#  'C:\\Windows\\Fonts\\ntailu.ttf',
#  'C:\\Windows\\Fonts\\Candarai.ttf',
#  'C:\\Windows\\Fonts\\corbel.ttf',
#  'C:\\Windows\\Fonts\\georgia.ttf',
#  'C:\\Windows\\Fonts\\ariblk.ttf',
#  'C:\\Windows\\Fonts\\Candaraz.ttf',
#  'C:\\Windows\\Fonts\\ntailub.ttf',
#  'C:\\Windows\\Fonts\\courbd.ttf',
#  'C:\\Windows\\Fonts\\msyh.ttc',
#  'C:\\Windows\\Fonts\\courbi.ttf',
#  'C:\\Windows\\Fonts\\msgothic.ttc',
#  'C:\\Windows\\Fonts\\corbelb.ttf',
#  'C:\\Windows\\Fonts\\comic.ttf',
#  'C:\\Windows\\Fonts\\segoesc.ttf',
#  'C:\\Windows\\Fonts\\Candarali.ttf',
#  'C:\\Windows\\Fonts\\msjhl.ttc',
#  'C:\\Windows\\Fonts\\micross.ttf',
#  'C:\\Windows\\Fonts\\framd.ttf',
#  'C:\\Windows\\Fonts\\timesbi.ttf',
#  'C:\\Windows\\Fonts\\sylfaen.ttf',
#  'C:\\Windows\\Fonts\\ebrima.ttf',
#  'C:\\Windows\\Fonts\\segoepr.ttf',
#  'C:\\Windows\\Fonts\\cambriai.ttf',
#  'C:\\Windows\\Fonts\\pala.ttf',
#  'C:\\Windows\\Fonts\\ebrimabd.ttf',
#  'C:\\Windows\\Fonts\\monbaiti.ttf',
#  'C:\\Windows\\Fonts\\consolai.ttf',
#  'C:\\Windows\\Fonts\\calibrili.ttf',
#  'C:\\Windows\\Fonts\\LeelaUIb.ttf',
#  'C:\\Windows\\Fonts\\cambriaz.ttf',
#  'C:\\Windows\\Fonts\\YuGothB.ttc',
#  'C:\\Windows\\Fonts\\Nirmala.ttc',
#  'C:\\Windows\\Fonts\\gulim.ttc',
#  'C:\\Windows\\Fonts\\constanb.ttf',
#  'C:\\Windows\\Fonts\\arialbd.ttf',
#  'C:\\Windows\\Fonts\\Candarab.ttf',
#  'C:\\Windows\\Fonts\\constan.ttf',
#  'C:\\Windows\\Fonts\\batang.ttc',
#  'C:\\Windows\\Fonts\\YuGothR.ttc',
#  'C:\\Windows\\Fonts\\gadugi.ttf',
#  'C:\\Windows\\Fonts\\verdanaz.ttf',
#  'C:\\Windows\\Fonts\\Candara.ttf',
#  'C:\\Windows\\Fonts\\calibrib.ttf',
#  'C:\\Windows\\Fonts\\segoeui.ttf',
#  'C:\\Windows\\Fonts\\l_10646.ttf',
#  'C:\\Windows\\Fonts\\cour.ttf',
#  'C:\\Windows\\Fonts\\segoeuisl.ttf',
#  'C:\\Windows\\Fonts\\segoescb.ttf',
#  'C:\\Windows\\Fonts\\framdit.ttf',
#  'C:\\Windows\\Fonts\\simsun.ttc',
#  'C:\\Windows\\Fonts\\seguiemj.ttf',
#  'C:\\Windows\\Fonts\\msyhbd.ttc',
#  'C:\\Windows\\Fonts\\seguisb.ttf',
#  'C:\\Windows\\Fonts\\corbelli.ttf',
#  'C:\\Windows\\Fonts\\georgiab.ttf',
#  'C:\\Windows\\Fonts\\Inkfree.ttf',
#  'C:\\Windows\\Fonts\\himalaya.ttf',
#  'C:\\Windows\\Fonts\\lucon.ttf',
#  'C:\\Windows\\Fonts\\mmrtext.ttf',
#  'C:\\Windows\\Fonts\\arial.ttf',
#  'C:\\Windows\\Fonts\\seguibl.ttf',
#  'C:\\Windows\\Fonts\\simsunb.ttf',
#  'C:\\Windows\\Fonts\\phagspab.ttf',
#  'C:\\Windows\\Fonts\\corbeli.ttf',
#  'C:\\Windows\\Fonts\\wingding.ttf',
#  'C:\\Windows\\Fonts\\msjhbd.ttc',
#  'C:\\Windows\\Fonts\\bahnschrift.ttf',
#  'C:\\Windows\\Fonts\\consolaz.ttf',
#  'C:\\Windows\\Fonts\\seguisbi.ttf',
#  'C:\\Windows\\Fonts\\seguihis.ttf',
#  'C:\\Windows\\Fonts\\calibril.ttf',
#  'C:\\Windows\\Fonts\\webdings.ttf',
#  'C:\\Windows\\Fonts\\palabi.ttf',
#  'C:\\Windows\\Fonts\\taile.ttf',
#  'C:\\Windows\\Fonts\\ariali.ttf',
#  'C:\\Windows\\Fonts\\georgiai.ttf',
#  'C:\\Windows\\Fonts\\segoeuii.ttf',
#  'C:\\Windows\\Fonts\\impact.ttf',
#  'C:\\Windows\\Fonts\\georgiaz.ttf',
#  'C:\\Windows\\Fonts\\palab.ttf',
#  'C:\\Windows\\Fonts\\cambriab.ttf',
#  'C:\\Windows\\Fonts\\constanz.ttf',
#  'C:\\Windows\\Fonts\\SitkaVF.ttf',
#  'C:\\Windows\\Fonts\\msjh.ttc',
#  'C:\\Windows\\Fonts\\calibrii.ttf',
#  'C:\\Windows\\Fonts\\SansSerifCollection.ttf',
#  'C:\\Windows\\Fonts\\NotoSerifKR-VF.ttf',
#  'C:\\Windows\\Fonts\\symbol.ttf',
#  'C:\\Windows\\Fonts\\segoeuib.ttf']

# %%
# 폰트 정보를 조회
f_info = fm.FontProperties(fname='C:\\Windows\\Fonts\\cambriaz.ttf')
f_info.get_name(), f_info.get_weight(), f_info.get_style()
# Out:
# ('Cambria', 'normal', 'normal')

# %%
# 맑은고딕 폰트의 이름을 조회
font_list = fm.findSystemFonts(fontpaths=None, fontext='ttf') # 모든 폰트파일 경로 조회
[(font_path, fm.FontProperties(fname=font_path).get_name()) 
                for font_path in font_list if 'malgun' in font_path.lower() ]
# Out:
# [('C:\\Windows\\Fonts\\malgunbd.ttf', 'Malgun Gothic'),
#  ('C:\\Windows\\Fonts\\malgun.ttf', 'Malgun Gothic'),
#  ('C:\\Windows\\Fonts\\malgunsl.ttf', 'Malgun Gothic')]

# %% [markdown]
# ## 그래프 구성요소
# <img src='https://matplotlib.org/stable/_images/anatomy.png' width='1024'>

# %% [markdown]
# - **figure**
#     - '전체 그래프'가 위치할 기본 '틀'(도화지)
#     - 하나의 figure에 여러개의 그래프를 그릴 수 있다.
#     - https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.figure.html
# - **axes(subplot)**
#     - figure내에 '한개의 그래프'를 그리기 위한 공간(하나 이상의 그림 그릴 영역)
#         - figure에 한개 이상의 axes(subplot)로 구성해서 각 axes에 그래프를 그린다.
#     - https://matplotlib.org/stable/api/axes_api.html
# - **axis**
#     - 축 (x축, y축)은 값들을 표시하는 선을 말한다.
#     - axis label (x, y) : 축의 레이블(설명)
# - **ticks** : 축의 값을 알려주는 눈금
#     - Major tick
#     - Minor tick
# - **title** : 플롯 제목
# - **legend (범례)**
#     - 하나의 axes내에 여러 그래프를 그린 경우 그것에 대한 설명

# %%
# %matplotlib qt
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np

# plt.style.use("dark_background")

fig = plt.figure(figsize=(15,7), facecolor='gray') #facecolor: figure의 배경색
axes1 = fig.add_subplot(1,2,1)
axes2 = fig.add_subplot(1,2,2)

axes1.plot([1,2,3,4,5], [10,20,30,40,50], label='line1')
axes1.plot([1,2,3,4,5], [50,40,30,20,10], label='line2')
axes2.scatter(np.random.randint(100, size=50), np.random.randint(100, 200, size=50), color='r')

fig.suptitle('Example of Plot', size=25, color='blue') #size: 폰트크기, color: 글자색
axes1.set_title("PLOT 1", size=20)
axes2.set_title("Plot 2", size=20)

axes1.set_xlabel("X축", size=15)
axes1.set_ylabel("Y축", size=15)
axes2.set_xlabel("가격1", size=15)
axes2.set_ylabel('가격2', size=15)

axes1.legend()
axes1.grid(True)
plt.show()

# %% [markdown]
# # 그래프 그리기
# 1. matplotlib.pyplot 모듈을 import
#     - '2차원 그래프'(axis가 두개인 그래프)를 그리기위한 함수를 제공하는 모듈
#     - 별칭(alias) 로 plt를 관례적으로 사용한다.
#     - `import matplotlib.pyplot as plt`
#
# 2. 그래프를 그린다.
#
# 3. 그래프에 필요한 '설정'을 한다.(눈금, 라벨, 제목 등 - 추가적인 정보 보여주기)
#
# 4. 화면에 그린다.(화면에 나오도록 함)
#     - 지연 랜더링(Deferred rendering) 메카니즘(화면에 뿌림 - '렌더링')
#     - 마지막에 `pyplot.show()` 호출 시 그래프를 그린다.(설정 할 때마다 그리는 게 아님)
#         - '주피터 노트북에서는 생략'할 수 있다.(생략하지 않는 습관이 좋음)

# %% [markdown]
# # 그래프를 그리는 두가지 방식
# - 'pyplot 모듈'의 '함수'들을 사용한다.
# - Figure와 Axes 객체의 '메소드'들을 사용한다.

# %% [markdown]
# ## pyplot 모듈을 이용해 그리기
# 1. pyplot 모듈이 그래프 그리는 함수와 Axes(Subplot) 설정 관련 함수를 제공

# %%
# 그래프에 사용할 데이터
x = [1,   2,  3,  4,   5]
y = [10,  5, 30,  30, 50]

# %%
# 임포트
import matplotlib.pyplot as plt  

# 그래프 그리기 (선그래프)
plt.plot(x, y)

### 그래프에 여러 설정
plt.title("그래프 제목", fontsize="25")
plt.xlabel("X축 Label")
plt.ylabel("Y축 Label")
plt.grid(True, linestyle=":") # 기본값 : False

# # 파일로 저장
plt.savefig("line.png")
# 그래프를 화면에 출력
plt.show()

# %% [markdown]
# 2. 하나의 figure에 여러 그래프 그리기
#     - plt.subplot(row,columns,num)

# %%
# 전체 figure의 크기 변경
plt.figure(figsize=(10, 5))  # (좌우너비, 상하높이) 단위: inch

# 좌->우, 상->하  순번: 1부터 시작
plt.subplot(2, 2, 1)   # (2행, 2열, 첫번째 위치)
# 그래프 그리고 설정.
plt.plot(x, y)
plt.scatter(x, x)   
plt.title("1번 그래프")

plt.subplot(1, 2, 2) # (1행, 2열, 두번째 위치)
plt.plot(y, x)
plt.title("2번 그래프")

plt.subplot(2, 2, 3) # (2행, 2열, 세번째 위치)
plt.scatter(x, y)
plt.title("3번 그래프")

plt.tight_layout() # 겹쳐지지 않도록 크기 조정
plt.show()

# %% [markdown]
# 3. 하나의 axes에 여러 그래프를 그리기.

# %%
# 최종 출력 전에 그래프 그리는 함수들을 호출 하면 하나의 axes에 모두 그린다.
plt.plot(x, y, label="1번 선") # label: 그래프의 이름
plt.plot(y, x, label="2번 선")
plt.scatter(y, y, label="1번 점", color="green")
plt.legend() # 각 그래프의 label을 이용해서 범례를 출력

plt.show()

# %% [markdown]
# ## Figure 와 Axes 객체를 이용해 그리기 (객체지향 방식)
#
# - AxesSubplot 객체(Axes를 표현하는 객체)의 메소드들을 이용해 그래프를 그린다.
# - axes 생성 방법
#     - plt.gca()(gca, get current axes): AxesSubplot
#         - plt로 그래프를 그릴때 대상 'axes 객체를 반환'한다.
#         - 하나의 figure에 '하나의 Axes'!! 만 사용할 경우 사용.
#     - 하나의 figure에 '여러개의 Axes'!!들을 사용할 경우
#         - 'figure.add_subplot() 메소드' 이용
#             - figure를 먼저 생성후 axes 들을 추가
#         - 'pyplot.subplots() 함수'를 이용
#             - figure와 axes배열을 동시에 생성

# %% [markdown]
# ### Figure에 하나의 axes 그리기
# - plt.gca() 사용

# %%
axes = plt.gca() # 그래프 그릴 Axes 객체를 생성.(보통 ax를 변수로 사용)
print(type(axes))
# 그래프 그리기, 설정 메소드 -> Axes
axes.plot(x, y)
axes.set_title("선그래프")
axes.set_xlabel("X축값")
axes.set_ylabel("Y축값")
axes.grid(True, linestyle=":")

plt.show()
# Out:
# <class 'matplotlib.axes._axes.Axes'>

# %% [markdown]
# ### 하나의 Figure에 여러개의 axes 그리기
# 1. <b style='font-size:1.3em'>figure.add_subplot() 메소드 이용</b>
#     - figure객체에 axes를 추가하는 형태
#     - nrows(총행수), ncols(총열수), index(axes위치) 지정

# %%
# FIGURE 객체
fig = plt.figure(figsize=(6, 6.5))  # figure생성
# figure에 axes(subplot)을 추가
ax1 = fig.add_subplot(2, 2, 1)
ax1.plot(x, y, label="선1")
ax1.plot(y, x, label="선2")
ax1.set_title("1번 그래프")
ax1.legend()

ax2 = fig.add_subplot(2, 2, 3)
ax2.scatter(x, y)
ax2.set_title("2번 그래프")

ax3 = fig.add_subplot(3, 2, 4)
ax3.plot(x, y, color='0.8')
ax3.set_title("3번 그래프")

plt.show()
# Out:
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_23356\1008138641.py:18: UserWarning: tight_layout not applied: number of rows in subplot specifications must be multiples of one another.
#   plt.tight_layout()

# %% [markdown]
# 2. <b style='font-size:1.3em'>pyplot.subplots()</b>
#     - nrows, ncols 로 axes개수와 위치 지정
#     - 반환: 'figure와 axes(subplot)들을 담은''**ndarray**(자료구조)'

# %%
a = fig, axes = plt.subplots(2, 2, figsize=(7, 7))
type(a), len(a), type(a[0]), type(a[1]) # 2개 길이의 튜플 자료구조 형태로 반환
# Out:
# (tuple, 2, matplotlib.figure.Figure, numpy.ndarray)

# %%
fig, axes = plt.subplots(2, 2, figsize=(7, 7)) # 2행, 2열, 7*7 크기의 fig
axes[0, 0].plot(x, y, color='r')
axes[0, 0].set_title("1번")

axes[1, 1].scatter(y, x, color="#E06F93")
axes[1, 1].set_title("2번")
plt.show()

# %% [markdown]
# # 색상과 스타일
#
# ## 색을 지정하는 방법
# - color 또는 c 매개변수를  이용해 지정
# - **색상이름으로 지정.**
#     - 색이름 또는 약자로 지정 가능
#     - 'red', 'r'
#
# | 문자열 | 약자 |
# |-|-|
# | `blue` | `b` |
# | `green` | `g` |
# | `red` | `r` |
# | `cyan` | `c` |
# | `magenta` | `m` |
# | `yellow` | `y` |
# | `black` | `k` |
# | `white` | `w` |
#
#
# - **HTML Color Hex code**
#     - #으로 시작하며 RGB의 성분을 16진수로 표현
#     - #RRGGBB 또는 #RRGGBBAA (A : Alpha - 투명도)
#     - #FF0000, #00FF00FA
# - **0 ~ 1 사이 실수로 흰식과 검정색 사이의 회색조를 표시**
#     - 0: 검정, 1: 흰색
# - **color 값 검색**
#     - https://matplotlib.org/2.0.2/examples/color/named_colors.html
#     - https://htmlcolorcodes.com/
#         - picker, chart(코드), name(색이름) 제공사이트
#     - google 에서 `color picker`로 검색

# %%
# plt.plot(x, y, color='maroon')
# plt.plot(x, y, color='m')
plt.plot(y, x, c='#4432ba', alpha=0.5) # alpha: 투명도 - 0 ~ 1 실수.
plt.plot(x, y, c="0.5") # 회색조(문자열로 줘야 함)
plt.show()

# %% [markdown]
# ## Style 설정
# - Style: 그래프의 여러 시각효과들을 미리 설정해 놓은 것
# - matplotlib는 다양한 스타일들을 미리 정의해 놓고 있다.
#     - [스타일목록](https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html)
#     - `plt.style.use()` 함수 이용해 지정
#     - `plt.style.available`
#         - 사용할 수 있는 스타일 이름 조회

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('fivethirtyeight')

# 스타일이 섞이는 것보다 일관성있는 게 좋음

# %%
fig, axes = plt.subplots(2, 2, figsize=(7, 7.5)) # 2행, 2열, 7*7 크기의 fig
axes[0, 0].plot(x, y)
axes[0, 0].set_title("1번")

axes[1, 1].scatter(y, x)
axes[1, 1].set_title("2번")
plt.show()
