# %% [markdown]
# # 성능개선 기법 실습

# %% [markdown]
# # 모듈 정의

# %% [markdown]
# ## train.py
#
# -   모델 학습과 검증 함수 정의

# %%
import os

os.makedirs("module", exist_ok=True)

# %%
# %%writefile module/train.py

import torch
import time

def test_multi_classification(dataloader, model, loss_fn, device="cpu") -> tuple:
    """
    다중 분류 검증/평가 함수
    
    Args:
        dataloader: DataLoader - 검증할 대상 데이터로더
        model: 검증할 모델
        loss_fn: 모델 추정값과 정답의 차이를 계산할 loss 함수.
        device: str - 연산을 처리할 장치. default-"cpu", gpu-"cuda"
    Returns:
        tuple: (loss, accuracy)
    """
    model.to(device)
    model.eval() 
    size = len(dataloader.dataset)
    num_steps = len(dataloader)
    
    test_loss, test_accuracy = 0., 0.
    
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            # 정확도 계산
            pred_label = torch.argmax(pred, axis=-1)
            test_accuracy += torch.sum(pred_label == y).item()
            
        test_loss /= num_steps
        test_accuracy /= size
    return test_loss, test_accuracy

def test_binary_classification(dataloader, model, loss_fn, device="cpu") -> tuple:
    """
    이진 분류 검증/평가 함수
    
    Args:
        dataloader: DataLoader - 검증할 대상 데이터로더
        model: 검증할 모델
        loss_fn: 모델 추정값과 정답의 차이를 계산할 loss 함수.
        device: str - 연산을 처리할 장치. default-"cpu", gpu-"cuda"
    Returns:
        tuple: (loss, accuracy)
    """
    model.to(device)
    model.eval() # 모델을 평가모드로 변환
    size = len(dataloader.dataset) # 총 데이터 개수
    num_steps = len(dataloader) # step 수
    
    test_loss, test_accuracy = 0., 0.
    
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            ## 정확도 계산
            pred_label = (pred >= 0.5).type(torch.int32)
            test_accuracy += (pred_label == y).sum().item() 
            
        test_loss /= num_steps
        test_accuracy /= size   #전체 개수로 나눈다.
    return test_loss, test_accuracy    

def train(dataloader, model, loss_fn, optimizer, device="cpu", mode:"binary or multi"='binary'):
    """
    모델을 1 epoch 학습시키는 함수

    Args:
        dataloader: DataLoader - 학습데이터셋을 제공하는 DataLoader
        model - 학습대상 모델
        loss_fn: 모델 추정값과 정답의 차이를 계산할 loss 함수.
        optimizer - 최적화 함수
        device: str - 연산을 처리할 장치. default-"cpu", gpu-"cuda"
        mode: str - 분류 종류. binary 또는 multi
    
    Returns:
        tuple: 학습후 계산한 Train set에 대한  train_loss, train_accuracy
    """
    model.train()
    size = len(dataloader.dataset) # 총 데이터포인트 개수

    for X, y in dataloader:
        # 1. DEVICE로 이동동
        X, y = X.to(device), y.to(device)
        # 2. 모델 추정
        pred = model(X)
        # 3. loss 계산
        loss = loss_fn(pred, y)
        # 4. gradient 초기화
        optimizer.zero_grad()
        # 5. gradient 계산
        loss.backward()
        # 6. 파라미터 업데이트트
        optimizer.step()
        
    if mode == 'binary':
        train_loss, train_accuracy = test_binary_classification(dataloader, model, loss_fn, device)
    else:
        train_loss, train_accuracy = test_multi_classification(dataloader, model, loss_fn, device)
    return train_loss, train_accuracy



def fit(train_loader, val_loader, model, loss_fn, optimizer, epochs, 
        save_best_model=True, save_model_path=None, 
        early_stopping=True, patience=10, device='cpu',  mode:"binary or multi"='binary', # :"binary or multi" : type 힌트를 문자열로 넣음
        lr_scheduler=None):
    """
    모델을 학습시키는 함수

    Args:
        train_loader (Dataloader): Train dataloader
        test_loader (Dataloader): validation dataloader
        model (Module): 학습시킬 모델
        loss_fn (_Loss): Loss function
        optimizer (Optimizer): Optimizer
        epochs (int): epoch수
        save_best_model (bool, optional): 학습도중 성능개선시 모델 저장 여부. Defaults to True.
        save_model_path (str, optional): save_best_model=True일 때 모델저장할 파일 경로. Defaults to None.
        early_stopping (bool, optional): 조기 종료 여부. Defaults to True.
        patience (int, optional): 조기종료 True일 때 종료전에 성능이 개선될지 몇 epoch까지 기다릴지 epoch수. Defaults to 10.
        device (str, optional): device. Defaults to 'cpu'.
        mode(str, optinal): 분류 종류. "binary(default) or multi
        lr_scheduler: Learning Rate Scheduler 객체. default: None, Epoch 단위로 LR 를 변경.
    
    Returns:
        tuple: 에폭 별 성능 리스트. (train_loss_list, train_accuracy_list, validation_loss_list, validataion_accuracy_list)
    """

    train_loss_list = []
    train_accuracy_list = []
    val_loss_list = []
    val_accuracy_list = []
    
        
    if save_best_model:
        best_score_save = torch.inf

    ############################
    # early stopping
    #############################
    if early_stopping:
        trigger_count = 0
        best_score_es = torch.inf
    
    # 모델 device로 옮기기
    model = model.to(device)
    s = time.time()
    for epoch in range(epochs):
        # train() 호출 -> 1 epoch 학습. train loss, accuracy 반환.
        train_loss, train_accuracy = train(train_loader, model, loss_fn, optimizer, device=device, mode=mode)
        
        ############ 1 epoch 학습 종료 -> Learning Rate 변경 ###########
        if lr_scheduler is not None:
            current_lr = lr_scheduler.get_last_lr()[0]  # log용
            lr_scheduler.step()
            new_lr = lr_scheduler.get_last_lr()[0] # log용
            if current_lr != new_lr: # LR가 변경되었으면
                print(f">>>>>>Learning Rate가 {current_lr}에서 {new_lr}로 변경됨<<<<<<")

        #  test() 함수 호출해서 1 epoch 학습한 것에 대해 검증
        if mode == "binary":
            val_loss, val_accuracy = test_binary_classification(val_loader, model, loss_fn, device=device)
        else:
            val_loss, val_accuracy = test_multi_classification(val_loader, model, loss_fn, device=device)

        train_loss_list.append(train_loss)
        train_accuracy_list.append(train_accuracy)
        val_loss_list.append(val_loss)
        val_accuracy_list.append(val_accuracy)
        
        print(f"Epoch[{epoch+1}/{epochs}] - Train loss: {train_loss:.5f} Train Accucracy: {train_accuracy:.5f} || Validation Loss: {val_loss:.5f} Validation Accuracy: {val_accuracy:.5f}")
        print('='*100)
        
        # 모델 저장
        if save_best_model:
            if val_loss < best_score_save:
                torch.save(model, save_model_path)
                print(f"저장: {epoch+1} - 이전 : {best_score_save}, 현재: {val_loss}")
                best_score_save = val_loss
        
        # early stopping 처리            
        if early_stopping:
            if val_loss < best_score_es: # 성능 개선 O
                best_score_es = val_loss  
                trigger_count = 0
                                
            else:                        # 성능 개선 X
                trigger_count += 1                
                if patience == trigger_count:
                    print(f"Early stopping: Epoch - {epoch}")
                    break
            
    e = time.time()
    print(e-s, "초")
    return train_loss_list, train_accuracy_list, val_loss_list, val_accuracy_list
# Out:
# Writing module/train.py

# %% [markdown]
# ## data.py
#
# -   dataset 생성 함수 제공 모듈

# %%
# %%writefile module/data.py

from torchvision import datasets, transforms
from torch.utils.data import DataLoader

def load_mnist_dataset(root_path, batch_size, is_train=True):
    """
    mnist dataset dataloader 제공 함수
    Args:
        root_path: str|Path - 데이터파일 저장 디렉토리
        batch_size: int
        is_train: bool = True - True: Train dataset, False - Test dataset
    
    Returns:
        DataLoader 
    """
    transform = transforms.Compose([
        transforms.ToTensor()
    ])
    dataset = datasets.MNIST(root=root_path, train=is_train, download=True, transform=transform)
    dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=is_train)  # shuffle: train이면 True, test면 False 할 것이므로 is_train을 넣음.
    
    return dataloader

def load_fashion_mnist_dataset(root_path, batch_size, is_train=True):
    """
    fashion mnist dataset dataloader 제공 함수
    Args:
        root_path: str|Path - 데이터파일 저장 디렉토리
        batch_size: int
        is_train: bool = True - True: Train dataset, False - Test dataset
    
    Returns:
        DataLoader
    """
    transform = transforms.Compose([
        transforms.ToTensor()
    ])
    dataset = datasets.FashionMNIST(root=root_path, train=is_train, download=True, transform=transform)
    dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=is_train)  # shuffle: train이면 True, test면 False 할 것이므로 is_train을 넣음.
    
    return dataloader
# Out:
# Writing module/data.py

# %% [markdown]
# ## utils.py

# %%
# %%writefile module/utils.py
# 학습 결과를 시각화하는 함수.
import matplotlib.pyplot as plt

def plot_fit_result(train_loss_list, train_accuracy_list, valid_loss_list, valid_accuracy_list):
    """epoch별 학습 결과를 시각화하는 함수
    epoch별 loss와 accuracy를 시각화한다.

    Args:
        train_loss_list (list): Epoch별 train loss
        train_accuracy_list (list): Epoch별 train accuracy
        valid_loss_list (list): Epoch별 validation loss
        valid_accuracy_list (list): Epoch별 validation accuracy
    """
    epoch = len(train_loss_list)
    plt.figure(figsize=(12, 5))
    
    plt.subplot(1, 2, 1)
    plt.plot(range(epoch), train_loss_list, label="train loss")
    plt.plot(range(epoch), valid_loss_list, label="validation loss")
    plt.title("Loss")
    plt.xlabel("epoch")
    plt.ylabel("loss")
    plt.grid(True, linestyle=':')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(range(epoch), train_accuracy_list, label="train accuracy")
    plt.plot(range(epoch), valid_accuracy_list, label="validation accuracy")
    plt.title("Accuracy")
    plt.xlabel("epoch")
    plt.ylabel("accuracy")
    plt.grid(True, linestyle=':')
    plt.legend()

    plt.tight_layout()
    plt.show()
# Out:
# Writing module/utils.py

# %% [markdown]
# ## Import

# %%
import torch
import torch.nn as nn
from torchinfo import summary

from module.train import fit
from module.data import load_mnist_dataset, load_fashion_mnist_dataset
from module.utils import plot_fit_result

# %% [markdown]
# ## 하이퍼파라미터, 변수 정의

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
root_data_path = "datasets"

epochs = 100
batch_size = 256
lr = 0.001

# %% [markdown]
# # Data 준비
#
# ## mnist 데이터 로딩

# %%
train_loader = load_mnist_dataset(root_data_path, batch_size)
test_loader = load_mnist_dataset(root_data_path, batch_size, False)

## Fashion Mnist
# train_loader = load_fashion_mnist_dataset(root_data_path, batch_size)
# test_loader = load_fashion_mnist_dataset(root_data_path, batch_size, False)

# %%
classes = train_loader.dataset.classes
class_to_idx = train_loader.dataset.class_to_idx

# %% [markdown]
# # 모델의 크기 변경에 따른 성능변화
# ## 작은 모델

# %%
class SmallModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.lr = nn.Linear(28*28, 10) # 입력 -> 출력 바로 뽑아냄 #  self.lr2 = nn.Linear(16, 10) 만 넣어도 성능이 0.96 정도로 개선됨.

    def forward(self, X):
        X = nn.Flatten()(X)
        out = self.lr(X)
        return out

# %%
small_model = SmallModel().to(device)
summary(small_model, (100, 1, 28, 28), device=device)
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# SmallModel                               [100, 10]                 --
# ├─Linear: 1-1                            [100, 10]                 7,850
# ==========================================================================================
# Total params: 7,850
# Trainable params: 7,850
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 0.79
# ==========================================================================================
# Input size (MB): 0.31
# Forward/backward pass size (MB): 0.01
# Params size (MB): 0.03
# Estimated Total Size (MB): 0.35
# ==========================================================================================

# %%
loss_fn = nn.CrossEntropyLoss() # 다중분류의 loss 함수
optimizer = torch.optim.Adam(small_model.parameters(), lr=lr)

lr_scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(
    optimizer,
    T_0=10,   # 변화주기 (step/epoch) 최소(eta_min) <-> 최대(초기 lr)
    T_mult=2, # 새로운 변화주기(T_0) = 현재 T_O * T_mult (한 주기가 끝날때마다 T_O를 다시 계산.)
    eta_min=1e-6 # 0.000001
)

# %%
epochs = 20
train_loss_list, train_acc_list, valid_loss_list, valid_acc_list = fit(
    train_loader, 
    test_loader,
    small_model, 
    loss_fn, 
    optimizer,
    epochs,
    save_best_model=False,
    device=device,
    mode="multi",
    lr_scheduler=lr_scheduler
)
# Out:
# >>>>>>Learning Rate가 0.0009755527298894294에서 0.0009046039886902864로 변경됨<<<<<<
# Epoch[1/20] - Train loss: 0.35689 Train Accucracy: 0.90395 || Validation Loss: 0.33870 Validation Accuracy: 0.90900
# ====================================================================================================
# >>>>>>Learning Rate가 0.0009046039886902864에서 0.0007940987335200904로 변경됨<<<<<<
# Epoch[2/20] - Train loss: 0.32857 Train Accucracy: 0.91077 || Validation Loss: 0.31400 Validation Accuracy: 0.91360
# ====================================================================================================
# >>>>>>Learning Rate가 0.0007940987335200904에서 0.0006548539886902864로 변경됨<<<<<<
# Epoch[3/20] - Train loss: 0.31314 Train Accucracy: 0.91408 || Validation Loss: 0.30033 Validation Accuracy: 0.91540
# ====================================================================================================
# >>>>>>Learning Rate가 0.0006548539886902864에서 0.0005005000000000001로 변경됨<<<<<<
# Epoch[4/20] - Train loss: 0.30358 Train Accucracy: 0.91650 || Validation Loss: 0.29276 Validation Accuracy: 0.91700
# ====================================================================================================
# >>>>>>Learning Rate가 0.0005005000000000001에서 0.0003461460113097139로 변경됨<<<<<<
# Epoch[5/20] - Train loss: 0.29740 Train Accucracy: 0.91843 || Validation Loss: 0.28720 Validation Accuracy: 0.91970
# ====================================================================================================
# >>>>>>Learning Rate가 0.0003461460113097139에서 0.00020690126647990973로 변경됨<<<<<<
# Epoch[6/20] - Train loss: 0.29415 Train Accucracy: 0.91873 || Validation Loss: 0.28464 Validation Accuracy: 0.91980
# ====================================================================================================
# >>>>>>Learning Rate가 0.00020690126647990973에서 9.639601130971382e-05로 변경됨<<<<<<
# Epoch[7/20] - Train loss: 0.29126 Train Accucracy: 0.91962 || Validation Loss: 0.28286 Validation Accuracy: 0.92070
# ====================================================================================================
# >>>>>>Learning Rate가 9.639601130971382e-05에서 2.5447270110570814e-05로 변경됨<<<<<<
# Epoch[8/20] - Train loss: 0.29044 Train Accucracy: 0.91940 || Validation Loss: 0.28193 Validation Accuracy: 0.92090
# ====================================================================================================
# >>>>>>Learning Rate가 2.5447270110570814e-05에서 0.001로 변경됨<<<<<<
# Epoch[9/20] - Train loss: 0.29045 Train Accucracy: 0.91973 || Validation Loss: 0.28178 Validation Accuracy: 0.92090
# ====================================================================================================
# >>>>>>Learning Rate가 0.001에서 0.0009938503261272714로 변경됨<<<<<<
# Epoch[10/20] - Train loss: 0.28339 Train Accucracy: 0.92067 || Validation Loss: 0.27741 Validation Accuracy: 0.92120
# ====================================================================================================
# >>>>>>Learning Rate가 0.0009938503261272714에서 0.0009755527298894294로 변경됨<<<<<<
# Epoch[11/20] - Train loss: 0.27660 Train Accucracy: 0.92335 || Validation Loss: 0.27317 Validation Accuracy: 0.92380
# ====================================================================================================
# >>>>>>Learning Rate가 0.0009755527298894294에서 0.0009455577588320898로 변경됨<<<<<<
# Epoch[12/20] - Train loss: 0.27195 Train Accucracy: 0.92507 || Validation Loss: 0.26884 Validation Accuracy: 0.92420
# ====================================================================================================
# >>>>>>Learning Rate가 0.0009455577588320898에서 0.0009046039886902864로 변경됨<<<<<<
# Epoch[13/20] - Train loss: 0.26805 Train Accucracy: 0.92528 || Validation Loss: 0.26655 Validation Accuracy: 0.92510
# ====================================================================================================
# >>>>>>Learning Rate가 0.0009046039886902864에서 0.0008536998372026805로 변경됨<<<<<<
# Epoch[14/20] - Train loss: 0.26534 Train Accucracy: 0.92593 || Validation Loss: 0.26554 Validation Accuracy: 0.92530
# ====================================================================================================
# >>>>>>Learning Rate가 0.0008536998372026805에서 0.0007940987335200904로 변경됨<<<<<<
# Epoch[15/20] - Train loss: 0.26232 Train Accucracy: 0.92698 || Validation Loss: 0.26442 Validation Accuracy: 0.92600
# ====================================================================================================
# >>>>>>Learning Rate가 0.0007940987335200904에서 0.0007272682546199037로 변경됨<<<<<<
# Epoch[16/20] - Train loss: 0.26022 Train Accucracy: 0.92793 || Validation Loss: 0.26267 Validation Accuracy: 0.92490
# ====================================================================================================
# >>>>>>Learning Rate가 0.0007272682546199037에서 0.0006548539886902864로 변경됨<<<<<<
# Epoch[17/20] - Train loss: 0.25868 Train Accucracy: 0.92780 || Validation Loss: 0.26205 Validation Accuracy: 0.92540
# ====================================================================================================
# >>>>>>Learning Rate가 0.0006548539886902864에서 0.0005786390152875954로 변경됨<<<<<<
# Epoch[18/20] - Train loss: 0.25723 Train Accucracy: 0.92817 || Validation Loss: 0.26103 Validation Accuracy: 0.92630
# ====================================================================================================
# >>>>>>Learning Rate가 0.0005786390152875954에서 0.0005005000000000001로 변경됨<<<<<<
# Epoch[19/20] - Train loss: 0.25619 Train Accucracy: 0.92858 || Validation Loss: 0.26078 Validation Accuracy: 0.92580
# ====================================================================================================
# >>>>>>Learning Rate가 0.0005005000000000001에서 0.00042236098471240487로 변경됨<<<<<<
# Epoch[20/20] - Train loss: 0.25485 Train Accucracy: 0.92892 || Validation Loss: 0.26032 Validation Accuracy: 0.92670
# ====================================================================================================
# 148.91840481758118 초

# %% [markdown]
# ## 큰모델

# %%
# ######  nn.Sequential() -> layer block: 레이어함수들을 묶어놓은 블록
s = nn.Sequential(
    nn.Linear(10, 20),
    nn.ReLU(),
    nn.Linear(20, 30),
    nn.ReLU() 
)
i = torch.randn(5, 10, dtype=torch.float32)
o = s(i)
print(o.shape)
o
# Out:
# torch.Size([5, 30])
# tensor([[0.0000e+00, 0.0000e+00, 0.0000e+00, 1.1455e+00, 0.0000e+00, 4.2234e-01,
#          0.0000e+00, 2.2766e-01, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          1.5943e-01, 0.0000e+00, 0.0000e+00, 0.0000e+00, 7.5003e-01, 0.0000e+00,
#          0.0000e+00, 1.9389e-02, 4.8229e-01, 0.0000e+00, 2.9822e-01, 3.5245e-01,
#          9.6258e-01, 3.2833e-01, 2.2612e-01, 5.6255e-01, 0.0000e+00, 8.2797e-01],
#         [1.8664e-01, 0.0000e+00, 3.3197e-01, 2.4371e-01, 0.0000e+00, 2.9406e-01,
#          0.0000e+00, 1.4742e-01, 0.0000e+00, 0.0000e+00, 1.8582e-01, 3.2936e-02,
#          2.5484e-01, 0.0000e+00, 1.3618e-01, 0.0000e+00, 2.6999e-01, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 1.4418e-01, 0.0000e+00,
#          3.5691e-02, 7.0115e-02, 6.7038e-02, 3.6505e-01, 0.0000e+00, 1.4669e-01],
#         [0.0000e+00, 1.2127e-01, 1.6041e-02, 6.9586e-01, 1.6660e-01, 3.4952e-01,
#          0.0000e+00, 2.2809e-01, 1.6627e-02, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          8.0771e-02, 0.0000e+00, 0.0000e+00, 0.0000e+00, 1.5314e-01, 0.0000e+00,
#          0.0000e+00, 1.1571e-01, 4.1531e-01, 0.0000e+00, 0.0000e+00, 2.0103e-01,
#          6.8875e-01, 0.0000e+00, 3.0859e-02, 1.6596e-01, 0.0000e+00, 3.9471e-01],
#         [3.9414e-02, 1.4057e-01, 2.0532e-01, 4.9875e-01, 1.3646e-01, 3.1897e-01,
#          2.4986e-01, 1.0516e-01, 0.0000e+00, 0.0000e+00, 9.7946e-02, 4.1902e-05,
#          2.5415e-01, 0.0000e+00, 0.0000e+00, 0.0000e+00, 1.1956e-01, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 2.0864e-01, 0.0000e+00, 2.4405e-01, 0.0000e+00,
#          4.0907e-01, 1.0382e-01, 7.1314e-02, 1.9992e-01, 0.0000e+00, 1.9825e-01],
#         [7.2181e-02, 0.0000e+00, 0.0000e+00, 1.9356e-01, 0.0000e+00, 2.9764e-01,
#          1.8551e-01, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          1.5636e-01, 2.2121e-01, 1.3961e-01, 0.0000e+00, 5.8727e-01, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 1.5547e-01, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 1.9251e-01, 4.8363e-01, 3.2515e-01, 0.0000e+00, 4.3342e-01]],
#        grad_fn=<ReluBackward0>)

# %%
class BigModel(nn.Module):

    def __init__(self):
        super().__init__()
        self.b1 = nn.Sequential(nn.Flatten(), nn.Linear(28*28, 2048), nn.ReLU())
        self.b2 = nn.Sequential(nn.Linear(2048, 1024), nn.ReLU())
        self.b3 = nn.Sequential(nn.Linear(1024, 512), nn.ReLU())
        self.b4 = nn.Sequential(nn.Linear(512, 256), nn.ReLU())
        self.b5 = nn.Sequential(nn.Linear(256, 128), nn.ReLU())
        self.b6 = nn.Sequential(nn.Linear(128, 64), nn.ReLU())
        self.b7 = nn.Sequential(nn.Linear(64, 32), nn.ReLU())
        self.out_block = nn.Linear(32, 10)
        
    def forward(self, X):
        X = self.b1(X)
        X = self.b2(X)
        X = self.b3(X)
        X = self.b4(X)
        X = self.b5(X)
        X = self.b6(X)
        X = self.b7(X)
        return self.out_block(X)

# %%
big_model = BigModel().to(device)
summary(big_model, (100, 1, 28, 28), device=device)
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# BigModel                                 [100, 10]                 --
# ├─Sequential: 1-1                        [100, 2048]               --
# │    └─Flatten: 2-1                      [100, 784]                --
# │    └─Linear: 2-2                       [100, 2048]               1,607,680
# │    └─ReLU: 2-3                         [100, 2048]               --
# ├─Sequential: 1-2                        [100, 1024]               --
# │    └─Linear: 2-4                       [100, 1024]               2,098,176
# │    └─ReLU: 2-5                         [100, 1024]               --
# ├─Sequential: 1-3                        [100, 512]                --
# │    └─Linear: 2-6                       [100, 512]                524,800
# │    └─ReLU: 2-7                         [100, 512]                --
# ├─Sequential: 1-4                        [100, 256]                --
# │    └─Linear: 2-8                       [100, 256]                131,328
# │    └─ReLU: 2-9                         [100, 256]                --
# ├─Sequential: 1-5                        [100, 128]                --
# │    └─Linear: 2-10                      [100, 128]                32,896
# │    └─ReLU: 2-11                        [100, 128]                --
# ├─Sequential: 1-6                        [100, 64]                 --
# │    └─Linear: 2-12                      [100, 64]                 8,256
# │    └─ReLU: 2-13                        [100, 64]                 --
# ├─Sequential: 1-7                        [100, 32]                 --
# │    └─Linear: 2-14                      [100, 32]                 2,080
# │    └─ReLU: 2-15                        [100, 32]                 --
# ├─Linear: 1-8                            [100, 10]                 330
# ==========================================================================================
# Total params: 4,405,546
# Trainable params: 4,405,546
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 440.55
# ==========================================================================================
# Input size (MB): 0.31
# Forward/backward pass size (MB): 3.26
# Params size (MB): 17.62
# Estimated Total Size (MB): 21.20
# ==========================================================================================

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(big_model.parameters(), lr=lr)

# %%
train_loss_list2, train_acc_list2, valid_loss_list2, valid_acc_list2 = fit(
    train_loader, test_loader,
    big_model,
    loss_fn,
    optimizer,
    epochs,
    save_best_model=False,
    patience=5,
    device=device,
    mode="multi"
)
# Out:
# Epoch[1/100] - Train loss: 0.20648 Train Accucracy: 0.93720 || Validation Loss: 0.22592 Validation Accuracy: 0.93090
# ====================================================================================================
# Epoch[2/100] - Train loss: 0.08240 Train Accucracy: 0.97682 || Validation Loss: 0.11498 Validation Accuracy: 0.96660
# ====================================================================================================
# Epoch[3/100] - Train loss: 0.05960 Train Accucracy: 0.98207 || Validation Loss: 0.09559 Validation Accuracy: 0.97370
# ====================================================================================================
# Epoch[4/100] - Train loss: 0.03805 Train Accucracy: 0.98888 || Validation Loss: 0.08371 Validation Accuracy: 0.97620
# ====================================================================================================
# Epoch[5/100] - Train loss: 0.03494 Train Accucracy: 0.99005 || Validation Loss: 0.08696 Validation Accuracy: 0.97390
# ====================================================================================================
# Epoch[6/100] - Train loss: 0.02576 Train Accucracy: 0.99248 || Validation Loss: 0.07689 Validation Accuracy: 0.97930
# ====================================================================================================
# Epoch[7/100] - Train loss: 0.02957 Train Accucracy: 0.99105 || Validation Loss: 0.07711 Validation Accuracy: 0.97840
# ====================================================================================================
# Epoch[8/100] - Train loss: 0.02495 Train Accucracy: 0.99227 || Validation Loss: 0.08238 Validation Accuracy: 0.97920
# ====================================================================================================
# Epoch[9/100] - Train loss: 0.02067 Train Accucracy: 0.99380 || Validation Loss: 0.07979 Validation Accuracy: 0.97810
# ====================================================================================================
# Epoch[10/100] - Train loss: 0.02105 Train Accucracy: 0.99355 || Validation Loss: 0.10209 Validation Accuracy: 0.97710
# ====================================================================================================
# Epoch[11/100] - Train loss: 0.01262 Train Accucracy: 0.99598 || Validation Loss: 0.09235 Validation Accuracy: 0.97930
# ====================================================================================================
# Early stopping: Epoch - 10
# 273.99482011795044 초

# %%
plot_fit_result(
    train_loss_list2, train_acc_list2, valid_loss_list2, valid_acc_list2
)

# %% [markdown]
# # Dropout 예제
#
# -   dropout 각 레이어에 적용
#     -   dropout은 nn.Dropout 객체를 사용
#     -   객체 생성시 dropout_rate 설정: 0.2 ~ 0.5
#     -   Drop시킬 노드를 가진 Layer 뒤에 추가한다.

# %%
class DropoutModel(nn.Module):

    def __init__(self, drop_rate=0.2):
        super().__init__()
        self.b1 = nn.Sequential(nn.Flatten(), nn.Linear(28*28, 2048), nn.ReLU(), nn.Dropout(p=drop_rate))
        self.b2 = nn.Sequential(nn.Linear(2048, 1024), nn.ReLU(), nn.Dropout(p=drop_rate))
        self.b3 = nn.Sequential(nn.Linear(1024, 512), nn.ReLU(), nn.Dropout(p=drop_rate))
        self.b4 = nn.Sequential(nn.Linear(512, 256), nn.ReLU(), nn.Dropout(p=drop_rate))
        self.b5 = nn.Sequential(nn.Linear(256, 128), nn.ReLU(), nn.Dropout(p=drop_rate))
        self.b6 = nn.Sequential(nn.Linear(128, 64), nn.ReLU(), nn.Dropout(p=drop_rate))
        self.b7 = nn.Sequential(nn.Linear(64, 32), nn.ReLU(), nn.Dropout(p=drop_rate))
        self.out_block = nn.Linear(32, 10)
        
    def forward(self, X):
        X = self.b1(X)
        X = self.b2(X)
        X = self.b3(X)
        X = self.b4(X)
        X = self.b5(X)
        X = self.b6(X)
        X = self.b7(X)
        return self.out_block(X)

# %%
dout_model = DropoutModel(drop_rate=0.5).to(device)
summary(dout_model, (100, 1, 28, 28))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# DropoutModel                             [100, 10]                 --
# ├─Sequential: 1-1                        [100, 2048]               --
# │    └─Flatten: 2-1                      [100, 784]                --
# │    └─Linear: 2-2                       [100, 2048]               1,607,680
# │    └─ReLU: 2-3                         [100, 2048]               --
# │    └─Dropout: 2-4                      [100, 2048]               --
# ├─Sequential: 1-2                        [100, 1024]               --
# │    └─Linear: 2-5                       [100, 1024]               2,098,176
# │    └─ReLU: 2-6                         [100, 1024]               --
# │    └─Dropout: 2-7                      [100, 1024]               --
# ├─Sequential: 1-3                        [100, 512]                --
# │    └─Linear: 2-8                       [100, 512]                524,800
# │    └─ReLU: 2-9                         [100, 512]                --
# │    └─Dropout: 2-10                     [100, 512]                --
# ├─Sequential: 1-4                        [100, 256]                --
# │    └─Linear: 2-11                      [100, 256]                131,328
# │    └─ReLU: 2-12                        [100, 256]                --
# │    └─Dropout: 2-13                     [100, 256]                --
# ├─Sequential: 1-5                        [100, 128]                --
# │    └─Linear: 2-14                      [100, 128]                32,896
# │    └─ReLU: 2-15                        [100, 128]                --
# │    └─Dropout: 2-16                     [100, 128]                --
# ├─Sequential: 1-6                        [100, 64]                 --
# │    └─Linear: 2-17                      [100, 64]                 8,256
# │    └─ReLU: 2-18                        [100, 64]                 --
# │    └─Dropout: 2-19                     [100, 64]                 --
# ├─Sequential: 1-7                        [100, 32]                 --
# │    └─Linear: 2-20                      [100, 32]                 2,080
# │    └─ReLU: 2-21                        [100, 32]                 --
# │    └─Dropout: 2-22                     [100, 32]                 --
# ├─Linear: 1-8                            [100, 10]                 330
# ==========================================================================================
# Total params: 4,405,546
# Trainable params: 4,405,546
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 440.55
# ==========================================================================================
# Input size (MB): 0.31
# Forward/backward pass size (MB): 3.26
# Params size (MB): 17.62
# Estimated Total Size (MB): 21.20
# ==========================================================================================

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(dout_model.parameters(), lr=lr)

# %%
train_loss_list3, train_acc_list3, valid_loss_list3, valid_acc_list3 = fit(
    train_loader, test_loader,
    dout_model,
    loss_fn,
    optimizer,
    epochs,
    save_best_model=False,
    patience=5,
    device=device,
    mode="multi"
)
# Out:
# Epoch[1/100] - Train loss: 0.56454 Train Accucracy: 0.76438 || Validation Loss: 0.57580 Validation Accuracy: 0.76370
# ====================================================================================================
# Epoch[2/100] - Train loss: 0.38081 Train Accucracy: 0.85923 || Validation Loss: 0.40424 Validation Accuracy: 0.85470
# ====================================================================================================
# Epoch[3/100] - Train loss: 0.31823 Train Accucracy: 0.87370 || Validation Loss: 0.35025 Validation Accuracy: 0.87020
# ====================================================================================================
# Epoch[4/100] - Train loss: 0.23487 Train Accucracy: 0.95368 || Validation Loss: 0.27396 Validation Accuracy: 0.94920
# ====================================================================================================
# Epoch[5/100] - Train loss: 0.20740 Train Accucracy: 0.95235 || Validation Loss: 0.26134 Validation Accuracy: 0.94760
# ====================================================================================================
# Epoch[6/100] - Train loss: 0.17592 Train Accucracy: 0.96183 || Validation Loss: 0.21065 Validation Accuracy: 0.95890
# ====================================================================================================
# Epoch[7/100] - Train loss: 0.17519 Train Accucracy: 0.95930 || Validation Loss: 0.22611 Validation Accuracy: 0.95470
# ====================================================================================================
# Epoch[8/100] - Train loss: 0.15469 Train Accucracy: 0.96652 || Validation Loss: 0.21954 Validation Accuracy: 0.96090
# ====================================================================================================
# Epoch[9/100] - Train loss: 0.11828 Train Accucracy: 0.97472 || Validation Loss: 0.19382 Validation Accuracy: 0.96720
# ====================================================================================================
# Epoch[10/100] - Train loss: 0.11293 Train Accucracy: 0.97612 || Validation Loss: 0.21383 Validation Accuracy: 0.96820
# ====================================================================================================
# Epoch[11/100] - Train loss: 0.10923 Train Accucracy: 0.97488 || Validation Loss: 0.19456 Validation Accuracy: 0.96880
# ====================================================================================================
# Epoch[12/100] - Train loss: 0.09207 Train Accucracy: 0.98188 || Validation Loss: 0.19025 Validation Accuracy: 0.97510
# ====================================================================================================
# Epoch[13/100] - Train loss: 0.09858 Train Accucracy: 0.97755 || Validation Loss: 0.18753 Validation Accuracy: 0.97070
# ====================================================================================================
# Epoch[14/100] - Train loss: 0.09680 Train Accucracy: 0.97763 || Validation Loss: 0.15482 Validation Accuracy: 0.97100
# ====================================================================================================
# Epoch[15/100] - Train loss: 0.07246 Train Accucracy: 0.98427 || Validation Loss: 0.15202 Validation Accuracy: 0.97740
# ====================================================================================================
# Epoch[16/100] - Train loss: 0.08100 Train Accucracy: 0.98262 || Validation Loss: 0.18010 Validation Accuracy: 0.97530
# ====================================================================================================
# Epoch[17/100] - Train loss: 0.06429 Train Accucracy: 0.98640 || Validation Loss: 0.17585 Validation Accuracy: 0.97950
# ====================================================================================================
# Epoch[18/100] - Train loss: 0.06523 Train Accucracy: 0.98665 || Validation Loss: 0.19496 Validation Accuracy: 0.97760
# ====================================================================================================
# Epoch[19/100] - Train loss: 0.06353 Train Accucracy: 0.98652 || Validation Loss: 0.16109 Validation Accuracy: 0.97870
# ====================================================================================================
# Epoch[20/100] - Train loss: 0.05970 Train Accucracy: 0.98682 || Validation Loss: 0.16167 Validation Accuracy: 0.97900
# ====================================================================================================
# Early stopping: Epoch - 19
# 1548.8652002811432 초

# %%
plot_fit_result(train_loss_list3, train_acc_list3, valid_loss_list3, valid_acc_list3)

# %% [markdown]
# # Batch Normalization
#
# - Dense 와 Activation 사이에 정의한다.

# %%
# nn.BatchNorm1d(입력 feature개수)
# Linear -> BatchNorm -> ReLU(Activation)
# Linear -> BatchNorm -> ReLU(Activation) -> Dropout

class BatchNormModel(nn.Module):

    def __init__(self, drop_rate=0.2):
        super().__init__()
        self.b1 = nn.Sequential(nn.Flatten(), nn.Linear(28*28, 2048), nn.BatchNorm1d(2048) ,nn.ReLU(), nn.Dropout(p=drop_rate))
        self.b2 = nn.Sequential(nn.Linear(2048, 1024), nn.BatchNorm1d(1024), nn.ReLU(), nn.Dropout(p=drop_rate))
        self.b3 = nn.Sequential(nn.Linear(1024, 512), nn.BatchNorm1d(512), nn.ReLU(), nn.Dropout(p=drop_rate))
        self.b4 = nn.Sequential(nn.Linear(512, 256), nn.BatchNorm1d(256), nn.ReLU(), nn.Dropout(p=drop_rate))
        self.b5 = nn.Sequential(nn.Linear(256, 128), nn.BatchNorm1d(128), nn.ReLU(), nn.Dropout(p=drop_rate))
        self.b6 = nn.Sequential(nn.Linear(128, 64), nn.BatchNorm1d(64), nn.ReLU(), nn.Dropout(p=drop_rate))
        self.b7 = nn.Sequential(nn.Linear(64, 32), nn.BatchNorm1d(32), nn.ReLU(), nn.Dropout(p=drop_rate))
        self.out_block = nn.Linear(32, 10)
        
    def forward(self, X):
        X = self.b1(X)
        X = self.b2(X)
        X = self.b3(X)
        X = self.b4(X)
        X = self.b5(X)
        X = self.b6(X)
        X = self.b7(X)
        return self.out_block(X)

# %%
bn_model = BatchNormModel(drop_rate=0.5).to(device)
summary(bn_model, (100, 1, 28, 28))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# BatchNormModel                           [100, 10]                 --
# ├─Sequential: 1-1                        [100, 2048]               --
# │    └─Flatten: 2-1                      [100, 784]                --
# │    └─Linear: 2-2                       [100, 2048]               1,607,680
# │    └─BatchNorm1d: 2-3                  [100, 2048]               4,096
# │    └─ReLU: 2-4                         [100, 2048]               --
# │    └─Dropout: 2-5                      [100, 2048]               --
# ├─Sequential: 1-2                        [100, 1024]               --
# │    └─Linear: 2-6                       [100, 1024]               2,098,176
# │    └─BatchNorm1d: 2-7                  [100, 1024]               2,048
# │    └─ReLU: 2-8                         [100, 1024]               --
# │    └─Dropout: 2-9                      [100, 1024]               --
# ├─Sequential: 1-3                        [100, 512]                --
# │    └─Linear: 2-10                      [100, 512]                524,800
# │    └─BatchNorm1d: 2-11                 [100, 512]                1,024
# │    └─ReLU: 2-12                        [100, 512]                --
# │    └─Dropout: 2-13                     [100, 512]                --
# ├─Sequential: 1-4                        [100, 256]                --
# │    └─Linear: 2-14                      [100, 256]                131,328
# │    └─BatchNorm1d: 2-15                 [100, 256]                512
# │    └─ReLU: 2-16                        [100, 256]                --
# │    └─Dropout: 2-17                     [100, 256]                --
# ├─Sequential: 1-5                        [100, 128]                --
# │    └─Linear: 2-18                      [100, 128]                32,896
# │    └─BatchNorm1d: 2-19                 [100, 128]                256
# │    └─ReLU: 2-20                        [100, 128]                --
# │    └─Dropout: 2-21                     [100, 128]                --
# ├─Sequential: 1-6                        [100, 64]                 --
# │    └─Linear: 2-22                      [100, 64]                 8,256
# │    └─BatchNorm1d: 2-23                 [100, 64]                 128
# │    └─ReLU: 2-24                        [100, 64]                 --
# │    └─Dropout: 2-25                     [100, 64]                 --
# ├─Sequential: 1-7                        [100, 32]                 --
# │    └─Linear: 2-26                      [100, 32]                 2,080
# │    └─BatchNorm1d: 2-27                 [100, 32]                 64
# │    └─ReLU: 2-28                        [100, 32]                 --
# │    └─Dropout: 2-29                     [100, 32]                 --
# ├─Linear: 1-8                            [100, 10]                 330
# ==========================================================================================
# Total params: 4,413,674
# Trainable params: 4,413,674
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 441.37
# ==========================================================================================
# Input size (MB): 0.31
# Forward/backward pass size (MB): 6.51
# Params size (MB): 17.65
# Estimated Total Size (MB): 24.48
# ==========================================================================================

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(bn_model.parameters(), lr=lr)

train_loss_list3, train_acc_list3, valid_loss_list3, valid_acc_list3 = fit(
    train_loader, test_loader,
    bn_model,
    loss_fn,
    optimizer,
    epochs,
    save_best_model=False,
    patience=5,
    device=device,
    mode="multi"
)
# Out:
# Epoch[1/100] - Train loss: 0.51186 Train Accucracy: 0.90927 || Validation Loss: 0.51731 Validation Accuracy: 0.90310
# ====================================================================================================
# Epoch[2/100] - Train loss: 0.28898 Train Accucracy: 0.87590 || Validation Loss: 0.29382 Validation Accuracy: 0.87210
# ====================================================================================================
# Epoch[3/100] - Train loss: 0.24532 Train Accucracy: 0.88658 || Validation Loss: 0.25547 Validation Accuracy: 0.88170
# ====================================================================================================
# Epoch[4/100] - Train loss: 0.15610 Train Accucracy: 0.96628 || Validation Loss: 0.18464 Validation Accuracy: 0.96050
# ====================================================================================================
# Epoch[5/100] - Train loss: 0.09976 Train Accucracy: 0.97592 || Validation Loss: 0.12090 Validation Accuracy: 0.97030
# ====================================================================================================
# Epoch[6/100] - Train loss: 0.08649 Train Accucracy: 0.97850 || Validation Loss: 0.11250 Validation Accuracy: 0.97220
# ====================================================================================================
# Epoch[7/100] - Train loss: 0.06956 Train Accucracy: 0.98323 || Validation Loss: 0.09931 Validation Accuracy: 0.97590
# ====================================================================================================
# Epoch[8/100] - Train loss: 0.07137 Train Accucracy: 0.98318 || Validation Loss: 0.10912 Validation Accuracy: 0.97480
# ====================================================================================================
# Epoch[9/100] - Train loss: 0.06745 Train Accucracy: 0.98402 || Validation Loss: 0.10707 Validation Accuracy: 0.97510
# ====================================================================================================
# Epoch[10/100] - Train loss: 0.05963 Train Accucracy: 0.98638 || Validation Loss: 0.10933 Validation Accuracy: 0.97790
# ====================================================================================================
# Epoch[11/100] - Train loss: 0.05048 Train Accucracy: 0.98808 || Validation Loss: 0.09850 Validation Accuracy: 0.97920
# ====================================================================================================
# Epoch[12/100] - Train loss: 0.04493 Train Accucracy: 0.98972 || Validation Loss: 0.08692 Validation Accuracy: 0.98090
# ====================================================================================================
# Epoch[13/100] - Train loss: 0.04400 Train Accucracy: 0.98985 || Validation Loss: 0.09164 Validation Accuracy: 0.98050
# ====================================================================================================
# Epoch[14/100] - Train loss: 0.04664 Train Accucracy: 0.98935 || Validation Loss: 0.10064 Validation Accuracy: 0.97830
# ====================================================================================================
# Epoch[15/100] - Train loss: 0.03672 Train Accucracy: 0.99172 || Validation Loss: 0.09773 Validation Accuracy: 0.98020
# ====================================================================================================
# Epoch[16/100] - Train loss: 0.03510 Train Accucracy: 0.99178 || Validation Loss: 0.08349 Validation Accuracy: 0.98180
# ====================================================================================================
# Epoch[17/100] - Train loss: 0.03157 Train Accucracy: 0.99257 || Validation Loss: 0.08663 Validation Accuracy: 0.98230
# ====================================================================================================
# Epoch[18/100] - Train loss: 0.03315 Train Accucracy: 0.99240 || Validation Loss: 0.08994 Validation Accuracy: 0.98260
# ====================================================================================================
# Epoch[19/100] - Train loss: 0.02991 Train Accucracy: 0.99317 || Validation Loss: 0.08756 Validation Accuracy: 0.98140
# ====================================================================================================
# Epoch[20/100] - Train loss: 0.03164 Train Accucracy: 0.99300 || Validation Loss: 0.09080 Validation Accuracy: 0.98190
# ====================================================================================================
# Epoch[21/100] - Train loss: 0.03013 Train Accucracy: 0.99318 || Validation Loss: 0.09341 Validation Accuracy: 0.98110
# ====================================================================================================
# Early stopping: Epoch - 20
# 510.0017931461334 초

# %% [markdown]
# # Learning rate decay

# %% [markdown]
# ### Optimizer와 Learning rate scheduler의 속성, 메소드 확인
#
# -   파이토치는 `torch.optim` 모듈에서 다양한 Learning rate 알고리즘(Learning rate scheduler)을 제공한다.

# %%
import matplotlib.pyplot as plt

def plot_lr(title, lr_list):
    """LearningRate 스케쥴러(학습도중 LR를 변경시키는 객체.)에 의해 변화되는 Learning Rate값을 시각화.

    Args:
        title (str): title
        lr_list (list): Learning Rate 스케쥴러에 의해 변경된 learning rate값들을 가지는 list
    """
    plt.figure(figsize=(15, 6))
    plt.plot(range(len(lr_list)), lr_list)

    plt.title(title)
    xticks = [x for x in range(len(lr_list)) if x % 10 == 0]
    plt.xticks(xticks)
    plt.xlabel("Epoch 수 또는 Step 수")
    plt.ylabel("학습률-LR")
    plt.grid(True, linestyle=":")
    plt.show()

# %% [markdown]
# #### StepLR

# %%
small_model = BatchNormModel() # 위 아무거나 써도 된다.
optim = torch.optim.Adam(small_model.parameters(), lr=0.001) 

# optimizer에서 현재 LR을 조회
optim.param_groups[0]["lr"]
# Out:
# 0.001

# %%
# LearingRate Scheduler - StepLR - 계단 형태로 Learning Rate를 특정 step마다 특정 비율로 줄여나간다.
# 초반에는 많이 움직이고 이후에 조금씩 움직임
steplr_scheduler = torch.optim.lr_scheduler.StepLR(
    optim,        # 학습률을 변경할 옵티마이저.
    step_size=30, # 몇 step/epoch마다 Learning를 변경할지 -> lr_scheduler.step()을 30번 호출하면 변경.
    gamma=0.5,    # 변경할 비율. 새 lr = 현재 lr * gamma
)
# 30 step/epoch 마다 LR를 `현재학습률 * gamma` 로 변경.

# 현재 learning rate를 스케쥴러로 부터 조회
steplr_scheduler.get_last_lr()
# Out:
# [0.001]

# %%
epochs = 300
step_size = 10 # len(dataloader)
lr_list = []
for epoch in range(epochs):
    
    for step in range(step_size): # for x, y in dataloader:
        # 1 step 학습
        # 1. x, y device로 이동
        # 2. 추론. p = model(x)
        # 3. loss. loss = loss_fn(p, y)
        # 4. grad. loss.backward()
        # 5. 파라미터 update
        optim.step()  
        # 6. grad 초기화
        optim.zero_grad() 
        
        # steplr_scheduler.step() # LR를 변경 요청. 1스텝이 끝나면 요청
        # lr_list.append(steplr_scheduler.get_last_lr()) # step()후 lr를 list에 저장.

    steplr_scheduler.step() # LR를 변경 요청. # 1에폭 끝나면 요청
    lr_list.append(steplr_scheduler.get_last_lr()) # step()후 lr를 list에 저장.

# %%
plt.rcParams['font.family'] = "malgun gothic"
plot_lr("Step LR", lr_list)
# 학습이 오래되면 기울기가 0이 되는 문제

# %% [markdown]
# #### CosineAnnealingLR
#
# cosine 그래프를 그리면서 learning rate를 변경 하는 방식.
# 최근에는 learning rate를 단순히 감소시키기 보다는 '감소와 증가를 반복'하여 진동하는 방식으로 '최적점을 찾아가는 알고리즘을' 많이 사용한다. 이러한 방법 중 가장 간단하면서도 많이 사용되는 방법이 CosineAnnealingLR이다.

# %%
optim = torch.optim.Adam(small_model.parameters(), lr=0.001)
ca_lr_scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
    optim,
    T_max=10, # 변화주기 step/epoch - 최대(초기LR) ~ 최소(eta_min), 최소 ~ 최대
    eta_min=1e-6, # lr 최소값 지정. 
)

# %%
lr_list = []
for epoch in range(epochs):
    for step in range(step_size):
        # ... 학습
        optim.step()
        optim.zero_grad()
    
    ca_lr_scheduler.step() # epoch단위로 lr 변경
    lr_list.append(ca_lr_scheduler.get_last_lr())

# %%
plot_lr("CosineAnnelingLR", lr_list)

# %% [markdown]
# #### CosineAnnealingWarmRestarts
#
# cosine annealing의 스케쥴링에 cosine 주기의 '에폭을 점점 늘리거나 줄'일 수 있다. ('보통 늘린다.')

# %%
optim = torch.optim.Adam(small_model.parameters(), lr=0.001)
cawr_lr_scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(
    optim,
    T_0=10,   # 변화주기 (step/epoch) 최소(eta_min) <-> 최대(초기 lr)
    T_mult=2, # 새로운 변화주기(T_0) = 현재 T_O * T_mult (한 주기가 끝날때마다 T_O를 다시 계산.)
    eta_min=1e-6 # 0.000001
)

# %%
lr_list = []
for epoch in range(epochs):

    for step in range(step_size):
        # 학습
        optim.step()
        optim.zero_grad()

    cawr_lr_scheduler.step()
    lr_list.append(cawr_lr_scheduler.get_last_lr())

# %%
plot_lr("CosineAnnealingWarmRestart", lr_list)
