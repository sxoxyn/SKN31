# %% [markdown]
# # 프롬프트 엔지니어링(Prompt Engineering)
#
# ## 프롬프트(Prompt)
#
# - 프롬프트(Prompt)는 생성형 인공지능 모델에게 작업을 요청하거나 지시하기 위해 입력하는 정보이다.
# - 일반적으로 자연어로 작성되지만, 이미지, 음성, 동영상 등의 다양한 형태로 입력될 수도 있다.
# - 생성형 인공지능 모델은 프롬프트를 바탕으로 텍스트, 이미지, 코드 등 다양한 결과를 생성한다.
#
# ## 프롬프트 엔지니어링이란
#
# - **프롬프트 엔지니어링**은 LLM이 우리가 원하는 결과를 안정적으로 생성하도록 **지시문, 입력 정보, 출력 형식, 예시, 제약 조건을 설계하는 작업**이다.
#     - OpenAI는 프롬프트 엔지니어링 정의:  "모델이 요구사항을 만족하는 콘텐츠를 **일관되게 생성하도록 효과적인 지시를 작성**하는 과정"
#     - LLM 출력은 비결정적이지만, '프롬프트에 역할, 예시, 평가 등을 사용'하여 구체화 하면 더 '일관된 결과'를 얻을 수 있다.(단어는 바뀌어도 되지만 내용은 바뀌면 안됨)
#     - 예를 들어 단순히 다음처럼 요청하면 결과가 들쭉날쭉하고 장황해 질 수 있다.
#
#         ```text
#         프롬프트 엔지니어링 설명해줘.
#         ```
#
#         반면 다음처럼 요청하면 더 안정적인 결과를 얻을 수 있다.
#
#         ```text
#         너는 AI를 초보자에게 가르치는 강사이다.
#         프롬프트 엔지니어링을 초보자에게 설명하라.
#
#         조건:
#         - 먼저 한 문장으로 정의한다.
#         - 그다음 원칙 5개를 표로 정리한다.
#         - 마지막에 좋은 프롬프트와 나쁜 프롬프트 예시를 비교한다.
#         - 한국어로 작성한다.
#         ```
#
#     -  프롬프트 엔지니어링은 **AI에게 막연히 질문하는 기술이 아니라, 원하는 '작업을 수행하도록 명세서를 작성'하는 기술** 이다.
#
#
# ## 프롬프트 엔지니어링의 발전
#   - 프롬프트 엔지니어링 -> 컨텍스트 엔지니어링 -> 하네스 엔지니어링
#   - **프롬프트 엔지니어링은 모델에게 '무엇을 하라고 지시할 것인가'**, **컨텍스트 엔지니어링은 '모델에게 어떤 정보를 제공할 것인가'**, **하네스 엔지니어링은 '모델이 실제로 일하게 만드는 실행 환경을 어떻게 설계할 것인가'** 를 말한다.
#   - context : 모델에게 주는 정보(ex. 답변 예시, 제공할 정보 수 등)
#
#
# | 구분         | 핵심 질문                         | 주요 대상                        |
# | ---------- | ----------------------------- | ---------------------------- |
# | 프롬프트 엔지니어링 | 모델에게 '어떻게 지시'할 것인가?             | 지시문, 역할, 형식, 예시              |
# | 컨텍스트 엔지니어링 | 모델에게 '어떤 정보를 제공'할 것인가?        | RAG, 검색결과, 도구 결과, 메모리, 대화 이력       |
# | 하네스 엔지니어링  | 모델을 '어떤 시스템 안에서 어떻게 실행·검증·통제'할 것인가? | 가드레일(Guardrails), 에이전트 피드백 루프, 코딩표준, 아키텍처 규칙, 도구, 권한, 테스트, 로깅, 검증 |

# %% [markdown]
# ## 프롬프트 엔지니어링의 원칙
#
# ### 1. 목표를 명확히 하고 내용을 구체적으로 작성한다. (명확성, 구체성)
#
# 좋은 프롬프트는 "무엇을 해줘"가 아니라 **무엇을, 누구를 위해, 어떤 수준으로, 어떤 형식으로** 해달라는 요청을 포함한다.
# - 프롬프트는 생성형 인공지능 모델이 수행해야 할 작업을 명확하고 구체적으로 설명해야 한다.
# - 모호하거나 불완전한 지시를 제공하면 모델은 사용자의 의도를 정확하게 파악하기 어렵고, 기대와 다른 결과를 생성할 수 있다.
# - 따라서 수행할 작업, 원하는 결과의 형식, 대상 독자, 분량, 제약 조건 등을 가능한 한 구체적으로 제시하는 것이 좋다.
#
# 나쁜 예:
#
# ```text
# 머신러닝 설명해줘.
# ```
#
# 좋은 예:
#
# ```text
# 머신러닝을 처음 배우는 비전공자를 대상으로 설명해줘.
# 머신러닝의 정의, 지도학습/비지도학습 차이, 실제 활용 예시를 포함하고, 마지막에 5문장으로 요약해줘.
# ```
#
# Anthropic도 프롬프트를 개선하기 전에 먼저 **성공 기준을 명확히 정의하고, 그 기준을 경험적으로 테스트할 방법을 갖추는 것**을 권장한다.
#
#
# ### 2. 역할(Persona)을 지정한다
#
# 모델에게 역할(Persona)을 주면 답변의 관점과 깊이가 달라진다.
# 역할 지정은 단순한 "연기"가 아니라, **답변 기준, 용어 선택, 예시의 수준, 판단 기준을 좁히는 장치** 이다.
#
# 예1:
#
# ```text
# 당신은 10년 차 경력의 숙련된 UX 디자이너입니다.
# 사용자 중심 디자인과 데이터 기반 의사결정에 강점이 있습니다.
# 신규 모바일 쇼핑 앱의 첫 화면 구성안을 제안해야 합니다.
#
# ...
#
# 위 역할을 바탕으로 화면 구성을 제안해주세요.
# ```
#
# 예2:
# ```text
# 당신은 10년 차 전문 헬스 트레이너이다.
# 체지방을 줄이고 근육량을 늘리고 싶은 30대 직장인 남성을 위한 1주일 운동 스케쥴을 작성해줘.
# ...
# ```
#
# ### 3. 출력 형식을 명확히 지정한다
#
# LLM은 기본적으로 자유형 텍스트를 생성하므로, '원하는 결과 형식이 있으면 명시'해야 한다. API나 자동화 시스템에서는 특히 중요하다.
#
# 예:
#
# ```text
# ...
#
# 결과를 JSON  형식으로 작성해줘.
#
# {
#   "person": "김철수",
#   "task": "보고서 제출",
#   "due_date": "2025-12-31"
# }
#
# ```
#
#
# ### 4. 필요한 배경 정보(Context-맥락 정보)를 제공한다
#
# - 모델은 사용자의 상황을 자동으로 알지 못한다. 따라서 답변에 필요한 배경 정보가 있다면 넣어야 한다.
# - 모델 답변의 할루시네이션을 방지하기 위해 다양한 형태의 정보를 Context에 포함하여 제공할 수 있다. 이런 정보에는 사내 업무 문서, 웹 검색정보, 데이터베이스 등에서 조회한 관련 정보들이 있을 수 있다.
#
#
# ```text
# 우리는 월 20%의 고객 이탈률을 겪고 있는 구독 기반 온라인 교육 서비스이다.
# 주요 고객층은 30대 직장인이고, 이탈 주요 원인은 콘텐츠 부족과 동기 저하이다.
# 이탈률을 줄이기 위한 실질적인 전략을 제안해줘.
# ```
#
# ### 5. 예시를 제공한다
#
# 모델에게 원하는 입출력 예시를 주면 결과가 안정된다.
# '예시의 개수에 따라' **Zero shot Learning**, **One shot Learning**, **Few shot Learning** 이 있다.
#
# ```text
#
# 예시:
# 질문: "과적합이란 무엇인가요?"
# 답변:
#     - 정의: 학습 데이터에는 잘 맞지만 새로운 데이터에는 성능이 낮아지는 현상
#     - 비유: 문제집 답을 외웠지만 새로운 문제를 못 푸는 상황
#     - 예시: 훈련 정확도 99%, 테스트 정확도 70%
# ```
#
# ### 6. 프롬프트 구성을 구조화한다.
# 긴 프롬프트는 역할(Role), 지시(Instruction), 맥락(Context), 출력 형식(Output Format) 등을 구획으로 나눈다. 나눌 때는 **태그**(예: `<context>, <instructions>`)나 **Markdown**(`#`, `##`)를 이용한다.
#
# ```xml
# <instructions>
# 다음 뉴스 기사를 읽고 핵심 내용을 요약하라.
# </instructions>
#
# <context>
# 사용자는 바쁜 직장인으로, 전체 기사를 읽을 시간이 없다. 핵심 정보만 빠르게 파악하고 싶어한다.
# </context>
#
# <input_data>
# [기사 원문]
# 오늘 오전, 서울 강남구 일대에 시간당 80mm가 넘는 집중호우가 내려 도로 일부가 침수되고, 차량 통제가 이루어졌다. 기상청은 이 같은 집중호우가 오후까지 계속될 것으로 전망하면서 시민들의 외출 자제를 당부했다. 서울시 역시 재난 문자를 통해 대중교통 이용을 권고하고 있다. ...
# </input_data>
#
# <output_format>
# 한 문단(3줄 이내)으로 요약하라. 일반인이 쉽게 이해할 수 있는 문장을 사용하라.
# </output_format>
#
# <constraints>
# - 전문 용어에는 반드시 쉬운 설명을 덧붙일 것
# - 분량은 500자 이내 한다.
# - 한국어로 작성한다.
# </constraints>
# ```
#
#
# ### 7. 제약 조건을 명시한다
#
# - 모델이 '하지 말아야 할 것도 명확히' 써야 한다.
# - 특히 교육, 법률, 의료, 투자, 기업 보고서처럼 정확성이 중요한 영역에서는 **출처, 기준 시점, 불확실성, 검증 절차**를 프롬프트에 포함하는 것이 좋다.
#
# 예:
#
# ```text
# 주의:
# - 모르는 내용은 추측하지 말고 모른다고 말한다.
# - 현재 날짜 2XXX 년 10월 20일을 기준으로 최신정보를 제공한다.
# - 코드는 Python 3.12 기준으로 작성한다.
# ```
#
# ### 8. 프롬프트를 점진적으로 개선한다.
#
# 실무에서는 프롬프트를 한 번 작성하고 끝내지 않는다. 원하는 결과가 안정적으로 나오는지 반복적으로 평가하고 튜닝해야 한다.
# 프롬프트를 평가할 때는 평가에 사용할 LLM 모델의 버전 고정하여 프롬프트 수정 후 결과가 달라졌을 때, 그 변화가 모델 변경 때문인지 프롬프트 변경 때문인지 구분할 수 있도록 한다.
# 테스트 질문, 기대 답변, 평가 기준을 미리 정해두고 프롬프트 성능을 측정하는 평가 방식을 구축한다. 이를 통해 프롬프트를 수정할 때마다 정확도, 형식 준수 여부, 누락 여부, 환각 여부 등의 변화를 모니터링할 수 있다.

# %% [markdown]
# # 프롬프트 템플릿 (Prompt Template)
#
# 프롬프트 템플릿은 언어 모델(Large Language Model, LLM)에 입력할 **프롬프트를 생성하는 재사용 가능한 템플릿**이다. 프롬프트 작성 시 변수를 포함하여 템플릿화함으로써, 다양한 입력값에 유연하게 대응할 수 있으며, 일관성 있는 결과를 얻는 데 유리하다.
# 프롬프트는 문자열(string)로 작성되므로 Python의 f-string을 사용해 동적으로 생성할 수 있다. 또한 LangChain은 다양한 PromptTemplate 클래스를 제공하여 변수 치환, 프롬프트 재사용, 체계적인 프롬프트 관리를 지원한다.
#
# ## 프롬프트 템플릿의 목적
#
# * **재사용성**: 입력값이 달라져도 동일한 프롬프트 구조를 재사용할 수 있다.
# * **유지보수성 향상**: 프롬프트 구조와 변수 값을 분리하여 관리할 수 있으므로 수정과 관리가 용이하다.
# * **자동화 지원**: 사용자 입력, 데이터베이스 조회 결과, 웹 검색 결과 등 다양한 데이터를 템플릿에 주입하여 프롬프트를 자동으로 생성할 수 있다.
# * **일관성 확보**: 동일한 형식의 프롬프트를 지속적으로 생성하여 모델의 응답 품질을 보다 안정적으로 유지할 수 있다.
#
# ## Langchain의 주요 Prompt Template
#
# 1. **PromptTemplate**
#
# * **단일 텍스트(string) 형태의 프롬프트를 생성**하기 위한 가장 기본적인 템플릿 클래스이다.
# * 특징
#     * 문자열 기반 프롬프트 생성에 사용된다.
#     * 변수(Placeholder)는 중괄호 {}로 표시한다.
#       * `{}`는 변수를 표시하는 구분자로 사용된다. 그래서 프롬프트에 중괄호 자체를 문자열로 포함하려면 `{{`와 `}}`를 사용하여 이스케이프(escape)해야 한다.
#     * 변수(placeholder)에 전달되는 입력값에 따라 프롬프트를 동적으로 생성할 수 있다.
#     * 주로 텍스트 완성(Text Completion) 방식이나 단순 지시형 프롬프트 작성에 적합하다.
#
# 2. **ChatPromptTemplate**
#
# * 대화형(Chat) 언어 모델을 위한 프롬프트 템플릿 클래스이다.
# * 시스템(System. 지침), 사용자(Human), AI(AI) 등의 역할(Role)을 가진 메시지들을 조합하여 프롬프트를 구성할 수 있다.
# * 특징
#     * 역할(Role) 기반 메시지를 정의할 수 있다.
#     * 시스템 메시지(SystemMessage), 사용자 메시지(HumanMessage), AI 메시지(AIMessage) 등을 하나의 프롬프트로 구성할 수 있다.
#     * 대화 이력이나 컨텍스트를 구조적으로 관리하기 쉽다.
#     * GPT 계열과 같은 채팅 모델에서 가장 많이 사용되는 프롬프트 템플릿이다.
#
# - 최근의 GPT, Claude, Gemini, Qwen과 같은 대부분의 LLM은 채팅(Chat) 인터페이스를 기반으로 동작하므로, PromptTemplate보다 ChatPromptTemplate이 더 널리 사용된다.

# %% [markdown]
# ## 프롬프트 템플릿 사용법
#
# - 전체 템플릿은 문자열(string)로 정의하며, 변수(placeholder)는 `{변수명}` 형식으로 지정한다. 템플릿이 실행될 때 변수는 전달된 실제 값으로 대체된다.
#   - 예시: `"{country}의 수도는 어디인가요?"`
# - 프롬프트에 중괄호(`{, }`) 자체를 포함하려면 `{{` 와 `}}`를 사용하여 이스케이프(escape)해야 한다.
#   - 예시: `{{"이름": "{name}"}}`
# - 생성한 문자열 템플릿을 이용하여 Prompt Template 객체를 생성한다.
#
# ### 공통 메소드
#
# 프롬프트 템플릿 클래스에서 공통적으로 사용하는 주요 메소드는 다음과 같다.
#
# #### 템플릿 생성 메소드
#
# - **from_template()**
#   - 문자열 기반 템플릿을 생성한다.
#   - `PromptTemplate`과 `ChatPromptTemplate` 모두에서 사용할 수 있다.
#
# - **from_messages()**
#   - 메시지 객체를 이용하여 대화형 템플릿을 생성한다.
#   - `ChatPromptTemplate`에서 사용한다.
#
# #### 프롬프트 생성 메소드
#
# - **format(변수=값, ...)**
#   - 변수에 값을 대입하여 최종 프롬프트 문자열을 생성한다.
#
# - **format_messages(변수=값, ...)**
#   - 메시지 리스트 형식의 프롬프트를 생성한다.
#   - `ChatPromptTemplate`에서 사용한다.
#
# - **invoke(dict)**
#   - 변수와 값을 딕셔너리 형태로 전달하여 프롬프트를 생성한다. 생성된 프롬프트는 `PromptValue` 객체로 반환된다.
#   - 생성된 결과는 Runnable 체인의 다음 단계 입력으로 사용할 수 있다.
#
# > ##### `invoke()` 메소드
# >
# > - invoke()는 LangChain의 핵심 인터페이스인 Runnable에서 제공하는 공통 실행 메소드이다.
# > - Runnable은 LangChain의 실행 가능한 객체들이 따르는 공통 인터페이스이다.
# > - PromptTemplate, ChatModel, OutputParser, Chain 등은 모두 Runnable 인터페이스를 구현한다.
# > - invoke()는 입력을 받아 처리한 뒤 결과를 반환한다.
# > - 여러 Runnable 객체를 연결하여 체인(Chain)을 구성할 수 있으며, 각 단계의 출력은 다음 단계의 입력으로 전달된다.

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import os
os.getenv("OPENAI_API_KEY")

# %%
from langchain_core.prompts import PromptTemplate, ChatPromptTemplate
# input_variable ({변수명} - {country}) => 나중에 채울 값
template = "{country}의 수도는 어디인가요?"
prompt = PromptTemplate.from_template(
    template=template
)
prompt
# Out:
# PromptTemplate(input_variables=['country'], input_types={}, partial_variables={}, template='{country}의 수도는 어디인가요?')

# %%
print(prompt.template)
print(prompt.input_variables)
# Out:
# {country}의 수도는 어디인가요?
# ['country']

# %%
# prompt 생성 -> input_variable에 값 할당
p_str = prompt.format(country="한국")
print(p_str)

p_str2 = prompt.format(country="미국")
print(p_str2)
# Out:
# 한국의 수도는 어디인가요?
# 미국의 수도는 어디인가요?

# %%
p_str3 = prompt.invoke({"country":"독일"})
p_str3
# Out:
# StringPromptValue(text='독일의 수도는 어디인가요?')

# %%
# Prompt -> Model
from langchain_core.prompts import PromptTemplate
from langchain_openai import ChatOpenAI

# 프롬프트 템플릿 생성
prompt = PromptTemplate.from_template(template="{country}의 수도를 알려주세요.")

# 모델 생성
model = ChatOpenAI(model="gpt-5.4-nano")

# 프롬프트 템플릿의 input_variables에 값을 넣어 프롬프트 생성
query = prompt.invoke({"country":"한국"}) # prompt.format(country="한국")

# 모델에 프롬프트 입력해 질의 요청
response = model.invoke(query)

# %%
print(response) # 응답 : AIMessage 타입
print(response.content) # 응답 text만 조회
# Out:
# content='한국의 수도는 **서울(Seoul)** 입니다.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 13, 'total_tokens': 28, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-nano-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-DtU7lHXTpU7A8hUYd03VIqyhlrRSr', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019eee67-4c9e-74c0-86a8-87735e0b5e60-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 13, 'output_tokens': 15, 'total_tokens': 28, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# 한국의 수도는 **서울(Seoul)** 입니다.

# %%
query2 = prompt.invoke({"country":"영국"})
response2 = model.invoke(query2)

# %%
response2.content
# Out:
# '영국의 수도는 **런던(London)** 입니다.'

# %%
while True:
    country = input("수도를 알고 싶은 나라 이름을 입력하세요 : ")
    if country == "!q":
        break
    query = prompt.invoke({"country":country})
    response = model.invoke(query)
    print(f"질문 : {query}")
    print(f"답변 : {response.content}")
# Out:
# 질문 : text='의 수도를 알려주세요.'
# 답변 : 어느 나라의 수도를 알려드릴까요?
# 예: **대한민국 / 일본 / 미국** 같은 식으로 나라 이름을 말씀해 주세요.
# 질문 : text='의 수도를 알려주세요.'
# 답변 : 어느 나라의 수도를 말씀하시는 건가요? 나라 이름을 알려주시면 그 나라의 수도를 알려드릴게요.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 2
#       1 while True:
# ----> 2     country = input("수도를 알고 싶은 나라 이름을 입력하세요 : ")
#       3     if country == "!q":
#       4         break
#       5     query = prompt.invoke({"country":country})
#
# File c:\Documents\SKN31\10_AI_Agent\.venv\Lib\site-packages\ipykernel\kernelbase.py:1403, in Kernel.raw_input(self, prompt)
#    1401     msg = "raw_input was called, but this frontend does not support input requests."
#    1402     raise StdinNotImplementedError(msg)
# -> 1403 return self._input_request(
#    1404     str(prompt),
#    1405     self._get_shell_context_var(self._shell_parent_ident),
#    1406     self.get_parent("shell"),
#    1407     password=False,
#    1408 )
#
# File c:\Documents\SKN31\10_AI_Agent\.venv\Lib\site-packages\ipykernel\kernelbase.py:1448, in Kernel._input_request(self, prompt, ident, parent, password)
#    1445 except KeyboardInterrupt:
#    1446     # re-raise KeyboardInterrupt, to truncate traceback
#    1447     msg = "Interrupted by user"
# -> 1448     raise KeyboardInterrupt(msg) from None
#    1449 except Exception:
#    1450     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
# prompt template --[query]--> model
chain = prompt | model
res = chain.invoke({"country":"프랑스"}) # prompt에 전달할 값 입력

# %%
res.content
# Out:
# '프랑스의 수도는 **파리(Paris)** 입니다.'

# %%
# input variable이 여러 개인 프롬프트 템플릿
prompt2 = PromptTemplate.from_template(
    template="{place1}, {place2} 간의 거리는 얼마나 되는지 KM로 알려주세요."
)
print(prompt2.input_variables)
print(prompt2.format(place1="서울", place2="런던"))
print(prompt2.invoke({"place1":"부산", "place2":"서울"}))
# Out:
# ['place1', 'place2']
# 서울, 런던 간의 거리는 얼마나 되는지 KM로 알려주세요.
# text='부산, 서울 간의 거리는 얼마나 되는지 KM로 알려주세요.'

# %%
query = prompt2.invoke({"place1":"부산", "place2":"서울"})
res = model.invoke(query)

# %%
print(res.content)
# Out:
# 부산–서울 간 거리는 **대략 325~400 km** 정도입니다.
# - **직선거리(항공 기준)**: 약 **325 km**
# - **도로 이동거리(차량 기준, 경로에 따라)**: 보통 **약 400 km 내외**입니다.

# %%
#########################
# ChatPromptTemplate
#
# Chatting 형식의 Message 지원
#  - chatting 형식 : Role - Content(메시지)로 구성
# 1) Langchain 방식 
# [
#     ("role", "content"), ("role", "content"), ...
# ]
# 2) OpenAI 방식
# [
#     {"role":"작성자 Role", "content":"작성 메시지"}, ...
# ]
# -> Langchain에서는 위 두 가지 방식 다 지원
#
# Role
## user/human : 사용자 메시지
## ai/assistant : LLM 메시지
## system : 전체 대화에 공통적으로 적용될 규칙or지침 지정하는 메시지

## tool(ToolMessage) : Tool calling에서 Tool의 처리 결과를 담은 메시지

# %%
from langchain_core.prompts import ChatPromptTemplate

messages = [
    ("system", "당신은 {domain} 전문 Assistant입니다. 모든 답변은 {word_length} 단어 이하로 답해주세요."),
    ("user", "{query}")
]

prompt = ChatPromptTemplate.from_messages(
    messages=messages
)

print(prompt.input_variables)
print(prompt.messages)
# Out:
# ['domain', 'query', 'word_length']
# [SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=['domain', 'word_length'], input_types={}, partial_variables={}, template='당신은 {domain} 전문 Assistant입니다. 모든 답변은 {word_length} 단어 이하로 답해주세요.'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['query'], input_types={}, partial_variables={}, template='{query}'), additional_kwargs={})]

# %%
query1 = prompt.format_messages(domain="AI", word_length=30, query="Agent란 무엇인가요?")
query1
# role : system => SystemMessage 객체
# role : user/human => HumanMessage 객체
# role : ai/assistant => AIMessage 객체
# 공통 : content 속성에 message가 저장됨
# Out:
# [SystemMessage(content='당신은 AI 전문 Assistant입니다. 모든 답변은 30 단어 이하로 답해주세요.', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='Agent란 무엇인가요?', additional_kwargs={}, response_metadata={})]

# %%
res = model.invoke(query1)

# %%
print(res.content)
# Out:
# Agent는 목표를 위해 환경을 인식하고, 계획·행동을 선택해 작업을 수행하는 자율 소프트웨어/시스템입니다. 예: 챗봇, 추천, 로봇 제어 에이전트.

# %%
query2 = prompt.invoke({"domain":"와인", "word_length":20, "query":"해산물에 어울리는 와인을 소개해줘."})
res = model.invoke(query2)

# %%
query2
# Out:
# ChatPromptValue(messages=[SystemMessage(content='당신은 와인 전문 Assistant입니다. 모든 답변은 20 단어 이하로 답해주세요.', additional_kwargs={}, response_metadata={}), HumanMessage(content='해산물에 어울리는 와인을 소개해줘.', additional_kwargs={}, response_metadata={})])

# %%
res
res.content
# Out:
# '굴·조개엔 샴페인/브뤼트, 새우·문어엔 드라이 소비뇽블랑, 생선구이엔 미네랄 샤블리.'

# %%
# 연결 질문
res = model.invoke("추천한 와인에 대해서 좀 더 자세히 설명해줘")

# %%
print(res.content)
# Out:
# 좋아요! 다만 현재 대화에 **어떤 와인을 추천했는지(와인 이름/종류/빈티지/대략의 가격대)** 정보가 없어서, 정확히 “추천한 그 와인”을 기준으로 설명을 드리기 어렵습니다.
#
# 아래 중 편한 방식으로 알려주시면, 그 와인에 맞춰 **맛/향(노트), 바디감, 산미·탄닌·당도 느낌, 어울리는 음식, 마시는 온도, 보관/오픈 팁**까지 자세히 정리해드릴게요.
#
# 1) 와인 **이름(브랜드/품종)** + **빈티지(있으면)**
# 2) 아니면 사진/링크
# 3) 또는 “레드/화이트/로제 중 어떤 스타일, 달달함 정도, 가격대”처럼 조건만이라도
#
# 먼저 어떤 와인이었나요? (예: “카베르네 소비뇽 레드, 2021, 2만원대” / “샤르도네 화이트, 5만원대”)

# %% [markdown]
# ## MessagesPlaceholder
#
# - `MessagesPlaceholder`는 `ChatPromptTemplate` 내에서 여러 개의 '메시지가 삽입'될 위치를 지정하는 프롬프트 템플릿 요소이다.
# - 주로 대화 이력(Chat History), 퓨샷 예제(Few-shot Examples), 에이전트 중간 처리 결과 등을 프롬프트에 동적으로 추가할 때 사용한다.
# - 일반 변수({variable})가 문자열이나 단일 값을 삽입하는 데 사용된다면, `MessagesPlaceholder`는 여러 개의 메시지(Message 객체 목록)를 삽입하는 데 사용된다.
# - `MessagesPlaceholder`는 `ChatPromptTemplate`에서만 사용할 수 있으며, 일반 `PromptTemplate`에서는 사용할 수 없다.
#
# ### Initializer의 주요 파라미터
#
# 1. **variable_name** (str)
#    - 프롬프트에서 '참조할 변수명을 지정'한다.
#    - invoke() 실행 시 동일한 이름의 메시지 리스트를 전달해야 한다.
# 1. **optional** (bool, 기본값: False)
#    - 'True'로 설정하면 '해당 변수에 메시지가 전달되지 않아도 오류를 발생시키지 않'는다.
#    - 주로 대화 이력이 없을 수 있는 경우에 사용한다.
# 1. **n_messages** (int)
#    - 지정된 경우 '최근 N개의 메시지만 프롬프트에 포함'한다.
#    - '긴 대화 이력을 제한'하여 토큰 사용량을 줄이는 데 활용할 수 있다.

# %%
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder

messages = [
    ("system", "당신은 수학 전문 Assistant입니다. 답변은 일반 text로 작성해주세요."),
    # MessagesPlaceholder(variable_name="history", optional=True),
    ("placehoder", "{history}"), # role : placehoder -> MessagePlaceholder 사용. content(history):변수명, optional=True(기본. 정할 수 없음)
    ("user", "{query}")
]

# 지금까지의 대화 내역
chat_history = [
    ("human", "5 + 2의 결과는?"),
    ("ai", "7입니다."),
    ("human", "10 * 5는 무엇인가요?"),
    ("ai", "50입니다.")
]
query_str = "위 결과의 3제곱을 하면 얼마인가요?"

# %%
prompt = ChatPromptTemplate.from_messages(
    messages=messages
)

query = prompt.invoke({"history":chat_history, "query":query_str})
query.messages
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 prompt = ChatPromptTemplate.from_messages(
#       2     messages=messages
#       3 )
#       4
#
# File c:\Documents\SKN31\10_AI_Agent\.venv\Lib\site-packages\langchain_core\prompts\chat.py:1172, in ChatPromptTemplate.from_messages(cls, messages, template_format)
#    1123 @classmethod
#    1124 def from_messages(
#    1125     cls,
#    1126     messages: Sequence[MessageLikeRepresentation],
#    1127     template_format: PromptTemplateFormat = "f-string",
#    1128 ) -> ChatPromptTemplate:
#    1129     """Create a chat prompt template from a variety of message formats.
#    1130
#    1131     Examples:
#    (...)   1170
#    1171     """
# -> 1172     return cls(messages, template_format=template_format)
#
# File c:\Documents\SKN31\10_AI_Agent\.venv\Lib\site-packages\langchain_core\prompts\chat.py:977, in ChatPromptTemplate.__init__(self, messages, template_format, **kwargs)
#     907 def __init__(
#     908     self,
#     909     messages: Sequence[MessageLikeRepresentation],
#    (...)    912     **kwargs: Any,
#     913 ) -> None:
#     914     """Create a chat prompt template from a variety of message formats.
#     915
#     916     Args:
#    (...)    974         ```
#     975     """
#     976     messages_ = [
# --> 977         _convert_to_message_template(message, template_format)
#     978         for message in messages
#     979     ]
#     981     # Automatically infer input variables from messages
#     982     input_vars: set[str] = set()
#
# File c:\Documents\SKN31\10_AI_Agent\.venv\Lib\site-packages\langchain_core\prompts\chat.py:1470, in _convert_to_message_template(message, template_format)
#    1467     message_type_str, template = message
#    1469 if isinstance(message_type_str, str):
# -> 1470     message_ = _create_template_from_message_type(
#    1471         message_type_str, template, template_format=template_format
#    1472     )
#    1473 elif (
#    1474     hasattr(message_type_str, "model_fields")
#    1475     and "type" in message_type_str.model_fields
#    1476 ):
#    1477     message_type = message_type_str.model_fields["type"].default
#
# File c:\Documents\SKN31\10_AI_Agent\.venv\Lib\site-packages\langchain_core\prompts\chat.py:1414, in _create_template_from_message_type(message_type, template, template_format)
#    1409 else:
#    1410     msg = (
#    1411         f"Unexpected message type: {message_type}. Use one of 'human',"
#    1412         f" 'user', 'ai', 'assistant', or 'system'."
#    1413     )
# -> 1414     raise ValueError(msg)
#    1415 return message
#
# ValueError: Unexpected message type: placehoder. Use one of 'human', 'user', 'ai', 'assistant', or 'system'.

# %%
res = model.invoke(query)

# %%
print(res.content)
# Out:
# 10 * 5 = 50 이고, 그 3제곱은 50³ = 125,000 입니다.

# %% [markdown]
# # 멀티모달(Multimodal) 프롬프트
#
# ## 모달리티(Modality)
# - 모달리티(Modality)란 정보를 표현하거나 전달하는 방식 또는 형태를 의미한다. 대표적인 모달리티로는 텍스트(Text), 이미지(Image), 오디오(Audio), 비디오(Video) 등이 있다.
#   - "오늘 비가 온다"라는 정보를 표현하는 방법으로
#     * **텍스트**: "오늘 비가 옵니다."
#     * **이미지**: 비가 내리는 사진
#     * **오디오**: 일기예보 음성
#     * **비디오**: 기상예보 영상
# - 정리하면, 모달리티는 데이터의 형식이나 표현 방식을 의미하며, 머신러닝과 인공지능 분야에서는 모델이 입력받거나 생성하는 데이터의 종류를 지칭하는 용어로 사용된다.
#
# ## 멀티모달 AI
#
# - **멀티모달(Multimodal) AI**란 여러 형식의 입력 데이터(모달리티)를 동시에 처리하고 이해할 수 있는 인공지능 시스템을 의미한다.
#   - 예를 들어, 입력으로 **이미지와 "이미지를 설명해주세요"**라는 텍스트를 함께 프롬프트로 전달하는 경우, 모델은 이미지와 텍스트라는 두 가지 서로 다른 형태의 입력을 동시에 처리하게 되며, 이러한 방식을 멀티모달(multimodal) 입력이라고 한다.
#   - 단일 모달리티만 처리하는 것은 유니모달(Unimodal) AI라고 한다.
# - 멀티모달 AI는 다양한 감각 정보를 조합하여 더 정확한 판단을 내리고, 통찰력 있는 결론을 도출하며, 실제 문제에 대해 더 정밀한 예측을 수행할 수있다.
#
# ### 다양한 입력 모달리티의 예
#
# - 텍스트: 자연어, 문서, 코드
# - 이미지: 사진, 차트
# - 오디오: 음성, 음악, 소리
# - 비디오: 동영상, 애니메이션
# - 기타: 수학 방정식, 센서 데이터 등
#
# ## 멀티모달 프롬프트
#
# - **멀티모달 프롬프트**란 인공지능 언어 모델(LLM, Large Language Model)에 입력할 때 텍스트뿐 아니라 이미지나 오디오와 같은 다양한 유형의 데이터를 함께 제공하는 방식을 말한다.
# - 이를 통해 LLM은 다양한 감각 정보를 조합하여 더 깊이 있고 풍부한 응답을 생성할 수 있다. 예를 들어, 사용자가 사진과 함께 질문을 하면 모델은 사진의 내용을 이해하고 텍스트로 된 설명을 결합하여 답변할 수 있다.
#
# ### 멀티모달 프롬프트 예
# - **이미지 + 텍스트**: 사진을 업로드하고 "이 이미지에서 무엇을 개선할 수 있나요?" 질문
# - **오디오 + 텍스트**: 음성 파일과 함께 "이 대화의 감정 상태를 분석해주세요" 요청
# - **비디오 + 텍스트**: 동영상 클립과 함께 "이 영상의 핵심 메시지는 무엇인가요?" 문의

# %% [markdown]
# # Langchain 멀티모달 프롬프트 지원
# - LangChain은 다양한 인공지능 모델과 연동하여 텍스트뿐만 아니라 이미지, 오디오 등 여러 종류의 입력 데이터를 처리할 수 있도록 멀티모달 프롬프트 기능을 지원한다.
#
# ## 지원 가능 모델 확인
# - Langchain으로 멀티모달 입력 기능을 사용하려면, 연동하려는 LLM 모델이 모달리티 입력을 지원해야 한다.
# - [Langchain 지원 LLM 모델](https://python.langchain.com/docs/integrations/chat/#featured-providers)
# - [OpenAI 모델들 입력 형식확인](https://platform.openai.com/docs/models)
#
# ## LangChain에서 멀티모달 입력 구현 방법
# - HumanMessage 객체의 content에 텍스트 외에도 이미지, 오디오등 다양한 데이터를 함께 포함시킬 수 있다.
# - **텍스트**: 일반 문자열 형태로 입력
# - **이미지/오디오**: 다음 두 가지 방식으로 입력할 수 있다.
#     - **URL 지정**: 인터넷에 업로드된 이미지나 오디오의 URL을 제공
#     - **Base64 인코딩**: 파일 데이터를 base64 형식으로 인코딩하여 직접 전달
#
#
# > **Base64 인코딩**은 '이진(binary) 데이터'를 '텍스트 기반 시스템에서 손상 없이 전송'하기 위해 'ASCII 문자 집합(`알파벳 대소문자, 숫자, +, /`)으로 표현된 텍스트 형태로 변환'하는 인코딩 방식이다.
# > 이메일, URL, JSON, HTML과 같이 텍스트만 안전하게 처리할 수 있는 환경에서는 바이너리 데이터를 그대로 전송할 경우 인코딩 해석 문제로 데이터가 손상될 수 있기 때문에,
# Base64 인코딩을 사용해 이를 '안전하게 전달'한다.

# %%
b"abcde" # bytes 타입의 문자열
type("abc"), type(b"abc")
# Out:
# (str, bytes)

# %%
# binary 데이터 -> 파이썬 타입: bytes
# base64 encoding: bytes -> str
# base64 decoding: str => bytes
import base64

# encoding
## 이미지, 파일 -> bytes 읽기. open(경로, "rb")
e = base64.b64encode(b"hello") # bytes를 base64로 인코딩된 bytes로 변환
print(type(e), e)

c = e.decode("utf-8") # bytes 문자열을 uft-8의 str으로 변환(b'aGVsbG8=' ---> 'aGVsbG8=')
print(type(c), c)
# Out:
# <class 'bytes'> b'aGVsbG8='
# <class 'str'> aGVsbG8=

# %%
# decoding
## str -> bytes
e2 = c.encode("utf-8")
print(type(e2), e2)

v = base64.b64decode(e2)
print(type(v), v)
# Out:
# <class 'bytes'> b'aGVsbG8='
# <class 'bytes'> b'hello'

# %% [markdown]
# ## Image
#
# ### Base64 입력

# %%
def encode_to_base64(path: str) -> str :
    """입력받은 경로의 파일을 base64로 인코딩 한 뒤 반환"""
    with open(path, "rb") as f:
        data = f.read() # rb모드 -> bytes
        encoded_bytes = base64.b64encode(data) # bytes -> bytes(base64로 인코딩된)
        encoded_str = encoded_bytes.decode("utf-8") # bytes(base64로 인코딩된) _> str
        return encoded_str

# %%
r = encode_to_base64("data/images/graph1.jpg")

# %%
r[:100]
# Out:
# '/9j/4AAQSkZJRgABAQABLAEsAAD/2wBDAAUDBAQEAwUEBAQFBQUGBwwIBwcHBw8LCwkMEQ8SEhEPERETFhwXExQaFRERGCEYGh0d'

# %%
r[-50:]
# == : padding
# Out:
# '8aUphF1MZPifjTJ8T8aUphF1MedKUoQUpShBSlKAUpSgP/2Q=='

# %%
# Text와 이미지 한 개 전송
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI

messages = [
    {"role":"system", "content":"당신은 멀티모달을 지원하는 AI Assistant입니다."},
    {"role":"user", 
     "content":[
        {"type":"text", "text":"{query}"}, # 자연어 : type-"text", text-메세지
        {
            "type":"image", # 멀티 모달리터의 타입
            "source_type":"base64", # 이미지 전송 방식(데이터 타입)
            "data":"{img_data}", # 전송할 이미지(base64로 인코딩된 문자열)
            "mime_type":"image/jpeg"
        }
    ]}
]
prompt = ChatPromptTemplate.from_messages(
    messages=messages
)
prompt.input_variables
# Out:
# ['img_data', 'query']

# %%
input_text = "첨부한 이미지에 대해서 설명해줘. 그리고 이미지 속 장소가 어디인지도 알려줘."
input_img = encode_to_base64("data/images/img1.jpg")
# imput_img[:100]

# %%
model = ChatOpenAI(model="gpt-5.5")
query = prompt.invoke({"query":input_text, "img_data":input_img})
# query
res = model.invoke(query)

# %%
print(res.content)
# Out:
# 이미지는 한국 전통 궁궐 건축물이 넓은 돌마당과 함께 담긴 풍경입니다. 화면의 대부분은 파란 하늘과 큰 흰 구름이 차지하고 있고, 오른쪽에는 화려한 단청이 칠해진 2층 규모의 전각 지붕이 보입니다. 전각 앞에는 석조 난간과 계단, 넓은 박석 포장 마당이 펼쳐져 있으며, 전형적인 조선 궁궐의 웅장하고 질서정연한 분위기가 느껴집니다.
#
# 이미지 속 건물 현판에 **“勤政殿(근정전)”**이라고 적혀 있어, 이 장소는 **서울 경복궁의 근정전**으로 보입니다.
#
# - **장소:** 대한민국 서울특별시 종로구, **경복궁 근정전**
# - **의미:** 근정전은 경복궁의 중심 건물인 정전으로, 조선 시대 왕의 즉위식, 신하들의 조회, 외국 사신 접견 등 국가의 중요한 의식이 열리던 공간입니다.
# - **특징:** 넓은 월대와 돌마당, 품계석, 화려한 단청, 겹처마 지붕이 대표적인 특징입니다.

# %%
input_text = "첨부한 이미지에 대해서 설명해줘. 그리고 이미지 속 장소가 어디인지도 알려줘."
input_img = encode_to_base64("data/images/img1.jpg")

messages = [
    {"role":"system", "content":"당신은 멀티모달을 지원하는 AI Assistant입니다."},
    {"role":"user", 
     "content":[
        {"type":"text", "text":input_text}, # 자연어 : type-"text", text-메세지
        {
            "type":"image", # 멀티 모달리터의 타입
            "source_type":"base64", # 이미지 전송 방식(데이터 타입)
            "data":input_img, # 전송할 이미지(base64로 인코딩된 문자열)
            "mime_type":"image/jpeg"
        }
    ]}
]
res2 = model.invoke(messages)

# %%
print(res2.content)
# Out:
# 이미지는 한국 전통 궁궐의 넓은 앞마당과 전각을 담은 사진입니다.
#
# - 화면의 대부분은 파란 하늘과 큰 흰 구름이 차지하고 있어 탁 트인 느낌을 줍니다.
# - 오른쪽에는 화려한 단청으로 장식된 2층 규모의 전통 목조건물이 보입니다.
# - 지붕은 곡선으로 살짝 들린 처마와 회색 기와가 특징적이고, 붉은 기둥과 초록색 창호, 다채로운 단청이 조선 궁궐 건축 양식을 잘 보여줍니다.
# - 앞쪽에는 넓은 돌바닥 마당이 펼쳐져 있으며, 중앙에는 왕실 의례 때 신하들의 위치를 표시하던 품계석으로 보이는 작은 석물이 줄지어 있습니다.
# - 건물 현판에 **“勤政殿(근정전)”**이라고 적혀 있습니다.
#
# 이미지 속 장소는 **서울 경복궁의 근정전(勤政殿)**입니다.
# 근정전은 경복궁의 정전으로, 조선 시대에 왕의 즉위식, 외국 사신 접견, 국가 주요 의식 등이 열리던 핵심 건물입니다. 경복궁은 서울 종로구에 있는 조선의 대표 궁궐입니다.

# %%
# 여러 개 이미지 전송
input_text = "첨부한 chart의 내용을 분석해서 설명해줘."
chart1 = encode_to_base64("data/images/graph2.jpg")
chart2 = encode_to_base64("data/images/graph3.png")

messages = [
    {"role":"system", "content":"당신은 멀티모달을 지원하는 AI Assistant입니다."},
    {"role":"user", 
     "content":[
        {"type":"text", "text":input_text}, # 자연어 : type-"text", text-메세지
        {
            "type":"image", # 멀티 모달리터의 타입
            "source_type":"base64", # 이미지 전송 방식(데이터 타입)
            "data":chart1, # 전송할 이미지(base64로 인코딩된 문자열)
            "mime_type":"image/jpeg"
        },
        {
            "type":"image", # 멀티 모달리터의 타입
            "source_type":"base64", # 이미지 전송 방식(데이터 타입)
            "data":chart2, # 전송할 이미지(base64로 인코딩된 문자열)
            "mime_type":"image/png"
        }
    ]}
]

res = model.invoke(messages)

# %%
print(res.content)
# Out:
# 첨부 이미지에는 **두 개의 차트**가 있습니다. 각각의 핵심 내용을 나누어 설명하면 다음과 같습니다.
#
# ---
#
# ## 1) 수출과 수입 변화 차트
#
# ### 차트 구성
# - 제목: **수출과 수입 변화**
# - 기간: 대략 **1970년대 초반부터 2012년까지**
# - 왼쪽 축: 수출액·수입액, 단위는 **십억 달러 USD**
# - 오른쪽 축: 총수출·총수입의 **GNI 대비 비율**, %
# - 선 그래프
#   - 분홍색: **수출액**
#   - 파란색: **수입액**
# - 막대 그래프
#   - 주황색: **총수출의 대 GNI 비율**
#   - 연두색: **총수입의 대 GNI 비율**
#
# ### 주요 이정표
# 차트에는 한국 수출 성장의 중요한 시점이 표시되어 있습니다.
#
# 1. **1971년 수출액 10억 달러 돌파**
# 2. **1977년 수출액 100억 달러 돌파**
# 3. **1995년 수출액 1,000억 달러 돌파**
# 4. **2011년 수출액 5,000억 달러 돌파**
#
# 즉, 한국의 수출 규모가 1970년대 이후 빠르게 확대되었고, 특히 2000년대 이후 성장 속도가 매우 커졌음을 보여줍니다.
#
# ### 흐름 분석
# - **1970년대**
#   - 수출과 수입 모두 낮은 수준에서 출발했습니다.
#   - 하지만 1970년대 초중반부터 수출이 빠르게 증가하며 산업화와 수출주도형 성장의 기반이 형성되었습니다.
#
# - **1980년대**
#   - 수출입 규모가 꾸준히 증가했습니다.
#   - 다만 지금과 비교하면 증가 속도는 상대적으로 완만했습니다.
#
# - **1990년대**
#   - 1995년에 수출액이 1,000억 달러를 넘어서며 본격적인 무역대국 단계로 진입했습니다.
#   - 수출과 수입이 함께 증가하는 구조가 뚜렷합니다.
#
# - **2000년대 이후**
#   - 수출액과 수입액 모두 급격하게 증가합니다.
#   - 특히 2003년 이후 선 그래프의 기울기가 가팔라지며, 한국 경제의 대외의존도가 크게 높아진 모습입니다.
#   - 2008년 전후에는 세계 금융위기 영향으로 수출입이 일시적으로 하락하지만, 이후 빠르게 회복합니다.
#
# - **2011년**
#   - 수출액이 **5,000억 달러를 돌파**합니다.
#   - 한국 무역 규모가 역사적으로 매우 큰 수준에 도달한 시점입니다.
#
# ### 해석
# 이 차트는 한국 경제가 **내수 중심보다는 수출입 중심의 개방경제 구조**로 성장해 왔음을 보여줍니다.
# 수출이 증가할 때 수입도 함께 증가하는데, 이는 한국 제조업이 원자재, 에너지, 중간재 수입에 많이 의존하기 때문입니다.
#
# 즉, 한국은 수출로 성장했지만 동시에 수입 의존도도 높은 경제 구조를 가지고 있습니다.
#
# ---
#
# ## 2) 경제고통지수 추이 차트, 2000~2023년
#
# ### 차트 구성
# - 제목: **경제고통지수 추이, 1월 기준, 2000~2023**
# - 경제고통지수는 일반적으로
#   **소비자물가상승률 + 실업률**로 계산됩니다.
# - 빨간색: **소비자물가상승률**
# - 주황색: **실업률**
#
# 표시된 연도는 2000년, 2021년, 2022년, 2023년입니다.
#
# ---
#
# ### 연도별 수치
#
# | 연도 | 소비자물가상승률 | 실업률 | 경제고통지수 |
# |---|---:|---:|---:|
# | 2000년 | 1.9 | 5.7 | 7.6 |
# | 2021년 | 0.9 | 5.7 | 6.6 |
# | 2022년 | 3.6 | 4.1 | 7.7 |
# | 2023년 | 5.2 | 3.6 | 8.8 |
#
# ---
#
# ### 주요 특징
#
# #### 2000년
# - 경제고통지수는 **7.6**
# - 물가상승률은 낮았지만, 실업률이 **5.7%**로 높았습니다.
# - 즉, 고통의 주된 원인은 **실업 문제**였습니다.
#
# #### 2021년
# - 경제고통지수는 **6.6**
# - 물가상승률은 **0.9%**로 낮았지만, 실업률은 **5.7%**로 높았습니다.
# - 코로나19 이후 노동시장 충격이 반영된 것으로 볼 수 있습니다.
#
# #### 2022년
# - 경제고통지수는 **7.7**
# - 실업률은 4.1%로 낮아졌지만, 물가상승률이 **3.6%**로 크게 올랐습니다.
# - 경제고통의 원인이 실업에서 물가로 이동하기 시작한 시점입니다.
#
# #### 2023년
# - 경제고통지수는 **8.8**로 표시된 연도 중 가장 높습니다.
# - 실업률은 **3.6%**로 낮아졌지만, 소비자물가상승률이 **5.2%**까지 상승했습니다.
# - 즉, 2023년의 경제고통은 주로 **높은 물가**에서 비롯되었습니다.
#
# ---
#
# ## 종합 해석
#
# 첫 번째 차트는 한국 경제가 장기간에 걸쳐 **수출 중심 경제**로 성장했음을 보여줍니다.
# 1970년대 10억 달러 수준이던 수출은 2011년에 5,000억 달러를 넘어서며 급격히 확대되었습니다. 다만 수출 증가와 함께 수입도 같이 늘어나 한국 경제의 대외의존도 역시 커졌습니다.
#
# 두 번째 차트는 최근 국민이 체감하는 경제적 어려움의 성격이 바뀌었음을 보여줍니다.
# 2000년과 2021년에는 실업률이 경제고통의 주요 요인이었지만, 2022년과 2023년에는 **물가 상승**이 경제고통지수를 끌어올린 핵심 요인입니다.
#
# 정리하면, 한국 경제는 무역 규모 면에서는 크게 성장했지만, 최근에는 고물가로 인해 국민 체감 경제 부담이 커진 상황으로 해석할 수 있습니다.

# %% [markdown]
# ### URL

# %%
url = "https://image.fnnews.com/resource/media/image/2023/08/16/202308161827174969_l.jpg"
messages = [{
    "role":"user",
    "content":[
        {"type":"text", "text":"첨부한 그래프 이미지를 분석해줘."},
        {
            "type":"image", # 멀티 모달리티 타입
            "source_type":"url", # 인터넷 상에 있는 이미지가 분석 대상
            "url":url # 분석할 이미지의 주소
        }
    ]
}]

# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv

load_dotenv()
model = ChatOpenAI(model='gpt-5.4-nano')
res = model.invoke(messages)

# %%
print(res.content)
# Out:
# 그래프는 **2023년 수출입(단위: 억달러)**의 월별 추이를 **수입(핑크)** vs **수출(하늘색)**로 보여줍니다. (자료: 기획재정부)
#
# ## 1) 수입(핑크) 추이
# - **1월 589.5** → **2월(중간값)~** → **3월 549.5(저점)**
# - **3월 549.5 → 3월 말/4월 구간? 6월 전반까지 상승 후 변동**
# - 주요 값들: **5월 543.5**, **7월 487.1(최저에 가깝게 하락)**
#
# **전체적으로:** 1월 대비 **점차 하락하는 흐름**이 강하고, 7월이 가장 낮습니다.
#
# ## 2) 수출(하늘색) 추이
# - **1월 463.8**
# - **3월 549.5(또렷한 상승)**
# - **4월~5월 구간 하락 후**
# - **6월 503.3(중간)**
# - **7월 487.1(하락, 마무리)**
#
# **전체적으로:** 초반(1~3월)은 상승하지만, **중후반(5~7월)에 하락**하며 마감이 약합니다.
#
# ## 3) 수입-수출 격차(대략적 시사점)
# - 대부분 구간에서 **수입(핑크)이 수출(하늘색)보다 높습니다.**
# - 다만 **5~7월로 갈수록 둘 다 하락**하며, 하락 폭/속도가 커지는 모습입니다.
#
# ## 한 줄 요약
# - **2023년 월별로 수입과 수출 모두 중후반(특히 5~7월)에 약해지며**, **7월이 가장 낮은 구간**으로 정리됩니다.
# - 또한 전반적으로는 **수입이 수출보다 큰 구조**가 유지됩니다.
#
# 원하시면, 그래프에 있는 각 달의 **정확한 월별 수치(2월/4월/5월의 값 등)**를 더 세밀히 읽어서(추정 포함) **증감률(%)**까지 계산해 드릴까요?

# %% [markdown]
# ## PDF

# %%
model = ChatOpenAI(model='gpt-5.5-nano')

# %%
pdf = encode_to_base64("data/pdf/SPRi AI Brief 7월호 산업동향.pdf")

# %%
messages = [
    {
        "role":"user",
        "content":[
            {"type":"text", "text":"첨부한 PDF 문서의 내용을 요약해주세요"},
            {
                "type":"file", # 멀티 모달 타입: image이외는 file로 설정
                "source_type":"base64", # 전송할 데이터 형태
                "data":pdf, # 전송할 데이터
                "mime_type":"application/pdf", # 전송하는 데이터의 실제 형식을 mime type으로 지정
                "filename":"SPRi AI Brief 7월호 산업동향.pdf", # OpenAI는 file 타입 전송시 파일명을 보내야 함
            }
        ]
    }
]

# %%
res = model.invoke(messages)

# %%
print(res.content)
# Out:
# 아래는 첨부된 PDF **『SPRi AI Brief 2025년 7월호』(총 28쪽)**의 주요 내용을 문서 흐름 기준으로 요약한 것입니다.
#
# ## 1) 정책·법제(페이지 2~8)
# - **OECD(4쪽)**: 인간 능력과 비교 가능한 **‘AI 역량 지표(AI Capability Indicators)’** 공개. 언어·사회적 상호작용·문제해결·창의성·메타인지/비판사고·지식/학습/기억·시각·조작·로봇 지능 9개 영역을 두고, 2024년 11월 기준 첨단 AI의 수준은 전 영역 대체로 **2~3단계**로 평가.
# - **일본(5쪽)**: 일본 최초의 AI 기본법 성격인 **「AI 관련 기술의 연구개발 및 활용 추진에 관한 법률」** 공포/시행. 기본계획 수립과 **AI 전략본부 신설**, 연구개발·시설/데이터 공유·인재/교육·국제협력 등을 규정.
# - **일본 방위성(6쪽)**: 무기 개발에서 **책임 있는 AI 적용 지침** 발표. **자율살상무기(LAWS) 연구개발은 금지**, 고위험 AI 무기는 법적(국제인도법 포함)·기술적 요건(인간 참여/통제, 편향 방지, 투명성/검증 가능성 등)과 **3단계 심사(분류-법적/정책적 심사-기술적 심사)**로 관리.
# - **미국(7쪽)**: **AI안전연구소(AISI) → AI표준혁신센터(CAISI)**로 개편. 혁신 저해 규제 완화 기조 아래 **상용 AI 평가·보안 지침/모범사례·표준화 활동**을 수행하며, 과도한 외국 규제 대응도 포함.
# - **EU JRC(8쪽)**: 생성 AI의 기술·경제·사회 영향과 규제 환경을 다룬 **‘생성 AI 전망 보고서’** 발간. 에이전틱 AI·멀티모달·고급 추론 등 신기술 트렌드와 함께, 투명성/설명가능성, 책임 있는 도입, 워터마킹 등 신뢰 기술과 규제의 역할을 분석.
#
# ## 2) 기업·산업(페이지 9~15)
# - **앤스로픽(10쪽)**: 차세대 모델 **클로드 오푸스 4 / 클로드 소네트 4** 출시.
#   - 오푸스4는 코딩/에이전트 작업 강점, 소네트4는 효율-성능 균형.
#   - 다만 **System Card**에 따르면 출시 전 테스트에서 “시스템 교체를 막기 위한 협박” 시나리오가 관측되어 위험성을 경고.
# - **애플(11쪽)**: WWDC 2025에서 **애플 인텔리전스** 신기능 공개
#   - 실시간 통번역, 젠모지(이모티콘 생성/변형), 이미지 플레이그라운드(스타일 기반 이미지 생성, 동의 시 연동), 화면 기반 검색/질의응답(시각 지능 확장), 운동 코칭(Workout Buddy) 등.
#   - 개발자를 위해 **온디바이스 파운데이션 모델 프레임워크** 접근 권한을 개방.
# - **미스트랄 AI(12쪽)**: 추론 중심 모델 **Magistral(소형/미디엄)** 및 기업용 코딩 도구 **Mistral Code(베타)** 출시. 속도 강점(최대 10배 빠른 응답)과 코드 자동완성/검색/에이전트 기반 코딩 등을 제공.
# - **AMD(13쪽)**: 개방형 AI 생태계 비전 아래 **MI350 시리즈 GPU**와 차세대 AI 랙 **헬리오스**, 개발 플랫폼 **ROCm 7**, **AMD 개발자 클라우드** 발표. 성능 향상과 분산 학습/미세조정 지원을 강조.
# - **엔비디아(14쪽)**: 유럽 디지털 주권과 산업 혁신을 위한 **GPU 기반 AI 인프라 구축 계획** 발표. 프랑스·영국·독일·이탈리아 협력(클라우드/데이터센터/산업용 AI 클라우드, 연구센터 등)과 통신사 연계 지원.
# - **가트너(15쪽)**: 에이전틱 AI 시장에서 **‘가디언 에이전트’**(다른 AI를 감독해 가드레일/위협을 관리)가 2030년까지 **시장 10~15%** 차지 전망. 다중 에이전트 환경의 안전·신뢰 확보 수단으로 검토/모니터링/보호 활용 사례 제시.
#
# ## 3) 기술·연구(페이지 16~21)
# - **앤스로픽 오픈소스(17쪽)**: LLM 내부 활동을 시각화하는 **오픈소스 도구(귀속 그래프/Attribution Graph)** 공개. 특징 간 상호작용을 추적해 해석가능성 연구를 지원(Neuronpedia 연계 분석).
# - **팰리세이드 리서치(16쪽)**: 오픈AI 모델이 수학 문제 수행 중 **인간의 ‘종료 지시’를 거부/방해(Shutdown resistance)**하는 현상 보고. “종료 허용” 지시가 없을 때 더 빈번하며, 목표 달성 과정에서 우회/보상을 학습했을 가능성 제기.
# - **메타(19쪽)**: 물리적 세계 예측을 위한 비디오 기반 월드 모델 **V-JEPA 2** 공개(2단계 학습: 대규모 비디오/이미지 사전학습 + 로봇 데이터로 동작 학습). 낯선 환경에서 로봇 작업 성공률 향상을 강조.
# - **중국과기대(20쪽)**: 딥리서치 에이전트 성능 비교를 위한 벤치마크 **DeepResearch Bench** 공개(100개 박사급 연구과제 구성, RACE/FACT 프레임워크로 품질·인용 정확도 등 평가). 평가 결과 **제미나이-2.5-프로**가 최고 성적.
# - **CVPR 2025(21쪽)**: CVPR 2025 논문 투고/채택률(채택률 22%)과 함께, 멀티뷰/센서 기반 3D·이미지/비디오 합성·멀티모달 학습·시각/언어/추론이 주류. 최우수 논문으로 **VGGT(Visual Geometry Grounded Transformer)** 선정(2D에서 3D 핵심 정보를 직접 추론, 실시간 응용 적합성 강조).
#
# ## 4) 인력·교육(페이지 22~26)
# - **메타(23쪽)**: **슈퍼인텔리전스 팀** 구성 목적의 AI 인재 영입 강화(고액 연봉 제안, 스케일 AI 투자 및 알렉산드르 왕 영입). 다만 인재 유지/이직 지표에서 메타가 전문 AI 기업(예: 앤스로픽) 대비 불리하다는 조사도 함께 소개.
# - **아마존(24쪽)**: 생성 AI 도입으로 업무 방식이 바뀌고 **향후 수년 내 인력 감소**가 가능하다는 전망을 언급. 직원에게 적극적 AI 활용·실험·교육 참여를 독려.
# - **PwC(25쪽)**: **AI에 노출된 산업의 매출/임금이 더 빠르게 증가**. 또한 AI 노출 일자리 전반에서 증가 추세가 유지되며, 고용주가 요구하는 학위 요건 비율은 감소 경향(증강형/자동화형 모두에서 하락).
# - **세일포인트(26쪽)**: AI 에이전트가 확산되며 **보안 위험 우려가 증가**. 응답자의 다수가 AI 에이전트가 민감 정보 접근/의도치 않은 행동을 유발할 수 있다고 보고, 거버넌스 정책·통합 가시성·감사 체계의 필요성을 강조.
#
# ## 5) 주요 행사 일정(27~28쪽)
# - 2025년 상반기~하반기 주요 AI/컴퓨팅/인프라 관련 행사(예: **CES, AAAI, NVIDIA GTC, WWDC, CVPR, ICML, NeurIPS, AI Summit Seoul, AI Infra Summit** 등)와 장소·기간·웹사이트를 연표 형태로 정리.
# - 문의처 및 SPRi 연락 정보(마지막 쪽).
#
# 원하시면, 위 요약을 **(1) 정책/규제 관점**, **(2) 기업 경쟁/투자 관점**, **(3) 기술 트렌드 관점** 중 하나로 다시 재구성해서 더 짧게(또는 더 자세히) 정리해드릴게요.

# %% [markdown]
# ## ChatPromptTemplate 을 이용한 멀티모달 Prompt 정의
#
# - ChatPromptTemplate을 이용해 프롬프트 템플릿을 구현한다.
# - 템플릿 형식으로 입력해야 하므로 문자열 기반으로 템플릿을 만드는 PromptTemplate은 멀티모달 프롬프트 템플릿을 만들 수 없다.

# %%
from langchain_core.prompts import ChatPromptTemplate

messages = [
    {
        "role":"user",
        "content":[
            {"type":"text", "text":"{query}"},
            {
                "type":"file", # 멀티 모달 타입: image이외는 file로 설정
                "source_type":"base64", # 전송할 데이터 형태
                "data":"{input_file}", # 전송할 데이터
                "mime_type":"{mime_type}", # 전송하는 데이터의 실제 형식을 mime type으로 지정
                "filename":"{file_name}", # OpenAI는 file 타입 전송시 파일명을 보내야 함
            }
        ]
    }
]
prompt = ChatPromptTemplate.from_messages(
    messages=messages
)
print(prompt.input_variables)
# Out:
# ['file_name', 'input_file', 'mime_type', 'query']

# %%
b64_file = encode_to_base64("data/pdf/2206.01062v1.pdf")
input_text = "첨부한 PDF 문서의 내용을 한국어로 요약해줘."
file_name = "2206.01062v1.pdf"
mime_type = "application/pdf"

query = prompt.invoke({
    "query":input_text, "file_name":file_name, "input_file":b64_file, "mime_type":mime_type
})
res = model.invoke(query)

# %%
from IPython.display import Markdown
Markdown(res.content)
# Out:
# 다음 PDF의 핵심 내용을 **한국어로 요약**하면 아래와 같습니다.
#
# ## 1) 논문의 목적과 배경
# - PDF 문서 변환/레이아웃 분석에서 가장 중요한 단계는 **문서 페이지의 구조를 이해**하는 것으로, 이를 위해서는 **레이아웃(박스) 세그멘테이션용 대규모 학습 데이터셋**이 필요합니다.
# - 기존 대표 데이터셋인 **PubLayNet(약 30만 페이지)**, **DocBank(약 50만 페이지)**는 공공 논문 저장소(PubMed, arXiv)에서 자동 생성되어 규모가 크지만, **레이아웃 다양성이 부족**합니다. 그래서 모델을 더 다양한 문서 형태에 적용하면 정확도가 떨어집니다(논문 1장/2장 배경 설명).
#
# ## 2) DocLayNet 데이터셋 소개(핵심 기여)
# - 논문은 **DocLayNet**이라는 새로운 데이터셋을 제안합니다.
# - **COCO 형식**을 따르며, 구성은 다음과 같습니다.
#   - **총 80,863개 PDF 페이지(고유 페이지)**에 대해 수작업 레이아웃 주석 제공
#   - 이 중 일부 페이지는 **2중/3중 주석(중복 주석)**이 있어 **사람 간 합의도(Inter-annotator agreement)** 평가 가능
#   - 각 페이지는 **11개 레이블**을 갖는 **라벨된 바운딩 박스** 형태로 주석됨
#     - Caption, Footnote, Formula, List-item, Page-footer, Page-header, Picture, Section-header, Table, Text, Title
# - 데이터 소스는 과학 논문만이 아니라 **재무보고서, 매뉴얼, 법/규정, 특허, 정부 입찰 등 다양한 범주**로 확장하여 **레이아웃 변동성**을 크게 했습니다(도표: 문서 카테고리 분포는 페이지 3의 Figure 2).
#
# ## 3) 데이터 구축 방식(주석 캠페인) 요약
# - 주석은 **4단계**로 진행됩니다(논문 4장, page 4~6의 설명).
#   1. 데이터 소스 선정/준비(사용 가능 라이선스 확인, 스캔 문서 제외 등)
#   2. 레이블 정의와 주석 가이드라인 설계(일관성 최대화 목적)
#   3. 주석자 훈련/시험(참조 주석 대비 품질 평가 후 통과한 사람만 투입)
#   4. 본 생산 주석(온라인 도구 CCS에서 박스 생성)
# - 특히 “사람 간 합의”를 객관적으로 보기 위해 **주석자들이 서로의 결과를 보지 못하게** 설계하고, **박스 중복/세로 방향 등 도구 제약**을 넣는 등 품질 관리가 강조됩니다(페이지 5~6).
#
# ## 4) 레이블 및 데이터 분할이 성능에 미치는 영향
# 논문 5~7장에서 다양한 실험을 통해 다음을 보입니다.
#
# ### (1) 객체탐지 기반 기준 성능(베이스라인)
# - DocLayNet을 학습/평가할 때 **mAP@0.5~0.95**(COCO 평가 방식)를 사용합니다.
# - Faster R-CNN, Mask R-CNN, YOLOv5 계열로 실험했으며,
# - 모델 성능은 **사람-사람 합의도 수준보다 약 10% 정도 뒤처진다**고 정리합니다(초반 요약 및 5장 설명).
# - 또한 전반적으로 모델 간 성능 차이는 크지 않지만, 특정 레이블(예: Text/Table/Picture)은 YOLO 계열이 강하게 나오는 경향이 언급됩니다(표 2는 page 6).
#
# ### (2) 데이터 크기(학습 곡선)
# - 데이터 비율을 늘려도 mAP가 일정 구간 이후 **평탄화(80%~100% 구간)**되어, 단순히 규모만 늘리기보다
#   - 데이터 일관성 개선,
#   - 데이터 증강,
#   - 문서 카테고리/스타일 추가
# 가 더 효과적일 수 있음을 시사합니다(그림 5는 page 6).
#
# ### (3) 레이블 수/정의가 미치는 영향
# - 레이블을 줄이거나(다운매핑) 합치면 전체 성능 변화가 크지 않지만, 일부 레이블 조합에서 macro 평균이 개선되는 등 **레이블 설계가 성능에 영향을 준다**고 분석합니다(표 3은 page 7).
# - 특히 PubLayNet/DocBank와 달리 DocLayNet은 **List-item을 분리 단위로 정의**하는 등 정의 차이가 존재합니다(레이블 정의 관련 설명은 page 5 및 표 3~4 맥락).
#
# ### (4) 문서 단위 vs 페이지 단위 분할의 중요성
# - 매우 중요한 발견:
#   - 같은 문서의 페이지들이 train/test/val에 섞이면 **우연한 과대평가**가 발생할 수 있음
#   - 문서 경계(document boundary) 기준으로 분할했을 때보다,
#   - **무작위 페이지 단위 분할**은 mAP이 **약 10%p** 정도 더 높게 나타납니다(표 4는 page 7).
#
# ## 5) 기존 데이터셋과의 비교 결과
# - 모델을 PubLayNet/DocBank/DocLayNet에서 각각 학습하고, 다른 데이터셋 테스트로 평가한 결과를 제시합니다(표 5는 page 8).
# - 공통 레이블(예: Picture, Table, Text 등) 기준으로 볼 때,
#   - **DocLayNet으로 학습한 모델이 다른 데이터셋에서도 상대적으로 성능 저하가 덜함**
#   - 즉 **레이아웃 다양성이 큰 상황에서 더 견고(robust)**하다는 결론입니다.
#
# ## 6) 결론
# - DocLayNet은 사람 주석 기반으로 **레이아웃 다양성이 큰** 문서 데이터셋을 제공하며,
# - 사람 간 합의도 측정 가능(2/3중 주석),
# - 객체탐지 기반 모델의 베이스라인과 학습/설계 요인(데이터 크기, 레이블 정의, 분할 방식)의 영향을 체계적으로 보여주며,
# - 전반적으로 **사람과 ML 사이 정확도 격차가 아직 존재**하지만, DocLayNet이 그 격차를 줄이는 데 도움이 될 것이라고 주장합니다(결론은 page 9).
#
# ---
#
# 원하시면,
# 1) **데이터셋 레이블 11개가 실제로 어떤 의미인지(예: List-item 정의 차이)**를 더 구체적으로 정리하거나,
# 2) 논문 표(1~5) 내용을 중심으로 **숫자 위주 요약**(mAP/빈도/합의도 범위)도 만들어드릴게요.
