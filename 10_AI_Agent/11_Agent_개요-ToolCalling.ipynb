# %% [markdown]
# # Agent 개요
#
# ## AI Agent란?
#
# - **AI Agent는 사용자의 목표를 달성하기 위해 대형 언어 모델(LLM)을 '추론과 의사결정의 중심으로 사용'하여 작업 계획 수립, 실행, 관찰, 판단 과정을 반복하며 자율적으로 작업을 수행하는 인공지능 시스템이다.**
# - AI Agent = LLM(계획/실행/판단) + tool
# - 일반적인 LLM 사용 방식은 다음과 같이 한 번의 질문에 대해 답변을 생성하는 구조이다.
#
#     ```text
#     사용자 질문 → LLM → 답변
#     ```
# - AI Agent는 단순히 답변만 생성하지 않는다. **사용자의 목표를 이해한 뒤, 목표를 달성하기 위해 필요한 작업을 스스로 판단하고 실행**한다.
#
#     ```text
#     목표 이해 → 계획 수립 → 도구 실행 → 결과 관찰 → 다음 행동 결정
#     ```
#     - **목표 이해.**
#         - Agent는 사용자의 요청을 단순한 문장으로만 처리하지 않고, 사용자가 실제로 달성하려는 목표가 무엇인지 파악한다.
#     - **작업 계획.**
#         - 목표를 달성하기 위해 어떤 순서로 작업해야 하는지 판단하고, 필요한 단계를 나눈다.
#     - **외부 도구 사용**
#         - Agent는 필요에 따라 검색 도구, API, 데이터베이스, 파일 시스템, 계산기, 코드 실행 환경 등 외부 도구를 호출할 수 있다.
#     - **실행 결과를 관찰하고 다음 행동을 결정.**
#         - 도구 실행 결과가 충분한지, 추가 작업이 필요한지 판단한 뒤 다음 단계를 결정한다.
#     - **반복 실행**
#         - 목표가 달성될 때까지 필요한 과정을 반복한다.
#     - 모든 단계를 사람이 직접 지시하지 않아도, Agent는 주어진 목표를 기준으로 스스로 판단하며 작업을 이어갈 수 있다.
#
#
# - 예를 들어 사용자가 “최근 AI 반도체 시장 동향을 조사해서 요약해줘”라고 요청했다고 하자.
#
#     ```text
#     1. 목표 파악: AI 반도체 시장 동향 조사
#     2. 계획 수립: 주요 기업, 시장 규모, 최근 이슈, 전망을 조사
#     3. 도구 사용: 웹 검색, 데이터베이스 조회
#     4. 결과 관찰: 수집한 자료가 충분한지 판단
#     5. 추가 실행: 부족한 정보가 있으면 추가 검색
#     6. 최종 답변: 조사 결과를 정리해 사용자에게 제공
#     ```
#
# 이처럼 Agent는 단순 응답 생성이 아니라 **목표 달성을 위한 일련의 작업 과정**을 수행한다.
# - 툴을 만드는 방법을 표준화 : MCP
#
# ## Workflow와 Agent
#
# - AI 시스템을 구현할 때 자주 비교되는 방식이 **Workflow**와 **Agent**이다.
# -   **Workflow**
#     - '미리 정해진 절차에 따라 실행'되는 방식이다.
#     - 실행 순서와 작업 단계가 사전에 고정되어 있으며, 입력이 들어오면 '정해진 흐름'대로 처리된다.
#     - 반복적이고 정형화된 작업에 적합하다.
# - **Agent**
#     - 주어진 목표를 달성하기 위해 '스스로 판단하면서 행동을 결정'하는 방식이다.
#     - 처음부터 모든 실행 단계가 고정되어 있지 않고, '상황에 따라 필요한 작업과 도구'를 선택하여 실행한다.
#     - Agent는 작업 과정이 고정되어 있지 않거나, 중간 결과에 따라 다음 행동이 달라지는 문제에 적합하다.

# %% [markdown]
# ## Agent의 주요 특징
#
# 1. **자율성** (Autonomy)
#    - Agent는 **사전 정의된 규칙**(Rule-based)에 의존하지 않고, LLM을 통해 현재 상황을 인지하고 추론하여 스스로 결정을 내리고 다음 행동을 계획할 수 있다.
#    - 즉, 사용자가 일일이 수행 단계를 지시하지 않아도, Agent는 **현재 상황을 해석하고 다음 행동을 동적으로 결정한다.**
#
# 2. **목표 지향성** (Goal-Oriented)
#     - Agent는 단순히 질문에 답변하는 **단순한 대화 상대가 아니라, 특정 목표와 복잡한 작업을 달성하기 위해 설계된 시스템**으로 최종 목표에 도달할 때 까지 반복적으로 행동한다.
#     - Agent는 어떤 처리를 할 때 항상 **"이 행동이 목표 달성에 도움이 되는가"를 기준**으로 판단한다.
#
# 3. **도구 활용** (Tool Utilization)
#     - Agent는 대형 언어 모델의 언어 이해 능력, 사전 학습 정보에만 의존하지 않고, 다양한 **외부 도구와 API를 함께 활용하여 실제 작업을 수행**한다.
#     - 이를 통해 LLM이 처리할 수없는 **최신 정보 검색, 복잡한 계산, 외부 시스템 제어**등과 같은 작업이 가능하다. 이를 통해 Agent는 **"말만 하는 AI"가 아니라 "실제로 일을 처리하는 AI"로 기능한다.**
#
# 4. **인간 개입 최소화** (Human-in-the-loop 최소화)
#     - Agent는 **문제 분석, 의사 결정, 행동 실행의 대부분을 스스로 결정하고 수행하도록 설계된다.**
#     - 사람은 **초기 목표 제시, 결과 확인 및 실행 최종 승인** 정도에 만 개입한다.

# %% [markdown]
# # 싱글에이전트(Single-Agent)와 멀티에이전트(Multi-Agent)
#
# ## 싱글에이전트(Single-Agent)
# - **'하나의 에이전트'가 '작업의 처음부터 끝까지' 전 과정을 책임지는 구조**로 구성된 Agent.
# - 싱글에이전트는 **"인식 → 추론 → 행동(도구 호출) → 결과 관찰"** 흐름의 모든 판단이 **'하나의 추론 컨텍스트'(context) 안**에서 이루어진다. 즉, 도구(검색, 코드 실행, 파일 읽기 등)와 메모리를 모두 한 에이전트가 쥐고 있으며, 작업 전체의 맥락이 단일한 의사결정자 안에 통합되어 있다.
#     - 예를 들어 "이 코드의 버그를 찾아 고쳐줘"라는 요청에서, 하나의 에이전트가 코드를 읽고, 원인을 추론하고, 수정안을 실행하고, 테스트 결과를 확인하는 일을 혼자 모두 처리한다.
# - **장점:** '구조가 단순'해 '응답이 빠르고'(저지연), '토큰 소비가 적어' 비용이 낮으며, 동작이 한 곳에서 일어나기 때문에 '디버깅과 추적이 쉽다.'
# - **한계:** '단일한 컨텍스트 윈도우에 작업 전체'가 담겨야 하므로 '정보량이 많'아지면 '한계'에 부딪히고, 단계들을 순차적으로 처리하기 때문에 여러 갈래를 동시에 진행하는 '**병렬 처리가 불가능**'하다. 작업 규모가 커질수록 이 두 가지(컨텍스트 한계·순차 병목)가 성능의 제약이 된다.
#
# ## 멀티에이전트 (Multi-Agent)
#
# - **역할이 나뉜 '여러 에이전트들이 협력'하여 '하나의 작업'을 처리하는 구조**이다.
# - 보통 '**오케스트레이터(orchestrator) 혹은 슈퍼바이저(supervisor)**' 라 불리는 상위 에이전트가 '큰 작업을 작은 하위 작업으로 분해'하고, 각 분야에 '특화된 **워커(worker) 에이전트**들에게 위임'한다. 각 워커는 자신만의 '독립된 컨텍스트와 도구', '역할'(role)을 가지며, 작업을 마치면 '결과를 상위 에이전트(슈퍼바이저)에게 보고'한다. 상위 에이전트는 이 '결과들을 종합'해 '최종 산출물(응답)'을 만든다.
# - 멀티에이전트 '구성 패턴'으로는 '상위가 하위를 지휘'하는 **슈퍼바이저/오케스트레이터-워커 패턴**, '단계별로 결과를 넘겨주'는 **순차 파이프라인 패턴**, 에이전트들이 서로 '동등하게 의견'을 주고받는 **수평적 협업 패턴** 등이 있다.
#
# ### 멀티에이전트가 효과적인 이유
#
# - Anthropic이 공개한 멀티에이전트 리서치 시스템 자료에 따르면, 리드 에이전트(Opus)와 서브에이전트(Sonnet)로 구성한 멀티에이전트가 단일 에이전트(Opus) 대비 내부 평가에서 **약 90% 이상 높은 성능**을 보였다.
# - 이 '성능 향상'은 주로 **토큰 사용량**, 그리고 추론을 여러 개의 독립된 컨텍스트 윈도우로 분산시킨 능력과 강하게 연결되어 있었다. 실제로 성능 변동의 약 80%가 토큰 사용량에 영향을 받았고, 그 외에는 도구 호출 수와 모델 선택 등이 영향을 주었다.
# - 토큰 사용량이란 '하나의 작업을 끝낼 때 까지 모델이 읽고 쓴 토큰의 총합'이다. 여기에는 입력받은 토큰들(검색결과, 도구 반환값, 읽어들인 문서, 이전 대화맥락등등)과 출력토큰들(모델이 생성한 추론, 도구 호출명령, 최종 답변등등)들이 있다.
# - 토큰 사용량이 많다는 것은 그 만큼 **모델이 많은 정보를 들여다 보고, 많이 생락을 했다**는 것을 뜻한다.
# - 즉 **'멀티에이전트'가 강한 이유는 결국 문제를 해결하는데 "더 많은 사고량(토큰)"을 병렬로 효율적으로 투입할 수 있기 때문**이다.
#
# ### 멀티에이전트의 비용과 위험
#
# - **조율 비용(coordination overhead):** 에이전트 간 작업을 나누고 결과를 주고받는 데 추가 비용이 든다.
# - **토큰·비용 급증:** 여러 에이전트가 각자 추론하므로 토큰 사용량이 크게 늘어난다. Anthropic 자료 기준으로 **일반 채팅 대비** 단일 에이전트는 약 4배, 멀티에이전트 리서치 시스템은 약 15배(십수 배)까지 토큰을 소비한다. (싱글에이전트를 기준으로  비교해 보면 멀티에이전트는 대략 4배 수준이다.)
# - **오류 전파(error propagation):** 한 에이전트의 오류가 다음 단계로 쉽게 번진다.
# - **디버깅 난이도:** 여러 주체의 비결정적(non-deterministic) 상호작용을 추적해야 하므로 재현과 디버깅이 까다롭다.
# - **맥락 단절 위험:** 서브에이전트들이 맥락을 충분히 공유하지 못하면 서로 모순되거나 일관성 없는 결과를 산출하고, 이를 합치는 과정에서 오히려 품질이 떨어질 수 있다. 즉 멀티에이전트는 만능이 아니며, 작업들이 서로 긴밀하게 의존해 **맥락 공유가 필수적인 경우**라면 무리하게 쪼개기보다 싱글에이전트로 두는 편이 오히려 안정적이다.
#
# ## 어떤 에이전트를 언제 사용해야 하는가
#
# - 가장 중요한 원칙은 **"싱글에이전트로 단순하게 시작하고, 한계에 부딪히면 멀티에이전트로 확장한다"** 이다.
# - 멀티에이전트는  **비용과 복잡도가 크기 때문**에 처음부터 **멀티에이전트를 선택하는 것은 과잉설계**(**over-engineering**)가 될 수 있다.
#
# ### 싱글/멀티 에이전트 트레이드오프
#
# | 기준 | 싱글에이전트 우위 | 멀티에이전트 우위 |
# | --- | --- | --- |
# | 지연시간(응답 속도) | ✅ 빠름 | 느림 |
# | 비용(토큰) | ✅ 낮음 | 높음(채팅 대비 ~15배) |
# | 디버깅·추적 | ✅ 쉬움 | 어려움 |
# | 병렬 처리 | 불가 | ✅ 가능 |
# | 전문 영역 분담 | 어려움 | ✅ 가능 |
# | 대용량 컨텍스트 처리 | 한계 있음 | ✅ 분산 처리 가능 |
# | 긴밀한 맥락 의존 작업 | ✅ 안정적 | 부적합 |
#
# ### 싱글에이전트가 적합한 경우
#
# - 대부분의 실무 작업은 사실 싱글에이전트로 충분하다.
# - 작업의 전체 맥락이 하나의 컨텍스트 윈도우 안에 들어가고, 단계들이 순차적으로 이어져 이전 단계의 결과가 다음 판단에 곧바로 영향을 줄 때 싱글에이전트가 유리하다.
#
# ### 멀티에이전트가 적합한 경우
#
# - 작업을 여러 갈래로 **병렬 처리**할 수 있을 때.
# - 서로 다른 **전문 영역**이 필요할 때(예: 검색 전담, 코드 작성 전담, 검증 전담).
# - 정보량이 너무 많아 하나의 컨텍스트 윈도우로는 감당이 안 될 때.

# %% [markdown]
# # ReAct 패턴
# - Agent 구현의 바탕이 되는 이론.
#
# ## 개요
#
# ReAct는 **Reasoning**(추론)과 **Acting**(행동)을 결합한 AI Agent의 프롬프팅 패턴이다. 대형 언어 모델(LLM)이 단순히 답변을 생성하는 것이 아니라, '문제를 분석'하고(Reasoning)하고 그에 따라 '필요한 도구를 선택'하여 '실행'하며(Acting), '결과를 관찰'하고(Observation) '다음 추론에 반영'하는 과정을 반복하면서 문제를 해결하는 Agent 설계 방식이다.
#
# ### ReAct의 핵심 개념
#
# 전통적인 프롬프팅 방식은 질문에 대해 즉시 답변을 생성한다. 하지만 **ReAct 패턴**은 다음과 같은 순환 구조를 따른다:
#
# ```
# 질문 → 생각(Thought) → 행동(Action) → (결과)관찰(Observation) → 생각 → 행동 →  관찰 → ... → 답변
# ```
#
# - 예)
#   - 질문: "현재 서울의 날씨와 미세먼지 농도를 알려줘":
#
#     - **Thought(생각)**: 날씨 정보를 얻기 위해 날씨 API를 호출해야겠다
#     - **Action(행동)**: WeatherAPI.get_weather("서울")
#     - **Observation(관찰)**: 기온 15도, 맑음
#     - **Thought(생각)**: 이제 미세먼지 정보도 필요하다
#     - **Action(행동)**: AirQualityAPI.get_pm("서울")
#     - **Observation(관찰)**: PM10 농도 20㎍/㎥, 좋음
#     - **Answer(답변)**: 서울의 현재 날씨는 기온 15도로 맑고, 미세먼지 농도는 30㎍/㎥로 좋은 상태이다
#
# 이처럼 ReAct는 Agent가 **사고 과정을 명시적으로 드러내면서** 외부 도구를 활용하여 복잡한 문제를 해결할 수 있도록 한다.
#
# ### ReAct의 장점
#
# 1. **투명성**: Agent의 사고 과정을 추적할 수 있어 디버깅이 용이하다
# 2. **정확성**: 외부 지식과 도구를 활용하여 환각(hallucination)을 줄인다
# 3. **유연성**: 다양한 도구를 조합하여 복잡한 작업을 수행할 수 있다
# 4. **해석 가능성**: 각 단계의 추론 과정을 이해할 수 있다

# %% [markdown]
# ## 동작 단계
# ReAct 패턴은 크게 **5단계**의 순환 구조로 동작한다.
#
# 1. **질문 입력** (Question)
#      - 사용자로부터 해결해야 할 질문이나 작업을 입력받는다.
#      - 예시
#     ```bash
#      User Input: "2024년 노벨 물리학상 수상자는 누구이고, 그들의 주요 업적은 무엇인가?"
#     ```
#
# 2. **사고 단계** (Thought)
#      - 언어 모델이 사용자의 질문(요청)을 분석하고, 문제 해결을 위해 다음에 무엇을 해야 할지 추론한다.(계획을 세운다.)
#      - 이 단계에서 Agent는:
#          - 문제를 이해하고 분해한다
#          - 필요한 정보가 무엇인지 파악한다
#          - 어떤 도구를 사용해야 할지 결정한다
#          - 충분한 정보가 모였는지 판단한다
#
#        ```bash
#        Thought: 2024년 노벨 물리학상 정보는 내 학습 데이터에 없을 수 있다. 최신 정보를 검색해야 한다.
#        ```
#
# 3. **행동 단계** (Action)
#      - 사고 단계에서 결정된 계획을 바탕으로 실제 행동을 실행한다. 행동은 일반적으로 외부 도구(Tool) 호출한다.
#
#         ```bash
#         Action: 검색엔진.검색("2024 노벨 물리학상 수상자")
#         ```
#
# 4. **관찰 단계** (Observation)
#      - 행동(Acttion)의 결과를 관찰하고 얻은 정보를 확인한다.
#
#        ```bash
#        Observation: 2024년 노벨 물리학상은 John Hopfield와 Geoffrey Hinton에게 수여되었다.
#        ```
#
#  5. **반복 또는 종료**
#        - 관찰한 정보가 사용자 질문에 대한 답변을 하는데 충분하지 않다면 2번의 사고 단계로 돌아가 추가 행동을 계획한다.(사고→행동→관찰 반복)
#        - 충분한 정보가 모였다면 그 정보를 바탕으로 최종 답변을 생성한다.
#
#           ```bash
#           Thought: 수상자 이름은 알았지만 구체적인 업적 내용이 필요하다.
#
#           Action: 정보검색.Search("John Hopfield Geoffrey Hinton 노벨상 업적")
#
#           Observation: Hopfield는 연상 메모리를 위한 Hopfield 네트워크를 개발했고, Hinton은 딥러닝의 역전파 알고리즘과 볼츠만 머신을 연구했다.
#
#           Thought: 이제 질문에 답할 충분한 정보가 모였다. 답변을 생성한다.
#
#           Action: Finish("2024년 노벨 물리학상은 John Hopfield와 Geoffrey Hinton에게 수여되었다. Hopfield는 연상 메모리를 위한 Hopfield 네트워크를 개발했고, Hinton은 딥러닝의 역전파 알고리즘과 볼츠만 머신 연구로 인공신경망 발전에 기여했다.")
#           ```
#
# ### 동작 흐름도
# ![ReAct](figures/agent-ReAct.png)

# %% [markdown]
# # Tool과 Tool Calling
#
# ## Tool
#
# ### Tool이란
#
# - **Tool은 하나의 기능을 처리하는 함수이다.**
#     - Tool은 하나의 명확한 기능을 수행하도록 정의된 함수(Function) 형태의 '외부 실행 수단'이다.
#     - 대형 언어 모델'(LLM)은 본래 텍스트를 생성하는 모델'이므로, '실제 계산, 검색, 파일 처리, 데이터베이스 조회'와 같은 '현실 세계의 작업'을 직접 수행할 수 없다. 이런 실제 작업을 '대신 수행'하는 단위가 Tool이다.
# - AI Agent는 '내부'적으로 **'LLM을 추론 엔진'으로 사용해 '판단'하고 'Tool'을 '호출'해서 실행**한다.
#
# ### Tool이 필요한 이유 — LLM의 두 가지 본질적 한계
#
# LLM은 강력한 추론(reasoning) 능력을 갖추고 있지만, 두 가지 본질적인 한계를 가진다. Tool은 이 한계를 보완한다.
#
# #### 한계 1 — **외부 세계를 읽지 못한다** (Read 제약)
#
# LLM은 학습 시점에 고정된 내부 지식만 갖고 있으며, 실행 시점의 외부 정보에 스스로 접근할 수 없다.
#
# - **Knowledge Cutoff:** 학습 데이터가 마지막으로 '업데이트된 시점 이후'에 발생한 '사건이나 정보를 알지 못'한다.
# - **실시간 데이터 미접근:** 현재 주가, 날씨, 데이터베이스 레코드처럼 '매 순간 바뀌는 데이터'는 '학습 데이터 자체가 존재하지 않'는다.
# - **개인·조직 데이터 미접근:** '사용자'의 파일, 이메일, 사내 문서 등 '공개되지 않은 데이터'는 LLM이 본래 '알 수 없'다.
#
# Tool은 Web Search, DB 조회, File Reader 등을 통해 이 Read 제약을 해소한다.
#
# #### 한계 2 — **외부 세계에 영향을 줄 수 없다** (Write/Execute 제약)
#
# LLM은 텍스트를 생성할 뿐, 그 결과를 실제 세계에 반영하거나 실행할 수 없다.
#
# - **연산 부정확:** 복잡한 수치 계산은 LLM의 언어 생성 방식으로는 신뢰하기 어렵다.
# - **코드 실행 불가:** 코드를 작성할 수는 있지만, 직접 실행해 결과를 얻지는 못한다.
# - **시스템 연동 불가:** 이메일 전송, 예약, 결제, 코드 배포처럼 실제 세계에 변화를 일으키는 액션(action)을 수행할 수 없다.
#
# Tool은 Code Executor, API 호출, 메시지 전송 함수 등을 통해 이 Execute 제약을 해소한다.
#
# #### **LLM의 한계와 Tool의 대응 관계**
#
# | LLM의 한계 | 분류 | Tool의 대응 | 예시 |
# |---|---|---|---|
# | Knowledge Cutoff | Read | 최신 정보 조회 | Web Search, News API |
# | 실시간 데이터 미접근 | Read | 현재 데이터 조회 | DB Query, Weather API |
# | 개인·조직 데이터 미접근 | Read | 파일·문서 접근 | File Reader, Email Reader |
# | 연산 부정확 | Execute | 정확한 계산 위임 | Calculator, Spreadsheet |
# | 코드 실행 불가 | Execute | 코드 실행 | Python REPL, Shell |
# | 시스템 연동 불가 | Execute | 외부 시스템 액션 | REST API, 메시지 전송 |
# | 상태(state) 비저장 | Read/Write | 영속적 저장소 활용 | Memory Tool, Vector DB |
#
# ## Tool Calling 개요
# **도구 호출**(Tool Calling)은 LLM이 자체적으로 수행할 수 없는 작업을 외부 도구나 API를 활용하여 처리할 수 있게 하는 핵심 기능이다.
# 이를 통해 **LLM은 자체 지식의 한계를 넘어서는 최신 정보, 정확한 계산, 외부 시스템 제어 등의 능력을 확보**할 수 있다.
#
# - **도구 호출(Tool Calling)의 3단계**
#     1. '도구 바인딩' (Tool Binding): **LLM에 사용가능한 'tool들을 등록'한다.**
#         - LLM에게 사용 가능한 '도구 목록'과 각 '도구의 기능(설명)' 및 필요한 '입력 매개변수를 미리 정의'하여 제공한다.
#             - Tool 함수
#             - Tool 이름
#             - Tool이 수행하는 기능 설명
#             - 입력 파라미터 type과 설명
#     2. **'사용자 질의'가 들어오면 'LLM이 도구 사용 여부를 판단**'한다.
#         - LLM '자체 추론으로 해결가능'한 문제인지 'Tool을 호출해야 처리'할 수있는 문제 인지를 확인한다.
#         - **'Tool 사용이 필요'한 문제** 라고 판단하면
#           - 도구를 호출 하는 것이 아니라 '어떻게 호출'해야 하는지 '요청정보를 생성한'다.
#             - '어떤 Tool'을 사용해야 하는지, 그 'Tool에 어떤 값을 전달'해야하는지를 '응답'으로 생성한다.
#     3.  **시스템이 Tool 호출 요청정보에 따라 Tool을 실행하고 그 결과를 LLM 에게 전달**한다.
#
#      ![toolcalling_concept](figures/toolcalling_concept.png)
#
# - **TOOL Calling 예**
#     - LLM이 수학 계산을 수행해야 할 때, 직접 계산하는 대신 미리 정의된 '계산' 도구를 호출하여 정확한 결과를 얻을 수 있다.
#   	- LLM에 최신 정보를 요청하는 질문이 들어왔을 때 '검색' 도구나 'Database 연동' 도구를 사용해 최신 뉴스를 검색하거나, 특정 데이터베이스에서 정보를 조회하는 등의 작업을 수행할 수 있다.
#   	- LLM 이 작성한 결과를 google docs와 같은 문서도구나 SNS에 등록한다.
#
# ## Langchain 과 Tool calling
# - Tool calling은 대부분의 LLM 서비스가 지원한다.
#   - [Tool Calling을 지원하는 LLM 모델](https://docs.langchain.com/oss/python/integrations/chat)만 사용할 수 있다.
# - LangChain은 다양한 모델들의 도구 호출 방식을 표준화하여 일관된 인터페이스로 제공한다. 이를 통해 개발자들은 다양한 모델과 도구들을 쉽게 통합할 수있다.
#   - [Langchain Tool Calling Concept](https://docs.langchain.com/oss/python/langchain/tools)
# - Langchain 제공 Built-in tools
#     -  https://docs.langchain.com/oss/python/integrations/tools

# %% [markdown]
# # LangChain Built-in Tools 사용으로 Tool Calling 이해
#
# - Langchain은 다양한 도구들을 미리 구현해서 제공하고 있다. 이것들을 builtin tool이라고 한다.
#   - [Langchain 지원 Built tools](https://docs.langchain.com/oss/python/integrations/tools)
# - Built-In tool 뿐만 아니라 사용자 정의 Tool들을 직접 구현할 수있는 방법도 제공한다.
#
# ## Tavily API 검색 Tool
# > Tavily 웹 검색 도구 사용해 Tool calling을 이해한다.
# - **Tavily** Service: AI을 위한 웹 검색 API Service.
# - https://tavily.com/
# -  LLM과 RAG 시스템에 최적화된 검색 엔진.
#    -  기존의 일반 검색 엔진들과 달리, Tavily는 AI 애플리케이션의 요구사항에 맞춰 설계되었다.
#    -  Tavily는 최대 20개 이상의 신뢰도 높은 웹사이트에서 관련정보를 수집한다.
#    -  수집된 데이터는 AI가 관련성, 신뢰도, 최신성 등을 기준으로 평가해 가장 적합한 정보만 선별해서 요약한다.
#    -  최종적으로 이 정보는 LLM이 바로 활용할 수있도록 컨텐츠 스티펫, 요약, 출처 등의 구조화된 형태로 반환한다.
#    -  월 1000회 무료 사용 가능.
# - **Tavily API Key 받기**
#   - 회원가입 후 로그인 한다.
#   - Overview 화면에서 API Key 생성
#     - default API key 사용할 수있다.
#   - 환경변수에 등록한다.
#       - 변수이름: `TAVILY_API_KEY`
#
# ### TavilySearch
# - Langchain에서 제공하는 tool로 Tavily 의 검색 엔진 API를 사용해 검색을 수행한다.
# - 설치
#   - `pip install langchain-tavily`
# - https://docs.langchain.com/oss/python/integrations/tools/tavily_search

# %% [markdown]
# ### Exa API 검색 Tool
#
# - **Exa** Service: AI(에이전트)를 위한 검색 API Service.
# - https://exa.ai/
# - AI를 위해 웹에서 실시간 최적의 데이터를 검색해 가져오는 검색 API.
#    - 기존의 키워드 기반 검색과 달리, Exa는 **임베딩(neural) 기반 의미 검색**을 중심으로 설계되었다.
#    - 검색 시 `type` 옵션으로 "neural", "keyword", "auto" 중 검색 방식을 선택할 수 있다.
#    - `livecrawl` 옵션("always", "fallback", "never")으로 실시간 크롤링 여부를 제어할 수 있고, `text_contents_options`로 반환되는 본문 텍스트 길이도 조절할 수 있다.
#    - 단순 키워드 매칭으로는 찾기 어려운, 의미적으로 관련된 페이지를 찾는 데 강점이 있다.
#    - 회원가입 시 **$10 무료 크레딧** 제공 (첫 검색 등 특정 액션 완료 시 추가 크레딧 지급).
# - **Exa API Key 받기**
#   - 회원가입 후 로그인한다.
#   - Dashboard에서 API Key를 생성한다.
#     - default API key를 사용할 수 있다.
#   - 환경변수에 등록한다.
#       - 변수이름: `EXA_API_KEY`
#
# #### ExaSearchResults / ExaFindSimilarResults
# - Langchain에서 제공하는 tool로 Exa 의 검색 엔진 API를 사용해 검색을 수행한다.
# - `ExaSearchResults`는 LangChain 에이전트와 함께 사용해 Exa 검색을 수행할 수 있는 tool이다.
# - `ExaFindSimilarResults`는 특정 URL을 기준으로 유사한 페이지를 찾아주는 tool이다.
# - (참고) `ExaSearchRetriever`는 tool이 아닌 retriever 형태로, RAG 체인에 바로 연결해 사용할 수 있다.
# - 설치
#   - `pip install -U langchain-exa`
# - https://docs.langchain.com/oss/python/integrations/tools/exa_search
#
# > Tavily는 "키워드/출처 우선" 성격이 강해 답변에 인용을 붙이기 좋은 반면, Exa는 "의미 기반 유사도 검색"이 강점이라 애매한 자연어 설명만으로도 관련 페이지를 잘 찾아준다.

# %%
from langchain_tavily import TavilySearch
from langchain_exa import ExaSearchResults
from pprint import pprint
from dotenv import load_dotenv

load_dotenv(override=True)
# Out:
# True

# %%
query = "2026년 북중미 월드컵에서 한국팀 성적은?"
# (Built-in) Tool 생성
tavily_search = TavilySearch(
    max_results=5, # 검색 결과 수
) # Runnable(-> invoke로 호출)

# 검색 - Tool 호출(사용)
result = tavily_search.invoke(query)
pprint(result)
# Out:
# {'answer': None,
#  'follow_up_questions': None,
#  'images': [],
#  'query': '2026년 북중미 월드컵에서 한국팀 성적은?',
#  'request_id': '480122b1-2eb3-4494-9641-6d96075ec88c',
#  'response_time': 0.0,
#  'results': [{'content': '# 한국 32강 진출 좌절... 한국 축구대표팀이 결국 2026 북중미 월드컵에서 조별리그 '
#                          '탈락의 고배를 마셨다. 홍명보 감독이 이끄는 한국 대표팀은 28일(한국시간) 조별리그 K조 '
#                          '일정이 모두 마무리된 뒤 각 조 3위 팀 가운데 성적 상위 8개 팀에게 주어지는 32강 진출 '
#                          '경쟁에서 밀리며 탈락이 확정됐다. 이에 따라 J조 잔여 경기 결과와 관계없이 한국의 32강 '
#                          '진출 가능성은 사라졌다. 이번 탈락으로 한국은 1954년 스위스, 1986년 멕시코, '
#                          '1990년 이탈리아, 1994년 미국, 1998년 프랑스, 2006년 독일, 2014년 '
#                          '브라질, 2018년 러시아 대회에 이어 월드컵 본선에서 역대 아홉 번째 조별리그 탈락을 '
#                          '기록하게 됐다. 한국 축구대표팀은 25일 오전 10시(한국시간) 멕시코 누에보레온주 몬테레이 '
#                          '스타디움에서 열린 조별리그 A조 최종전에서 남아프리카공화국에 0-1로 패배했다. 앞서 한국 '
#                          '축구대표팀은 조별리그 A조 첫 경기인 체코전에서 2-1로 승리를 거뒀으나, 멕시코전에서 '
#                          '1-0으로 패배했다. 한국은 1승 2패로 승점 3점, 골득실차 -1, 그리고 2골을 기록했다. '
#                          '한국의 32강 진출 여부는 크로아티아(L조), 알제리(J조), 그리고 콩고민주공화국(K조)의 '
#                          '남은 경기 결과에 달려 있다. 세 팀이 한국보다 높은 승점을 얻지 못하거나, 승점이 같을 경우 '
#                          '골득실에서 한국에 밀려야 한국의 32강 진출 가능성이 살아날 수 있다.',
#               'raw_content': None,
#               'score': 0.76659125,
#               'title': '한국 32강 진출 결국 좌절... 역대 9번째 조별리그 탈락 - BBC News 코리아',
#               'url': 'https://www.bbc.com/korean/articles/c1ky034l732o'},
#              {'content': '2026 북중미 월드컵 한국 대표팀의 성적은? | 페노 vs 박문성은 생각이 달라 EP. '
#                          '41\n'
#                          '장르가 머니\n'
#                          '149000 subscribers\n'
#                          '641 likes\n'
#                          '109444 views\n'
#                          '4 Jun 2026\n'
#                          '대한민국 축구 대표팀의 운명을 두고, 말빨 좋은 두 해설가가 역대급 끝장 토론을 펼쳤습니다!\n'
#                          '\n'
#                          '과연 여러분은 어느 쪽 의견에 더 공감하시나요? 영상을 통해 두 해설가의 짜릿한 티키타카를 '
#                          '확인해 보세요!\n'
#                          '#월드컵 #북중미월드컵 #대한민국\n'
#                          '281 comments\n',
#               'raw_content': None,
#               'score': 0.7163977,
#               'title': '2026 북중미 월드컵 한국 대표팀의 성적은? | 페노 vs 박문성은 생각이 달라 EP. 41',
#               'url': 'https://www.youtube.com/watch?v=q4hb1bVMMOM'},
#              {'content': "[LIVE] '역대급 참사' 북중미월드컵 축구대표팀 귀국 현장 생중계/2026년 6월 "
#                          '30일(화)/KBS\n'
#                          'KBS News\n'
#                          '3650000 subscribers\n'
#                          '396 likes\n'
#                          '124345 views\n'
#                          '30 Jun 2026\n'
#                          "2026 북중미 월드컵에서 '역대급 졸전' 끝에 조별리그에서 탈락한 축구대표팀이 "
#                          '오늘(30일), 인천국제공항에 도착합니다.\n'
#                          '\n'
#                          '사상 최악의 성적을 낸 홍명보호는 별도의 귀국 행사 없이 귀국할 예정입니다.\n'
#                          '\n'
#                          '축구대표팀의 귀국 현장을 생중계로 전해드립니다.\n'
#                          '\n'
#                          '#북중미월드컵 #월드컵 #홍명보 #축구대표팀 #역대급 #참사 #졸전 #사령탑 #감독 #홍명보호 '
#                          '#김민재 #이강인 #황인범 #귀국 #인천국제공항 #생중계 #라이브\n'
#                          '\n'
#                          'Copyright ⓒ KBS. All rights reserved. 무단 전재, 재배포 및 '
#                          '이용(AI 학습 포함) 금지\n'
#                          ' \n'
#                          '\n'
#                          '▣ KBS뉴스 유튜브 구독하기 : https://goo.gl/qCWZjZ\n'
#                          '▣ KBS뉴스 유튜브 커뮤니티 : https://goo.gl/6yko39\n'
#                          '▣ KBS 뉴스  \n'
#                          '◇ PC : http://news.kbs.co.kr    \n'
#                          '◇ 모바일 : http://mn.kbs.co.kr \n'
#                          '▣ 인스타그램 : https://www.instagram.com/kbsnews    \n'
#                          '▣ 페이스북 : https://www.facebook.com/kbsnews  \n'
#                          '▣ 트위터 : https://twitter.com/kbsnews\n'
#                          '▣ 틱톡 : https://tiktok.com/@kbsnewsofficial\n'
#                          '56 comments\n',
#               'raw_content': None,
#               'score': 0.6643884,
#               'title': "[LIVE] '역대급 참사' 북중미월드컵 축구대표팀 귀국 현장 생중계/2026년 6월 "
#                        '30일(화)/KBS',
#               'url': 'https://www.youtube.com/watch?v=eIV3s_6jpk8'},
#              {'content': "By continuing, you agree to Instagram's Terms of Use "
#                          'and Privacy Policy. Video by 대한민국 축구국가대표팀 on May 16, '
#                          "2026. May be an image of text that says 'INSIDE 국제매표 "
#                          '국게해AM CAM 북중미 월드컵 26인 명단 공개 #북공미월드컵 #복공미일드컵#최종명단 # '
#                          "최종명단'. 2026 FIFA 북중미 월드컵 26인 최종 명단 공개. 🇰🇷v🇨🇿\xa0"
#                          '#체코\xa06/12(금)\xa011:00\xa0@과달라하라\xa0스타디움. 🇰🇷v🇲🇽\xa0'
#                          '#멕시코\xa06/19(금)\xa010:00\xa0@과달라하라\xa0스타디움. 🇰🇷v🇿🇦\xa0'
#                          '#남아프리카공화국\xa06/25(목)\xa010:00\xa0@몬테레이\xa0스타디움. '
#                          "sh.ohjahon4117's profile picture. delgado.barbara's "
#                          "profile picture. ___zedekiah.17____'s profile "
#                          "picture. s.hmxx7's profile picture. shinyu.tws.xq's "
#                          'profile picture. Photo by 대한민국 축구국가대표팀 on May 16, '
#                          '2026. May be an image of \u200eposter and \u200etext '
#                          "that says '\u200eKOREA ΝΑΤΙ ONAL FOOTBALL TEAM "
#                          'FINAL26 KOREANATIONALFOTSALTEAK+FNAL 26 運 KObl か יב '
#                          '13 15 सव WE WEARE ARE KOREA 한계를 넘어하나된Reds '
#                          "KOREA\u200e'\u200e\u200e. Photo by 대한민국 축구국가대표팀 on "
#                          'June 10, 2026. May be an image of text. May be an '
#                          "image of poster and text that says '금게름넘어 OHEReds "
#                          'KOREA KOREAREPUBLIC REPUBLIC XI STARTING 10:00 '
#                          '2026/05/25(THU)10:00 vs. Video by 대한민국 축구국가대표팀 on '
#                          'June 24, 2026.',
#               'raw_content': None,
#               'score': 0.65914243,
#               'title': 'Instagram',
#               'url': 'https://www.instagram.com/reel/DYZBrQMxvLs'},
#              {'content': "By continuing, you agree to Instagram's Terms of Use "
#                          'and Privacy Policy. Photo by @michellee3 on June 20, '
#                          '2026. May be an image of text. • 1954 스위스 – 2패 (김용식 '
#                          '감독). • 1986 멕시코 – 1무 2패 (김정남 감독). • 1998 프랑스 – 1무 2패 '
#                          '(차범근 감독). • 2006 독일 – 1승 1무 1패 (아드보카트 감독). • 2014 '
#                          '브라질 – 1무 2패 (홍명보 감독). • 2018 러시아 – 1승 2패 (신태용 감독). • '
#                          '2026 북중미 – 홍명보 감독 2기. May be an image of Superman, '
#                          "poster and text that says 'WATCHOUT WAYCHOUTUNIVERSE "
#                          "WAT CHOUT UNIVERSE 安谷量 국매용도 SUPERGIRL'. May be an "
#                          'image of Superman, poster and text that says '
#                          "'SUPERGIRL SUPERG SEE ORLY ORLVINEINENAS "
#                          "OXLYINCINEMAS CINEMAS'. May be an image of poster, "
#                          "magazine and text that says 'EncoraConcert. Video by "
#                          '@michellee3 on July 03, 2026. May be an image of '
#                          'magazine, poster, book and text. May be an image of '
#                          'book, poster and text.',
#               'raw_content': None,
#               'score': 0.63452125,
#               'title': 'Instagram',
#               'url': 'https://www.instagram.com/p/DZzQ5Xtxpl2'}]}
# Failed to get info from https://apissmith.langchain.com: LangSmithConnectionError('Connection error caused failure to GET /info in LangSmith API. Please confirm your LANGCHAIN_ENDPOINT. ConnectionError(MaxRetryError(\'HTTPSConnectionPool(host=\\\'apissmith.langchain.com\\\', port=443): Max retries exceeded with url: /info (Caused by NameResolutionError("HTTPSConnection(host=\\\'apissmith.langchain.com\\\', port=443): Failed to resolve \\\'apissmith.langchain.com\\\' ([Errno 11001] getaddrinfo failed)"))\'))\nContent-Length: None\nAPI Key: lsv2_********************************************74')
# Run compression is not enabled. Please update to the latest version of LangSmith. Falling back to regular multipart ingestion.
# Failed to multipart ingest runs: Connection error caused failure to POST https://apissmith.langchain.com/runs/multipart in LangSmith API. Please confirm your LANGCHAIN_ENDPOINT. ConnectionError(MaxRetryError('HTTPSConnectionPool(host=\'apissmith.langchain.com\', port=443): Max retries exceeded with url: /runs/multipart (Caused by NameResolutionError("HTTPSConnection(host=\'apissmith.langchain.com\', port=443): Failed to resolve \'apissmith.langchain.com\' ([Errno 11001] getaddrinfo failed)"))'))
# Content-Length: 8759
# API Key: lsv2_********************************************74trace=019f3a91-ef72-7702-85ca-680ed73c6e3f,id=019f3a91-ef72-7702-85ca-680ed73c6e3f

# %%
exa_search = ExaSearchResults(max_results=5) # Tool 생성
result2 = exa_search.invoke(query) # Tool 호출
pprint(result2)
# Out:
# SearchResponse(results=[Result(url='https://www.yna.co.kr/view/AKR20260628020651007',
#                                id='https://www.yna.co.kr/view/AKR20260628020651007',
#                                title="[월드컵] 홍명보호, 하늘도 버렸다…사흘 '희망 고문' 끝에 32강행 "
#                                      '좌절(종합) | 연합뉴스',
#                                score=None,
#                                published_date='2026-06-28T01:48:49.000Z',
#                                author='오명언',
#                                image='https://img6.yna.co.kr/photo/yna/YH/2026/06/25/PYH2026062523480001300_P4.jpg',
#                                favicon=None,
#                                subpages=None,
#                                extras=None,
#                                text="[월드컵] 홍명보호, 하늘도 버렸다…사흘 '희망 고문' 끝에 32강행 "
#                                     '좌절(종합) | 연합뉴스\n'
#                                     '\n'
#                                     '연합뉴스본문 바로가기 메뉴 바로가기\n'
#                                     '\n'
#                                     '국가기간뉴스 통신사 연합뉴스국가기간뉴스 통신사 연합뉴스\n'
#                                     '\n'
#                                     '마이페이지로그인검색창 열기 메뉴 열기\n'
#                                     '\n'
#                                     '국가기간뉴스 통신사 연합뉴스국가기간뉴스 통신사 연합뉴스\n'
#                                     '\n'
#                                     "[월드컵] 홍명보호, 하늘도 버렸다…사흘 '희망 고문' 끝에 32강행 "
#                                     '좌절(종합)\n'
#                                     '\n'
#                                     '북마크 공유 댓글 글자크기 프린트제보\n'
#                                     '\n'
#                                     '마이페이지로그인검색창 열기 메뉴 열기\n'
#                                     '\n'
#                                     '오명언기자 구독 구독중\n'
#                                     '\n'
#                                     '이전 다음\n'
#                                     '\n'
#                                     '## 통산 3번째 원정 16강 도전 일찌감치 실패, 역대 9번째 조별리그 '
#                                     '탈락 고배\n'
#                                     '\n'
#                                     '## 최종 성적 33위 혹은 34위…예전 32개 참가 대회 기준 본선도 못 '
#                                     '오른 성적\n'
#                                     '\n'
#                                     '이미지 확대\n'
#                                     '\n'
#                                     '‘이런’\n'
#                                     '\n'
#                                     '(몬테레이=연합뉴스) 신준희 기자 = 한국 축구 국가대표팀 홍명보 감독이 '
#                                     '24일(현지시간) 멕시코 몬테레이 스타디움에서 열린 2026 북중미 월드컵 '
#                                     'A조 3차전 남아프리카공화국과의 경기에서 어두운 표정을 하고 있다. '
#                                     '2026.6.25 hama@yna.co.kr\n'
#                                     '\n'
#                                     "(과달라하라=연합뉴스) 오명언 기자 = 홍명보호가 사흘의 '희망 고문' "
#                                     '끝에 2026 북중미 월드컵 조별리그 탈락의 굴욕을 맛봤다.\n'
#                                     '\n'
#                                     '홍명보 감독이 지휘해온 한국 축구대표팀은 28일(이하 한국시간) 대회 '
#                                     '조별리그 K조 경기 결과 조 3위 팀 간 경쟁에서 32강 진출 마지노선인 '
#                                     '8위 밖으로 밀려났다.\n'
#                                     '\n'
#                                     '이날 남은 J조 경기 결과와 관계없이 한국의 탈락은 확정됐다.\n'
#                                     '\n'
#                                     '한국 축구가 월드컵 조별리그를 통과하지 못한 건 2018년 러시아 대회 '
#                                     '이후 8년 만의 일이다.\n'
#                                     '\n'
#                                     '홍명보호는 2010년 남아공(16강), 2022년 카타르(16강) 대회에 '
#                                     '이어 통산 3번째이자 2회 연속 원정 16강 진출에 도전했으나 뜻을 이루지 '
#                                     '못했다.\n'
#                                     '\n'
#                                     '한국이 월드컵에서 조별리그 탈락한 건 1954년 스위스, 1986년 '
#                                     '멕시코, 1990년 이탈리아, 1994년 미국, 1998년 프랑스, '
#                                     '2006년 독일, 2014년 브라질, 2018년 러시아 대회에 이어 이번이 '
#                                     '9번째다.\n'
#                                     '\n'
#                                     '이미지 확대\n'
#                                     '\n'
#                                     '아쉬워하는 손흥민\n'
#                                     '\n'
#                                     '(몬테레이=연합뉴스) 신준희 기자 = 한국 축구 국가대표팀 주장 손흥민이 '
#                                     '24일(현지시간) 멕시코 몬테레이 스타디움에서 열린 2026 북중미 월드컵 '
#                                     'A조 3차전 남아프리카공화국과의 경기에서 0대1로 패배한 뒤 아쉬워 하고 '
#                                     '있다. 2026.6.25 hama@yna.co.kr\n'
#                                     '\n'
#                                     '한국은 J조 결과에 따라 33위 혹은, 34위의 최종 성적표를 받아 '
#                                     '든다.\n'
#                                     '\n'
#                                     '이번 대회에서 처음으로 참가국이 48개국으로 확대됐다. 32개국이 경쟁한 '
#                                     '예전 대회 기준으로 따지면 본선 진출도 해내지 못한 거나 마찬가지인, '
#                                     '처참한 성적이다.\n'
#                                     '\n'
#                                     '2014년 브라질 대회에서 대표팀을 이끌고 1무 2패의 성적을 내 '
#                                     "2002년 한일 대회 '4강 신화'의 주역에서 '실패의 아이콘'으로 "
#                                     '전락했던 홍 감독은 사령탑으로 받은 두 번째 월드컵 기회도 성공으로 마무리 '
#                                     '짓지 못하며 다시 한번 추락할 위기에 놓였다.\n'
#                                     '\n'
#                                     '특히 대회를 불과 1년 앞두고 지휘봉을 잡았던 브라질 대회와 달리 이번에는 '
#                                     '개막을 2년 앞두고 선임돼 충분한 준비 시간이 있었다.\n'
#                                     '\n'
#                                     '이미지 확대\n'
#                                     '\n'
#                                     '작전 지시하는 홍명보 감독\n'
#                                     '\n'
#                                     '(몬테레이=연합뉴스) 류영석 기자 = 24일(현지시간) 멕시코 몬테레이 '
#                                     '스타디움에서 열린 2026 북중미 월드컵 A조 3차전 남아프리카공화국과의 '
#                                     '경기. 홍명보 감독이 선수들에게 작전을 지시하고 있다. 2026.6.25 '
#                                     'ondol@yna.co.kr\n'
#                                     '\n'
#                                     '조별리그 A조로 묶인 한국은 지난 12일 체코와 1차전에서 2-1 역전승을 '
#                                     "거뒀으나 19일 '개최국' 멕시코와의 2차전에선 선전을 펼치고도 수비 "
#                                     '실수에 실점하며 0-1로 석패했다.\n'
#                                     '\n'
#                                     '1, 2차전 장소이자 베이스캠프를 둔 멕시코 과달라하라를 떠나 몬테레이에서 '
#                                     '25일 치른 남아프리카공화국과 마지막 3차전에서 졸전 끝에 0-1로 '
#                                     '충격적인 패배를 당하면서 홍명보호는 승점 3에 머물며 조 3위로 '
#                                     '떨어졌다.\n'
#                                     '\n'
#                                     '한국은 26∼28일 사흘에 걸쳐 다른 조 결과를 초조하게 기다려야 했다.\n'
#                                     '\n'
#                                     '남아공전 직후 기준으로 한국은 3위 간 순위에서 4위로 높은 축이라 32강 '
#                                     '진출 가능성은 작지 않아 보였다.\n'
#                                     '\n'
#                                     "이어진 9개 조 경기에서 한국에 유리한 '경우의 수'가 3개만 실현돼도 "
#                                     '한국은 다음 단계로 나아갈 수 있었다.\n'
#                                     '\n'
#                                     '이미지 확대\n'
#                                     '\n'
#                                     '한국, 32강 자력진출 실패\n'
#                                     '\n'
#                                     '(몬테레이=연합뉴스) 신준희 기자 = 한국 축구 국가대표팀 손흥민 등 '
#                                     '선수들이 24일(현지시간) 멕시코 몬테레이 스타디움에서 열린 2026 '
#                                     '북중미 월드컵 A조 3차전 남아프리카공화국과의 경기에서 0대1로 패배한 뒤 '
#                                     '아쉬워하고 있다. 2026.6.25 hama@yna.co.kr\n'
#                                     '\n'
#                                     '그러나 이후 사흘에 걸쳐 K조까지 8개 조 경기가 치러지는 동안 한국에 '
#                                     '유리한 결과가 나온 건 27일 경기에서 스페인이 우루과이에 이긴 것 '
#                                     '하나뿐이었다.\n'
#                                     '\n'
#                                     '이날 K조에서 우즈베키스탄이 콩고민주공화국에 1-3으로 역전패하면서 한국의 '
#                                     "탈락은 확정됐다. '하늘'도 홍명보호를 버린 셈이다.\n"
#                                     '\n'
#                                     "이번이 4번째 월드컵 무대였던 한국 축구의 '캡틴' 손흥민(LAFC)은 "
#                                     "확연한 '에이징 커브'를 그리며 공격포인트 '제로'에 그쳤다.\n"
#                                     '\n'
#                                     '한 골만 넣었다면 안정환, 박지성을 넘어 한국인 월드컵 최다 4골 신기록을 '
#                                     '쓸 수 있었지만, 한국이 32강 진출에 실패하면서 더는 기회가 주어지지 '
#                                     '않았다.\n'
#                                     '\n'
#                                     '이미지 확대\n'
#                                     '\n'
#                                     '아쉬운 패배\n'
#                                     '\n'
#                                     '(몬테레이=연합뉴스) 류영석 기자 = 24일(현지시간) 멕시코 몬테레이 '
#                                     '스타디움에서 열린 2026 북중미 월드컵 A조 3차전 한국과 '
#                                     '남아프리카공화국의 경기. 한국의 손흥민이 0-1 경기 종료 후 아쉬운 '
#                                     '표정을 짓고 있다. 2026.6.25 ondol@yna.co.kr\n'
#                                     '\n'
#                                     'coup@yna.co.kr\n'
#                                     '\n'
#                                     '관련 뉴스\n'
#                                     '\n'
#                                     '- [2보][월드컵] 한국, 8년 만에 조별리그 탈락…32강 진출 끝내 '
#                                     '좌절\n'
#                                     '- [월드컵] 오늘이 마지막일지 모르지만…32강 간절한 홍명보호 묵묵히 '
#                                     '훈련\n'
#                                     '- [월드컵] 한국, 32강 가면 독일 피해 G조 1위와 시애틀서 격돌\n'
#                                     '- [월드컵] 한국, 32강 가면 벨기에와 격돌…확률은 30%대까지 '
#                                     '추락(종합)\n'
#                                     '\n'
#                                     '제보는 카카오톡 okjebo<저작권자(c) 연합뉴스, 무단 전재-재배포, '
#                                     'AI 학습 및 활용 금지>\n'
#                                     '\n'
#                                     '댓글\n'
#                                     '\n'
#                                     '좋아요 슬퍼요 화나요 후속요청\n'
#                                     '\n'
#                                     '북마크\n'
#                                     '\n'
#                                     '공유\n'
#                                     '\n'
#                                     '공유하기\n'
#                                     '\n'
#                                     '카카오톡 페이스북 X 페이스북 메신저 네이버 밴드 URL 복사\n'
#                                     '\n'
#                                     '닫기\n'
#                                     '\n'
#                                     'URL이 복사되었습니다.\n'
#                                     '\n'
#                                     '댓글\n'
#                                     '\n'
#                                     '글자크기\n'
#                                     '\n'
#                                     '본문 글자 크기 조정\n'
#                                     '\n'
#                                     '폰트 1단계 13px 폰트 2단계 16px 폰트 3단계 18px 폰트 '
#                                     '4단계 20px 폰트 5단계 22px\n'
#                                     '\n'
#                                     '닫기\n'
#                                     '\n'
#                                     '유럽인들이 노점서 떡볶이를 먹는다\n'
#                                     '\n'
#                                     "[베네수 강진] 유기견서 구조견으로…베네수 국민의 희망이 된 '쓰나미'\n"
#                                     '\n'
#                                     '80년 계엄, 김종필 불법구금…장녀에게 1억4천만원 국가배상\n'
#                                     '\n'
#                                     '코스피 150배·삼전닉스 50배에 뭉칫돈…"무법지대 도박판"\n'
#                                     '\n'
#                                     "[월드컵] 네덜란드 공격수 학포, '둘째 유산' 비보에도 32강 준비\n"
#                                     '\n'
#                                     '"스마트폰 걷었더니 서울대 대박"…\'폰프리스쿨\' 성공 사례 주목\n'
#                                     '\n'
#                                     '"경찰에 밥 사고 싶다" K-치안에 감탄한 젠슨 황 가족\n'
#                                     '\n'
#                                     '"구청인데 소화기 사세요"…고령 자영업자 울리는 신종사기 비상\n'
#                                     '\n'
#                                     '이전 콘텐츠 다음 콘텐츠\n'
#                                     '\n'
#                                     '[영상] 흙먼지속 아기, 눈만 껌벅이던 강아지…참혹 현장속 기적의 순간\n'
#                                     '\n'
#                                     '[영상] 냉방기기 품귀·대규모 정전…기록적 폭염에 신음하는 유럽\n'
#                                     '\n'
#                                     "[영상] '핵 올인' 김정은, 트럼프와 담판 시도할 유일한 변수\n"
#                                     '\n'
#                                     '이전 콘텐츠 다음 콘텐츠\n'
#                                     '\n'
#                                     "[월드컵] 홍명보호, 하늘도 버렸다… 사흘 '희망 고문' 끝에 32강행 "
#                                     '좌절\n'
#                                     '\n'
#                                     '美·이란, 연이틀 무력공방…트럼프 "이란 존재하지 않을 수도"\n'
#                                     '\n'
#                                     '베네수 강진후 72시간 골든타임 지나…구조현장엔 희망·절망 교차\n'
#                                     '\n'
#                                     '6월 한달 내내 출렁인 코스피…실적 시즌 7월에는 다를까\n'
#                                     '\n'
#                                     '이전 콘텐츠 다음 콘텐츠\n'
#                                     '\n'
#                                     '### 랭킹뉴스\n'
#                                     '\n'
#                                     '- 많이 본 뉴스\n'
#                                     '- 공감 많은 뉴스\n'
#                                     '\n'
#                                     '한국, 해상 연합훈련 림팩서 첫 해군 지휘\n'
#                                     '\n'
#                                     "'최악 지진' 베네수엘라…참혹 현장 속 '기적의 순간'\n"
#                                     '\n'
#                                     '화면 상단으로 이동\n'
#                                     '\n'
#                                     '뉴스레터연합뉴스 Games APP설치\n'
#                                     '\n'
#                                     '뉴스\n'
#                                     '\n'
#                                     '정치메뉴 열기/닫기\n'
#                                     '\n'
#                                     '북한메뉴 열기/닫기\n'
#                                     '\n'
#                                     '경제메뉴 열기/닫기\n'
#                                     '\n'
#                                     '마켓+메뉴 열기/닫기\n'
#                                     '\n'
#                                     '산업메뉴 열기/닫기\n'
#                                     '\n'
#                                     '사회메뉴 열기/닫기\n'
#                                     '\n'
#                                     '전국메뉴 열기/닫기\n'
#                                     '\n'
#                                     '세계메뉴 열기/닫기\n'
#                                     '\n'
#                                     '문화메뉴 열기/닫기\n'
#                                     '\n'
#                                     '건강메뉴 열기/닫기\n'
#                                     '\n'
#                                     '연예메뉴 열기/닫기\n'
#                                     '\n'
#                                     '스포츠메뉴 열기/닫기\n'
#                                     '\n'
#                                     '사람들메뉴 열기/닫기\n'
#                                     '\n'
#                                     '뉴스+ 메뉴 열기/닫기\n'
#                                     '\n'
#                                     '비주얼뉴스메뉴 열기/닫기\n'
#                                     '\n'
#                                     '테마별뉴스 메뉴 열기/닫기\n'
#                                     '\n'
#                                     '외국어 뉴스\n'
#                                     '\n'
#                                     '뉴스상품\n'
#                                     '\n'
#                                     '출판물\n'
#                                     '\n'
#                                     '서비스안내\n'
#                                     '\n'
#                                     '- 서비스 소개\n'
#                                     '- 모바일앱 안내\n'
#                                     '\n'
#                                     'SNS\n'
#                                     '\n'
#                                     '다양한 채널에서 연합뉴스를 만나보세요!\n'
#                                     '\n'
#                                     '뉴스 검색어 입력 양식\n'
#                                     '\n'
#                                     '통합 검색 삭제 검색\n'
#                                     '\n'
#                                     '전체메뉴 닫기\n'
#                                     '\n'
#                                     '뉴스\n'
#                                     '\n'
#                                     '정치메뉴 열기/닫기\n'
#                                     '\n'
#                                     '북한메뉴 열기/닫기\n'
#                                     '\n'
#                                     '경제메뉴 열기/닫기\n'
#                                     '\n'
#                                     '마켓+메뉴 열기/닫기\n'
#                                     '\n'
#                                     '산업메뉴 열기/닫기\n'
#                                     '\n'
#                                     '사회메뉴 열기/닫기\n'
#                                     '\n'
#                                     '전국메뉴 열기/닫기\n'
#                                     '\n'
#                                     '세계메뉴 열기/닫기\n'
#                                     '\n'
#                                     '문화메뉴 열기/닫기\n'
#                                     '\n'
#                                     '건강메뉴 열기/닫기\n'
#                                     '\n'
#                                     '연예메뉴 열기/닫기\n'
#                                     '\n'
#                                     '스포츠메뉴 열기/닫기\n'
#                                     '\n'
#                                     '사람들메뉴 열기/닫기\n'
#                                     '\n'
#                                     '뉴스+ 메뉴 열기/닫기\n'
#                                     '\n'
#                                     '비주얼뉴스메뉴 열기/닫기\n'
#                                     '\n'
#                                     '테마별뉴스 메뉴 열기/닫기\n'
#                                     '\n'
#                                     '외국어 뉴스\n'
#                                     '\n'
#                                     '뉴스상품\n'
#                                     '\n'
#                                     '출판물\n'
#                                     '\n'
#                                     '서비스안내\n'
#                                     '\n'
#                                     '- 서비스 소개\n'
#                                     '- 모바일앱 안내\n'
#                                     '\n'
#                                     'SNS\n'
#                                     '\n'
#                                     '다양한 채널에서 연합뉴스를 만나보세요!\n'
#                                     '\n'
#                                     'ESC 닫기\n'
#                                     '\n'
#                                     '이미지 확대\n'
#                                     '\n'
#                                     '‘이런’\n'
#                                     '\n'
#                                     '(몬테레이=연합뉴스) 신준희 기자 = 한국 축구 국가대표팀 홍명보 감독이 '
#                                     '24일(현지시간) 멕시코 몬테레이 스타디움에서 열린 2026 북중미 월드컵 '
#                                     'A조 3차전 남아프리카공화국과의 경기에서 어두운 표정을 하고 있다. '
#                                     '2026.6.25 hama@yna.co.kr\n'
#                                     '\n'
#                                     '2026-06-27 19:29\n'
#                                     '\n'
#                                     '이미지 확대\n'
#                                     '\n'
#                                     '아쉬워하는 손흥민\n'
#                                     '\n'
#                                     '(몬테레이=연합뉴스) 신준희 기자 = 한국 축구 국가대표팀 주장 손흥민이 '
#                                     '24일(현지시간) 멕시코 몬테레이 스타디움에서 열린 2026 북중미 월드컵 '
#                                     'A조 3차전 남아프리카공화국과의 경기에서 0대1로 패배한 뒤 아쉬워 하고 '
#                                     '있다. 2026.6.25 hama@yna.co.kr\n'
#                                     '\n'
#                                     '2026-06-27 19:43\n'
#                                     '\n'
#                                     '이미지 확대\n'
#                                     '\n'
#                                     '작전 지시하는 홍명보 감독\n'
#                                     '\n'
#                                     '(몬테레이=연합뉴스) 류영석 기자 = 24일(현지시간) 멕시코 몬테레이 '
#                                     '스타디움에서 열린 2026 북중미 월드컵 A조 3차전 남아프리카공화국과의 '
#                                     '경기. 홍명보 감독이 선수들에게 작전을 지시하고 있다. 2026.6.25 '
#                                     'ondol@yna.co.kr\n'
#                                     '\n'
#                                     '2026-06-27 19:43\n'
#                                     '\n'
#                                     '이미지 확대\n'
#                                     '\n'
#                                     '한국, 32강 자력진출 실패\n'
#                                     '\n'
#                                     '(몬테레이=연합뉴스) 신준희 기자 = 한국 축구 국가대표팀 손흥민 등 '
#                                     '선수들이 24일(현지시간) 멕시코 몬테레이 스타디움에서 열린 2026 '
#                                     '북중미 월드컵 A조 3차전 남아프리카공화국과의 경기에서 0대1로 패배한 뒤 '
#                                     '아쉬워하고 있다. 2026.6.25 hama@yna.co.kr\n'
#                                     '\n'
#                                     '2026-06-27 19:44\n'
#                                     '\n'
#                                     '이미지 확대\n'
#                                     '\n'
#                                     '아쉬운 패배\n'
#                                     '\n'
#                                     '(몬테레이=연합뉴스) 류영석 기자 = 24일(현지시간) 멕시코 몬테레이 '
#                                     '스타디움에서 열린 2026 북중미 월드컵 A조 3차전 한국과 '
#                                     '남아프리카공화국의 경기. 한국의 손흥민이 0-1 경기 종료 후 아쉬운 '
#                                     '표정을 짓고 있다. 2026.6.25 ondol@yna.co.kr\n'
#                                     '\n'
#                                     '2026-06-27 19:44\n'
#                                     '\n'
#                                     '이전 콘텐츠 다음 콘텐츠\n'
#                                     '\n'
#                                     '메뉴 열기/닫기\n'
#                                     '\n'
#                                     '이전 콘텐츠 다음 콘텐츠\n'
#                                     '\n'
#                                     '본문으로 돌아가기\n'
#                                     '\n'
#                                     '댓글 닫기',
#                                highlights=None,
#                                highlight_scores=None,
#                                summary=None),
#                         Result(url='https://www.hankyung.com/article/2026062821597',
#                                id='https://www.hankyung.com/article/2026062821597',
#                                title='홍명보호, 북중미 월드컵 최종 34위 마감…역대 최저 순위 | 한국경제',
#                                score=None,
#                                published_date='2026-06-28T06:22:55.000Z',
#                                author=None,
#                                image=None,
#                                favicon=None,
#                                subpages=None,
#                                extras=None,
#                                text='# 홍명보호, 북중미 월드컵 최종 34위 마감…역대 최저 순위 | '
#                                     '한국경제\n'
#                                     '\n'
#                                     'Published: 2026-06-28T15:22:55+09:00\n'
#                                     'Source: hankyung.com (hankyung.com)\n'
#                                     'Language: ko\n'
#                                     '\n'
#                                     '## Story\n'
#                                     '\n'
#                                     '홍명보호, 북중미 월드컵 최종 34위 마감…역대 최저 순위 | 한국경제\n'
#                                     '\n'
#                                     '본문 바로가기\n'
#                                     '\n'
#                                     '전체메뉴\n'
#                                     '\n'
#                                     '통합검색\n'
#                                     '\n'
#                                     '한국경제 통합검색\n'
#                                     '\n'
#                                     '검색어 삭제\n'
#                                     '\n'
#                                     '검색\n'
#                                     '\n'
#                                     '검색창 닫기\n'
#                                     '\n'
#                                     '[![한국경제](https://hkstatic.hankyung.com/resource/common/img/logo/logo-hk-short.svg)](https://www.hankyung.com/)\n'
#                                     '\n'
#                                     '[신문 '
#                                     '구독](https://members.hankyung.com/?utm_source=dotcom&utm_medium=top&utm_campaign=affiliate)\n'
#                                     '\n'
#                                     '한경 프리미엄9 구독\n'
#                                     '\n'
#                                     '[로그인](https://member.hankyung.com/apps.frame/login)\n'
#                                     '\n'
#                                     'My한경\n'
#                                     '\n'
#                                     '[한국경제](https://www.hankyung.com/)전체메뉴 닫기\n'
#                                     '\n'
#                                     '그룹별 가나다순\n'
#                                     '\n'
#                                     '미디어그룹\n'
#                                     '\n'
#                                     '최근 사용 메뉴\n'
#                                     '\n'
#                                     '전문채널\n'
#                                     '\n'
#                                     '특정 주제에 집중한 한경의 전문 콘텐츠 서비스\n'
#                                     '\n'
#                                     '# 트렌드\n'
#                                     '\n'
#                                     '[https://www.hankyung.com/trend](https://www.hankyung.com/trend)\n'
#                                     '\n'
#                                     '- '
#                                     '[핫피플](https://www.hankyung.com/trend/hotpeople)\n'
#                                     '- '
#                                     '[연예](https://www.hankyung.com/trend/entertainment)\n'
#                                     '- '
#                                     '[건강](https://www.hankyung.com/trend/health)\n'
#                                     '- '
#                                     '[음식맛집](https://www.hankyung.com/trend/food)\n'
#                                     '- '
#                                     '[여행레저](https://www.hankyung.com/trend/tour)\n'
#                                     '- '
#                                     '[날씨](https://www.hankyung.com/trend/weather)\n'
#                                     '- '
#                                     '[스포츠](https://www.hankyung.com/trend/sports)\n'
#                                     '- '
#                                     '[연예포토](https://www.hankyung.com/trend/celebrity-photo)\n'
#                                     '- [트렌드 '
#                                     '일반](https://www.hankyung.com/trend/trend-others)\n'
#                                     '\n'
#                                     '[트렌드](https://www.hankyung.com/trend)\n'
#                                     '\n'
#                                     '[한경 PREMIUM9 AI를 넘어서는 성공투자 '
#                                     '구독하기](https://www.hankyung.com/premium9/open-event)\n'
#                                     '\n'
#                                     '# 홍명보호, 북중미 월드컵 최종 34위 마감…역대 최저 순위\n'
#                                     '\n'
#                                     '입력2026.06.28 15:22 수정2026.06.28 15:25\n'
#                                     '\n'
#                                     '기사 스크랩\n'
#                                     '\n'
#                                     '기사 스크랩\n'
#                                     '\n'
#                                     '댓글\n'
#                                     '\n'
#                                     '댓글\n'
#                                     '\n'
#                                     '기사 공유\n'
#                                     '\n'
#                                     '공유\n'
#                                     '\n'
#                                     '글자크기 조절\n'
#                                     '\n'
#                                     '글자크기\n'
#                                     '\n'
#                                     '프린트\n'
#                                     '\n'
#                                     '프린트\n'
#                                     '\n'
#                                     '[![박상경 '
#                                     '](https://hkstatic.hankyung.com/resource/common/img/thumb/thumb-profile.svg)](https://www.hankyung.com/reporter/6143)\n'
#                                     '\n'
#                                     '[박상경](https://www.hankyung.com/reporter/6143)기자 '
#                                     '구독하기\n'
#                                     '\n'
#                                     '[구글 검색 선호 출처로 '
#                                     '추가](https://www.google.com/preferences/source?q=hankyung.com)\n'
#                                     '\n'
#                                     'Google 검색에서 한국경제 기사를 더 자주 볼 수 있습니다.\n'
#                                     '\n'
#                                     '조별리그 1승 2패 조 3위 마감 각 조 3위 상위 8개 팀에 들지 못해 '
#                                     '탈락 확정 홍명보 감독 "데이터로도 경기력 저하 원인 찾기 어려워"\n'
#                                     '\n'
#                                     '![사진=뉴스1](https://img.hankyung.com/photo/202606/ZN.44828316.1.jpg)\n'
#                                     '\n'
#                                     '사진=뉴스1 홍명보 감독이 이끄는 한국 축구대표팀이 2026 '
#                                     '국제축구연맹(FIFA) 북중미 월드컵에서 32강 토너먼트 진출에 실패하며 '
#                                     '최종 순위 34위로 대회를 마감했다.28일 한국은 이번 대회 조별리그 '
#                                     'A조에서 1승 2패(승점 3·득실 차 -1)를 기록하며 조 3위로 '
#                                     '조별리그를 마쳤다. 이번 대회부터 본선 출전국이 32개국에서 48개국으로 '
#                                     '확대 개편되면서 각 조 1·2위 24개 팀과 조 3위 12개 팀 중 상위 '
#                                     '8개 팀이 32강 토너먼트에 진출하는 구조였다. 그러나 조별리그 최종일 '
#                                     '경기 결과 한국은 조 3위 팀 중 10위에 그치며 탈락이 확정됐다.이에 '
#                                     '따라 한국의 최종 순위는 48개 참가국 중 34위가 됐다. 이는 16개국이 '
#                                     '출전해 최하위를 기록했던 1954년 스위스 대회를 제외하고, 조별리그 제도 '
#                                     '도입 이후 종전 최저 순위였던 1998년 프랑스 대회(30위)보다 낮은 '
#                                     '역대 최저 성적이다. 홍 감독 체제 1기였던 2014년 브라질 대회 당시 '
#                                     '최종 순위는 27위였다. 한국 축구의 조별리그 탈락은 2018년 러시아 '
#                                     '대회 이후 8년 만이며 통산 9번째다.한국은 조별리그 1차전에서 체코를 '
#                                     '상대로 황인범(페예노르트)과 오현규(베식타시)의 연속골에 힘입어 2-1 '
#                                     '역전승을 거두며 출발했다. 그러나 개최국 멕시코와의 2차전에서 후반 5분 '
#                                     '골키퍼 김승규(FC도쿄)의 실책으로 결승골을 내주며 0-1로 패했다. 이어 '
#                                     '비기기만 해도 조 2위로 32강에 오를 수 있었던 남아프리카공화국과의 '
#                                     '최종전에서 손흥민(LAFC)이 선발 제외된 가운데 0-1로 패배하며 자력 '
#                                     "진출 기회를 놓쳤다.남아공전 패배 직후 스포츠통계업체 '옵타'는 한국의 "
#                                     '32강 진출 확률을 87%로 전망했으나, 타 조의 타임라인 및 경우의 수 '
#                                     '시뮬레이션 결과 스페인의 우루과이전 승리(1-0) 외에는 한국에 유리한 '
#                                     '결과가 나오지 않았다. 최종적으로 K조 경기에서 콩고민주공화국이 '
#                                     '우즈베키스탄에 3-1 역전승을 거두고, J조 오스트리아와 알제리가 '
#                                     '3-3으로 비기면서 한국의 탈락 및 최종 34위 순위가 확정됐다.대표팀 '
#                                     '내부에서도 경기력 저하에 대한 원인을 정밀하게 진단하지 못했다. 홍 감독은 '
#                                     '남아공전 패배 이튿날 취재진과의 인터뷰에서 "데이터로도 이유를 찾기 '
#                                     '어려웠다"며 "나도 왜 이런 경기력이 나왔는지 당황스럽다"고 '
#                                     '언급했다.선수단은 28일 저녁 식사를 함께하며 타 조 경기를 시켜본 뒤 '
#                                     '탈락이 확정됨에 따라 귀국 일정을 정리했다. 한편 이번 대회 48개 참가국 '
#                                     '중 최하위인 48위는 3패(승점 0·득실 차 -11)를 기록한 이라크가 '
#                                     '차지했으며, 1승 2패(승점 3·득실 차 0)의 이란은 33위로 대회를 '
#                                     '마쳤다.홍 감독은 오는 29일 현지 결산 기자회견을 가진 후 선수단과 함께 '
#                                     '미국을 경유해 30일 인천국제공항을 통해 귀국할 예정이다.박상경 한경닷컴 '
#                                     '기자 highseoul@hankyung.com\n'
#                                     '\n'
#                                     '좋아요 싫어요 후속기사 원해요\n'
#                                     '\n'
#                                     'ⓒ 한경닷컴, 무단전재 및 재배포 금지\n'
#                                     '\n'
#                                     '[한국경제 '
#                                     '구독신청](https://members.hankyung.com/?utm_source=dotcom&amp;utm_medium=article&utm_campaign=affiliate) '
#                                     '[한경 프리미엄9 '
#                                     '구독신청](https://www.hankyung.com/premium9/open-event)\n'
#                                     '\n'
#                                     '![박상경 '
#                                     '](https://hkstatic.hankyung.com/resource/common/img/thumb/thumb-profile.svg)\n'
#                                     '\n'
#                                     '[박상경](https://www.hankyung.com/reporter/6143)\n'
#                                     '\n'
#                                     '관련 뉴스\n'
#                                     '\n'
#                                     '[![ALICE Q 게임 '
#                                     '바로가기](https://img.hankyung.com/data/service/www.hankyung.com/articlePromotion/img/ae0b10dd5abf25a3d2cc6c0a0a9940f8.png)](https://www.hankyung.com/game)\n'
#                                     '\n'
#                                     '1\n'
#                                     '\n'
#                                     "[홍명보호, 처음으로 '귀국 행사' 생략…엿 세례 "
#                                     '걱정됐나](https://www.hankyung.com/article/2026062820617)\n'
#                                     '\n'
#                                     '2026 북중미 월드컵에서 손흥민·이강인·김민재 등 역대 최고 수준으로 '
#                                     '평가받는 멤버와 비교적 수월한 대진으로 기대감을 모았던 한국 축구대표팀이 '
#                                     '결국 32강 토너먼트 진출에 실패하고 씁쓸하게...\n'
#                                     '\n'
#                                     '2026.06.28 13:42\n'
#                                     '\n'
#                                     "[![홍명보호, 처음으로 '귀국 행사' 생략…엿 세례 "
#                                     '걱정됐나](https://img.hankyung.com/photo/202606/ZA.44793299.3.jpg)](https://www.hankyung.com/article/2026062820617)\n'
#                                     '\n'
#                                     '2\n'
#                                     '\n'
#                                     '[홍명보 감독 잘못인데, 왜 조나단에 악플…엉뚱한 '
#                                     '분풀이](https://www.hankyung.com/article/2026062820687)\n'
#                                     '\n'
#                                     '방송인 조나단이 한국의 월드컵 32강 진출이 불발된 후 악플 공격을 '
#                                     '받으면서 "엉뚱한 분풀이"라는 지적이 나오고 있다.28일 미국 조지아주 '
#                                     '애틀랜타 스타디움에서 2026 FIFA 북중미 월드컵 K조 콩고민주공화국과 '
#                                     '...\n'
#                                     '\n'
#                                     '2026.06.28 13:36\n'
#                                     '\n'
#                                     '[![홍명보 감독 잘못인데, 왜 조나단에 악플…엉뚱한 '
#                                     '분풀이](https://img.hankyung.com/photo/202606/01.44827848.3.jpg)](https://www.hankyung.com/article/2026062820687)\n'
#                                     '\n'
#                                     '3\n'
#                                     '\n'
#                                     '[박지성, 한국 32강 탈락에 "10년간 배우고도 까먹었다" '
#                                     '분노](https://www.hankyung.com/article/2026062819697)\n'
#                                     '\n'
#                                     '홍명보 감독이 이끄는 국가대표 축구팀이 2026 FIFA 북중미 월드컵 '
#                                     '32강 진출에 실패한 후 박지성 SBS 해설위원이 작심 발언을 '
#                                     '했다.박지성은 28일(한국시간) 미국 조지아주 애틀랜타 스타디움에서 열린 '
#                                     '북중미 ...\n'
#                                     '\n'
#                                     '2026.06.28 11:30\n'
#                                     '\n'
#                                     '[![박지성, 한국 32강 탈락에 "10년간 배우고도 까먹었다" '
#                                     '분노](https://img.hankyung.com/photo/202606/02.44790884.3.jpg)](https://www.hankyung.com/article/2026062819697)\n'
#                                     '\n'
#                                     '많이 본 뉴스\n'
#                                     '\n'
#                                     '1\n'
#                                     '\n'
#                                     '["다이소도 아닌데"…3만원 들고 가면 가방에 옷까지 '
#                                     '풀세팅](https://www.hankyung.com/article/202606269802g)\n'
#                                     '\n'
#                                     '2026.06.27 20:00\n'
#                                     '\n'
#                                     '[!["다이소도 아닌데"…3만원 들고 가면 가방에 옷까지 '
#                                     '풀세팅](https://img.hankyung.com/photo/202606/01.44803495.3.jpg)](https://www.hankyung.com/article/202606269802g)\n'
#                                     '\n'
#                                     '2\n'
#                                     '\n'
#                                     '["대실 안 해요" 서울 모텔 돌변한 이유가…\'돈벼락\' '
#                                     '맞았다](https://www.hankyung.com/article/2026062607161)\n'
#                                     '\n'
#                                     '2026.06.26 20:00\n'
#                                     '\n'
#                                     '[!["대실 안 해요" 서울 모텔 돌변한 이유가…\'돈벼락\' '
#                                     '맞았다](https://img.hankyung.com/photo/202606/99.44809122.3.jpg)](https://www.hankyung.com/article/2026062607161)\n'
#                                     '\n'
#                                     '3\n'
#                                     '\n'
#                                     '["집에서 삼겹살 자주 구워 먹었는데"…뜻밖의 연구 '
#                                     '결과](https://www.hankyung.com/article/2026062588137)\n'
#                                     '\n'
#                                     '2026.06.25 22:07\n'
#                                     '\n'
#                                     '[!["집에서 삼겹살 자주 구워 먹었는데"…뜻밖의 연구 '
#                                     '결과](https://img.hankyung.com/photo/202606/99.26416666.3.jpg)](https://www.hankyung.com/article/2026062588137)\n'
#                                     '\n'
#                                     '4\n'
#                                     '\n'
#                                     '[![PREMIUM9](https://hkstatic.hankyung.com/resource/www/common/img/icon/icon-premium9.svg)](https://www.hankyung.com/premium9/0102001) '
#                                     '[핫스톡](https://www.hankyung.com/premium9/0102001)\n'
#                                     '\n'
#                                     '[삼전닉스 못 샀다면…올해 소외된 대형주 10개 '
#                                     '뽑아보니](https://www.hankyung.com/article/202606260168i)\n'
#                                     '\n'
#                                     '2026.06.27 08:00\n'
#                                     '\n'
#                                     '[![삼전닉스 못 샀다면…올해 소외된 대형주 10개 '
#                                     '뽑아보니](https://img.hankyung.com/photo/202606/01.44806377.3.jpg)](https://www.hankyung.com/article/202606260168i)\n'
#                                     '\n'
#                                     '5\n'
#                                     '\n'
#                                     "['자산 26억' 58세 명퇴자, 국민연금 7년 "
#                                     "남았는데…'날벼락'](https://www.hankyung.com/article/202606260031i)\n"
#                                     '\n'
#                                     '2026.06.27 10:00\n'
#                                     '\n'
#                                     "[!['자산 26억' 58세 명퇴자, 국민연금 7년 "
#                                     "남았는데…'날벼락'](https://img.hankyung.com/photo/202606/01.44804978.3.jpg)](https://www.hankyung.com/article/202606260031i)\n"
#                                     '\n'
#                                     '이 시각 관심정보\n'
#                                     '\n'
#                                     '팝업 닫기\n'
#                                     '\n'
#                                     '글자크기\n'
#                                     '\n'
#                                     '- 1단계\n'
#                                     '- 2단계\n'
#                                     '- 3단계\n'
#                                     '- 4단계\n'
#                                     '- 5단계\n'
#                                     '\n'
#                                     '글자행간\n'
#                                     '\n'
#                                     '- 1단계\n'
#                                     '- 2단계\n'
#                                     '- 3단계\n'
#                                     '\n'
#                                     '팝업 닫기\n'
#                                     '\n'
#                                     '- 카카오톡\n'
#                                     '- 페이스북\n'
#                                     '- 엑스\n'
#                                     '- URL복사\n'
#                                     '- 네이버\n'
#                                     '- 밴드\n'
#                                     '- 메일\n'
#                                     '\n'
#                                     '팝업 닫기\n'
#                                     '\n'
#                                     '로그인이 필요한 서비스 입니다. 로그인 하시겠습니까?\n'
#                                     '\n'
#                                     '아니오 예\n'
#                                     '\n'
#                                     '한국경제신문 '
#                                     '[회사소개](https://company.hankyung.com/ked/) '
#                                     '[구독신청](https://members.hankyung.com/?utm_source=dotcom&utm_medium=footer&utm_campaign=affiliate) '
#                                     '[고충처리](https://company.hankyung.com/ked/kor/ombudsman) '
#                                     '[광고안내](https://company.hankyung.com/ked/kor/ad) '
#                                     '[블루애드](https://ooh.hankyung.com/)대표번호: '
#                                     '02-3604-114 사업자등록번호: 110-81-07390 '
#                                     '통신판매업신고번호: 중구 02559\n'
#                                     '\n'
#                                     '한경닷컴 '
#                                     '[회사소개](https://company.hankyung.com/dotcom/) '
#                                     '[제휴](https://company.hankyung.com/dotcom/partnership/business/)/ '
#                                     '[콘텐츠구입](https://company.hankyung.com/dotcom/partnership/contents/) '
#                                     '[광고안내](https://company.hankyung.com/dotcom/partnership/advertising/) '
#                                     '[사이트맵](https://www.hankyung.com/sitemap.html) '
#                                     '[고객센터](https://www.hankyung.com/help) '
#                                     '[RSS](https://www.hankyung.com/feed) '
#                                     '[이용약관](https://id.hankyung.com/user/selectAuthAgree.do) '
#                                     '[개인정보처리방침](https://id.hankyung.com/user/selectPrivacy.do) '
#                                     '[청소년보호정책(책임자: '
#                                     '이지연)](https://id.hankyung.com/user/selectYouthProtection.do)서울시 '
#                                     '중구 청파로 463 한국경제신문사 대표번호: 02-3277-9900 '
#                                     '사업자등록번호: 104-81-47984 통신판매업신고번호: 중구 00606 '
#                                     '인터넷신문등록번호: 서울 아01035 등록(발행)일자: 2009.11.23 '
#                                     '발행·편집인: 박수진 본지는 한국신문윤리위원회의 서약사로서 신문윤리강령을 '
#                                     '준수합니다.\n'
#                                     '\n'
#                                     'Copyright 1999-2026. 한경닷컴 All rights '
#                                     'reserved.\n'
#                                     '\n'
#                                     '상단 바로가기\n'
#                                     '\n'
#                                     '[내 배지 '
#                                     '보러가기](https://www.hankyung.com/myhankyung)\n'
#                                     '\n'
#                                     '팝업 닫기',
#                                highlights=None,
#                                highlight_scores=None,
#                                summary=None),
#                         Result(url='https://www.spotvnews.co.kr/news/articleView.html?idxno=825357',
#                                id='https://www.spotvnews.co.kr/news/articleView.html?idxno=825357',
#                                title="[오피셜] 손흥민의 치욕, 월드컵 마지막 기록 '남아공전 후반 교체 "
#                                      "출전' 유력...'꿀대진' 홍명보호, 월드컵 탈락 확정 < 월드컵 국외 "
#                                      '< 해외축구 < 기사본문 - SPOTV NEWS',
#                                score=None,
#                                published_date='2026-06-28T01:44:00.000Z',
#                                author='SPOTV NEWS',
#                                image='https://cdn.spotvnews.co.kr/news/thumbnail/202606/825357_1354144_4336_v150.jpg',
#                                favicon=None,
#                                subpages=None,
#                                extras=None,
#                                text="[오피셜] 손흥민의 치욕, 월드컵 마지막 기록 '남아공전 후반 교체 출전' "
#                                     "유력...'꿀대진' 홍명보호, 월드컵 탈락 확정 < 월드컵 국외 < "
#                                     '해외축구 < 기사본문 - SPOTV NEWS\n'
#                                     '\n'
#                                     '## 본문영역\n'
#                                     '\n'
#                                     '[스포티비뉴스=장하준 기자] 홍명보 감독이 이끄는 한국 축구대표팀의 '
#                                     '2026 국제축구연맹(FIFA) 북중미 월드컵 여정이 조별리그에서 막을 '
#                                     '내렸다.\n'
#                                     '\n'
#                                     '한국은 28일(한국시간) 열린 K조 경기 결과에 따라 조 3위 팀 순위 '
#                                     '경쟁에서 32강 진출 마지노선인 8위 밖으로 밀려났다. 이어 남아 있던 '
#                                     'J조 경기 결과와 상관없이 토너먼트 진출 가능성이 완전히 사라지며 조별리그 '
#                                     '탈락이 확정됐다.\n'
#                                     '\n'
#                                     '이로써 한국은 8년 만에 월드컵 조별리그 문턱을 넘지 못했다. 2018년 '
#                                     '러시아 월드컵 이후 다시 한 번 조별리그에서 대회를 마감하게 됐다.\n'
#                                     '\n'
#                                     '홍명보호는 이번 대회에서 2010년 남아프리카공화국 월드컵과 2022년 '
#                                     '카타르 월드컵에 이어 역대 세 번째 원정 16강 진출, 그리고 사상 첫 '
#                                     '원정 16강 2회 연속 달성에 도전했다. 그러나 기대했던 성과를 이루지 '
#                                     '못하며 아쉬움을 남겼다.\n'
#                                     '\n'
#                                     '한국 축구의 월드컵 조별리그 탈락은 이번이 통산 아홉 번째다. 앞서 '
#                                     '1954년 스위스, 1986년 멕시코, 1990년 이탈리아, 1994년 '
#                                     '미국, 1998년 프랑스, 2006년 독일, 2014년 브라질, 2018년 '
#                                     '러시아 월드컵에서도 조별리그를 통과하지 못한 바 있다.\n'
#                                     '\n'
#                                     '최종 순위는 J조 경기 결과에 따라 결정된다. 한국은 이번 대회를 33위 '
#                                     '또는 34위로 마칠 예정이다.\n'
#                                     '\n'
#                                     '이번 월드컵은 사상 처음으로 참가국이 48개국으로 확대돼 진행됐다. '
#                                     '그럼에도 한국은 토너먼트 진출에 실패했다. 기존 32개국 체제와 비교하면 '
#                                     '본선 진출에 버금가는 성과조차 거두지 못한 셈으로, 한국 축구에는 뼈아픈 '
#                                     '결과로 남게 됐다.\n'
#                                     '\n'
#                                     '동시에 한국 대표팀 역사상 최고의 선수로 꼽히는 손흥민은 사실상 본인의 '
#                                     '마지막 월드컵을 이렇게 마무리하게 됐다. 남아공전 후반 교체 출전은 그의 '
#                                     '마지막 월드컵 경력이 될 가능성이 커졌다.\n'
#                                     '\n'
#                                     '기자명 장하준 기자 waterjun@spotv.net\n'
#                                     '\n'
#                                     '#### 관련기사\n'
#                                     '\n'
#                                     "- '18살 차이' 장기하♥윤가이, 2년 넘게 사랑 키웠다...소속사도 "
# ...
#                                     '[AI 해설]\n'
#                                     '\n'
#                                     '2026 북중미 월드컵에서 한국 축구 대표팀이 조별리그 탈락이라는 뼈아픈 '
#                                     '성적표를 받으면서, 여러모로 아쉬운 기록들을 남기게 되었어요. 😥 특히 '
#                                     '홍명보 감독이 동일 국가 대표팀 감독으로서 월드컵 본선 조별리그에서 두 번 '
#                                     '탈락한 세계 최초의 불명예 기록을 세운 점은 충격적이죠. 2014년 브라질 '
#                                     '월드컵에서도 1무 2패로 탈락했던 경험이 있는데, 12년 만에 다시 '
#                                     '지휘봉을 잡았음에도 불구하고 2026년 대회에서 1승 2패라는 성적으로 '
#                                     '다시 한번 같은 결과를 맞이하게 된 거예요. 씁쓸한 역사인데요. 😔이번 '
#                                     '월드컵에서는 참가국이 48개국으로 확대되면서 이전보다 32강 진출의 문턱이 '
#                                     '낮아졌지만, 한국 대표팀은 34위라는 역대 최저 순위에 머물렀어요. 😭 '
#                                     '이는 1954년 첫 월드컵 출전 이후 72년 만에 가장 낮은 성적이라고 '
#                                     '하니, 한국 축구의 위기감을 더욱 고조시키고 있답니다. ⚽️ 득점력 부진도 '
#                                     '심각한 문제로 떠올랐는데, 조별리그 3경기에서 단 2골에 그치면서 '
#                                     '1998년 이후 28년 만에 가장 적은 득점을 기록했고, 특히 멕시코전과 '
#                                     '남아공전에서는 두 경기 연속 무득점에 그치는 아쉬움을 보였어요. 😥이러한 '
#                                     '결과는 단순히 감독 개인의 문제로만 볼 수는 없을 것 같아요. 🧐 관련 '
#                                     "기사들을 보면, '무전술', '불통축구', '정치권 개입 논란' 등 여러 "
#                                     '복합적인 문제들이 한국 축구의 발목을 잡고 있었음을 짐작해 볼 수 있어요. '
#                                     "📈 월드컵 본선 진출을 넘어 '경우의 수'에 기대야 하는 상황 자체가 이미 "
#                                     '위기 신호였고, 상대 팀에게 경기 방식이 간파당했다는 지적은 전술적인 '
#                                     '준비와 변화가 부족했음을 시사하고 있어요. 🤔 앞으로 한국 축구가 이 '
#                                     '위기를 어떻게 극복하고 반등할 수 있을지, 심도 깊은 논의와 쇄신이 필요한 '
#                                     '시점이라고 할 수 있습니다. 🇰🇷\n'
#                                     '\n'
#                                     '출처\n'
#                                     '\n'
#                                     '- 1.월드컵, 국민 고문만 하다 끝났다…“홍명보, 책임 어떻게 질거냐”\n'
#                                     '- 2.조별리그를 2번이나 탈락한 감독…홍명보 ‘월드컵 최초’ 불명예 기록 '
#                                     '썼다\n'
#                                     "- 3.'불통축구' 자멸\n"
#                                     '- 4.2014년 이어 또 초라한 퇴장 … 韓축구 대혼란\n'
#                                     '- 5.홍명보가 세계 최초라니…월드컵 탈락, 한국축구가 세운 불명예 기록\n'
#                                     '\n'
#                                     '### 닫기\n'
#                                     '\n'
#                                     '매일경제 회원전용 서비스 입니다.\n'
#                                     '\n'
#                                     '기존 회원은 로그인 해주시고, 아직 가입을 안 하셨다면, 무료 회원가입을 '
#                                     '통해 서비스를 이용해주세요\n'
#                                     '\n'
#                                     '전체 많이 본 기사 국제 많이 본 기사\n'
#                                     '\n'
#                                     '#### [속보] 법원, 홈플러스 회생절차 폐지 결정\n'
#                                     '\n'
#                                     '#### “이건 안 들면 진짜 손해”…‘연 19%’에 200만명 몰린 '
#                                     '‘초고금리 적금’ 오늘 마감\n'
#                                     '\n'
#                                     '#### “하이닉스 폭락 많이 놀라셨죠?”…목표가 420만 꺼내든 증권사 '
#                                     '[오늘 나온 보고서]\n'
#                                     '\n'
#                                     '#### 안 오른 종목들 많이 담았습니다…국민연금 2분기 사들인 기업은\n'
#                                     '\n'
#                                     '#### “마지막 글 될 것 같습니다”…장윤정 친모, 메시지 남기고 행방 '
#                                     '묘연\n'
#                                     '\n'
#                                     '#### 오늘의 운세 2026년 7월 3일 金(음력 5월 19일)\n'
#                                     '\n'
#                                     '#### “한국 너무 좋아요” 외쳤던 일본인 관광객, 올여름 발길 끊길 '
#                                     '수도…왜?\n'
#                                     '\n'
#                                     '#### “여기 290층인데 구조대 오나요”…메타발 쇼크에 휘청,반도체주의 '
#                                     '전망\n'
#                                     '\n'
#                                     '#### [MBN] 천하장사 백승일의 애틋한 병수발\n'
#                                     '\n'
#                                     '#### “아직도 빠질 게 더 남았나”…JP모건이 뽑은 올 여름 두 가지 '
#                                     '위험은?\n'
#                                     '\n'
#                                     '#### “한국 너무 좋아요” 외쳤던 일본인 관광객, 올여름 발길 끊길 '
#                                     '수도…왜?\n'
#                                     '\n'
#                                     '#### “이륙 15분만에 비상착륙”…여객기 안에서 탑승객이 한 짓 '
#                                     '‘경악’\n'
#                                     '\n'
#                                     '#### 31만원 에어컨에 새벽 4시부터 줄…폭염 예보에 佛 마트 북새통\n'
#                                     '\n'
#                                     '#### “우리 안도와줬지” 홍명보호 저주, 이정도면 진짜…‘경우의수’ '
#                                     '국가들, 소름\n'
#                                     '\n'
#                                     '#### 버핏도 울고 갈 트럼프의 촉?…정책 발표 직전 수백건 주식 '
#                                     '단타쳤다\n'
#                                     '\n'
#                                     '#### 인니 돈풀기 후폭풍 … 외국자본 떠난다\n'
#                                     '\n'
#                                     '#### “30분 넘게 계속 앉아 있으면 암 사망 위험 높아질 수도”\n'
#                                     '\n'
#                                     '#### “저걸 왜 가지고 간 거야”…동료 가방속 물건에 빵 터진 메시, '
#                                     '뭐길래\n'
#                                     '\n'
#                                     '#### “아들이 30만주를 가지고 있네요”…인터넷으로 총 팔아도 된다는 '
#                                     '아빠의 속내\n'
#                                     '\n'
#                                     '#### 협상하면서 뒤로는 암살 계획?…“이스라엘, 이란 대표단 탄 항공기 '
#                                     '노렸다”\n'
#                                     '\n'
#                                     '### Shorts',
#                                highlights=None,
#                                highlight_scores=None,
#                                summary=None),
#                         Result(url='https://www.mt.co.kr/sports/2026/06/30/202606291437776617O',
#                                id='https://www.mt.co.kr/sports/2026/06/30/202606291437776617O',
#                                title='"월드컵 역대급 꿀조에서 탈락" 美 매체 팩폭...\'D-\' 홍명보호 '
#                                      '성적표 나왔다 "에이스 손흥민 벤치→최약체 남아공에 패배" - 머니투데이',
#                                score=None,
#                                published_date='2026-06-29T20:25:00.000Z',
#                                author='OSEN 제공',
#                                image='https://menu.mt.co.kr/cdn-cgi/image/w=1200,h=912,fit=cover,bg=whilte,f=auto,quality=high,sharpen=2,g=face/mobile/osen/data/2026/06/29/202606291437776617_1.jpg',
#                                favicon='https://menu.mt.co.kr/common/favicons/favicon-32.ico',
#                                subpages=None,
#                                extras=None,
#                                text='"월드컵 역대급 꿀조에서 탈락" 美 매체 팩폭...\'D-\' 홍명보호 '
#                                     '성적표 나왔다 "에이스 손흥민 벤치→최약체 남아공에 패배" - 머니투데이\n'
#                                     '\n'
#                                     '로그인|회원가입\n'
#                                     '\n'
#                                     '닫기\n'
#                                     '\n'
#                                     '## "월드컵 역대급 꿀조에서 탈락" 美 매체 팩폭...\'D-\' '
#                                     '홍명보호 성적표 나왔다 "에이스 손흥민 벤치→최약체 남아공에 패배"\n'
#                                     '\n'
#                                     '2026 FIFA 북중미 월드컵 조별리그에서 탈락한 홍명보호가 미국 '
#                                     'ESPN으로부터 낙제점인 D- 성적표를 받았다. 한국은 남아프리카공화국과의 '
#                                     '조별리그 3차전에서 0-1로 패하며 32강 진출이 좌절되었고, 이에 홍명보 '
#                                     '감독은 자진 사퇴를 선언했다. ESPN은 한국이 에이스 손흥민을 선발 '
#                                     '제외하고 최약체 남아공에 경기 내용까지 밀리며 무기력하게 패배했다고 '
#                                     '지적했다.\n'
#                                     '\n'
#                                     '[OSEN=고성환 기자] 한국 축구 역사에 남을 대참사를 쓴 결과다. '
#                                     '2026 국제축구연맹(FIFA) 북중미 월드컵 조별리그에서 탈락한 '
#                                     "홍명보호가 'D-'라는 성적표를 받았다.\n"
#                                     '\n'
#                                     '미국 \'ESPN\'은 28일(이하 한국시간) "지금부터 대회가 끝날 '
#                                     '때까지 탈락한 47개 팀을 평가할 것이다. 대회 전 기대치, 대회에서 '
#                                     '보여준 경기력, 그리고 그 밖에 고려할 만한 요소들을 종합해 가장 최근 '
#                                     '탈락한 팀부터 순서대로 채점한다"라며 월드컵 조별리그에서 탈락한 팀들의 '
#                                     '성적을 매겼다.\n'
#                                     '\n'
#                                     '홍명보 감독이 이끄는 한국 축구대표팀의 최종 평점은 D-로 낙제점이었다. '
#                                     '이유는 분명하다. 조별리그 3차전에서 FIFA 랭킹 60위 '
#                                     '남아프리카공화국을 상대로 0-1로 충격패하며 32강 진출이 좌절됐기 때문. '
#                                     '남아공과 비기기만 해도 조 2위로 32강에 올라갈 수 있었지만, 최악의 '
#                                     '졸전으로 기회를 걷어찼다.\n'
#                                     '\n'
#                                     '그 여파로 홍명보 감독은 자진 사퇴를 선언했다. 그는 한국 축구 역사상 '
#                                     '최초로 두 차례 월드컵에 나서서 모두 조별리그 탈락한 지도자로 남게 '
#                                     '됐다.\n'
#                                     '\n'
#                                     'ESPN은 "최종전을 앞두고 한국은 사실상 32강에서 홈경기나 다름없는 '
#                                     '환경을 얻을 상황이었다. 경기 장소는 로스앤젤레스였고, 상대도 프랑스나 '
#                                     '아르헨티나가 아닌 충분히 해볼 만한 캐나다가 될 가능성이 컸다. 게다가 '
#                                     '캐나다 역시 홈 이점을 잃은 상태였다. 필요했던 것은 앞선 두 경기에서 '
#                                     '이번 대회 최약체로 보였던 남아공을 이기는 것뿐이었다"라고 짚었다.\n'
#                                     '\n'
#                                     '모두가 한국과 캐나다의 32강 맞대결을 점쳤지만, 남아공이 무기력한 한국을 '
#                                     '무너뜨리면서 캐나다를 만나러 갔다. 매체는 "하지만 감독은 에이스 손흥민을 '
#                                     '선발에서 제외했고, 한국은 0-1 패배를 당하는 과정에서 경기 내용까지 '
#                                     '남아공에 밀렸다. 그렇게 한국의 월드컵은 끝났다"고 전했다.\n'
#                                     '\n'
#                                     '사실 한국의 기대치를 생각하면 최하점인 F를 받아도 이상하지 않았다. '
#                                     '모두가 손흥민과 이재성, 이강인, 김민재 등을 보유한 한국의 무난한 32강 '
#                                     '진출을 점쳤다. 멕시코, 체코, 남아공과 함께 A조에 배정되면서 조 편성도 '
#                                     '역대 최고 수준이라는 평가를 받았다.\n'
#                                     '\n'
#                                     '그럼에도 D-로 참은 ESPN. 매체는 "F가 아닌 D-를 준 이유는 '
#                                     '체코전 승리에서는 꽤 좋은 경기력을 보여줬기 때문이다. 또 멕시코전에서는 '
#                                     "이번 대회 최고의 '더블 세이브'만 아니었다면 무승부를 만들 수도 있었다. "
#                                     '그 슈팅이 들어갔다면 지금 이 글을 쓰고 있지도 않았을 것이다. 하지만 '
#                                     '들어가지 않았다"고 설명했다.\n'
#                                     '\n'
#                                     '## 독자들의 PICK!\n'
#                                     '\n'
#                                     '### "24살 연하 직원과 바람난 남편...언니집까지 경매로 날렸어요"\n'
#                                     '\n'
#                                     '### "며느리가 죽는 게 낫지" 17년 버텼는데 무너진 아내…남편은 '
#                                     '방관\n'
#                                     '\n'
#                                     '### "아빠랑 하는 병원놀이" 두 딸에 몹쓸짓...언니는 세상 떠났다\n'
#                                     '\n'
#                                     '### \'15살 임신\' 싱글맘 "아이 낳자 돌변한 남친...양육비도 안 '
#                                     '줘"\n'
#                                     '\n'
#                                     '- '
#                                     'https://www.mt.co.kr/entertainment/2026/06/30/2026063003323668849\n'
#                                     '- '
#                                     'https://www.mt.co.kr/entertainment/2026/06/29/2026062906252099463\n'
#                                     '- '
#                                     'https://www.mt.co.kr/entertainment/2026/06/29/2026062915583457758\n'
#                                     '- '
#                                     'https://www.mt.co.kr/entertainment/2026/06/30/2026063003103273909\n'
#                                     '\n'
#                                     '한국에도 패하면서 탈락한 A조 꼴찌 체코도 나란히 D-를 기록했다. 체코는 '
#                                     '첫 경기에서 홍명보호를 만나 1-2로 역전패했고, 남아공전에서도 선제골을 '
#                                     '지키지 못하며 1-1로 비겼다. 그리고 마지막 경기에서 멕시코에 0-3으로 '
#                                     '대패하며 씁쓸히 짐을 싸야 했다.\n'
#                                     '\n'
#                                     'ESPN은 "이 팀에는 세트피스가 있었다. 그리고 그 외에는 거의 아무것도 '
#                                     '없었다"라며 "체코의 모든 득점은 세트피스에서 나왔다. 34개의 슈팅 '
#                                     '가운데 18개가 세트피스에서 나왔고, 총 기대득점(xG) 2.37 가운데 '
#                                     '1.38도 세트피스에서 만들어졌다"고 짚었다.\n'
#                                     '\n'
#                                     '이어 매체는 "최상위 수준의 선수가 없는 첫 출전 국가라면, 조금이라도 '
#                                     '우위를 만들기 위해 이런 방식에 의존하는 것도 이해할 수 있다. 하지만 '
#                                     '체코의 선발 명단 대부분은 유럽 상위 리그에서 뛰는 선수들"이라고 '
#                                     '지적했다.\n'
#                                     '\n'
#                                     '한국 축구에도 뼈아픈 일침까지 덧붙였다. ESPN은 "체코 정도의 '
#                                     '전력이라면 최소한 32강에는 올라가고, 16강 진출을 노릴 만한 이변을 '
#                                     '만들 수 있는 위치까지는 가야 한다. 그런데 체코는 월드컵 역사상 가장 '
#                                     '약한 수준의 조 가운데 하나에서 최하위로 대회를 마쳤다"라고 강조했다.\n'
#                                     '\n'
#                                     '/ [email protected]\n'
#                                     '\n'
#                                     '<저작권자 © ‘돈이 보이는 리얼타임 뉴스’ 머니투데이. 무단전재 및 '
#                                     '재배포, AI학습 이용 금지>\n'
#                                     '\n'
#                                     '## 지금 뜨는 검색키워드\n'
#                                     '\n'
#                                     '## 많이 찾는 종목\n'
#                                     '\n'
#                                     '- 코스피\n'
#                                     '- 코스닥\n'
#                                     '\n'
#                                     '공유',
#                                highlights=None,
#                                highlight_scores=None,
#                                summary=None)],
#                autoprompt_string=None,
#                resolved_search_type='',
#                auto_date=None,
#                context=None,
#                statuses=None,
#                cost_dollars=CostDollars(total=0.007,
#                                         search={'neural': 0.007},
#                                         contents=None))
# Failed to multipart ingest runs: Connection error caused failure to POST https://apissmith.langchain.com/runs/multipart in LangSmith API. Please confirm your LANGCHAIN_ENDPOINT. ConnectionError(MaxRetryError('HTTPSConnectionPool(host=\'apissmith.langchain.com\', port=443): Max retries exceeded with url: /runs/multipart (Caused by NameResolutionError("HTTPSConnection(host=\'apissmith.langchain.com\', port=443): Failed to resolve \'apissmith.langchain.com\' ([Errno 11001] getaddrinfo failed)"))'))
# Content-Length: 2881
# API Key: lsv2_********************************************74trace=019f3a95-8621-7920-9f0d-f7b1776ad73b,id=019f3a95-8621-7920-9f0d-f7b1776ad73b
# Failed to multipart ingest runs: Connection error caused failure to POST https://apissmith.langchain.com/runs/multipart in LangSmith API. Please confirm your LANGCHAIN_ENDPOINT. ConnectionError(MaxRetryError('HTTPSConnectionPool(host=\'apissmith.langchain.com\', port=443): Max retries exceeded with url: /runs/multipart (Caused by NameResolutionError("HTTPSConnection(host=\'apissmith.langchain.com\', port=443): Failed to resolve \'apissmith.langchain.com\' ([Errno 11001] getaddrinfo failed)"))'))
# Content-Length: 122206
# API Key: lsv2_********************************************74trace=019f3a95-99b4-7bb0-a484-32d83e9cadeb,id=019f3a95-99b4-7bb0-a484-32d83e9cadeb

# %%
############################################################################################
# Tool 정보 확인 - LLM이 Tool을 사용할지 결정할 때 판단 근거, 호출할 때 전달할 값 결정하는 근거
############################################################################################
print("도구 이름 :", tavily_search.name, exa_search.name, sep=", ")
print("도구 설명 :", tavily_search.description)
# Out:
# 도구 이름 :, tavily_search, exa_search_results_json
# 도구 설명 : A search engine optimized for comprehensive, accurate, and trusted results. Useful for when you need to answer questions about current events. It not only retrieves URLs and snippets, but offers advanced search depths, domain management, time range filters, and image search, this tool delivers real-time, accurate, and citation-backed results.Input should be a search query.

# %%
# 도구 스키마 - 도구 호출 시 값 전달할 파라미터 정보
tavily_search.args
# Out:
# {'query': {'description': 'Search query to look up',
#   'title': 'Query',
#   'type': 'string'},
#  'include_domains': {'anyOf': [{'items': {'type': 'string'}, 'type': 'array'},
#    {'type': 'null'}],
#   'default': [],
#   'description': 'A list of domains to restrict search results to.\n\n        Use this parameter when:\n        1. The user explicitly requests information from specific websites (e.g., "Find climate data from nasa.gov")\n        2. The user mentions an organization or company without specifying the domain (e.g., "Find information about iPhones from Apple")\n\n        In both cases, you should determine the appropriate domains (e.g., ["nasa.gov"] or ["apple.com"]) and set this parameter.\n\n        Results will ONLY come from the specified domains - no other sources will be included.\n        Default is None (no domain restriction).\n        ',
#   'title': 'Include Domains'},
#  'exclude_domains': {'anyOf': [{'items': {'type': 'string'}, 'type': 'array'},
#    {'type': 'null'}],
#   'default': [],
#   'description': 'A list of domains to exclude from search results.\n\n        Use this parameter when:\n        1. The user explicitly requests to avoid certain websites (e.g., "Find information about climate change but not from twitter.com")\n        2. The user mentions not wanting results from specific organizations without naming the domain (e.g., "Find phone reviews but nothing from Apple")\n\n        In both cases, you should determine the appropriate domains to exclude (e.g., ["twitter.com"] or ["apple.com"]) and set this parameter.\n\n        Results will filter out all content from the specified domains.\n        Default is None (no domain exclusion).\n        ',
#   'title': 'Exclude Domains'},
#  'search_depth': {'anyOf': [{'enum': ['basic',
#      'advanced',
#      'fast',
#      'ultra-fast'],
#     'type': 'string'},
#    {'type': 'null'}],
#   'default': 'basic',
#   'description': 'Controls search thoroughness and result comprehensiveness.\n    \n        Use "basic" for simple queries requiring quick, straightforward answers.\n        \n        Use "advanced" for complex queries, specialized topics, \n        rare information, or when in-depth analysis is needed.\n        \n        Use "fast" for optimized low latency with high relevance.\n        \n        Use "ultra-fast" when latency is prioritized above all else.\n        ',
#   'title': 'Search Depth'},
#  'include_images': {'anyOf': [{'type': 'boolean'}, {'type': 'null'}],
#   'default': False,
#   'description': 'Determines if the search returns relevant images along with text results.\n   \n        Set to True when the user explicitly requests visuals or when images would \n        significantly enhance understanding (e.g., "Show me what black holes look like," \n        "Find pictures of Renaissance art").\n        \n        Leave as False (default) for most informational queries where text is sufficient.\n        ',
#   'title': 'Include Images'},
#  'time_range': {'anyOf': [{'enum': ['day', 'week', 'month', 'year'],
#     'type': 'string'},
#    {'type': 'null'}],
#   'default': None,
#   'description': 'Limits results to content published within a specific timeframe.\n        \n        ONLY set this when the user explicitly mentions a time period \n        (e.g., "latest AI news," "articles from last week").\n        \n        For less popular or niche topics, use broader time ranges \n        ("month" or "year") to ensure sufficient relevant results.\n   \n        Options: "day" (24h), "week" (7d), "month" (30d), "year" (365d).\n        \n        Default is None.\n        ',
#   'title': 'Time Range'},
#  'topic': {'anyOf': [{'enum': ['general', 'news', 'finance'],
#     'type': 'string'},
#    {'type': 'null'}],
#   'default': 'general',
#   'description': 'Specifies search category for optimized results.\n   \n        Use "general" (default) for most queries, INCLUDING those with terms like \n        "latest," "newest," or "recent" when referring to general information.\n\n        Use "finance" for markets, investments, economic data, or financial news.\n\n        Use "news" ONLY for politics, sports, or major current events covered by \n        mainstream media - NOT simply because a query asks for "new" information.\n        ',
#   'title': 'Topic'},
#  'start_date': {'anyOf': [{'type': 'string'}, {'type': 'null'}],
#   'default': None,
#   'description': 'Filters search results to include only content published on or after this date.\n        \n        Use this parameter when you need to:\n        - Find recent developments or updates on a topic\n        - Exclude outdated information from search results\n        - Focus on content within a specific timeframe\n        - Combine with end_date to create a custom date range\n        \n        Format must be YYYY-MM-DD (e.g., "2024-01-15" for January 15, 2024).\n        \n        Examples:\n        - "2024-01-01" - Results from January 1, 2024 onwards\n        - "2023-12-25" - Results from December 25, 2023 onwards\n        \n        When combined with end_date, creates a precise date range filter.\n        \n        Default is None (no start date restriction).\n        ',
#   'title': 'Start Date'},
#  'end_date': {'anyOf': [{'type': 'string'}, {'type': 'null'}],
#   'default': None,
#   'description': 'Filters search results to include only content published on or before this date.\n        \n        Use this parameter when you need to:\n        - Exclude content published after a certain date\n        - Study historical information or past events\n        - Research how topics were covered during specific time periods\n        - Combine with start_date to create a custom date range\n        \n        Format must be YYYY-MM-DD (e.g., "2024-03-31" for March 31, 2024).\n        \n        Examples:\n        - "2024-03-31" - Results up to and including March 31, 2024\n        - "2023-12-31" - Results up to and including December 31, 2023\n        \n        When combined with start_date, creates a precise date range filter.\n        For example: start_date="2024-01-01", end_date="2024-03-31" \n        returns results from Q1 2024 only.\n        \n        Default is None (no end date restriction).\n        ',
#   'title': 'End Date'}}

# %% [markdown]
# ## LLM ToolCalling 흐름
#
# ### 1. Tool 생성 및 LLM Model에 tool binding
# - `LLM-Model.bind_tools(tools=[tool_1, tool_2, ...])`

# %%
from langchain_openai import ChatOpenAI
from langchain_exa import ExaSearchResults
# Tool과 LLm 모델 생성
exa_search = ExaSearchResults(max_results=5)
model = ChatOpenAI(model="gpt-5.4-mini")

# LLm 모델에 Tool을 binding(: Tool binding)
tool_model = model.bind_tools(tools=[exa_search])
# model: LLM(Tool X), tool_model: LLM + Tool들

# %%
# Tool 호출이 필요 없는 질문에 대한 응답
result = tool_model.invoke("안녕하세요")

# %%
# type(result)
print(result.content) # LLM 응답 text
print(result.tool_calls) # 호출할 tool에 대한 정보(어떤 tool을 어떻게 호출할지)
# 응답에는 위 둘 중 하나만 값이 존재(content에 답이 있다는 것은 tool 호출이 필요 없는 것)
# Out:
# 안녕하세요! 무엇을 도와드릴까요?
# []

# %%
# Tool 호출이 필요한 질문
result2 = tool_model.invoke("2026년 7월 7일 서울의 날씨는 어떤가요?")

# %%
print(result2.content) # 빈문자열 -> tool 호출 O
print(result2.tool_calls)
# Out:
# [{'name': 'exa_search_results_json', 'args': {'query': '2026년 7월 7일 서울 날씨 예보', 'num_results': 5, 'type': 'fast', 'livecrawl': 'fallback', 'use_autoprompt': True, 'summary': True, 'text_contents_options': {'max_characters': 1200}}, 'id': 'call_9pVAy33bOsvKU9gdcbkuDyBi', 'type': 'tool_call'}]

# %%
query = "2026년 7월 7일 서울, 런던, 뉴옥의 날씨를 알려줘. 그리고 오늘 월드컵 경기 결과도 알려줘."
result3 = tool_model.invoke(query)

# %%
result3.content
print(len(result3.tool_calls)) # list[dict]
for r in result3.tool_calls:
    print(r)
    print("--------------------------")
# Out:
# 4
# {'name': 'exa_search_results_json', 'args': {'query': 'Seoul weather July 7 2026 forecast', 'num_results': 5, 'type': 'fast', 'livecrawl': 'always', 'summary': True}, 'id': 'call_1zJoTQrlzJc3nLDAyV6UNoST', 'type': 'tool_call'}
# --------------------------
# {'name': 'exa_search_results_json', 'args': {'query': 'London weather July 7 2026 forecast', 'num_results': 5, 'type': 'fast', 'livecrawl': 'always', 'summary': True}, 'id': 'call_lH1UpJnrlLYMI1Y7WCXDUdcY', 'type': 'tool_call'}
# --------------------------
# {'name': 'exa_search_results_json', 'args': {'query': 'New York weather July 7 2026 forecast', 'num_results': 5, 'type': 'fast', 'livecrawl': 'always', 'summary': True}, 'id': 'call_7mmGhiPThd7eL4oTDZU9bfP7', 'type': 'tool_call'}
# --------------------------
# {'name': 'exa_search_results_json', 'args': {'query': 'today World Cup results July 7 2026', 'num_results': 10, 'type': 'fast', 'livecrawl': 'always', 'summary': True}, 'id': 'call_tVmAF3nGSPomB1VdMadKvabv', 'type': 'tool_call'}
# --------------------------

# %% [markdown]
# ### 2. Tool 호출
# - LLM 모델이 tool 요청을 결정한 경우 **어떤 tool을 어떻게 호출할 지** AIMessage의 `tool_calls` 속성에 넣어 반환한다.
# - `tool_calls` 의 호출 정보를 넣어 `tool.invoke()` 호출한다.
#    - `tool.invoke(result.tool_calls[0])`
#    - **반환타입**: `ToolMessage`
#      - Tool의 처리결과를 담는 Message Type 이다.

# %%
# exa_search tool을 tool_calls[K](dict)를 전달해 호출
result3.tool_calls
# Out:
# [{'name': 'exa_search_results_json',
#   'args': {'query': 'Seoul weather July 7 2026 forecast',
#    'num_results': 5,
#    'type': 'fast',
#    'livecrawl': 'always',
#    'summary': True},
#   'id': 'call_1zJoTQrlzJc3nLDAyV6UNoST',
#   'type': 'tool_call'},
#  {'name': 'exa_search_results_json',
#   'args': {'query': 'London weather July 7 2026 forecast',
#    'num_results': 5,
#    'type': 'fast',
#    'livecrawl': 'always',
#    'summary': True},
#   'id': 'call_lH1UpJnrlLYMI1Y7WCXDUdcY',
#   'type': 'tool_call'},
#  {'name': 'exa_search_results_json',
#   'args': {'query': 'New York weather July 7 2026 forecast',
#    'num_results': 5,
#    'type': 'fast',
#    'livecrawl': 'always',
#    'summary': True},
#   'id': 'call_7mmGhiPThd7eL4oTDZU9bfP7',
#   'type': 'tool_call'},
#  {'name': 'exa_search_results_json',
#   'args': {'query': 'today World Cup results July 7 2026',
#    'num_results': 10,
#    'type': 'fast',
#    'livecrawl': 'always',
#    'summary': True},
#   'id': 'call_tVmAF3nGSPomB1VdMadKvabv',
#   'type': 'tool_call'}]

# %%
search_result1 = exa_search.invoke(result3.tool_calls[0]) #한 개 Tool 호출 - 4개 중 첫 번째 호출
type(search_result1)
# 사람의 입력: HumanMessage
# LLM 응답: AIMessage
# Tool 실행 결과: ToolMessage
# Out:
# langchain_core.messages.tool.ToolMessage

# %%
print(search_result1.content)
# Out:
# Title: Seoul, South Korea Weather Today, Jul 7 | Dense drizzle, High 83°F
# URL: https://exa.ai/library/weather/seoul-south-korea?latitude=37.5500&longitude=127.0000&date=2026-07-07&t=6a4c99e138bf04dae522561e
# ID: https://exa.ai/library/weather/seoul-south-korea?latitude=37.5500&longitude=127.0000&date=2026-07-07
# Score: None
# Published Date: 2026-07-07T05:16:52.425Z
# Author: None
# Image: None
# Favicon: None
# Extras: None
# Subpages: None
# Text: None
# Highlights: None
# Highlight Scores: None
# Summary: Seoul, South Korea forecast for July 7, 2026:
# - Conditions: Dense drizzle
# - High / Low: 83°F / 73°F (28.3°C / 22.7°C)
# - Precipitation: 2.9 mm expected
# - Rain probability: 0%
# - UV Index: 5.9
# - Sunrise / Sunset: 5:17 AM / 7:56 PM
#
# Note: Despite drizzle and measurable precipitation, overall rain probability is listed as 0% for the day.
#
#
# Title: Weather in Seoul, South Korea - 7-Day Forecast & Live Conditions
# URL: https://weather.now/kr/seoul
# ID: https://weather.now/kr/seoul
# Score: None
# Published Date: 2026-07-07T03:31:18.000Z
# Author: None
# Image: https://weather.now/ogimage/weather-in-kr-seoul.jpg?v=1755445622
# Favicon: https://weather.now/static/favicon-32x32.png
# Extras: None
# Subpages: None
# Text: None
# Highlights: None
# Highlight Scores: None
# Summary: Seoul weather forecast for July 7, 2026:
#
# - Current conditions: 25°C with patchy rain nearby. Humidity ~84%. Feels like 22°C. Light breeze around 5 kph.
# - Today’s rain risk: Very high; about 87% chance of rain with up to 10 mm possible. Showers likely from around 2:00 PM.
# - 7-day outlook: Changeable week with rain possible again around Thursday. The July average and seasonal context noted (record high 37°C for this date).
# - Hourly snapshot (today): Temperatures near 25–30°C early afternoon, with intermittent rain amounts varying; notable rain potential persists into the afternoon and early evening.
# - 7-day summary: Expect mixed skies with periods of rain; plan for showers on Thursday; next few days hover around mid-20s to low-30s Celsius depending on sun/rain gaps.
#
#
# Title: Weather in Seoul,, for July 7 — Temperature, precipitation, wind
# URL: https://meteum.ai/weather/en/seoul/date/july/7
# ID: https://meteum.ai/weather/en/seoul/date/july/7
# Score: None
# Published Date: None
# Author: None
# Image: https://weather.yastatic.net/s3/weather-frontend/front2/_next/static/media/meteum_black.e74474f0.svg
# Favicon: https://meteum.ai/weather/favicon.ico
# Extras: None
# Subpages: None
# Text: None
# Highlights: None
# Highlight Scores: None
# Summary: Seoul forecast for July 7, 2026:
# - Conditions: hot, cloudy with rain likely
# - Temperatures: high around 30°C (morning ~25°C, evening ~29°C, night ~27°C)
# - Precipitation: rain in morning and afternoon (feels more humid; afternoon may have light rain)
# - Feels like: up to ~38°C during the hottest part of the day
# - Wind: generally light to moderate, SE to S directions (2–4 m/s; gusts up to ~15 m/s)
# - Humidity: high (roughly 78–89%)
# - Pressure: around 747–749 mmHg
#
# Key takeaways: hot and wet day with rain at times; plan for heat and potential showers.
#
#
# Title: Seoul 7 July Weather. Forecast for Seoul - South Korea
# URL: https://globalmeteo.com/weather/seoul/jul-07/
# ID: https://globalmeteo.com/weather/seoul/jul-07/
# Score: None
# Published Date: None
# Author: None
# Image: https://globalmeteo.com/images/precip-svg/23.svg
# Favicon: https://globalmeteo.com/images/icon/favicon-32x32.png
# Extras: None
# Subpages: None
# Text: None
# Highlights: None
# Highlight Scores: None
# Summary: Summary:
# - Forecast for Seoul, South Korea on July 7, 2026: Heavy rain is expected today with hot afternoon highs around 89°F (about 32°C). Thunderstorms are forecast for July 7–9, with similar hot+humid conditions.
# - Hourly vibe: Morning temperatures around mid-70s°F, rising to the upper 80s°F by early afternoon, with light to moderate winds (roughly 3–7 mph). Pressure around 29.6 inHg.
# - Short-term trend: Heavy rain today (July 7), continued thunderstorms on July 8–9, then a possible shift to cloudier conditions by July 11, with temps remaining hot.
#
# If you want, I can highlight times for expected rain or create a quick hourly bullet for July 7.
#
#
# Title: Weather Seoul in July 2026: Temperature & Climate
# URL: https://en.climate-data.org/asia/south-korea/seoul/seoul-718563/t/july-7/
# ID: https://en.climate-data.org/asia/south-korea/seoul/seoul-718563/t/july-7/
# Score: None
# Published Date: None
# Author: None
# Image: https://www.climate-data.org/images/hotel-room-nature-small.jpg
# Favicon: https://en.climate-data.org/favicon.ico
# Extras: None
# Subpages: None
# Text: None
# Highlights: None
# Highlight Scores: None
# Summary: Seoul July 7, 2026 forecast highlights (based on typical July climate data for Seoul):
#
# - Expected conditions: Rain likely to be heavy around early July dates, with varying rain risk through the month. On July 7 specifically, historical pattern shows a mix of rain possibilities but not a single-day forecast here.
# - Temperature trend: Typical July highs around 28–31°C (82–87°F) with lows around 23–25°C (73–77°F). July peak tends to near month-end; early-month days are warm.
# - Rainfall: High daily rainfall possible in early to mid-July; monthly average rainfall ~319 mm (12.6 inches). Individual days can see 13–30+ mm of rain according to the pattern cited (e.g., July 7–10 historically included rain events).
# - Humidity and wind: High humidity (around 75–89%) with light to moderate southerly winds (roughly 7–12 km/h).
#
# Note: The page provides July averages and day-by-day patterns rather than a precise 2026 forecast for July 7. For an exact forecast, please check updated weather services closer to the date (hourly forecast 24–48 hours ahead).
#
# CostDollars: total=0.012
#   - search: {'neural': 0.007}

# %% [markdown]
# ##### tool_call 이 여러개일 경우
# - 질의에 대해 tool을 여러번 호출 해야 하는 경우 tool_calling 정보를 여러개 반환할 수 있다.
#     - 예) 검색할 키워드가 여러개인 경우.
# - `tool.batch([tool_call1, tool_call2, ..])`

# %%
search_result = exa_search.batch(result3.tool_calls) # 같은 Tool을 여러 번 호출할 경우 -> batch([{}, {}, ...])

# %%
print(len(search_result))
search_result
# Out:
# 4
# [ToolMessage(content="Title: Weather in Seoul,, for July 7 — Temperature, precipitation, wind\nURL: https://meteum.ai/weather/en/seoul/date/july/7\nID: https://meteum.ai/weather/en/seoul/date/july/7\nScore: None\nPublished Date: None\nAuthor: None\nImage: https://weather.yastatic.net/s3/weather-frontend/front2/_next/static/media/meteum_black.e74474f0.svg\nFavicon: https://meteum.ai/weather/favicon.ico\nExtras: None\nSubpages: None\nText: None\nHighlights: None\nHighlight Scores: None\nSummary: Seoul weather forecast for July 7, 2026:\n\n- Conditions: hot, cloudy with rain showers throughout the day.\n- Temperature: highs near 30°C; morning around 25°C, afternoon up to 30°C, evening ~29°C, night ~27°C. Feels like up to around 38°C at times in the afternoon.\n- Wind: varying light to moderate; morning 2–4 m/s (SE to SE), afternoon ~3 m/s (S), evening ~2 m/s (N), night ~4 m/s (SE). Gusts up to ~15 m/s possible.\n- Humidity: high (roughly 78–89%), muggy.\n- Pressure: around 747–749 mmHg.\n\nTips: carry an umbrella for rain, stay hydrated, and be prepared for heat with light, breathable clothing.\n\n\nTitle: Weather in Seoul, South Korea - 7-Day Forecast & Live Conditions\nURL: https://weather.now/kr/seoul\nID: https://weather.now/kr/seoul\nScore: None\nPublished Date: 2026-07-07T03:31:18.000Z\nAuthor: None\nImage: https://weather.now/ogimage/weather-in-kr-seoul.jpg?v=1755445622\nFavicon: https://weather.now/static/favicon-32x32.png\nExtras: None\nSubpages: None\nText: None\nHighlights: None\nHighlight Scores: None\nSummary: Seoul weather forecast for July 7, 2026:\n\n- Current conditions: 25°C with patchy rain nearby; feels like 22°C. Humidity ~84%, light breeze ~5 kph.\n- Today’s rain: Rain is very likely, about 87% chance, with up to 10 mm possible. Showers are expected from around 2:00 PM.\n- 7-day outlook: Changeable with rain possible later in the week; pack for rain around Thursday. Record high on this date is 37°C.\n- 7-day snapshot (selected): \n  - Tue Jul 7: Patchy rain nearby, highs around 28.7°C / 25.4°C; precipitation ~9.5–10 mm; wind ~9–10 kph.\n  - Wed Jul 8: Light rain shower; showers continue with notable rainfall (around 23.4 mm) and cooler temperatures.\n\n- Hourly Today (highlights): Temps from 30°C to mid-20s°C, with brief rain amounts fluctuating; near-peak temps around ~28°C around midday.\n\nFor precise hourly timing and precipitation details, view the page’s hourly forecast.\n\n\nTitle: Seoul 7 July Weather. Forecast for Seoul - South Korea\nURL: https://globalmeteo.com/weather/seoul/jul-07/\nID: https://globalmeteo.com/weather/seoul/jul-07/\nScore: None\nPublished Date: None\nAuthor: None\nImage: https://globalmeteo.com/images/precip-svg/23.svg\nFavicon: https://globalmeteo.com/images/icon/favicon-32x32.png\nExtras: None\nSubpages: None\nText: None\nHighlights: None\nHighlight Scores: None\nSummary: Seoul weather forecast for July 7, 2026:\n\n- Overall: Hot with incoming storms possible later in the day.\n- Temperature: About 77–89°F (25–32°C) through the day; peak near 89°F in the afternoon.\n- Likely conditions by time:\n  - Early morning: around 76–77°F, light winds.\n  - Midday: rising to around 85–88°F with increasing heat.\n  - Afternoon/evening: near 84–81°F with continued hot conditions; heavy rain or thunderstorms possible in the afternoon/evening.\n- Wind: Generally light, 3–7 mph, gusts possible during storms.\n- Precipitation risk: Thunderstorms and heavy rain forecast for the day, with likely storm activity in the afternoon to evening.\n\nNotes:\n- Forecast is based on GFS data and provided for personal use; shows hourly temperature and wind, plus daily precipitation risk for July 7.\n\n\nTitle: Seoul, Seoul, South Korea Monthly Weather | AccuWeather\nURL: https://www.accuweather.com/en/kr/seoul/226081/july-weather/226081\nID: https://www.accuweather.com/en/kr/seoul/226081/july-weather/226081\nScore: None\nPublished Date: None\nAuthor: None\nImage: https://www.accuweather.com/images/logos/aw- ...
#  ToolMessage(content="Title: London (Greater London) weather - Met Office\nURL: https://weather.metoffice.gov.uk/forecast/gcpvj0v07\nID: https://weather.metoffice.gov.uk/forecast/gcpvj0v07\nScore: None\nPublished Date: None\nAuthor: None\nImage: https://weather.metoffice.gov.uk/forecast/static/images/common/icons/social_card.jpg\nFavicon: https://weather.metoffice.gov.uk/favicon.png\nExtras: None\nSubpages: None\nText: None\nHighlights: None\nHighlight Scores: None\nSummary: Summary:\n- The Met Office forecast for London (Greater London) on July 7, 2026 shows hot conditions with daytime highs around 31–32°C.\n- The 7-day outlook remains predominantly warm, with peak temperatures reaching about 30–32°C and very low chances of rain (below 5% most hours).\n- Expected conditions by time on July 7:\n  - Morning starting around 20–25°C, rising through the day.\n  - By early afternoon, temperatures reach roughly 29–31°C.\n  - Evening remains warm, cooling gradually to about 25–27°C after sunset.\n- Light to moderate southerly or westerly winds around 6–7 mph.\n\nIf you need a specific hourly slice (e.g., exact temperatures at 2pm or precipitation chance for a particular hour), I can pull that out.\n\n\nTitle: London - BBC Weather\nURL: https://www.bbc.com/weather/6058560\nID: https://www.bbc.com/weather/6058560\nScore: None\nPublished Date: None\nAuthor: None\nImage: https://weather.files.bbci.co.uk/weather-web-component-renderer/109/og-image.png\nFavicon: https://static.files.bbci.co.uk/core/website/assets/static/icons/favicon/weather/favicon-32.97881c35d3eb6eac0075.png\nExtras: None\nSubpages: None\nText: None\nHighlights: None\nHighlight Scores: None\nSummary: London weather forecast for July 7, 2026:\n\n- Overall: Warm with a mix of light cloud and gentle breezes.\n- Tonight: Misty with light north-easterly winds; low around 19°C (66°F).\n- Tuesday (July 7, 2026): Light cloud and a gentle breeze; high near 28°C (83°F), low around 16°C (60°F); north-easterly winds ~8 mph (13 km/h).\n\nHourly details are available in the BBC forecast section if you need specific times.\n\n\nTitle: London, United Kingdom Hourly Weather Forecast | Weather Underground\nURL: https://wu-next-prod-us-east-1-aws.wunderground.com/hourly/gb/london/ILONDO540/date/2026-7-7\nID: https://wu-next-prod-us-east-1-aws.wunderground.com/hourly/gb/london/ILONDO540/date/2026-7-7\nScore: None\nPublished Date: None\nAuthor: None\nImage: https://www.wunderground.com/static/i/c/v4/32.svg\nFavicon: None\nExtras: None\nSubpages: None\nText: None\nHighlights: None\nHighlight Scores: None\nSummary: London, England, United Kingdom hourly forecast (Weather Underground) for July 7, 2026:\n\n- Today (Tue 07/07): Partly cloudy and hot. High around 89°F (31°C). WNW winds 10–15 mph.\n- Tonight: Mostly clear. Low near 65°F (18°C). Light north winds 5–10 mph.\n- Conditions snapshot: Clear skies, humidity ~56%, pressure ~30 in, visibility ~10 miles, no rainfall expected.\n\nSunrise/sunset: 4:53 AM / 9:20 PM. Moon currently waning crescent, about 52% illuminated. Day length ~16h 26m. Length of tomorrow slightly shorter by ~1m 33s.\n\n\nTitle: London - BBC Weather\nURL: https://www.bbc.com/weather/2643743\nID: https://www.bbc.com/weather/2643743\nScore: None\nPublished Date: None\nAuthor: None\nImage: https://weather.files.bbci.co.uk/weather-web-component-renderer/109/og-image.png\nFavicon: https://static.files.bbci.co.uk/core/website/assets/static/icons/favicon/weather/favicon-32.97881c35d3eb6eac0075.png\nExtras: None\nSubpages: None\nText: None\nHighlights: None\nHighlight Scores: None\nSummary: Summary:\n- The BBC Weather page for London shows a hot, sunny spell around early July.\n- Today: Sunny with a gentle breeze; high around 31°C (87°F), low ~18°C (64°F).\n- Tomorrow (Wednesday 8 July): Sunny with light winds; high ~32°C (89°F), low ~19°C (67°F).\n- The forecast through the week anticipates mostly sunny, hot days with light to gentle breezes, and the occasional cloud. Friday to Sa ...
#  ToolMessage(content="Title: New York City, NY Hourly Weather Forecast | Weather Underground\nURL: https://www.wunderground.com/hourly/us/ny/new-york-city/KNYNEWYO2109/date/2026-6-7\nID: https://www.wunderground.com/hourly/us/ny/new-york-city/KNYNEWYO2109/date/2026-6-7\nScore: None\nPublished Date: None\nAuthor: None\nImage: https://www.wunderground.com/static/i/c/v4/26.svg\nFavicon: None\nExtras: None\nSubpages: None\nText: None\nHighlights: None\nHighlight Scores: None\nSummary: New York weather forecast for July 7, 2026:\n- Today (July 7): Cloudy with a slight chance of a rain shower. High near 71°F. Winds NNE 5–10 mph.\n- Tonight: Cloudy with a low around 65°F. Winds NNE 5–10 mph.\n- Conditions: High humidity (dew point ~65°F), pressure ~30.02 in, visibility ~8 miles. No precipitation expected beyond a possible brief shower. Moon visible with last quarter around 1:11 PM; civil/nautical/astronomical twilights provided.\n\n\nTitle: New York, NY 7 July Weather. Forecast for New York, NY - United States, New York\nURL: https://globalmeteo.com/weather/new-york/jul-07/\nID: https://globalmeteo.com/weather/new-york/jul-07/\nScore: None\nPublished Date: None\nAuthor: None\nImage: https://globalmeteo.com/images/precip-svg/22.svg\nFavicon: https://globalmeteo.com/images/icon/favicon-32x32.png\nExtras: None\nSubpages: None\nText: None\nHighlights: None\nHighlight Scores: None\nSummary: Summary:\n- The page provides a July 7 forecast for New York, NY (2026) with hourly temperature and wind estimates.\n- Typical daily pattern shown: temperatures around mid-60s to low 70s °F during the day, with highs near 73–75°F and morning around 67–68°F.\n- Winds generally light, around 7–11 mph, with pressure near 29.96–29.98 inHg.\n- Includes a note that the forecast is based on GFS data and is for personal “as is” use, with a climate-norm comparison and past July 7 weather for context.\n\nIf you want, I can extract the exact hourly temperatures and winds for July 7, 2026 from the table.\n\n\nTitle: New York City, NY Monthly Weather | AccuWeather\nURL: https://www.accuweather.com/en/us/new-york/10021/july-weather/14-349727_1_al\nID: https://www.accuweather.com/en/us/new-york/10021/july-weather/14-349727_1_al\nScore: None\nPublished Date: None\nAuthor: None\nImage: https://www.accuweather.com/images/logos/aw-logo-og-meta.png\nFavicon: None\nExtras: None\nSubpages: None\nText: None\nHighlights: None\nHighlight Scores: None\nSummary: New York weather forecast for July 7, 2026:\n- AccuWeather provides a day-by-day forecast for July 2026, with daily highs generally in the low to mid 30s °C (21.6–32.4°C) and overnight lows around 17.9–23.3°C.\n- July average: high ~29°C, low ~21°C.\n- The page emphasizes RealFeel temperatures to reflect how conditions actually feel.\n- For a specific date like July 7, 2026, expect a typical July day with hot daytime highs and warm nights, with RealFeel adjustments noted on the daily entries (visit the site’s 10-day/July sections for the exact numbers).\n\n\nTitle: New York, NY 7 Days Weather - The Weather Network\nURL: https://www.theweathernetwork.com/en/city/us/new-york/new-york/7-days\nID: https://www.theweathernetwork.com/en/city/us/new-york/new-york/7-days\nScore: None\nPublished Date: None\nAuthor: Pelmorex Corp.\nImage: https://www.theweathernetwork.com/images/logos/twn-logo.png\nFavicon: https://www.theweathernetwork.com/favicon.ico\nExtras: None\nSubpages: None\nText: None\nHighlights: None\nHighlight Scores: None\nSummary: New York, NY weather forecast for July 7, 2026:\n- Condition: Cloudy with showers\n- High/Low: Reach around 22–23°C (mid-70s°F); overnight near 20–21°C (70s°F)\n- Wind: Light to moderate, around 19–22 km/h from the N/NE\n- Precipitation: About 40% chance of showers; precipitation amounts likely under 1 mm\n- Feels like: Approximately 21–23°C (around 70–74°F)\n\nNotes: The forecast indicates cooler, cloudy conditions with a chance of light showers on July 7.\n\n\nTitle: Manhattan, NY Monthly  ...
#  ToolMessage(content="Title: Argentina v Egypt: Line-ups, Score & Live Updates | Round of 16 | FIFA World Cup 2026™ | FIFA\nURL: https://www.fifa.com/en/match-centre/match/17/285023/289288/400021528\nID: https://www.fifa.com/en/match-centre/match/17/285023/289288/400021528\nScore: None\nPublished Date: None\nAuthor: None\nImage: https://digitalhub.fifa.com/transform/032a70c6-594c-4b5a-9545-0c96383708a0/fifapls_fallbackimage_1200x630\nFavicon: https://www.fifa.com/favicon-32x32.png?v=1ea068c804e8ba88b84f6e9598e3172d\nExtras: None\nSubpages: None\nText: None\nHighlights: None\nHighlight Scores: None\nSummary: Here’s a concise summary tailored to your query:\n\n- Event: FIFA World Cup 2026 Round of 16\n- Match: Argentina vs Egypt\n- Date and time: July 7, 2026, 16:00 local\n- Location: Atlanta Stadium, Atlanta\n- Match status: Line-ups, score, and live updates available on FIFA’s match centre\n- Official details: Referee François Letexier; Fourth official Espen Eskås\n- Additional context: Pre-match page shows kick-off time, teams’ links, and related World Cup content\n\nIf you want, I can pull the live score and final result as soon as the match concludes.\n\n\nTitle: USA v Belgium - Round of 16 - FIFA World Cup Score Centre - ABC News\nURL: https://www.abc.net.au/news/sport/score-centre/fifa-world-cup/2026-07-07/united-states-belgium/2608352\nID: https://www.abc.net.au/news/sport/score-centre/fifa-world-cup/2026-07-07/united-states-belgium/2608352\nScore: None\nPublished Date: 2026-07-07T00:00:00.000Z\nAuthor: None\nImage: https://live-production.wcms.abc-cdn.net.au/1e2294b09eda2b20b970dc3516af67cb?impolicy=wcms_crop_resize&cropH=2512&cropW=4466&xPos=167&yPos=0&width=1200&height=675&imformat=generic\nFavicon: https://www.abc.net.au/news-assets/favicon-32x32.png\nExtras: None\nSubpages: None\nText: None\nHighlights: None\nHighlight Scores: None\nSummary: Summary:\n- The page is ABC News’ FIFA World Cup Score Centre focusing on Round of 16 results, including the USA vs Belgium matchup.\n- It indicates live coverage and score updates for the Round of 16 on July 7, 2026.\n- Related links highlight post-match analysis and controversy surrounding the USA-Belgium game (Balogun red card, discussions of referee decisions, and fallout).\n- The page serves as a hub for latest World Cup scores and stories, with quick-links to individual articles about the USA vs Belgium clash and other 2026 World Cup coverage.\n\n\nTitle: USA 1-4 Belgium: Romelu Lukaku scores as co-hosts exit World Cup - BBC Sport\nURL: https://www.bbc.com/sport/football/live/c24y8ded80vt\nID: https://www.bbc.com/sport/football/live/c24y8ded80vt\nScore: None\nPublished Date: 2026-07-06T03:00:50.000Z\nAuthor: None\nImage: https://ichef.bbci.co.uk/ace/branded_sport/1200/cpsprodpb/11eb/live/16dbe950-79ad-11f1-b09b-459fdc8efd5a.jpg\nFavicon: https://static.files.bbci.co.uk/core/website/assets/static/icons/favicon/sport/favicon-32.729e81a820.png\nExtras: None\nSubpages: None\nText: None\nHighlights: None\nHighlight Scores: None\nSummary: Belgium defeated the United States 4-1 to reach the World Cup quarter-finals, setting up a last-8 clash with Spain. Key moments:\n- Charles De Ketelaere scored twice for Belgium (including the opener and a second before halftime).\n- De Ketelaere added a third after a US goalkeeper error.\n- Romelu Lukaku scored a late fourth as a substitute, becoming the first player to score three goals as a substitute in a World Cup tournament.\n- Malik Tillman equalized for the US with a deflection off Hans Vanaken, but Belgium pulled away in the second half.\n- Belgium’s win ensures they advance to the quarter-finals in Los Angeles to face Spain.\n\n\nTitle: Netherlands 1-1 Morocco (Morocco win 3-2 on penalties) – as it happened\nURL: https://www.europesays.com/netherlands/29210/\nID: https://www.europesays.com/netherlands/29210/\nScore: None\nPublished Date: 2026-07-07T04:44:42.000Z\nAuthor: None\nImage: None\nFavicon: None\nExtras: None\nSubpages: None\n ...

# %% [markdown]
# ### 3. Tool의 처리(응답) 결과를 LLM 요청시 사용
# - ToolMessage를 prompt 에 추가하여 LLM에 요청한다.
# - ToolMessage 는 Tool Calling 정보를 가진 AIMessage 다음에 들어와야 한다.
# - Prompt 순서
#     1. 일반 prompt (system, 대화 history, .., human)
#     2. AIMessage: tool calling 정보를 가진 AIMessage. (tool_model에 질의 받은 tool calling 정보가 있는 응답)
#     3. ToolMessage:  Tool의 처리 결과

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import chain
from langchain_tavily import TavilyResearch
from langchain_exa import ExaSearchResults

from datetime import date
from dotenv import load_dotenv

load_dotenv(override=True)
# Out:
# True

# %%
prompt_str = """
- 당신은 사용자의 다양한 질문에 답변하는 AI assistant입니다.
- 사용자의 질문에 상대적 시간 표현이 포함되어 있고 절대 날짜가 명시되어 있지 않은 경우, 오늘 날짜를 기준으로 실제 날짜를 계산한 뒤 검색합니다.
    - 상대적 시간 표현 예: 현재, 오늘, 어제, 내일, 이번 주, 지난주, 이번 달, 지난달, 올해, 작년
- 오늘 날짜는 {today}입니다.
-답변에 필요한 정보가 부족하거나 최신 정보 확인이 필요한 경우, 적절한 tool을 사용해 정보를 수집합니다.  
    -질문에 답변하기 위해 웹 검색 tool을 사용할 때, 질문에 시점 정보가 필요한 경우 계산된 날짜나 시간 범위를 검색 쿼리에 포함해야 합니다.
- 웹 검색이 필요할 경우 binding 된 웹검색 tool(tavily_search, exa_search_results_json) 을 모두 사용합니다.
- 사용할 수 있는 tool은 다음과 같습니다.
    - tavily_search: 웹 검색 tool
    - exa_search_results_json: 웹 검색 tool
"""

# %%
# Chain 구성
# 모델 정의
model = ChatOpenAI(model="gpt-5.4-mini")
 
# Tool 정의
tavily_search = TavilyResearch(max_results=5)
exa_search = ExaSearchResults(max_results=5)

# model-bind-tools
tool_model = model.bind_tools(tools=[tavily_search, exa_search])

today = date.today().strftime('%Y년 %m월 %d일') # date -> str (ex. 2026년 07월 07일)
prompt = ChatPromptTemplate(
    [
        ('system', prompt_str), # SystemMessage
        ('human', "{query}"),   # HumanMessage
        MessagesPlaceholder(variable_name="tool_messages", optional=True) # Tool 호출 결과인 ToolMessage 넣을 placehold
        # AIMessage(tool 호출하라는 AI의 응답 메시지) -> ToolMessage
    ],
    partial_variables = {"today": today}
)
# prompt.invoke({"query": "질문"})

tool_model_chain = prompt | tool_model

# tool_model_chain
## 질문 -[llm 판단: 직접 답변 가능]-> 응답 결과(AIMessage.content)
## 질문 -[llm 판단: tool 호출]-> Tool calls(AIMessage.tool_calls)

# %%
tavily_search_name = tavily_search.name
exa_search_name = exa_search.name

@chain
def web_agent(query:str)->tuple[str, list]:
    """
    Agent의 전체 흐름 처리하는  Runnable
    사용자 질문(query) 받아 tool_model과 tool을 이용해 최종 응답 생성 후 반환
    Args:
        query(str): 사용자 질의
    Returns:
        tuple[str, list]: AI의 최종 답변(str과 Tool 메시지들(list)
    """
    # 0. ToolMessage 저장할 list
    messages = []
    # 1. Tool model에 query 질의
    ai_message = tool_model_chain.invoke(query) # ai_message.content="" 툴 요청
    
    while ai_message.tool_calls: # 빈 리스트가 아니라면 -> tool 호출 [{}, {}, {}]
        for tool_call in ai_message.tool_calls:
            if tool_call["name"] == tavily_search_name:
                messages.append(tavily_search.invoke(tool_call))
            elif tool_call["name"] == exa_search_name:
                messages.append(exa_search.invoke(tool_call))

        # tool 호출 완료 -> tool_model_chain(LLM) 다시 호출 <= query, ToolMessage
        messages = [ai_message] + messages # AIMessage(Tool calls 정보를 가진) + ToolMessate(tool 처리 결과)

        ai_message = tool_model_chain.invoke({"query": query, "tool_messages": messages})

    # AI 최종 응답(end of while)
    messages.append(ai_message) # 마지막 AI 응답 포함
    return ai_message.content, messages

# %%
result1 = web_agent.invoke("안녕하세요. 반갑습니다.")
result1
# Out:
# ('안녕하세요! 반갑습니다. 무엇을 도와드릴까요?',
#  [AIMessage(content='안녕하세요! 반갑습니다. 무엇을 도와드릴까요?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 18, 'prompt_tokens': 1360, 'total_tokens': 1378, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1152}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-mini-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-DytpG5XxKKv8fIfBx5K3FvtZK481q', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f3b51-cfc4-7391-9523-7fb3b0ea6e37-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1360, 'output_tokens': 18, 'total_tokens': 1378, 'input_token_details': {'audio': 0, 'cache_read': 1152}, 'output_token_details': {'audio': 0, 'reasoning': 0}})])

# %%
result2 = web_agent.invoke("북중미 월드컵 현재까지 결과가 어떻게 되는지 조사해서 알려줘.")

# %%
print(result2[0])
# Out:
# 북중미 월드컵(2026 FIFA 월드컵) **2026년 7월 7일 기준 현재까지 결과**를 간단히 정리해드릴게요.
# 이번 대회는 **캐나다·멕시코·미국 공동 개최**, **48개국 체제**로 진행 중입니다.
#
# ## 현재까지 대회 진행 상황
# - **조별리그는 종료**
# - **16강(라운드 오브 16) 일부 진행 중**
# - 지금까지 **8강 진출팀 일부가 확정**된 상태입니다.
#
# ## 현재까지 확정된 8강 진출팀
# 알자지라 기준으로, 7월 7일 현재까지 8강 진출을 확정한 팀은 다음과 같습니다.
# - **모로코**
# - **프랑스**
# - **노르웨이**
# - **잉글랜드**
# - **스페인**
# - **벨기에**
#
# ## 최근 주요 결과
# ### 16강
# - **스페인 1-0 포르투갈**
# - **벨기에 4-1 미국**
# - **잉글랜드 3-2 멕시코**
# - **노르웨이 2-1 브라질**
# - **프랑스 1-0 파라과이**
# - **모로코 3-0 캐나다**
#
# ### 32강
# - **콜롬비아 1-0 가나**
# - **아르헨티나 3-2 카보베르데(연장)**
# - **이집트 1-1 호주, 승부차기 이집트 승(4-2)**
# - **스위스 2-0 알제리**
# - **포르투갈 2-1 크로아티아**
# - **스페인 3-0 오스트리아**
# - **미국 2-0 보스니아 헤르체고비나**
# - **벨기에 3-2 세네갈**
# - **잉글랜드 2-1 DR 콩고**
# - **멕시코 2-0 에콰도르**
# - **프랑스 3-0 스웨덴**
# - **노르웨이 2-1 코트디부아르**
# - **모로코 1-1 네덜란드, 승부차기 모로코 승(3-2)**
# - **파라과이 1-1 독일, 승부차기 파라과이 승(4-3)**
# - **브라질 2-1 일본**
# - **캐나다 1-0 남아공**
#
# ## 주목할 만한 점
# - **브라질 탈락**: 노르웨이에 1-2로 져서 탈락
# - **미국 탈락**: 벨기에에 1-4 패
# - **멕시코 탈락**: 잉글랜드에 2-3 패
# - **캐나다 탈락**: 모로코에 0-3 패
# - **프랑스, 스페인, 벨기에, 잉글랜드, 노르웨이, 모로코**가 강하게 8강권에 진입
#
# ## 앞으로 남은 16강 주요 일정
# - **7월 7일**: 스위스 vs 콜롬비아
# - **7월 7일**: 아르헨티나 vs 이집트
#
# ## 다음 단계
# 8강 대진은 일부 확정됐고, 남은 16강 결과에 따라 완성됩니다.
#
# 원하시면 제가 이어서
# 1) **16강 대진표를 보기 좋게 표로 정리**하거나
# 2) **한국 시간 기준으로 남은 경기 일정**까지 정리해드릴게요.

# %%
result2[1]
# Out:
# [AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 186, 'prompt_tokens': 1371, 'total_tokens': 1557, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1152}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-mini-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-DytpIbpez5Z9kyc9eZAjtkRvAPxh8', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019f3b51-d7ce-7d73-9d24-5a1ee720c60a-0', tool_calls=[{'name': 'tavily_research', 'args': {'input': '북중미 월드컵 2026 현재까지 결과 정리. 2026년 07월 07일 기준, 현재까지 진행된 경기 결과, 대회 현황, 주요 순위/진출 상황을 조사해 한국어로 요약해줘.', 'model': 'auto', 'citation_format': 'numbered', 'stream': False}, 'id': 'call_B1vVPPUIeQqzjrjyaWsZhCdE', 'type': 'tool_call'}, {'name': 'exa_search_results_json', 'args': {'query': '2026 FIFA World Cup North America current results July 7 2026 standings fixtures results', 'num_results': 5, 'type': 'deep', 'livecrawl': 'fallback', 'use_autoprompt': True, 'text_contents_options': {'max_characters': 4000}, 'summary': True}, 'id': 'call_NkjcxT0ScxAtGR2W9w4TdjbK', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1371, 'output_tokens': 186, 'total_tokens': 1557, 'input_token_details': {'audio': 0, 'cache_read': 1152}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  ToolMessage(content='{"status": "pending", "input": "북중미 월드컵 2026 현재까지 결과 정리. 2026년 07월 07일 기준, 현재까지 진행된 경기 결과, 대회 현황, 주요 순위/진출 상황을 조사해 한국어로 요약해줘.", "model": "auto", "created_at": "2026-07-07T06:44:10.414173+00:00", "response_time": 0.05, "request_id": "50c8b450-742a-4a72-81f6-8376cb3f5285"}', name='tavily_research', tool_call_id='call_B1vVPPUIeQqzjrjyaWsZhCdE'),
#  ToolMessage(content="Title: World Cup results 2026: Updated scores today, yesterday, and so far from 2026 FIFA tournament | Sporting News\nURL: https://www.sportingnews.com/us/soccer/news/world-cup-results-2026-updated-scores-today-yesterday-2026/0aac196507c2f55a95cff893\nID: https://www.sportingnews.com/us/soccer/news/world-cup-results-2026-updated-scores-today-yesterday-2026/0aac196507c2f55a95cff893\nScore: None\nPublished Date: 2026-07-07T02:00:00.000Z\nAuthor: None\nImage: https://library.sportingnews.com/styles/crop_style_16_9_1200_webp/s3/2025-12/Basic-WC-logo-graphic-%288%29.jpg.webp?itok=aFlO-zAS\nFavicon: https://static-nw-production.sportingnews.com/8569b8dc1128a9900aeca7bf9d0094fa16152af7-static/assets/images/favicon.ico\nExtras: None\nSubpages: None\nText: World Cup results 2026: Updated scores today, yesterday, and so far from 2026 FIFA tournament | Sporting News\n\nContinue Without Login\n\nFeatured\n\n- NFL\n- NBA\n- MLB\n- NHL\n- World Cup\n- Betting\n- SN 140\n- Archive\n\nSports\n\n- NFL\n- NBA\n- MLB\n- NHL\n- Soccer\n- NCAAF\n- NCAAMB\n- NCAAWB\n- WNBA\n- Boxing\n- MMA\n- WWE\n- F1\n- NASCAR\n- Golf\n- Tennis\n- College\n- High School\n- Darts\n- Horse Racing\n- Olympics\n- More Sports\n\nExplore More\n\n- Fantasy\n- Betting\n- Prediction Markets\n- Watch\n- The Scene\n- Tickets\n- Stadium Guides\n\nEditions\n\nIf you purchase a product or register for an account through one of the links on our site, we may receive compensation. Learn more >\n\n# World Cup results 2026: Updated scores today, yesterday, and so far from 2026 FIFA tournament\n\nDan Treacy\n\n•\n\nAdd The Sporting News on Google\n\nAn expanded World Cup means 40 more matches in 2026, but the goal for each team is still the same: win the final one.\n\nWhile that goal is much more realistic for some than others, the start of the World Cup brings hope for all 48 teams in the field as they look to make their home fans proud on the biggest stage in the world.\n\nSTREAM: Watch 2026 World Cup games live with fubo (U.S. only free trial)\n\nNorth America is the host for all 104 matches, but teams from Europe, South America, Africa and beyond know this is their chance to leave a lasting global impression.\n\nTake a look at the World Cup results so far, including today's matches.\n\n2026 WORLD CUP HQ: Latest World Cup news| Full World Cup schedule| Updated World Cup standings\n\n## World Cup matches today\n\n### Monday, July 6\n\nToday is the penultimate day of the Round of 16.\n\nWe began by watching Cristiano Ronaldo at a World Cup for the final time, his Portugal side beaten 1-0 by Spain. Next up is USA vs. Belgium.\n\n| Round | Game | Location | Time (ET) | TV/Streaming |\n| --- | --- | --- | --- | --- |\n| Round of 16 | Spain 1, Portugal 0 | AT&T Stadium (Arlington, TX) | 3 p.m. | FOX, fubo |\n| Round of 16 | Belgium 4, USA 1 | Lumen Field (Seattle, WA) | 8 p.m. | FOX, fubo |\n\n## 2026 World Cup results so far\n\nHere are the results of matches already in the books at the 2026 World Cup:\n\n| Date | Group/Round | Match |\n| --- | --- | --- |\n| July 6 | Round of 16 | Belgium 4, USA 1 |\n| July 6 | Round of 16 | Spain 1, Portugal 0, |\n| July 5 | Round of 16 | England 3, Mexico 2 |\n| July 5 | Round of 16 | Norway 2, Brazil 1 |\n| July 4 | Round of 16 | France 1, Paraguay 0 |\n| July 4 | Round of 16 | Morocco 3, Canada 0 |\n| July 3 | Round of 32 | Colombia 1, Ghana 0 |\n| July 3 | Round of 32 | Argentina 3, Cape Verde 2 (ET) |\n| July 3 | Round of 32 | Egypt 1 (4-2 pens) Australia 1 |\n| July 2 | Round of 32 | Switzerland 2, Algeria 0 |\n| July 2 | Round of 32 | Portugal 2, Croatia 1 |\n| July 2 | Round of 32 | Spain 3, Austria 0 |\n| July 1 | Round of 32 | United States 2, Bosnia and Herzegovina 0 |\n| July 1 | Round of 32 | Belgium 3, Senegal 2 |\n| July 1 | Round of 32 | England 2, DR Congo 1 |\n| June 30 | Round of 32 | Mexico 2, Ecuador 0 |\n| June 30 | Round of 32 | France 3, Sweden 0 |\n| June 30 | Round of 32 | Norway 2, Ivory Coast 1 |\n|  ...
#  AIMessage(content='북중미 월드컵(2026 FIFA 월드컵) **2026년 7월 7일 기준 현재까지 결과**를 간단히 정리해드릴게요.  \n이번 대회는 **캐나다·멕시코·미국 공동 개최**, **48개국 체제**로 진행 중입니다.\n\n## 현재까지 대회 진행 상황\n- **조별리그는 종료**\n- **16강(라운드 오브 16) 일부 진행 중**\n- 지금까지 **8강 진출팀 일부가 확정**된 상태입니다.\n\n## 현재까지 확정된 8강 진출팀\n알자지라 기준으로, 7월 7일 현재까지 8강 진출을 확정한 팀은 다음과 같습니다.\n- **모로코**\n- **프랑스**\n- **노르웨이**\n- **잉글랜드**\n- **스페인**\n- **벨기에**\n\n## 최근 주요 결과\n### 16강\n- **스페인 1-0 포르투갈**\n- **벨기에 4-1 미국**\n- **잉글랜드 3-2 멕시코**\n- **노르웨이 2-1 브라질**\n- **프랑스 1-0 파라과이**\n- **모로코 3-0 캐나다**\n\n### 32강\n- **콜롬비아 1-0 가나**\n- **아르헨티나 3-2 카보베르데(연장)**\n- **이집트 1-1 호주, 승부차기 이집트 승(4-2)**\n- **스위스 2-0 알제리**\n- **포르투갈 2-1 크로아티아**\n- **스페인 3-0 오스트리아**\n- **미국 2-0 보스니아 헤르체고비나**\n- **벨기에 3-2 세네갈**\n- **잉글랜드 2-1 DR 콩고**\n- **멕시코 2-0 에콰도르**\n- **프랑스 3-0 스웨덴**\n- **노르웨이 2-1 코트디부아르**\n- **모로코 1-1 네덜란드, 승부차기 모로코 승(3-2)**\n- **파라과이 1-1 독일, 승부차기 파라과이 승(4-3)**\n- **브라질 2-1 일본**\n- **캐나다 1-0 남아공**\n\n## 주목할 만한 점\n- **브라질 탈락**: 노르웨이에 1-2로 져서 탈락\n- **미국 탈락**: 벨기에에 1-4 패\n- **멕시코 탈락**: 잉글랜드에 2-3 패\n- **캐나다 탈락**: 모로코에 0-3 패\n- **프랑스, 스페인, 벨기에, 잉글랜드, 노르웨이, 모로코**가 강하게 8강권에 진입\n\n## 앞으로 남은 16강 주요 일정\n- **7월 7일**: 스위스 vs 콜롬비아\n- **7월 7일**: 아르헨티나 vs 이집트\n\n## 다음 단계\n8강 대진은 일부 확정됐고, 남은 16강 결과에 따라 완성됩니다.\n\n원하시면 제가 이어서  \n1) **16강 대진표를 보기 좋게 표로 정리**하거나  \n2) **한국 시간 기준으로 남은 경기 일정**까지 정리해드릴게요.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 830, 'prompt_tokens': 10068, 'total_tokens': 10898, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1152}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-mini-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-DytpftaH9fp6MlNS5bpVJGxCljnZM', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f3b52-3238-7e83-a805-9d9b0a04a1de-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 10068, 'output_tokens': 830, 'total_tokens': 10898, 'input_token_details': {'audio': 0, 'cache_read': 1152}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]

# %% [markdown]
# # 사용자 정의 Tool 구현
#
# ## @tool 사용
# - 함수로 구현하고 `@tool` 데코레이터를 사용해 tool(StructuredTool)로 정의한다.
#     - `langchain_core.tools` 모듈에 있다.
# - tool name
#     - 함수의 이름이 tool의 이름이 된다.
# - parameters
#     - 함수의 파라미터가 tool의 파라미터가 된다.
#     - **type hint**를 이용해 타입을 지정한다.
# - description
#     - doctring이 description이 된다.
#     - RunnableBinding(model + tool)이 tool을 잘 찾을 수 있도록 하려면 **tool의 기능을 최대한 구체적**으로 작성한다.
# - **@tool이 적용된 함수(StructuredTool)가 tool**이므로 model에 binding 한다.

# %%
from langchain_core.tools import tool

# 사칙연산 툴 정의
@ tool
def plus(num1:int|float, num2:int|float) -> int|float:
    """받은 두 개의 수를 덧셈하는 툴"""
    return num1 + num2

@ tool
def minus(num1:int|float, num2:int|float) -> int|float:
    """받은 두 개의 수를 뺄셈하는 툴"""
    return num1 - num2

@ tool
def multiply(num1:int|float, num2:int|float) -> int|float:
    """받은 두 개의 수를 곱셈하는 툴"""
    return num1 * num2

# 파라미터에 대한 자세한 설명을 해야 하는 경우: Pydantic.BaseModel로 정의
from pydantic import BaseModel, Field
class DivideToolParameter(BaseModel):
    num1: int|float = Field(..., description="나눌 때 사용할 첫 번째 값")
    num2: int|float = Field(..., description="나눌 때 사용할 두 번째 값. 0은 사용할 수 없다.")

@ tool("divide_tool", args_schema=DivideToolParameter)
def divide(num1:int|float, num2:int|float) -> int|float:
    """받은 두 개의 수를 나눗셈하는 툴"""
    return num1 / num2

# %%
print(plus.name) # 툴이름
print(divide.name)
print(divide.description) # 툴설명
divide.args # 피라미터 설명
# Out:
# plus
# divide_tool
# 받은 두 개의 수를 나눗셈하는 툴
# {'num1': {'anyOf': [{'type': 'integer'}, {'type': 'number'}],
#   'description': '나눌 때 사용할 첫 번째 값',
#   'title': 'Num1'},
#  'num2': {'anyOf': [{'type': 'integer'}, {'type': 'number'}],
#   'description': '나눌 때 사용할 두 번째 값. 0은 사용할 수 없다.',
#   'title': 'Num2'}}

# %%
plus.invoke({"num1": 10, "num2": 20})
divide.invoke({"num1": 10, "num2":20})
# Out:
# 0.5

# %%
tool_model = ChatOpenAI(model="gpt-5.4-nano").bind_tools([plus, minus, multiply, divide])
result = tool_model.invoke("30-20*10의 결과는 얼마야? 계산할 때 툴이 있으면 툴을 사용해줘.")

# %%
result.tool_calls
# Out:
# [{'name': 'multiply',
#   'args': {'num1': 20, 'num2': 10},
#   'id': 'call_oC0LsIZcyBfEt7DdyfX9irNw',
#   'type': 'tool_call'}]

# %% [markdown]
# ## Runnable을 tool로 정의
# - `Runnable객체.as_tool()`
#     - name, description, args_schema 파라미터를 이용해 tool의 이름, 설명, 스키마를 설정한다.

# %%
# !uv pip install wikipedia
# 위키 백과 사전의 내용을 검색할 수 있는 lib
# Out:
# Resolved 9 packages in 2.52s
#    Building wikipedia==1.4.0
#       Built wikipedia==1.4.0
# Prepared 1 package in 903ms
# Installed 1 package in 14ms
#  + wikipedia==1.4.0

# %%
# 위키백과사전 검색해 크롤링
from langchain_community.document_loaders import WikipediaLoader 
from pydantic import BaseModel, Field
from langchain_core.runnables import chain
import json

# Runnable 구현 -> tool 변환
@ chain
def wikipedia_search(inputs: dict) -> str:
    """
    사용자의 쿼리를 검색어로 위키백과사전(wikipedia)을 검색하고, 그 결과 중 k개의 문서 내용을 반환
    Args:
        inputs(dict): key- query, max_result. query(str) 검색할 키워드, max_result(int) 검색할 결과 수
    Returns:
        str- 검색한 결과들을 json 형식의 문자열로 반환. 형식: {"result": [{검색된 문서 정보들}, {검색된 문서 정보들}]}
    """
    query = inputs['query']
    max_result = inputs.get("max_result", 3)

    loader = WikipediaLoader(
        query=query,  # 검색어
        load_max_docs=max_result,  # 검색할 문서 최대 개수
        lang="ko"  # 검색할 wikipedia 나라
    )
    docs = loader.load()  # list[Document]
    result_list = []
    for doc in docs:
        result_list.append(
            {
                "content": doc.page_content,  # 조회 내용
                "title": doc.metadata.get("title"),
                "url": doc.metadata.get("source")
            }
        )
    if result_list:
        result = {"result": result_list}
    else:
        result = {"result": "검색된 문서가 없습니다."}

    # List/Dictionary => str(JSON 형식)
    return json.dumps(result, ensure_ascii=False)

# %%
# l = {"name": "홍길동", "age": 30}
# json.dumps(l) # , ensure_ascii=False)

# %%
type(wikipedia_search) #-> RunnableLambda
r = wikipedia_search.invoke({"query": "비빔밥", "max_result":2})

# %%
json.loads(r)
# Out:
# {'result': [{'content': '비빔은 한국의 밥 요리이다. 쌀밥에 고기나 나물 등과 여러 가지의 양념을 넣어 비벼 먹는 음식이며, 비빔밥이나 제삿밥, 골동반(骨董飯), 교반(攪飯)으로도 부른다. 과거 궁중에서는 비빔이라 불렀다. 대한민국의 국민 음식 가운데 하나로 여겨진다.\n\n\n== 역사 ==\n비빔밥의 기원은 정확하지 않다. 그릇이 많이 없는 집 밖에서 산신제나 동신제를 지낼 때 신인공식(神人共食)이라는 생각에 따라 그릇 하나에 이것저것 받아 섞어 먹던 것, 또는 조상을 위한 제사를 지낼 때 제물을 빠짐없이 음복하기 위해 밥에 여러 가지 제찬을 고루 섞어 비벼 먹던 것에서 발달하였을 수 있다.\n비빔밥은 조선 중기의 문신 박지혜(1569~1635)가 지은 역사서 《기재잡기》에 "혼돈반(混沌飯)"으로, 조선 후기의 문신 권상일(1679~1760)이 쓴 일기인 《청대일기》에 "골동반(骨董飯)"으로 언급된다. 그 외에도 실학자 이익(1681~1764)이 지은 《성호전집》에는 "골동(骨董)"으로, 실학자 이덕무(1741~1793)의 《청장관전서》에는 "골동반(汨董飯)"으로, 이학규(1770~1835)의 《낙하생집》에는 "골동반(骨董飯)"과 "골동(骨董)"으로 언급된다.\n\n"전임(?∼1509)이 대답하기를, \'오직 공께서 명하시는 대로 먹겠습니다\' 하니, 곧 밥 한 대접에다가 생선과 채소를 섞어 세상에서 말하는 비빔밥과 같이(如俗所謂混沌飯/여속소위혼돈반) 만들고 술 세 병들이나 되는 한 잔을 대접하니, 전임이 두어 숟갈에 그 밥을 다 먹어 치우고 단숨에 그 술을 들이켰다."\n\n1810년 장혼이 지은 학습용 백과서 《몽유편》에는 "브뷔음"이라는 한글 표기가 등장하며, 1870년 《명물기략》에는 "비빔밥을 한자로는 \'골동반(骨董飯)\'이라고 쓰고, 부를 때는 \'부빔밥(捊排飯/부배반)\'이라고 한다(骨董飯取飮食雜和飯俗言捊排飯又曰谷董/골동반취음식잡화반속언부배반우왈곡동)."는 언급이 나온다.\n이규경(1788~1856)이 지은 《오주연문장전산고》에는 채소비빔밥, 잡비빔밥, 회비빔밥, 전어비빔밥, 대하비빔밥, 새우젓갈비빔밥, 새우알비빔밥, 게장비빔밥, 달래비빔밥, 생오이비빔밥, 김가루비빔밥, 고추장비빔밥, 황두비빔밥 등 여러 가지 비빔밥이 소개되어 있으며, 지역의 특산물을 소개하며 "평양의 감홍로, 냉면, 비빔밥(平壤之紺紅露冷麪骨蕫飯/평양지감홍로랭면골동반)"을 들기도 하였다.\n19세기 후반의 조리서인 《시의전서》에는 비빔밥의 조리법이 다음과 같이 언급된다.\n\n"밥을 정히 짓고 고기는 재워 볶고 간납은 부쳐 썬다. 각색 남새를 볶아 놓고 좋은 다시마로 튀각을 튀겨서 부숴 놓는다. 밥에 모든 재료를 다 섞고 깨소금·기름을 많이 넣어 비벼서 그릇에 담는다. 위에는 잡탕거리처럼 계란을 부쳐서 골패짝만큼씩 썰어 얹는다. 완자는 고기를 곱게 다져 잘 재워 구슬만큼씩 빚은 다음 밀가루를 약간 묻혀 계란을 씌워 부쳐 얹는다. 비빔밥 상에 장국은 잡탕국으로 해서 쓴다."\n\n\n== 비빔밥종류 ==\n\n지역에 따라 여러 가지 비빔밥이 있는데, 특히 전주비빔밥과 진주비빔밥 등이 유명하다. 최근 식단이 서구화되면서, 다양한 재료를 활용한 퓨전 비빔밥이 등장하거나, 잊혀져가는 지방의 비빔밥을 재해석해 현대화하기도 한다.\n\n꼬막비빔밥: 전라남도 순천, 벌교의 비빔밥으로 벌교 꼬막과 무순 등을 넣고 비벼 만든다.\n닭비빔밥: 평안도 지방의 비빔밥으로 삶은 닭고기를 넣어 푸짐하고 고추장대신 참기름에 고춧가루를 개어 칼칼하다. 또한 닭고기와 콩나물이 들어간 닭국을 곁들여 먹는다.\n돌솥비빔밥: 돌솥에 내는 비빔밥이다.\n마산비빔밥: 경상남도 마산의 비빔밥으로 마산의 특산물인 장에 미더덕과 조개의 육즙으로 무친 나물을 넣고 만든다.\n멍게젓비빔밥: 멍게젓을 이용한 거제도의 대표적인 향토음식이다. 거제도의 특산물인 멍게를 잘게 썰어 서늘한 곳에 2~5일 젓갈로 숙성시킨 후 밥위에 비벼 먹는다. 고추장 대신 김가루와 깨소금, 참기름에 비벼먹는다.\n알밥: 생선알을 넣어 만든 비빔밥이다.\n육회비빔밥: 여러 가지 야채와 배를 썰어 넣고 육회가 어우러진 것으로, 부드럽게 씹히는 생고기와 감칠맛 나는 매콤한 양념장이 어우러져 함평만이 독특한 비빔밥이다.\n전주비빔밥: 전북특별자치도 전주시의 비빔밥으로서, 재료 중에서 콩나물이 중요하다. 임실군에서 나는 서목태와 좋은 물로 길러서 오래 삶아도 질감이 좋은 것이 특징이다. 밥을 지을 때 쇠머리 고운 물로 밥을 짓고 뜸들일 때에 콩나물을 넣는다. 달걀 노른자는 생으로 올라간다. 콩나물국과 함께 먹는다. 육수에 밥을 짓고 쇠고기, 콩나물, 시금치, 쑥갓, 고사리, 도라지, 미나리, 표고버섯 등을 얹어 고추장에 비벼먹는 따뜻한 밥이다. 육회가 올려지기도 한다.\n진주비빔밥: 경상남도 진주 지방의 비빔밥으로 놋그릇에 흰밥과 다섯 가지 나물을 담은 후 고추장을 얹는 데, 그 모습이 아름다워서 화반(花飯)이라고 불린다. 일반적인 비빔밥처럼 콩나물 대신 숙주나물을 쓰며, 해초나물과 해물보탕국 한국자 넣고, 그 위에 소고기 육회를 듬뿍 얹어낸다. 곁들여 먹는 국물은 선짓국을 쓴다.\n통영비빔밥: 경상남도 통영의 비빔밥으로, 그 지역 사람들은 명절의 차례 및 기 제사, 잔치 등에 먹는다. 미륵도 근처 이끼섬에서 자생하는 방풍초(防風草)를 나물로 무친 방풍나물이 들어간다. 그외 볶은 조개를 두부에 섞어 만든 톳나물과 계절에 따라 10가지 이상의 나물을 넣는다. 생합자와 바지락 볶은 것을 넣는 것도 특색이다.\n평양비빔밥: 전주비빔밥과 유사하지만 육회대신 볶은 소고기를, 콩나물 대신 숙주나물을 사용하여 고유의 독특한 맛을 지닌다.\n해주비빔밥: 황해도 해주의 비빔밥으로, 모양이 아름다워서 교반(交飯)이라고 하여 유명하였다.\n헛제삿밥: 대구 헛제삿밥도 유명했으나 지금은 사라지고, 안동의 헛제삿밥만이 남았다. 실제 제사가 아니라 제삿상에 주로 올리는 음식들을 요리하여, 제사가 아닌 평상시에 비벼 먹는 비빔밥을 의미한다. 실제 제사를 올린 음식으로 비빔밥을 해 먹을 때에는 \'제삿밥\'으로 지칭한다. 고추장 대신, 간장으로 맛을 내며, 전이나 구운 생선 토막, 또는 산적을 곁들인다.\n회덮밥: 생선회를 넣어 만든 비빔밥이다. 대표적으로 홍어회 비빔밥 / 장어 덮밥/ 참치 덮밥/광어 덮밥/연어 덮밥/새우장 덮밥\n산채비빔밥: 여러 가지 나물을 넣고 참기름과 고추장에 비벼서 먹는 비빔밥이라고 전해지고 있다.\n닭고기 비빔밥:닭과 여러가지 야채 및 고명으로 계란을 올려서 고추장에 비벼먹는 비빔밥이라고 한다.\n\n\n== 풍속 ==\n비빔밥을 "헛제삿밥"이라고도 하며, 밤참을 파는 집을 "헛제삿집"이라고도 한다. 이는 밤참을 먹는 것이 마치 제례 후에 음복을 하고 종가에서 비벼주는 밥을 먹는 듯하다는 뜻에서 붙여진 말로, 현대에도 제사를 지내는 집에서는 음복 후에 젯메(밥)와 제삿상에 올린 적, 숙채, 간납 등을 넣고 밥을 비벼 먹는 경우가 있다.\n섣달 그믐날에는 그 해에 먹던 반찬이 해를 넘기는 것을 꺼려하여서, 남은 밥에 먹다 남은 반찬을 모두 넣고 비벼서 밤참으로 나누어 먹기도 하였다.\n농촌에서는 들밥을 준비할 때 밥과 나물을 준비하고 그릇으로 쓸 자그마한 바가지를 많이 가지고 나가면, 일꾼들이 각자 바가지에 먹을 만큼 밥을 덜고 나물과 고추장을 덜어 넣어 비벼 먹기도 하였다.\n\n\n== 사진 ==\n\n\n== 같이 보기 ==\n껌 엄푸\n볶음밥\n비빔국수\n\n\n== 각주 ==',
#    'title': '비빔밥',
#    'url': 'https://ko.wikipedia.org/wiki/%EB%B9%84%EB%B9%94%EB%B0%A5'},
#   {'content': "《보석 비빔밥》은 2009년 9월 5일부터 2010년 2월 21일까지 방영된 문화방송 주말 특별기획 드라마이며 해당 작품부터 MBC의 주말 특별기획 드라마가 9시 45분으로 이동하면서 2009년 4월 4일 독립 편성된 뒤 토요일 밤 10시 35분에 편성됐지만 MBC가 《2009 외인구단》을 통해 주말 특별기획 드라마를 부활(2차)시킴에 따라 같은 해 5월 2일부터 9시 45분으로 옮겨간 《세바퀴》는 《2009 외인구단》과 그 후속작 《친구, 우리들의 전설》이 기대 이하의 성적에 그치자 앞서 본 것처럼 해당 작품부터 주말 특별기획 드라마가 9시 45분으로 옮겨짐에 따라 2009년 9월 5일부터 토요일 10시 45분으로 옮겨갔고 주말 《뉴스데스크》시간대가 2010년 가을개편부터 8시로 조정되자 같은 해 11월 6일부터 토요일 밤 11시 15분으로 이동했다.\n\n\n== 기획 의도 ==\n네 가지 보석(비취, 루비, 산호, 호박) 이름을 지닌 4남매의 로맨스 이야기를 다룬 홈 드라마.\n\n\n== 등장 인물 ==\n\n\n=== 루비네 ===\n한진희 : 궁상식(55세) 역 - 궁씨 집안의 가장이며 5남매의 아빠, S호텔 도어맨.\n한혜숙 : 피혜자(55세) 역 - 궁씨 집안의 안주인이며 5남매의 엄마.\n강세정 : 궁비취(28세) 역 - 장녀, 구성작가 → 분식집 사장, 영국의 아내.\n소이현 : 궁루비(26세) 역 - 차녀, 간호사. 병훈의 여자친구- 아내\n이현진 : 궁산호(24세) 역 - 장남, 외무고시생 → 외교관. 강지의 남자친구->남편\n이일민 : 궁호박(18세) 역 - 차남, 고등학생.\n레시퐁 레오 : 궁태자(2세) 역 - 3남, 궁상식이 밖에서 낳아온 아들\n김영옥 : 결명자(74세) 역 - 상식의 어머니, 욕쟁이며 5남매의 친할머니.\n정혜선 : 백조(74세) 역 - 혜자의 친정엄마, 5남매의 외할머니\n\n\n=== 영국이네 ===\n박근형 : 서로마 (62세) 역 - 영국과 끝순의 아버지, 태리의 남편, 청명자기 회장\n홍유진 : 이태리 (55세) 역 - 영국과 끝순의 엄마, 로마의 아내\n이태곤 : 서영국(30세) 역 - 로마의 큰아들, 끝순의 오빠, 비취의 남편\n최아진 : 서끝순(18세) 역 - 로마의 막내딸, 영국의 여동생, 호박의 여자친구\n\n\n=== 그 외 인물 ===\n마이클 블렁크 : 카일(32세) 역 - 수도승 지원자\n정유미 : 이강지(23세) 역 - 산호의 여자친구 → 아내\n서우림 : 사장(70세) 역 - 루비가 일하는 병원의 환자, 전 의상실 사장이자 자산가\n신신애 : 피혜자의 친구 역\n최재호 : 조방규(40세) 역 - 궁상식의 동료, 호텔 도어맨\n황효은 : 마예순(35세) 역 - 로마네 가사 도우미\n윤종화 : 유병훈(29세) 역 - 루비의 남자친구 → 남편, 대학병원 의사\n이서빈 : 황우빈(30세) 역 - 영국의 친구, 연예인\n정이연 : 명선미 역 - 서끝순의 간호사이자 보디가드\n원종례 : 병훈 모 역 - 병훈의 어머니\n설운도 : 설황도 역 - 모창가수, 사장의 연인\n서동수 : 김손광 역 - 드라마 PD, 진상\n김지혜 : 옥동자(18세) 역 - 끝순의 친구\n홍석천 : 홍사현 역 - 비취가 집필하는 '늙은 아씨들' PD\n박대원 : 이진욱 역\n정세형 : 황 과장 역 - 서로마의 운전기사\n차성훈 : 박 기사 역\n서수남 : 미인대회 진행자 역\n김광규 : 성형외과 의사 역 (특별출연)\n오미희 : 정애 역 (특별출연) - 카일의 어머니, 재력가의 세련된 안주인\n김희라 : 사장네 가사 도우미\n양영준 : 박사월(74) 노래방 사장 결명자의 재혼남 역\n\n\n== 시청률 ==\n최저 시청률과 최고 시청률은 시청률 조사회사와 지역별로 시청률에 차이가 있을 수 있습니다.\n\n\n== 수상 ==\n2009년 MBC 연기대상 미니시리즈 여자 우수상 강세정\n2009년 MBC 연기대상 연속극 부문 황금 연기상 김영옥, 정혜선\n\n\n== 경쟁 프로그램 ==\n스타일 (SBS)\n그대, 웃어요 (SBS)\n천추태후 (KBS2)\n열혈 장사꾼 (KBS2)\n명가 (KBS1)\n\n\n== 참고 사항 ==\n임성한 작가의 전작 <보고 또 보고>처럼 가제는 <손짓>이었으나, 가족 구성원의 다양한 이야기를 맛있게 비벼낸다는 의미에서 제목을 <보석 비빔밥>으로 바꾸었다.\n이시영은 궁루비 역에 캐스팅되었으나 최종적으로 출연이 무산되었다.\n설운도는 한혜숙의 추천으로 첫 드라마 출연을 하게 되었다.\n2009년 10월 3일 (9회) 방영분에서 루비네 가족들이 서로 언쟁을 벌인 끝에 자식들이 부모에게 집에서 나가달라는 장면을 두고 시청자들 사이에서는 논란이 일어났다. 아무리 드라마라고 하지만 힘들게 키워준 부모를 자식 넷이 합세하여 집에서 쫓아냈다는 것은 예의와 윤리도덕상 벗어나는 행동이며, 공교스럽게도 추석 당일에 이런 장면이 방송된 것에 대한 유감을 표시하기도 했다. 드라마 홈페이지에서는 시청자들의 비판과 항의가 잇따라 빗발쳤으며 일각에서는 '고려장 드라마', '패륜 및 불효조장 드라마', '늙은 부모님들을 조롱한 드라마'라며 비꼬기도 했으며 '갈수록 막장으로 갔다'라는 비판도 이어졌다. 더군더나 궁상식 부부가 밖을 떠돌다가 각자 시댁 어머니와 친정 어머니 집을 왕래하는 장면 또한 문제로 제기되었다.\n2019년 개국한 MBC ON에서 재방송되었으며 MBC는 해당 드라마에 앞서 《그대, 웃어요》를 편성할 예정이었으나 해당 드라마 때문에 무산되자 SBS에서 간신히 편성됐다.\n\n\n== 각주 ==\n\n\n== 외부 링크 ==\niMBC 보석 비빔밥 홈페이지",
#    'title': '보석비빔밥',
#    'url': 'https://ko.wikipedia.org/wiki/%EB%B3%B4%EC%84%9D%EB%B9%84%EB%B9%94%EB%B0%A5'}]}

# %%
# Runnable -> Tool
class WikiSearchParameter(BaseModel):
    query: str = Field(..., description="한국어 Wikipedia에서 조회할 검색 keyword")
    max_result: int = Field(default=3, description="검색할 문서의 최대 개수. 생략하면 기본값으로 3을 사용")

wikipedia_search_tool = wikipedia_search.as_tool(
    name="search_wikipedia_korea", # 툴 이름
    description="""이 도구는 위키백과사전에서 정보를 검색할 때 사용한다.
사용자의 질문과 관련된 내용을 위키백과사전 사이트에서 지정한 개수의 문서만큼 검색해서 반환한다.
일반적인 지식이나 백과사전식 정보가 필요할 때 사용한다.""",
    args_schema=WikiSearchParameter
)
# Out:
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_29672\135443783.py:6: LangChainBetaWarning: This API is in beta and may change in the future.
#   wikipedia_search_tool = wikipedia_search.as_tool(

# %%
wikipedia_search_tool.name
wikipedia_search_tool.description
wikipedia_search_tool.args
# Out:
# {'query': {'description': '한국어 Wikipedia에서 조회할 검색 keyword',
#   'title': 'Query',
#   'type': 'string'},
#  'max_result': {'default': 3,
#   'description': '검색할 문서의 최대 개수. 생략하면 기본값으로 3을 사용',
#   'title': 'Max Result',
#   'type': 'integer'}}

# %%
tool_model = ChatOpenAI(model="gpt-5.4-mini").bind_tools([wikipedia_search_tool])
res = tool_model.invoke("사마귀의 종류에는 어떤 것이 있는지 조사해서 알려줘.")

# %%
res.content
res.tool_calls
# Out:
# [{'name': 'search_wikipedia_korea',
#   'args': {'query': '사마귀 종류', 'max_result': 5},
#   'id': 'call_g1gfr8KKUVP2HLG6nOCNmiGR',
#   'type': 'tool_call'}]

# %%
wikipedia_search_tool.invoke(res.tool_calls[0])
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\Documents\SKN31\10_AI_Agent\.venv\Lib\site-packages\requests\models.py:1116, in Response.json(self, **kwargs)
#    1115 try:
# -> 1116     return complexjson.loads(self.text, **kwargs)
#    1117 except JSONDecodeError as e:
#    1118     # Catch JSON-related errors and raise as requests.JSONDecodeError
#    1119     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~\AppData\Roaming\uv\python\cpython-3.13-windows-x86_64-none\Lib\json\__init__.py:352, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     349 if (cls is None and object_hook is None and
#     350         parse_int is None and parse_float is None and
#     351         parse_constant is None and object_pairs_hook is None and not kw):
# --> 352     return _default_decoder.decode(s)
#     353 if cls is None:
#
# File ~\AppData\Roaming\uv\python\cpython-3.13-windows-x86_64-none\Lib\json\decoder.py:345, in JSONDecoder.decode(self, s, _w)
#     341 """Return the Python representation of ``s`` (a ``str`` instance
#     342 containing a JSON document).
#     343
#     344 """
# --> 345 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     346 end = _w(s, end).end()
#
# File ~\AppData\Roaming\uv\python\cpython-3.13-windows-x86_64-none\Lib\json\decoder.py:363, in JSONDecoder.raw_decode(self, s, idx)
#     362 except StopIteration as err:
# --> 363     raise JSONDecodeError("Expecting value", s, err.value) from None
#     364 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 wikipedia_search_tool.invoke(res.tool_calls[0])
#
# File c:\Documents\SKN31\10_AI_Agent\.venv\Lib\site-packages\langchain_core\tools\base.py:738, in BaseTool.invoke(self, input, config, **kwargs)
#     730 @override
#     731 def invoke(
#     732     self,
#    (...)    735     **kwargs: Any,
#     736 ) -> Any:
#     737     tool_input, kwargs = _prep_run_args(input, config, **kwargs)
# --> 738     return self.run(tool_input, **kwargs)
#
# File c:\Documents\SKN31\10_AI_Agent\.venv\Lib\site-packages\langchain_core\tools\base.py:1100, in BaseTool.run(self, tool_input, verbose, start_color, color, callbacks, tags, metadata, run_name, run_id, config, tool_call_id, **kwargs)
#    1098 if error_to_raise:
#    1099     run_manager.on_tool_error(error_to_raise, tool_call_id=tool_call_id)
# -> 1100     raise error_to_raise
#    1101 output = _format_output(content, artifact, tool_call_id, self.name, status)
#    1102 run_manager.on_tool_end(output, color=color, name=self.name, **kwargs)
#
# File c:\Documents\SKN31\10_AI_Agent\.venv\Lib\site-packages\langchain_core\tools\base.py:1066, in BaseTool.run(self, tool_input, verbose, start_color, color, callbacks, tags, metadata, run_name, run_id, config, tool_call_id, **kwargs)
#    1064     if config_param := _get_runnable_config_param(self._run):
#    1065         tool_kwargs |= {config_param: config}
# -> 1066     response = context.run(self._run, *tool_args, **tool_kwargs)
#    1067 if self.response_format == "content_and_artifact":
#    1068     msg = (
#    1069         "Since response_format='content_and_artifact' "
#    1070         "a two-tuple of the message content and raw tool output is "
#    1071         f"expected. Instead, generated response is of type: "
#    1072         f"{type(response)}."
#    1073     )
#
# File c:\Documents\SKN31\10_AI_Agent\.venv\Lib\site-packages\langchain_core\tools\structured.py:97, in StructuredTool._run(self, config, run_manager, *args, **kwargs)
#      95     if config_param := _get_runnable_config_param(self.func):
#      96         kwargs[config_param] = config
# ---> 97     return self.func(*args, **kwargs)
#      98 msg = "StructuredTool does not support sync invocation."
#      99 raise NotImplementedError(msg)
#
# File c:\Documents\SKN31\10_AI_Agent\.venv\Lib\site-packages\langchain_core\tools\convert.py:460, in convert_runnable_to_tool.<locals>.invoke_wrapper(callbacks, **kwargs)
#     459 def invoke_wrapper(callbacks: Callbacks | None = None, **kwargs: Any) -> Any:
# --> 460     return runnable.invoke(kwargs, config={"callbacks": callbacks})
#
# File c:\Documents\SKN31\10_AI_Agent\.venv\Lib\site-packages\langchain_core\runnables\base.py:6004, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5997 @override
#    5998 def invoke(
#    5999     self,
#    (...)   6002     **kwargs: Any | None,
#    6003 ) -> Output:
# -> 6004     return self.bound.invoke(
#    6005         input,
#    6006         self._merge_configs(config),
#    6007         **{**self.kwargs, **kwargs},
#    6008     )
#
# File c:\Documents\SKN31\10_AI_Agent\.venv\Lib\site-packages\langchain_core\runnables\base.py:5313, in RunnableLambda.invoke(self, input, config, **kwargs)
#    5298 """Invoke this `Runnable` synchronously.
#    5299
#    5300 Args:
#    (...)   5310
#    5311 """
#    5312 if hasattr(self, "func"):
# -> 5313     return self._call_with_config(
#    5314         self._invoke,
#    5315         input,
#    5316         ensure_config(config),
#    5317         **kwargs,
#    5318     )
#    5319 msg = "Cannot invoke a coroutine function synchronously.Use `ainvoke` instead."
#    5320 raise TypeError(msg)
#
# File c:\Documents\SKN31\10_AI_Agent\.venv\Lib\site-packages\langchain_core\runnables\base.py:2289, in Runnable._call_with_config(self, func, input_, config, run_type, serialized, **kwargs)
#    2285     child_config = patch_config(config, callbacks=run_manager.get_child())
#    2286     with set_config_context(child_config) as context:
#    2287         output = cast(
#    2288             "Output",
# -> 2289             context.run(
#    2290                 call_func_with_variable_args,  # type: ignore[arg-type]
#    2291                 func,
#    2292                 input_,
#    2293                 config,
#    2294                 run_manager,
#    2295                 **kwargs,
#    2296             ),
#    2297         )
#    2298 except BaseException as e:
#    2299     run_manager.on_chain_error(e)
#
# File c:\Documents\SKN31\10_AI_Agent\.venv\Lib\site-packages\langchain_core\runnables\config.py:526, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     524 if run_manager is not None and accepts_run_manager(func):
#     525     kwargs["run_manager"] = run_manager
# --> 526 return func(input, **kwargs)
#
# File c:\Documents\SKN31\10_AI_Agent\.venv\Lib\site-packages\langchain_core\runnables\base.py:5170, in RunnableLambda._invoke(self, input_, run_manager, config, **kwargs)
#    5168                 output = chunk
#    5169 else:
# -> 5170     output = call_func_with_variable_args(
#    5171         self.func, input_, config, run_manager, **kwargs
#    5172     )
#    5173 # If the output is a Runnable, invoke it
#    5174 if isinstance(output, Runnable):
#
# File c:\Documents\SKN31\10_AI_Agent\.venv\Lib\site-packages\langchain_core\runnables\config.py:526, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     524 if run_manager is not None and accepts_run_manager(func):
#     525     kwargs["run_manager"] = run_manager
# --> 526 return func(input, **kwargs)
#
# Cell In[50], line 25, in wikipedia_search(inputs)
#      21         query=query,  # 검색어
#      22         load_max_docs=max_result,  # 검색할 문서 최대 개수
#      23         lang="ko"  # 검색할 wikipedia 나라
#      24     )
# ---> 25     docs = loader.load()  # list[Document]
#      26     result_list = []
#      27     for doc in docs:
#      28         result_list.append(
#
# File c:\Documents\SKN31\10_AI_Agent\.venv\Lib\site-packages\langchain_core\document_loaders\base.py:43, in BaseLoader.load(self)
#      37 def load(self) -> list[Document]:
#      38     """Load data into `Document` objects.
#      39
#      40     Returns:
#      41         The documents.
#      42     """
# ---> 43     return list(self.lazy_load())
#
# File c:\Documents\SKN31\10_AI_Agent\.venv\Lib\site-packages\langchain_community\document_loaders\wikipedia.py:59, in WikipediaLoader.lazy_load(self)
#      46 """
#      47 Loads the query result from Wikipedia into a list of `Document` objects.
#      48
#    (...)     51         Wikipedia pages.
#      52 """
#      53 client = WikipediaAPIWrapper(  # type: ignore[call-arg]
#      54     lang=self.lang,
#      55     top_k_results=self.load_max_docs,  # type: ignore[arg-type]
#      56     load_all_available_meta=self.load_all_available_meta,  # type: ignore[arg-type]
#      57     doc_content_chars_max=self.doc_content_chars_max,  # type: ignore[arg-type]
#      58 )
# ---> 59 yield from client.load(self.query)
#
# File c:\Documents\SKN31\10_AI_Agent\.venv\Lib\site-packages\langchain_community\utilities\wikipedia.py:115, in WikipediaAPIWrapper.load(self, query)
#     107 def load(self, query: str) -> List[Document]:
#     108     """
#     109     Run Wikipedia search and get the article text plus the meta information.
#     110     See
#    (...)    113
#     114     """
# --> 115     return list(self.lazy_load(query))
#
# File c:\Documents\SKN31\10_AI_Agent\.venv\Lib\site-packages\langchain_community\utilities\wikipedia.py:125, in WikipediaAPIWrapper.lazy_load(self, query)
#     117 def lazy_load(self, query: str) -> Iterator[Document]:
#     118     """
#     119     Run Wikipedia search and get the article text plus the meta information.
#     120     See
#    (...)    123
#     124     """
# --> 125     page_titles = self.wiki_client.search(
#     126         query[:WIKIPEDIA_MAX_QUERY_LENGTH], results=self.top_k_results
#     127     )
#     128     for page_title in page_titles[: self.top_k_results]:
#     129         if wiki_page := self._fetch_page(page_title):
#
# File c:\Documents\SKN31\10_AI_Agent\.venv\Lib\site-packages\wikipedia\util.py:28, in cache.__call__(self, *args, **kwargs)
#      26   ret = self._cache[key]
#      27 else:
# ---> 28   ret = self._cache[key] = self.fn(*args, **kwargs)
#      30 return ret
#
# File c:\Documents\SKN31\10_AI_Agent\.venv\Lib\site-packages\wikipedia\wikipedia.py:103, in search(query, results, suggestion)
#     100 if suggestion:
#     101   search_params['srinfo'] = 'suggestion'
# --> 103 raw_results = _wiki_request(search_params)
#     105 if 'error' in raw_results:
#     106   if raw_results['error']['info'] in ('HTTP request timed out.', 'Pool queue is full'):
#
# File c:\Documents\SKN31\10_AI_Agent\.venv\Lib\site-packages\wikipedia\wikipedia.py:742, in _wiki_request(params)
#     739 if RATE_LIMIT:
#     740   RATE_LIMIT_LAST_CALL = datetime.now()
# --> 742 return r.json()
#
# File c:\Documents\SKN31\10_AI_Agent\.venv\Lib\site-packages\requests\models.py:1120, in Response.json(self, **kwargs)
#    1116     return complexjson.loads(self.text, **kwargs)
#    1117 except JSONDecodeError as e:
#    1118     # Catch JSON-related errors and raise as requests.JSONDecodeError
#    1119     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# -> 1120     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %% [markdown]
# ## Vector Store(Vector 저장소)를 tool로 생성
#
# 1.  `langchain_core.tools.create_retriever_tool` 함수 이용
#     - 이미 만든 retriever를 Agent가 호출할 수 있는 Tool로 변환하는 함수
#     - **주요 파라미터**
#         - `retriever`: vectorstore.as_retriever() 등으로 만든 Retriever
#         - `name`: Agent가 사용할 Tool 이름
#         - `description`: Agent가 언제 이 Tool을 써야 하는지 판단하는 설명
#         - `document_prompt`:
#           - 검색된 각 문서를 어떤 형식으로 문자열화할지 지정. 개별 검색결과를 지정한 PromptTemplate에 맞춰 프롬프트를 만든다.
#           - PromptTemplate의 변수는 Document의 metadata의 key 값들을 사용하여, 그 값(value)이 입력되도록 한다.
#         - `document_separator`: 검색결과가 여러개일 경우 그 결과를 하나의 문자열로 묶어서 반환한다. 합칠때 사용할 구분자를 지정한다. 기본값은 `\n\n` 이다.
#         - `response_format`: Tool 응답을 content:str만 줄지("content"), 원본 Document까지 artifact ("content_and_artiface")로 줄지 지정
#
# 2. `@tool` 을 이용해 직접 구현
#    - query를 입력받아 retriever를 이용해 조회하여 그 결과를 반환하는 tool을 직접 구현한다.
#    - create_retriever_tool() 함수는 빠르고 쉽게 구현할 수 있지만 유연성이 떨어진다. 그래서 전/후 처리등을 직접 제어해야 할 경우 @tool을 이용해 구현한다.
#
# 3. VectorStore도 Runnable이므로 `as_tool()` 메소드를 이용해 변환할 수 있다.

# %% [markdown]
# ### text loading -> Document 생성
# - 레스토랑 메뉴를 vector store에 저장한다.
# 1. 메뉴 text 를 로딩한다.
# 2. 각 메뉴의 내용(음식이름, 메뉴설명, 파일명)을 넣어 Document를 생성한다.

# %%
# 문서 Load
import os
# 메뉴읽어 오기
menu_file_path = "data/restaurant_menu.txt"
with open(menu_file_path, "r", encoding="utf-8") as f:
    menu = f.read()

# %%
# Split - 메뉴별로 분리하기 위해 직접 처리
from langchain_core.documents import Document
import re
from pprint import pprint

def create_documents(menu_all: str, file_name) -> list[Document]:
    """메뉴별로 분리 한뒤 Document로 변환. 변환된 Document들을 리스트로 반환
    metadata: 메뉴이름, 주요 재료, 가격, source(파일이름)
    """
    menu_list = menu_all.split("\n\n")
    menu_documents = []
    for menu_item in menu_list:

        # 메뉴 이름 추출
        menu_name_pattern = r"(^\d+.\s)([가-힣a-zA-Z\d ]+)"
        menu_name_result = re.search(menu_name_pattern, menu_item)
        menu_name = menu_name_result.group(2).strip()  # 메뉴 이름 추출 # 1은 번호

        # 주요재료 추출 - text로 indexing.
        menu_ingredient_pattern = r"(?<=주요 재료: ).+"
        ingredients = re.search(menu_ingredient_pattern, menu_item).group().strip()
    
        # 가격추출
        price_pattern = r"(?<=가격: )[\d,]+(?=원)"
        price_result = re.search(price_pattern, menu_item)
        price = int(price_result.group().replace(",", ""))

        
        # 메뉴 이름을 제외한 나머지는 메뉴 설명으로 간주
        menu_doc = Document(
            page_content=menu_item,     # 메뉴 설명을 page_content에 넣는다. metadata는 나중에 따로 따로 payload filtering 할 수있기 때문에 
            metadata={
                "menu_name": menu_name, # 메뉴 이름
                "price": price,         # 가격
                "ingredients": ingredients, # 재료 리스트
                "source": file_name     # 메뉴가 저장된 파일 이름
            }
        )
        menu_documents.append(menu_doc)
    return menu_documents


menu_documents = create_documents(menu, menu_file_path)
print(len(menu_documents))

# %%
# VectorDB 저장 및 VectorStore 생성
from langchain_qdrant import QdrantVectorStore
from langchain_openai import OpenAIEmbeddings
from qdrant_client import QdrantClient
from qdrant_client.http.models import Distance, VectorParams
from dotenv import load_dotenv

load_dotenv()

COLLECTION_NAME = "restaurant_menu"
VECTOR_SIZE = 1536  # OpenAIEmbeddings의 벡터 크기

embeddings = OpenAIEmbeddings(model="text-embedding-3-small")

client = QdrantClient(host="localhost", port=6333)
if client.collection_exists(COLLECTION_NAME):
    client.delete_collection(COLLECTION_NAME)

# Collection 생성
client.create_collection(
    collection_name=COLLECTION_NAME,
    # 벡터 저장소에 대한 설정. - vector_config는 default이므로 이름을 안줘도 됨(default 로 잡힘) 이름을 줄 거면 {"이름":VectorParams()} 설정
    vectors_config=VectorParams(
        size=VECTOR_SIZE, 
        distance=Distance.COSINE
    )
)

vectorstore = QdrantVectorStore(
    client=client, # QdrantClient
    embedding=embeddings, # Embedding Model
    collection_name=COLLECTION_NAME # 연결할 Collection 지정.
)
ids = vectorstore.add_documents(menu_documents)
print(f"저장된 문서 개수: {len(ids)}")
##################################################
# Retriever 생성
##################################################
menu_retriever = vectorstore.as_retriever(
    search_kwargs={"k": 3}  # 검색할 결과 개수
)

from langchain_core.runnables import ConfigurableField
retriever = menu_retriever.configurable_fields(
    search_type=ConfigurableField(
        id="search_type"
    ),
    search_kwargs=ConfigurableField(
        id="search_kwargs"
    ),
)

# %% [markdown]
# # create_agent() 를 이용한 Agent 구현
#
# - create_agent()
#   - 랭체인에서 제공하는 표준 에이전트 생성함수로 LLM이 도구를 사용해서 문제를 해결하는 기본구조를 기반으로 설계되었다.
#     - Agent 생성 및 실행을 표준화, 단순화 하기 위헤 Langchain 1.0에서 도입 되었다.
#     - 도구사용 기본 구조에 **middleware**를 이용해 다양한 시점에 다양한 동작이 실행될 수 있는 유연한 구조를 지원한다.
#
#     ![기본구조](figures/langgraph_basic_flow.png)
#   - 0.x 버전까지는 Agent 생성 함수는
#     1. model과 tool들을 넣어 Agent를 생성하고
#     2. 그것을 실행하는 Executor를 생성하는 방식으로
#   - 여러 단계를 거쳐야 했다.
#   - create_agent()는 이러한 단계를 1단계로 축약한 API이다.
#
# - create_agent 설계 철학
#     1. Agent를 구성하는 모든 실행단위는 Runnable 이다.
#     2. Agent도 Runnable 이다.
#     3. Agent는 하나의 표준 팩토리 함수(생성함수)로 통합한다.
#
# ## 주요 파라미터
# - https://reference.langchain.com/python/langchain/agents/
# - `model`
#   - Agent에서 사용할 모델을 지정한다.
#   - 문자열로 모델이름을 넣을 수도 있고 BaseChatModel(ex: ChatOpenAI) 타입의 객체를 전달 할 수도 있다.
# - `tools`
#   -  Agent가 사용할 외부 도구(tool) 목록(list)을 전달한다.
# - `system_prompt`
#   - Agent에 입력하는 시스템 프롬프트. 문자열 또는 `SystemMessage`객체로 입력한다.
#   - 이 prompt는 모델 호출시 가장 먼저 입력되는 것으로 Agent의 행동 지침, 성격을 정의하는 데 사용된다.
#   - `middleware`
#     - Agent 실행 흐름에서 특정 지점에서 동작을 가로채서 실행되는 middelware(중간처리기) 목록을 전달한다.
#     - Agent실행 전/후, Model 호출 전/후 등 사전 정의된 hook에 맞춰 정의된 middleware들을 등록한다.
#   - `response_format`
#     - Agent 최종 출력 결과 형식을 구조화하는 schema를 설정.
#   - `checkpointer`
#     - 에이전트 실행 중 상태를 저장하는 객체, 즉 단기 메모리 저장소을 설정한다.
#   - `store`
#     - 지속성 저장소 즉 장기 메모리 저장소를 설정한다.

# %% [markdown]
# # LangChain에서 MCP 연동
#
# ## MCP란
#
# - **MCP**(**Model Context Protocol**)는 Anthropic이 주도하여 2024년 말에 발표한 개방형 표준으로, LLM 애플리케이션이 외부 데이터 소스나 도구에 접근하는 방식을 표준화 하는 프로토콜이다.
#   - Agent가 이용할 수 있는 tool을 구현하는 방법은 framework 마다 다르기 때문에 서로 호환 되지 않는 문제가 있다.
#   - MCP는 이런 문제를 해결하기 위해 만든 표준 프로토콜이다.
#
# ## MCP 아키텍처 구성 요소
# - **MCP 호스트**
#   -  AI 애플리케이션(예: LLM 채팅 애플리케이션)으로 MCP 클라이언트를 통해 여러 서버에 연결한다.
#
# - **MCP 클라이언트**
#   -  각 MCP 서버와의 연결을 유지하는 구성요소로, 서버로부터 도구/리소스/프롬프트를 가져와 LLM 모델에게 전달한다.
#
# - **MCP 서버**
#   -  외부 데이터 소스나 Tool들을 제공하는 프로그램이다. 서버는 도구, 리소스, 프롬프트를 노출하고 클라이언트와 JSON‑RPC 2.0 메시지로 통신한다.
#   -  MCP는 서버 클라이언트 간의 **로컬 프로세스 간 통신을 위한 STDIO**와 **원격 서버 접속을 위한 Streamable HTTP** 두 가지 전송 방식을 지원한다
#   -  **MCP 서버가 제공하는 것**
#      -  **도구**(**Tools**): LLM이 호출할 수 있는 함수형 작업이다. 예를 들어 “queryDatabase”, “sendEmail” 등이 있으며 각 도구는 이름, 설명, 입력 스키마를 포함한다.
#      -  **리소스**(**Resources**): 읽기 전용 데이터 소스로, 검색 색인·파일시스템·데이터베이스 등에서 컨텍스트를 제공한다.
#      -  **프롬프트**(**Prompts**): LLM 프롬프트 템플릿이나 예시를 서버에서 제공해 AI 모델의 질의를 돕는다.
#
#
# ## 사용 가능한 MCP 서버 검색
#
# - MCP 생태계에는 수천 개의 툴 서버가 이미 공개되어 있으며, 원하는 기능의 툴을 검색하여 사용할 수 있다.
# - MCP 검색 및 서비스 사이트
#   - [PulseMCP](pulsemcp.com)
#   - [MCP 마켓](https://mcpmarket.com/ko)
#   - [MCP Servers](https://mcp.so/)
#   - [smithery](https://smithery.ai/servers)

# %% [markdown]
# ## LangChain에서 MCP 서버 연동하기
# - MCP 서버를 사용하기 위해서는 **Node.js**를 설치 해야 한다.
#   - https://nodejs.org/ko/download
# - LangChain에서 MCP 서버와 연동하기 위해서는 Adapter lib 설치가 필요하다.
#   - `pip install langchain-mcp-adapters`
#
# ###  MultiServerMCPClient
# - **MCP 클라이언트 객체**로, LangChain에서 **하나 이상의 MCP 서버를 연결하고 Tool 목록을 가져오기 위해 사용**한다.
#     - 여러 개의 MCP 서버를 **동시에 등록하고 연결**할 수 있다.
#     - 서버 설정들을 **하나의 딕셔너리**(**Dictionary**)로 묶어 전달하며, **각 개별 서버 역시 Dictionary로 설정**한다.
#     - MCP 클라이언트에 등록된 모든 서버는 이후 `get_tools()` 호출을 통해 서버가 제공하는 tool들을 **LangChain의 Tool 객체로 자동 변환해 Agent가 호출**(**사용**)할 수있게 한다.
#
# #### 개별 서버 설정 Key 정의
# - **`dict[str: 서버 별칭, dict: 서버 설정]`**
#
# | 설정 Key        | 의미                                                                  | 사용 예                            |
# | --------------- | --------------------------------------------------------------------- | ---------------------------------- |
# | **`transport`** | 서버와 통신하는 방식                                                  | `"stdio"` 또는 `"streamable-http"` |
# | **`command`**   | MCP 서버를 실행할 프로그램(프로세스)                                  | `"python"` 또는 `"npx"`            |
# | **`args`**      | command에 전달할 세부 실행 인자를 **리스트(List)**에 문자열로 순서대로 배치 | `["-m", "mcp_server_time"]`  |
# | **`env`**       | MCP 서버 실행시 필요한 환경변수 설정. (API Key)                       | `{"FIRECRAWL_API_KEY": os.getenv("FIRECRAWL_API_KEY")}`|
#
# - **transport 값에 따른 동작 구분**
#     - `"stdio"`: 로컬에서 실행되는 서버 연결
#     - `"streamable-http"`: 원격 MCP 서버(서비스형) 연결
#
#     ```json
#         {
#             "time": {
#                 "transport": "stdio",
#                 "command": "python",
#                 "args": ["-m", "mcp_server_time"]
#             }
#
#             "github": {
#                 "transport": "streamable-http",
#                 "url": "https://server.smithery.ai/github",
#             }
#         }
#     ```
#
# #### command + args 와 실행 명령어 관계
#
# | 실제 실행 명령                    | 설정으로 표현되는 방식                                             |
# | --------------------------- | -------------------------------------------------------- |
# | `python -m mcp_server_time` | `"command": "python", "args": ["-m", "mcp_server_time"]` |
# | `npx -y @org/server`        | `"command": "npx", "args": ["-y", "@org/server"]`        |
#
# * **command는 실행 프로그램**, args는 **명령 뒤에 붙는 옵션을 순서 그대로 리스트에 나열**한다.
