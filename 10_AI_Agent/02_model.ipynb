# %%
# 가상환경
# uv venv .venv --python=3.13

# uv pip install ipykernel ipywidgets
# uv pip install langchain python-dotenv

# %% [markdown]
# # Model I/O
#
# - **Model I/O는 언어 모델(LLM)에 입력을 전달하고, 생성된 출력을 처리하는 과정과 이를 구성하는 요소들을 의미한다.**
# - LangChain에서는 주로 **프롬프트 템플릿**(**Prompt Template**), **언어 모델**(**Language Model**), **출력 파서**(**Output Parser**)를 사용하여 Model I/O를 구성한다.
#
# ## Model I/O 구성 요소
#
# ### 프롬프트 템플릿 (Prompt Template)
#
# - LLM에 전달할 프롬프트를 생성하는 역할을 한다.
# - '사용자 입력과 고정된 템플릿을 결합'하여 '일관된 형식의 프롬프트를 생성'한다.
# - 프롬프트를 구조화하여 모델이 원하는 방식으로 응답하도록 유도한다.
#
# ### 대형 언어 모델 (LLM - Large Language Model)
#
# - '입력된 프롬프트'를 기반으로 '텍스트를 생성'하거나 입력 '내용을 분석'하여 결과를 생성한다.
# - OpenAI의 GPT, Anthropic의 Claude, Google의 Gemini 등이 대표적인 언어 모델이다.
# - Langchain은 LLM 연동 API를 제공한다.
#
# ### 출력 파서 (Output Parser)
#
# - 언어 모델의 '출력을 원하는 형식으로 변환'하는 역할을 한다.
# - 텍스트 응답에서 '필요한 정보를 추출'하거나 'JSON, Pydantic 객체 등' 구조화된 데이터로 변환할 수 있다.
# - 출력 데이터를 정제하고 후처리하여 다음 단계에서 활용하기 쉽도록 만든다.
#
# ![model id](figures/model_io.jpg)

# %% [markdown]
# # Chatbot 서비스 사용과 LLM API 사용의 차이
#
# ChatGPT나 Claude 챗봇 서비스를 사용하는 것과 GPT 5.5 모델 또는 Opus 4.8 와 같은 LLM 모델을 API를 이용해 사용하는 것의 차이는 다음과 같이 정리할 수 있다.
#
# | 구분        | Chatbot서비스 사용       | LLM API 사용 |
# | --------- | ---------------- | ------------- |
# | 대상        | 일반 사용자           | 개발자           |
# | 목적        | AI를 바로 사용        | AI를 서비스에 내장   |
# | 인터페이스     | 웹/앱              | 프로그래밍 코드      |
# | 사용자 제어 수준     | 제한적       | 매우 높음         |
# | 비용        | 구독료(Plus, Pro 등) | 사용량 기반 과금     |
# | 개발 가능성    | 없음               | 가능            |
# | 시스템 프롬프트  | 일부만 가능           | 완전 제어         |
# | 외부 시스템 연동 | 제한적              | 자유롭게 가능       |
#
# **ChatGPT와 같은 LLM 기반 Chatbot는 완성된 AI 서비스**이고, **OpenAI GPT 5.5 같은 API는 단순히 응답을 생성해 주는 LLM 모델을 이용해 AI 서비스를 만들기 위한 것**이다.

# %% [markdown]
# # OpenAI 모델 사용
# - https://platform.openai.com
#
# ## 결제
# 1. 로그인 후 Billing 페이지로 이동.
#    - **신용카드가 등록된 경우 바로 충전할 수 있다.**
#    - setting -> Billing
#
#    ![openai_payment.png](figures/openai_payment.png)
#    - 금액 입력 후 `continue`
#    - 다음 페이지에서 세금 포함 결제 금액 나오면 `Confirm`  한다.
#
# 2. 신용카드 등록
#    - Payment methods 탭을 선택하고 카드를 등록한다.
#
#    ![openai_payment2.png](figures/openai_payment2.png)
#
#    - 등록이 끝나면 최초 구매를 진행한다. $5 ~ $100 사이의 금액을 선택할 수 있다.
#    - 자동 충전을 설정하고 싶다면 automatic recharge 를 활성화 하고 아래 추가 설정에 입력한다.
#      - 자동 충전은 특정 금액 이하로 떨어지면 자동으로 충전한다. (**비활성화**)
#
#    ![openai_payment3.png](figures/openai_payment3.png)
#
# 3. 수동으로 **추가 결제하기**
#    - Billing 페이지의 Overview에서 `Add to credit balance` 를 클릭한 뒤 금액을 입력하고 결제한다.
#
# ## 사용량 확인
# - profile/설정 -> Usage 에서 확인

# %% [markdown]
# ## API Key 생성
#
# ![openai_create_apikey.png](figures/openai_create_apikey.png)
#
# - 로그인 -> Dashboard -> API Keys -> Create New Secreat Key
# > Settings -> API Keys
#
# ## API Key 등록
# - 환경변수에 등록
#   - 변수이름: OPENAI_API_KEY
#   - 값: 생성된 키
# - dotenv를 이용해서 load
#   - Working directory에  `.env` 파일 생성하고 `OPENAI_API_KEY=생성된키` 추가한다.
#   - load_dotenv() 호출 하면 .env 파일에 있는 값을 읽은 뒤 환경변수로 등록한다.
# - **주의**
#   - 생성된 API Key는 노출되면 안된다.
#   - API Key가 저장된 파일(코드나 설정파일)이 github에 올라가 공개되서는 안된다.
#
# ## 사용 비용 확인
# - settings -> Usage 에서 확인
#
# ## OpenAI LLM 모델들
# -  OpenAI LLM 모델: https://platform.openai.com/docs/models
# -  모델별 가격: https://platform.openai.com/docs/pricing
# -  토큰사이즈 확인: https://platform.openai.com/tokenizer
#    -  1토큰: 영어 3\~4글자 정도, 한글: 대략 1\~2글자 정도
#    -  모델이 업데이트 되면서 토큰 사이즈도 조금씩 커지고 있다.

# %% [markdown]
# ## OpenAI 를 연동하기 위한 package 설치
# ```bash
# pip install langchain-openai -qU
# ```
#
# - OpenAI 자체 라이브러리 설치
#     - `pip install openai -qU`
#     - langchain-openai를 설치하면 같이 설치 된다.

# %%
# uv pip install langchain-openai

# %% [markdown]
# ## OpenAI Library 를 이용한 API 호출

# %%
from dotenv import load_dotenv

load_dotenv(override=True)
# Out:
# True

# %%
import os
os.getenv("OPENAI_API_KEY")

# %%
from openai import OpenAI

client = OpenAI() # 환경 변수로 등록 안 한 경우 API Key 설정.
response = client.chat.completions.create(
    model="gpt-5.4-nano",
    messages=[
        {"role":"user", "content":"OpenAI의 LLM 모델 종류는 뭐가 있나요?"}
    ] # 프롬프트 입력 - 대화 형식
)

# %%
print(response)
# Out:
# ChatCompletion(id='chatcmpl-DsLzKRejg3qDr6pcqMv2r4bMo7sla', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='OpenAI의 LLM(대규모 언어모델) 라인업은 시기/목적에 따라 여러 “모델 계열”로 나뉩니다. 다만 정확한 “현재 제공 중인 모델 목록”은 시간이 지나며 바뀔 수 있어요. 아래는 **대표적으로 알려진 OpenAI LLM 계열** 정리입니다.\n\n## 1) GPT(범용 대화/추론) 계열\n- **GPT-4 / GPT-4o / GPT-4.1**: 고성능 범용 추론·대화 모델(최신 멀티모달 포함 여부는 버전에 따라 다름)\n- **GPT-4o mini**: 비용/지연을 낮춘 경량(빠른) 모델로 자주 쓰임\n- **GPT-3.5**(구형): 경량 모델로 과거에 많이 사용되었고, 현재 제공 여부/역할은 달라질 수 있음\n\n## 2) o-series (추론 특화) 계열\n- **o1 / o3-mini** 등: “추론(reasoning)”에 강점을 둔 계열로 알려져 있습니다(복잡한 문제에서 성능을 노리는 용도).\n\n## 3) 임베딩(Embedding) 모델(LLM이라기보단 관련 계열)\n- **text-embedding-3-small / -3-large**: 텍스트를 벡터로 바꾸는 모델(검색/RAG에 흔히 사용)\n\n## 4) 이미지/음성 등 멀티모달 관련\n- GPT-4o 같은 모델은 텍스트뿐 아니라 이미지/음성 등 **멀티모달**로 확장된 형태가 있습니다(세부 지원은 모델/엔드포인트에 따라 다름).\n\n---\n\n원하시면 제가 더 정확히 맞춰드릴게요.  \n1) **지금 사용하려는 목적**이 대화/코딩/추론/검색(RAG)/음성 중 뭐에 가까운가요?  \n2) 그리고 “**현재 API에서 사용 가능한 정확한 모델명**”이 필요하신가요, 아니면 “**계열 개요**”면 충분하신가요?', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1781846606, model='gpt-5.4-nano-2026-03-17', object='chat.completion', moderation=None, service_tier='default', system_fingerprint=None, usage=CompletionUsage(completion_tokens=480, prompt_tokens=19, total_tokens=499, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))

# %%
print(response.choices[0].message.content)
# Out:
# OpenAI의 LLM(대규모 언어모델) 라인업은 시기/목적에 따라 여러 “모델 계열”로 나뉩니다. 다만 정확한 “현재 제공 중인 모델 목록”은 시간이 지나며 바뀔 수 있어요. 아래는 **대표적으로 알려진 OpenAI LLM 계열** 정리입니다.
#
# ## 1) GPT(범용 대화/추론) 계열
# - **GPT-4 / GPT-4o / GPT-4.1**: 고성능 범용 추론·대화 모델(최신 멀티모달 포함 여부는 버전에 따라 다름)
# - **GPT-4o mini**: 비용/지연을 낮춘 경량(빠른) 모델로 자주 쓰임
# - **GPT-3.5**(구형): 경량 모델로 과거에 많이 사용되었고, 현재 제공 여부/역할은 달라질 수 있음
#
# ## 2) o-series (추론 특화) 계열
# - **o1 / o3-mini** 등: “추론(reasoning)”에 강점을 둔 계열로 알려져 있습니다(복잡한 문제에서 성능을 노리는 용도).
#
# ## 3) 임베딩(Embedding) 모델(LLM이라기보단 관련 계열)
# - **text-embedding-3-small / -3-large**: 텍스트를 벡터로 바꾸는 모델(검색/RAG에 흔히 사용)
#
# ## 4) 이미지/음성 등 멀티모달 관련
# - GPT-4o 같은 모델은 텍스트뿐 아니라 이미지/음성 등 **멀티모달**로 확장된 형태가 있습니다(세부 지원은 모델/엔드포인트에 따라 다름).
#
# ---
#
# 원하시면 제가 더 정확히 맞춰드릴게요.
# 1) **지금 사용하려는 목적**이 대화/코딩/추론/검색(RAG)/음성 중 뭐에 가까운가요?
# 2) 그리고 “**현재 API에서 사용 가능한 정확한 모델명**”이 필요하신가요, 아니면 “**계열 개요**”면 충분하신가요?

# %% [markdown]
# ## Langchain을 이용한 OpenAI API 호출
#
# - **ChatOpenAI**
#     - chat (대화-채팅) 기반 모델 model.
#     - Default 로 gpt-3.5-turbo 사용
#     - llm 전달 입력과 llm 응답 출력 타입:  Message
# - **Initializer 주요 파라미터**
#     -  **model**
#         -  사용할 openai 모델 지정
#     -  **temperature**
#         -  'llm 모델의 출력' '무작위성을 지정'한다.
#         -  0 ~ 2 사이 실수를 설정하며 클 수록 무작위성이 커진다. 기본값: 0.7
#         -  정확한 답변을 얻어야 하는 경우 작은 값을 창작을 해야 하는 경우 큰 값을 지정한다.
#            -  정확한 답변: 0.0 ~ 0.3
#            -  일반 챗봇: 0.5 ~ 0.8
#            -  창작: 1.0 이상
#     - **max_tokens**:
#         - llm 모델이 '응답할 최대 token 수'.
#         - gpt-5 모델은 '추론과정'을 거칠 수있고 이 경우 '토큰을 소비'한다. 그래서 max_tokens를 '너무 작게 잡으면 응답이 안올 수 있'다.
#     - **api_key**
#         - OpenAI API key를 직접 입력해 생성시 사용.
#         - API key가 환경변수에 설정 되있으면 생략한다.
#     - **OpenAI GPT-5 계열 모델 파라미터**
#         - **reasoning_effort**
#             - 모델의 추론 강도(수학, 코딩 등)
#             - None, "low", "medium", "high", "xlarge"
#         - **verbosity**
#             - 응답 길이 제어.
#             - "low", "medium", "high"
# -  메소드
#     - **`invoke(message)`** : LLM에 프롬프트 메세지를 전달하며 LLM의 응답을 반환한다.

# %%
from langchain_openai import ChatOpenAI

model = ChatOpenAI(
    model="gpt-5.4-nano",
    temperature=1.0,
)
response = model.invoke("OpenAI의 LLM 모델 종류는 뭐가 있나요?")

# %%
response
# Out:
# AIMessage(content='OpenAI의 LLM(대규모 언어 모델) 라인업은 시기/용도에 따라 여러 “모델 계열”로 나뉘는데, 대표적으로 다음과 같은 종류가 있어요(정확한 제공 모델은 시점에 따라 바뀔 수 있습니다).\n\n## 1) GPT 계열(범용 대화/작문)\n- **GPT-4.x**: 고성능 범용 모델(대화, 추론, 코딩, 문서 작업 등)\n- **GPT-4o / GPT-4o-mini**: 멀티모달(텍스트+이미지 등) 성격이 더 강한 계열로 알려져 있고, 빠르고 실용적인 옵션도 함께 제공됨\n- **GPT-3.5 계열**: 이전 세대의 경량/저비용 범용 모델(일부 환경에서 제공)\n\n## 2) 추론/코딩 특화로 알려진 모델 옵션\n- **코딩에 최적화된 변형**(예: “code” 관련 네이밍이 붙는 계열): 코드 작성/리뷰, 알고리즘 설명 등에 자주 사용\n- **응답 품질/지연시간 요구에 맞춘 경량 모델**(예: mini 계열): 비용 절감 목적\n\n## 3) 임베딩(Embedding) 모델\n- 텍스트를 벡터로 바꿔주는 모델(검색, RAG, 문서 유사도 계산 등에 사용)\n- “LLM”이라기보다는 보통 *텍스트→벡터*용이지만, OpenAI에서 함께 제공되는 중요한 모델 종류예요.\n\n## 4) 음성/멀티모달 관련 모델(사용 맥락에 따라 LLM과 함께 활용)\n- 텍스트만이 아니라 **이미지/음성** 같은 입력을 처리하거나 변환하는 모델들이 있어요.\n- 이건 “LLM 종류”라기보다 멀티모달 파이프라인의 일부로 같이 쓰이는 경우가 많습니다.\n\n---\n\n### 확인 질문\n원하시는 게 **(1) OpenAI API에서 현재 제공 중인 “구체적인 모델명 목록”**인지, 아니면 **(2) “카테고리/종류” 관점에서의 분류**인지에 따라 답이 달라져요.\n\n가능하면 “지금 쓰는 환경(예: API에서 사용할 모델)” 기준으로 **원하는 목록을 최신 상태로 정리**해드릴까요? (사용 중인 날짜/목적: 챗봇, 요약, RAG, 코딩 등도 알려주시면 더 정확히 추천할 수 있어요.)', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 579, 'prompt_tokens': 19, 'total_tokens': 598, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-nano-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-DsM8lVcYUOr22RBAD1dpWFf5rC2vb', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019ede5e-69f5-7712-9c84-8240cd174bbf-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 19, 'output_tokens': 579, 'total_tokens': 598, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
print(response.content)
# Out:
# OpenAI의 LLM(대규모 언어 모델) 라인업은 시기/용도에 따라 여러 “모델 계열”로 나뉘는데, 대표적으로 다음과 같은 종류가 있어요(정확한 제공 모델은 시점에 따라 바뀔 수 있습니다).
#
# ## 1) GPT 계열(범용 대화/작문)
# - **GPT-4.x**: 고성능 범용 모델(대화, 추론, 코딩, 문서 작업 등)
# - **GPT-4o / GPT-4o-mini**: 멀티모달(텍스트+이미지 등) 성격이 더 강한 계열로 알려져 있고, 빠르고 실용적인 옵션도 함께 제공됨
# - **GPT-3.5 계열**: 이전 세대의 경량/저비용 범용 모델(일부 환경에서 제공)
#
# ## 2) 추론/코딩 특화로 알려진 모델 옵션
# - **코딩에 최적화된 변형**(예: “code” 관련 네이밍이 붙는 계열): 코드 작성/리뷰, 알고리즘 설명 등에 자주 사용
# - **응답 품질/지연시간 요구에 맞춘 경량 모델**(예: mini 계열): 비용 절감 목적
#
# ## 3) 임베딩(Embedding) 모델
# - 텍스트를 벡터로 바꿔주는 모델(검색, RAG, 문서 유사도 계산 등에 사용)
# - “LLM”이라기보다는 보통 *텍스트→벡터*용이지만, OpenAI에서 함께 제공되는 중요한 모델 종류예요.
#
# ## 4) 음성/멀티모달 관련 모델(사용 맥락에 따라 LLM과 함께 활용)
# - 텍스트만이 아니라 **이미지/음성** 같은 입력을 처리하거나 변환하는 모델들이 있어요.
# - 이건 “LLM 종류”라기보다 멀티모달 파이프라인의 일부로 같이 쓰이는 경우가 많습니다.
#
# ---
#
# ### 확인 질문
# 원하시는 게 **(1) OpenAI API에서 현재 제공 중인 “구체적인 모델명 목록”**인지, 아니면 **(2) “카테고리/종류” 관점에서의 분류**인지에 따라 답이 달라져요.
#
# 가능하면 “지금 쓰는 환경(예: API에서 사용할 모델)” 기준으로 **원하는 목록을 최신 상태로 정리**해드릴까요? (사용 중인 날짜/목적: 챗봇, 요약, RAG, 코딩 등도 알려주시면 더 정확히 추천할 수 있어요.)

# %%
# streaming 방식으로 응답 받기

response = model.stream("LangChain은 어떤 Framework인가요? 자세하게 설명해주세요.")
response
# Out:
# <generator object BaseChatModel.stream at 0x000002539CDF5F40>

# %%
for token in response:
    print(token.content, end="")
# Out:
# LangChain은 **LLM(대규모 언어 모델)** 기반 애플리케이션을 더 쉽게 만들 수 있도록 도와주는 **오픈소스 프레임워크(프레임워크+라이브러리)** 입니다. 예를 들어 챗봇, RAG(검색 기반 생성), 에이전트(도구 호출), 문서 요약/질의응답 같은 작업을 “구성 요소(모듈)”로 조립해 빠르게 구현하게 해줍니다.
#
# 아래에 구성 요소 관점에서 비교적 자세히 설명하겠습니다.
#
# ---
#
# ## 1) LangChain이 해결하려는 문제
# LLM을 그냥 “API 호출” 수준으로만 쓰면 금방 복잡해집니다. 보통 다음 요구가 생기는데, 이 부분을 공통 패턴으로 정리해주는 게 LangChain의 역할입니다.
#
# - **프롬프트/체인 구성 복잡성**
#   예: “질문 분류 → 적절한 문서 검색 → 컨텍스트 합치기 → 답변 생성 → 형식 후처리”
# - **RAG 구현의 반복 작업**
#   문서 수집/분할 → 임베딩 → 벡터DB 저장 → 검색 → 검색 결과를 프롬프트에 주입
# - **도구 사용(에이전트) 자동화**
#   예: 검색, 계산, DB 조회, API 호출 등을 모델이 필요할 때 선택하도록 설계
# - **데이터/대화 흐름 관리**
#   대화 히스토리, 세션, 메모리, 콜백/로깅 등 운영적인 부분
#
# ---
#
# ## 2) 핵심 개념: “Chain(연쇄) / Runnable(실행 단위)” 중심
# LangChain은 전통적으로 **Chain**이라는 개념으로 로직을 “단계별 파이프라인”처럼 만들었습니다. 요즘은 버전이 올라가며 **Runnable** 같은 실행 단위를 중심으로 유연하게 구성하는 흐름이 더 강조됩니다.
#
# 예를 들어 RAG는 보통 아래 단계들로 나뉩니다.
#
# 1. 사용자 질문 받기
# 2. 질문을 임베딩해서 문서 검색(벡터DB)
# 3. 검색 결과(컨텍스트) 정리
# 4. LLM에 프롬프트로 넣어 답변 생성
# 5. (선택) 출처/형식 검증, 후처리
#
# LangChain은 이런 단계를 “이미 준비된 블록”으로 만들고 조합할 수 있게 합니다.
#
# ---
#
# ## 3) 주요 구성 요소(프레임워크 관점)
# LangChain에서 자주 등장하는 구성 요소들을 정리하면:
#
# ### (1) LLM / Chat Model
# - OpenAI, Anthropic, Google 등 다양한 모델을 동일한 인터페이스로 감싸서 사용하게 합니다.
# - 프롬프트 템플릿과 결합해 호출합니다.
#
# ### (2) Prompt Template
# - 시스템/사용자 프롬프트 템플릿을 변수 치환 형태로 관리
# - 예: `{question}`, `{context}` 같은 변수를 주입
#
# ### (3) Retrievers / Vector Stores (RAG 핵심)
# - 문서를 쪼개고(텍스트 스플리터)
# - 임베딩 모델로 벡터화
# - 벡터DB(예: Pinecone, FAISS, Chroma 등)에 저장
# - Retriever를 통해 “질문과 유사한 문서”를 찾아 context로 사용
#
# ### (4) Document Transformers
# - 문서 로딩, 정규화, 청킹(chunking), 메타데이터 관리 등을 수행
#
# ### (5) Output Parsers / Structured Output
# - LLM의 출력이 문자열만 나오면 후처리가 어려운데,
# - JSON 스키마/정해진 포맷으로 파싱하거나 검증하는 패턴을 지원합니다.
#
# ### (6) Memory (대화 기록)
# - 대화 히스토리(요약 메모리 등)를 LLM 입력에 반영
# - 장기 대화에서 컨텍스트 길이 문제를 완화하는 전략을 적용하기 좋습니다.
#
# ### (7) Tools / Agents (에이전트)
# - LLM이 “필요한 도구”를 선택해 호출하게 구성할 수 있습니다.
# - 예: `검색 도구`, `계산 도구`, `DB 조회 도구`, `웹 요청 도구` 등
# - 에이전트는 보통 “계획 → 도구 사용 → 결과 반영 → 최종 답변” 흐름을 만듭니다.
#
# ### (8) Observability(로깅/트레이싱)
# - 어디서 어떤 입력/출력이 생성됐는지 추적
# - 운영/디버깅에 중요합니다.
#
# ---
#
# ## 4) LangChain이 제공하는 대표적인 사용 시나리오
#
# ### A. RAG(검색 증강 생성, Retrieval-Augmented Generation)
# 가장 널리 쓰는 패턴 중 하나입니다.
#
# - 단순 LLM은 학습 이후 데이터는 잘 모릅니다.
# - RAG는 사용자의 질문에 관련된 문서를 검색해 모델이 그 근거로 답하도록 유도합니다.
# - “정확도 향상”, “출처 기반 답변”, “사내 문서 Q&A” 등에 유리합니다.
#
# ### B. 문서 질의응답(Q&A) / 요약 / 분류 자동화
# - 문서를 가져와 chunking 후 검색하거나
# - 특정 템플릿으로 요약/정리하는 파이프라인을 구성합니다.
#
# ### C. 에이전트 기반 자동화
# - 단순 챗봇을 넘어 “작업 수행” 형태로 확장됩니다.
# - 예: “이번 달 매출을 조회해서 요약해줘” 같은 업무에서
#   DB 조회 도구를 호출하고 결과를 요약하는 식.
#
# ---
#
# ## 5) LangChain을 쓰면 좋은 점
# - **구성의 생산성**: 공통 패턴(프롬프트+검색+생성)을 빠르게 조립
# - **호환성**: 다양한 LLM/벡터DB/툴을 일관된 방식으로 사용
# - **확장성**: 체인/에이전트/도구를 커스텀하기 쉬움
# - **디버깅/운영**: 추적/로깅/중간 결과 관리가 상대적으로 용이
#
# ---
#
# ## 6) 주의할 점(단점/복잡성)
# - “프레임워크를 쓰면 무조건 쉬워진다”기보다는, **개념을 이해하고 설계를 잘 해야** 합니다.
# - RAG에서 품질은 결국:
#   - 청킹 전략
#   - 임베딩/검색 품질
#   - 프롬프트 설계
#   - 후처리(근거/형식 검증)
#   에 크게 좌우됩니다.
# - 또한 LangChain은 계속 업데이트되며 개념/구성 방식이 진화해왔기 때문에(버전별 차이),
#   최신 문서 기반으로 학습하는 게 중요합니다.
#
# ---
#
# ## 7) 한 줄 요약
# **LangChain은 LLM 애플리케이션을 만들 때 필요한 “프롬프트, 문서 검색(RAG), 도구 사용(에이전트), 대화 메모리, 출력 파싱, 로깅” 같은 구성 요소들을 조립식으로 제공하는 프레임워크**입니다.
#
# ---
#
# 원하시면,
# 1) **RAG 예시(문서 로딩→청킹→벡터DB→검색→프롬프트→답변)** 흐름으로 실제 설계도를 설명해드리거나,
# 2) “에이전트 vs RAG vs 단순 체인” 중 어떤 걸 써야 하는지 사용 목적 기준으로 비교해드릴 수도 있어요.
#
# 어떤 용도로 LangChain을 알아보시는 걸까요? (예: 사내 문서 Q&A, 고객지원 챗봇, 자동 리서치/요약, DB 연동 등)

# %%
model = ChatOpenAI(
    model="gpt-5.5",
    reasoning={
        "effort":"medium", "summary":"auto"
    }
)
result = model.invoke("LLM 모델에 대한 설명을 초심자들을 위해 최대한 쉽게 작성해줘.")

# %%
result.content
# Out:
# [{'id': 'rs_0df555070c94e1ba006a34d80d8e9c8199b881c28e0198aa77',
#   'summary': [{'text': "**Providing a beginner-friendly explanation**\n\nI want to offer an answer in Korean that's easy to understand. I think it would help to use an analogy to explain how LLMs work. I’ll include a few examples, talk about their limitations, and suggest some tips for crafting good prompts. My goal is to keep it simple and engaging. I'll aim for a final piece that's structured and moderate in length, maybe around five concise points.",
#     'type': 'summary_text'}],
#   'type': 'reasoning',
#   'content': []},
#  {'type': 'text',
#   'text': '# LLM 모델이란? 초심자를 위한 쉬운 설명\n\nLLM은 **Large Language Model**의 줄임말로, 한국어로는 **대규모 언어 모델**이라고 합니다.  \n쉽게 말하면, **사람이 쓰는 말을 많이 학습해서 글을 이해하고 만들어내는 인공지능**입니다.\n\nChatGPT 같은 서비스가 대표적인 LLM을 사용합니다.\n\n---\n\n## 1. LLM은 무엇을 할 수 있나요?\n\nLLM은 글과 관련된 다양한 일을 할 수 있습니다.\n\n예를 들면:\n\n- 질문에 답하기\n- 글 요약하기\n- 번역하기\n- 이메일이나 보고서 작성하기\n- 아이디어 제안하기\n- 코드 작성하기\n- 문장 고치기\n- 대화하기\n\n즉, LLM은 **언어를 다루는 인공지능 도구**라고 볼 수 있습니다.\n\n---\n\n## 2. LLM은 어떻게 똑똑해졌나요?\n\nLLM은 인터넷 글, 책, 문서, 코드 등 아주 많은 데이터를 학습합니다.\n\n예를 들어 사람이 책을 많이 읽으면 표현력이 좋아지고 여러 지식을 알게 되는 것처럼,  \nLLM도 엄청나게 많은 문장을 보면서 다음과 같은 것을 배웁니다.\n\n- 단어와 문장의 관계\n- 질문과 답변의 형태\n- 문법과 표현 방식\n- 여러 분야의 지식\n- 글을 자연스럽게 이어가는 방법\n\n하지만 중요한 점이 있습니다.\n\nLLM은 사람처럼 “진짜로 이해”한다기보다는,  \n**앞뒤 문맥을 보고 다음에 올 가능성이 높은 말을 예측하는 방식**으로 작동합니다.\n\n---\n\n## 3. 아주 쉬운 예시\n\n문장이 있다고 해봅시다.\n\n> 오늘 날씨가 너무 좋아서 공원에 ___\n\n사람이라면 빈칸에 이런 말을 떠올릴 수 있습니다.\n\n- 갔다\n- 산책하러 갔다\n- 놀러 갔다\n\nLLM도 비슷하게, 앞의 문장을 보고 다음에 올 만한 단어를 예측합니다.\n\n이 예측을 아주 빠르고 복잡하게 반복해서 긴 답변을 만들어냅니다.\n\n---\n\n## 4. LLM은 검색엔진과 무엇이 다른가요?\n\n검색엔진은 사용자가 입력한 키워드와 관련된 웹페이지를 찾아줍니다.\n\n예를 들어:\n\n> 김치찌개 레시피\n\n라고 검색하면 여러 웹사이트 목록을 보여줍니다.\n\n반면 LLM은 직접 답변을 만들어줍니다.\n\n예를 들어:\n\n> 김치찌개 쉽게 끓이는 법 알려줘\n\n라고 하면 재료와 조리 순서를 정리해서 설명해줍니다.\n\n즉,\n\n- **검색엔진**: 관련 정보를 찾아줌\n- **LLM**: 정보를 바탕으로 답변을 만들어줌\n\n이라고 이해하면 쉽습니다.\n\n---\n\n## 5. LLM은 완벽한가요?\n\n아닙니다. LLM은 매우 유용하지만 한계도 있습니다.\n\n### 1) 틀린 정보를 말할 수 있습니다\n\nLLM은 그럴듯하게 말하지만, 항상 정답을 말하는 것은 아닙니다.  \n가끔 없는 사실을 만들어내기도 합니다. 이를 **환각 현상**, 또는 **Hallucination**이라고 합니다.\n\n예를 들어 실제로 존재하지 않는 책이나 논문을 있는 것처럼 말할 수 있습니다.\n\n---\n\n### 2) 최신 정보를 모를 수 있습니다\n\nLLM은 학습한 시점 이후의 정보를 모를 수 있습니다.  \n그래서 최신 뉴스, 주가, 날씨, 법률 변경 사항 등은 반드시 확인이 필요합니다.\n\n---\n\n### 3) 질문이 애매하면 답변도 애매해질 수 있습니다\n\nLLM은 사용자가 입력한 문장을 바탕으로 답합니다.  \n질문이 구체적일수록 더 좋은 답변을 받을 수 있습니다.\n\n예를 들어:\n\n> 보고서 써줘\n\n보다는\n\n> 신입사원을 대상으로 한 AI 기초 교육 보고서를 A4 1장 분량으로 써줘\n\n라고 하는 것이 더 좋습니다.\n\n---\n\n## 6. LLM에게 질문을 잘하는 방법\n\nLLM을 잘 사용하려면 질문을 명확하게 하는 것이 중요합니다.  \n이렇게 입력하는 문장을 **프롬프트(prompt)**라고 합니다.\n\n좋은 프롬프트에는 보통 다음 요소가 들어갑니다.\n\n### 1) 원하는 역할을 알려주기\n\n예:\n\n> 너는 초등학생에게 설명하는 선생님이야.\n\n### 2) 원하는 결과물을 말하기\n\n예:\n\n> LLM에 대해 쉽게 설명해줘.\n\n### 3) 형식을 지정하기\n\n예:\n\n> 표로 정리해줘.  \n> 5문장으로 요약해줘.  \n> 예시를 3개 들어줘.\n\n### 4) 대상 독자를 알려주기\n\n예:\n\n> AI를 처음 접하는 사람도 이해할 수 있게 설명해줘.\n\n---\n\n## 7. 좋은 질문 예시\n\n나쁜 예:\n\n> AI 설명해줘.\n\n좋은 예:\n\n> AI를 처음 배우는 대학생을 대상으로, LLM이 무엇인지 쉬운 비유와 예시를 들어 설명해줘. 너무 어려운 전문 용어는 피하고, 마지막에 장단점도 정리해줘.\n\n이렇게 질문하면 훨씬 원하는 답변에 가까워집니다.\n\n---\n\n## 8. LLM의 대표적인 활용 예시\n\n### 글쓰기\n\n- 자기소개서 작성\n- 블로그 글 작성\n- 보고서 초안 작성\n- 이메일 문장 다듬기\n\n### 공부\n\n- 어려운 개념 쉽게 설명받기\n- 영어 문장 번역하기\n- 시험 대비 문제 만들기\n- 요약 노트 만들기\n\n### 업무\n\n- 회의록 요약\n- 기획안 작성\n- 고객 응대 문구 작성\n- 데이터 분석 아이디어 얻기\n\n### 개발\n\n- 코드 작성\n- 오류 원인 찾기\n- 코드 설명\n- 간단한 프로그램 설계\n\n---\n\n## 9. LLM을 사용할 때 주의할 점\n\nLLM을 사용할 때는 다음을 조심해야 합니다.\n\n- 중요한 정보는 반드시 다시 확인하기\n- 개인정보를 입력하지 않기\n- 법률, 의료, 금융 조언은 전문가에게 확인하기\n- 답변을 그대로 믿기보다 참고 자료로 활용하기\n- 출처가 필요한 경우 출처 확인하기\n\nLLM은 좋은 도구이지만, 최종 판단은 사람이 해야 합니다.\n\n---\n\n## 10. 한 문장으로 정리하면\n\n**LLM은 많은 글을 학습해서 사람처럼 자연스럽게 문장을 이해하고 답변을 만들어내는 인공지능 모델입니다.**\n\n조금 더 쉽게 말하면,\n\n**LLM은 글을 아주 많이 읽고 배운 똑똑한 글쓰기 도우미**라고 할 수 있습니다.',
#   'annotations': [],
#   'id': 'msg_0df555070c94e1ba006a34d80f6c548199add2ad742ddb878e',
#   'phase': 'final_answer'}]

# %%
model = ChatOpenAI(model="gpt-5.4-nano")

prompt = """태양계를 구성하는 행성들에 대해 태양계에서 가까운 순서대로 알려줘.

결과는 다음 답변 형식에 맞춰줘.
<답변 형식>
- 행성 한국어 이름(영어 이름): 간단한 한 줄 설명
</답변 형식>
"""

res = model.invoke(prompt)

# %%
print(res.content)
# Out:
# - 수성( Mercury ): 태양에 가장 가까운 행성으로, 공전 궤도가 가장 빠르고 낮(낮과 밤의 시간차)이 매우 큽니다.
# - 금성( Venus ): 두껍고 뜨거운 대기 때문에 표면 온도가 가장 높은 행성으로, ‘지구의 쌍둥이’로도 불립니다.
# - 지구( Earth ): 액체 상태의 물이 풍부하고 생명체가 존재하는 것으로 알려진 행성입니다.
# - 화성( Mars ): 붉은색을 띠며, 과거에 물이 있었을 가능성이 제기되는 행성입니다.
# - 목성( Jupiter ): 태양계에서 가장 큰 행성으로, 강력한 중력과 대적점(거대 폭풍)이 유명합니다.
# - 토성( Saturn ): 아름다운 고리(환상 고리)로 잘 알려진 행성이며, 주로 얼음과 암석 조각으로 이루어져 있습니다.
# - 천왕성( Uranus ): 옆으로 누운 듯한 자전축 기울기를 가진 행성으로, 푸른빛이 특징입니다.
# - 해왕성( Neptune ): 태양계의 바깥쪽 행성으로, 강한 바람과 짙은 푸른색 대기가 특징입니다.

# %% [markdown]
# # Hugging Face 모델 사용
#
# ## Local 에 설치된 모델 사용
# - HuggingFacePipeline 에 Model id를 전달해 Model객체를 생성한다.
# - huggingface transformers 라이브러리를 이용해 model을 생성 한 뒤 HuggingFacePipeline 에 넣어 생성한다.
# - 모델이 local에 없는 경우 다운로드 받는다.
#
# ### HuggingFace 모델을 사용하기 위한 package 설치
# ```bash
# pip install langchain-huggingface transformers torch -qU
# ```
# - nvidia GPU가 있는 경우 `torch cuda`  버전을 먼저 설치하고 `langchain-huggingface`를 설치 해야 한다. 아니면 `torch cpu` 버전이 설치된다.

# %%
from langchain_huggingface.llms import HuggingFacePipeline

model_id = "Qwen/Qwen2.5-0.5B-Instruct"
model = HuggingFacePipeline.from_model_id(
    task= "text-generation", model_id = model_id
)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/659 [00:00<?, ?B/s]
# c:\Documents\SKN31\10_AI_Agent\.venv\Lib\site-packages\huggingface_hub\file_download.py:137: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Playdata\.cache\huggingface\hub\models--Qwen--Qwen2.5-0.5B-Instruct. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# tokenizer_config.json:   0%|          | 0.00/7.30k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.03M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/988M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/290 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/242 [00:00<?, ?B/s]

# %%
res = model.invoke("HuggingFace를 소개해줘.")
# Out:
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer Qwen2Tokenizer. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.

# %%
print(res)
# Out:
# HuggingFace를 소개해줘. HuggingFace는 어떤 기술이나 서비스를 제공하는지 설명해주시면 감사하겠습니다. HuggingFace은 현재 가장 인기 있는 대형 NLP 라이브러리 중 하나입니다. 그의 주요 특징과 사용법을 아래와 같이 제시할 수 있습니다:
#
# 1. **OpenAI의 기능**:
#    - HuggingFace는 OpenAI가 개발한 NLP 라이브러리로, 그룹에서 제공되는 다양한 기능을 제공합니다.
#    - 예를 들어, 텍스트 분석, 문장 생성, 자연어 처리 등의 기능이 포함됩니다.
#
# 2. **유니버설 라이브러리**:
#    - HuggingFace는 유니버설 라이브러리로서, 다양한 언어에 대한 오픈 소스 프로그램으로 구성되어 있습니다.
#    - 이로 인해 여러 언어의 훈련 데이터를 공유하고 분석하여 사용자에게 제공합니다.
#
# 3. **고객 경험**:
#    - HuggingFace는 브랜드 이름인 "Hugging Face"라는 단어로 알려져 있으며, 고객 서비스를 통해 고객들이 쉽게 접근할 수

# %%
message = [
    {"role":"user", "content":"서울에서 추천하는 여행지 3곳을 알려줘."}
]
res = model.invoke(message)
# Out:
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)

# %%
print(res)
# Out:
# Human: 서울에서 추천하는 여행지 3곳을 알려줘.
#
# 1. 서울에서 가장 인기 있는 여행지는?
# 2. 서울에서 가장 높은 산으로는?
# 3. 서울에서 가장 아름다운 날씨는?
#
# Assistant: 서울에서 추천하는 여행지 3곳은 다음과 같습니다:
#
# 1. 광주
# 2. 울산
# 3. 강원도
#
# 1. 광주:
# - 광주는 한국의 첫 번째 수도이며, 이 곳에 대한 인기가 매우 높습니다.
# - 광주에서는 여러 관광 명소들이 있습니다. 예를 들어, 동해안에서 가장 큰 물고기를 먹는 곳인 "광주동해"와, 전통적인 음식 '광주 맥주' 등이 있습니다.
#
# 2. 울산:
# - 울산은 광주보다 더 작은 도시로, 하지만 여유있는 분위기는 특별합니다.
# - 울산에는 여러 관광 명소가 있으며, 특히 황금빛 캔버스를 보는 루브라우스(서울보다 훨씬 더 가까운 도시)와 고등학교 시절부터

# %%
gpt = ChatOpenAI(model="gpt-5.4-mini")
res_gpt = gpt.invoke(message)

# %%
print(res_gpt.content)
# Out:
# 서울에서 추천하는 여행지 3곳을 꼽아보면:
#
# 1. **경복궁**
#    - 서울의 대표적인 궁궐로, 한국 전통미를 가장 잘 느낄 수 있는 곳이에요.
#    - 한복을 입고 산책하면 사진 찍기에도 좋습니다.
#    - 근처에 **북촌한옥마을, 삼청동**도 함께 둘러보기 좋아요.
#
# 2. **남산서울타워**
#    - 서울 전경을 한눈에 볼 수 있는 전망 명소예요.
#    - 낮에는 시내 풍경, 밤에는 야경이 특히 아름답습니다.
#    - 연인, 가족, 친구 누구와 가도 무난한 곳이에요.
#
# 3. **홍대 거리**
#    - 젊고 활기찬 분위기를 느끼기 좋은 곳이에요.
#    - 길거리 공연, 카페, 맛집, 쇼핑을 함께 즐길 수 있습니다.
#    - 밤까지 즐길 거리 많은 여행지를 찾는다면 추천해요.
#
# 원하시면 제가 **“자연”, “쇼핑”, “맛집”, “가족 여행”** 기준으로 서울 여행지를 다시 3곳 추천해드릴게요.

# %% [markdown]
# # Anthropic의 Claude 모델 사용
#
# - Anthropic사의 Claude 모델은 (성능 순으로) **Haiku, Sonnet, Opus** 세가지 모델이 있다.
# - [Anthropic사 사이트](https://www.anthropic.com/)
# - [Claude 서비스 사이트](https://claude.ai)
# - API 가격: https://docs.anthropic.com/en/docs/about-claude/pricing
# - Langchain으로 Anthropic claude 모델 사용: https://python.langchain.com/docs/integrations/chat/anthropic/
#
# ## API Key 발급받기
# 1. https://console.anthropic.com/ 이동 후 가입한다.
# 2. 로그인 하면 Dashboard로 이동한다. Dashbord에서 `Get API Keys`를 클릭해 이동한다.
#
# <img src="figures/anthropic_apikey1.png" width="640">
#
# 3. Create key 클릭해서 API Key를 생성한다.
#
# 4. 생성된 API Key를 복사한 뒤 저장. (다시 볼 수 없다.)
#    - 환경변수에 등록
#       - 변수이름: ANTHROPIC_API_KEY
#       - 값: 생성된 키
#
# ## 결제 정보 등록 및 결제 (최소 $5)
#    - Settings -> Billing
#
# <img src="figures/anthropic_apikey3.png" height="480">
#
#   - 설문조사 후 카드 등록한다.

# %% [markdown]
# ## Anthropic의 Claude 모델 사용
# - 모델 확인: https://docs.anthropic.com/en/docs/about-claude/models

# %% [markdown]
# ### Claude 모델 사용을 위한 package 설치
#
# ```bash
# pip install langchain-anthropic -qU
# ```
# - `anthropic`package도 같이 설치 된다.

# %%
# ! uv pip install langchain-anthropic

# %% [markdown]
# ### Langchain-antropic 사용

# %%
from langchain_anthropic import ChatAnthropic # , Anthropic 지원하는 모델이 다른 것 같다.
from dotenv import load_dotenv
load_dotenv()
model="claude-sonnet-4-6"

llm = ChatAnthropic(
    model=model,
    temperature=0.2,
    # max_tokens=1024,
)
result = llm.invoke("Anthropic의 LLM 모델은 어떤 것이 있는지 알려주고 간단한 설명도 부탁해.")

# %%
print(result.content)
# Out:
# # Anthropic의 LLM 모델
#
# ## 🤖 Claude 시리즈
#
# Anthropic은 **Claude**라는 이름의 AI 어시스턴트 시리즈를 개발했습니다.
#
# ---
#
# ### 📌 Claude 3 시리즈 (2024년 3월 출시)
#
# | 모델 | 특징 |
# |------|------|
# | **Claude 3 Haiku** | 가장 빠르고 경량화된 모델. 간단한 작업에 적합, 비용 효율적 |
# | **Claude 3 Sonnet** | 속도와 성능의 균형. 일반적인 비즈니스 용도에 적합 |
# | **Claude 3 Opus** | 가장 강력한 모델. 복잡한 분석, 추론 작업에 최적화 |
#
# ---
#
# ### 📌 Claude 3.5 시리즈 (2024년)
#
# | 모델 | 특징 |
# |------|------|
# | **Claude 3.5 Haiku** | 3 Haiku 대비 성능 향상, 빠른 응답 속도 유지 |
# | **Claude 3.5 Sonnet** | 코딩, 추론 능력이 크게 향상. Opus를 능가하는 성능 |
#
# ---
#
# ### 📌 Claude 3.7 시리즈 (2025년 초)
#
# | 모델 | 특징 |
# |------|------|
# | **Claude 3.7 Sonnet** | **확장된 사고(Extended Thinking)** 기능 도입. 복잡한 문제에서 단계적 추론 가능 |
#
# ---
#
# ## 🔑 주요 특징 (공통)
#
# - ✅ **Constitutional AI** 기반으로 안전성 강조
# - ✅ 긴 **컨텍스트 윈도우** 지원 (최대 200K 토큰)
# - ✅ 한국어를 포함한 **다국어 지원**
# - ✅ 텍스트 + 이미지 **멀티모달** 지원
#
# ---
#
# > ⚠️ **참고:** 저는 **Claude**이며, 제 학습 데이터 이후 출시된 모델에 대한 정보는 정확하지 않을 수 있습니다. 최신 정보는 [Anthropic 공식 사이트](https://www.anthropic.com)를 확인해 주세요!

# %% [markdown]
# # Gemini
# - 모델: https://ai.google.dev/gemini-api/docs/models?hl=ko
# - 가격정책: https://ai.google.dev/gemini-api/docs/pricing?hl=ko
#
# ## API Key 생성
#
# 1. https://aistudio.google.com/api-keys
#     - 연결 후 로그인(구글계정)
# 2. `API Key 만들기` 선택
#
#     ![img](figures/gemini_api1.png)
#
# 3. `키이름 지정`하고 `가져온 프로젝트 선택`에서 프로젝트 선택(없으면 만든다) 하고 키 만들기
# 4. 키가 생성되면 왼쪽에 복사 아이콘을 클릭하면 키가 복사된다.
#
# ## 환경변수
# - `GOOGLE_API_KEY` 환경변수에 생성된 API Key를 등록한다.
# ## 설치
# - `pip install langchain_google_genai`

# %%
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(
    model="gemini-3.1-flash-lite"
)

# %%
res = model.invoke("Gemini와 Gemma 모델의 차이는 무엇인가요?")

# %%
print(res.content[0]['text'])
# Out:
# Google의 **Gemini(제미나이)**와 **Gemma(젬마)**는 모두 구글이 개발한 최신 AI 모델들이지만, 개발 목적과 사용 방식에서 큰 차이가 있습니다. 핵심을 요약하자면 다음과 같습니다.
#
# ---
#
# ### 1. Gemini (제미나이)
# **"구글의 가장 강력하고 범용적인 상업용 AI 모델"**
#
# *   **성격:** 구글이 직접 서비스하는 **최상위 성능의 AI 모델**입니다.
# *   **특징:**
#     *   **멀티모달(Multimodal):** 처음부터 텍스트, 이미지, 오디오, 비디오, 코드 등 다양한 형태의 데이터를 동시에 이해하고 처리하도록 설계되었습니다.
#     *   **규모:** 가장 거대하고 강력한 성능을 내는 'Ultra', 범용적인 'Pro', 효율성을 강조한 'Flash' 등 다양한 크기로 구성됩니다.
#     *   **사용처:** 챗봇 서비스(Gemini 웹/앱), 구글 워크스페이스(Docs, Gmail 등), 안드로이드 스마트폰의 AI 기능 등 구글의 서비스 전반에 통합되어 있습니다.
#     *   **폐쇄형:** 모델의 내부 구조나 가중치(Weights)가 공개되지 않은 **Closed Source(비공개 모델)**입니다. 사용자는 API를 통해 호출해서 사용합니다.
#
# ### 2. Gemma (젬마)
# **"누구나 자유롭게 활용할 수 있는 경량형 오픈 모델"**
#
# *   **성격:** Gemini를 만드는 데 사용된 기술을 기반으로 만든 **개방형(Open Weights) AI 모델**입니다.
# *   **특징:**
#     *   **가벼움:** 개인용 PC나 소형 서버에서도 원활하게 돌아갈 수 있도록 최적화된 경량 모델입니다.
#     *   **오픈 모델:** 모델의 가중치가 공개되어 있어 개발자가 자신의 환경에 직접 설치하고, 필요에 따라 특정 목적에 맞게 추가 학습(Fine-tuning)을 시킬 수 있습니다.
#     *   **사용처:** 연구 목적, 개인 프로젝트, 특정 기업의 맞춤형 AI 서비스 개발 등 개발자가 직접 통제권을 갖고 활용하기 좋습니다.
#     *   **생태계:** 개발자가 자신의 인프라에서 AI를 직접 돌리고 싶을 때 가장 선호되는 모델입니다.
#
# ---
#
# ### 요약 비교표
#
# | 구분 | Gemini (제미나이) | Gemma (젬마) |
# | :--- | :--- | :--- |
# | **성격** | 구글의 주력 서비스용 AI | 개발자/연구용 오픈 모델 |
# | **모델 유형** | 폐쇄형 (Closed Source) | 개방형 (Open Weights) |
# | **접근 방식** | API 또는 웹 서비스를 통해 사용 | 다운로드하여 직접 실행/튜닝 |
# | **성능/규모** | 매우 큼 (최상급 성능) | 작음 ~ 중간 (효율적 성능) |
# | **주요 용도** | 일반 사용자, 구글 서비스 통합 | 개발자, 연구원, 기업의 자체 구축 |
#
# ### 한 문장 정리
# *   **Gemini**는 구글이 직접 운영하는 **'완성된 고성능 AI 서비스'**이고, **Gemma**는 개발자가 가져다 쓸 수 있도록 구글이 제공하는 **'AI 개발용 부품'**이라고 이해하시면 됩니다.
# Google의 **Gemini(제미나이)**와 **Gemma(젬마)**는 모두 구글이 개발한 최신 AI 모델들이지만, 개발 목적과 사용 방식에서 큰 차이가 있습니다. 핵심을 요약하자면 다음과 같습니다.
#
# ---
#
# ### 1. Gemini (제미나이)
# **"구글의 가장 강력하고 범용적인 상업용 AI 모델"**
#
# *   **성격:** 구글이 직접 서비스하는 **최상위 성능의 AI 모델**입니다.
# *   **특징:**
#     *   **멀티모달(Multimodal):** 처음부터 텍스트, 이미지, 오디오, 비디오, 코드 등 다양한 형태의 데이터를 동시에 이해하고 처리하도록 설계되었습니다.
#     *   **규모:** 가장 거대하고 강력한 성능을 내는 'Ultra', 범용적인 'Pro', 효율성을 강조한 'Flash' 등 다양한 크기로 구성됩니다.
#     *   **사용처:** 챗봇 서비스(Gemini 웹/앱), 구글 워크스페이스(Docs, Gmail 등), 안드로이드 스마트폰의 AI 기능 등 구글의 서비스 전반에 통합되어 있습니다.
#     *   **폐쇄형:** 모델의 내부 구조나 가중치(Weights)가 공개되지 않은 **Closed Source(비공개 모델)**입니다. 사용자는 API를 통해 호출해서 사용합니다.
#
# ### 2. Gemma (젬마)
# **"누구나 자유롭게 활용할 수 있는 경량형 오픈 모델"**
#
# *   **성격:** Gemini를 만드는 데 사용된 기술을 기반으로 만든 **개방형(Open Weights) AI 모델**입니다.
# *   **특징:**
#     *   **가벼움:** 개인용 PC나 소형 서버에서도 원활하게 돌아갈 수 있도록 최적화된 경량 모델입니다.
#     *   **오픈 모델:** 모델의 가중치가 공개되어 있어 개발자가 자신의 환경에 직접 설치하고, 필요에 따라 특정 목적에 맞게 추가 학습(Fine-tuning)을 시킬 수 있습니다.
#     *   **사용처:** 연구 목적, 개인 프로젝트, 특정 기업의 맞춤형 AI 서비스 개발 등 개발자가 직접 통제권을 갖고 활용하기 좋습니다.
#     *   **생태계:** 개발자가 자신의 인프라에서 AI를 직접 돌리고 싶을 때 가장 선호되는 모델입니다.
#
# ---
#
# ### 요약 비교표
#
# | 구분 | Gemini (제미나이) | Gemma (젬마) |
# | :--- | :--- | :--- |
# | **성격** | 구글의 주력 서비스용 AI | 개발자/연구용 오픈 모델 |
# | **모델 유형** | 폐쇄형 (Closed Source) | 개방형 (Open Weights) |
# | **접근 방식** | API 또는 웹 서비스를 통해 사용 | 다운로드하여 직접 실행/튜닝 |
# | **성능/규모** | 매우 큼 (최상급 성능) | 작음 ~ 중간 (효율적 성능) |
# | **주요 용도** | 일반 사용자, 구글 서비스 통합 | 개발자, 연구원, 기업의 자체 구축 |
#
# ### 한 문장 정리
# *   **Gemini**는 구글이 직접 운영하는 **'완성된 고성능 AI 서비스'**이고, **Gemma**는 개발자가 가져다 쓸 수 있도록 구글이 제공하는 **'AI 개발용 부품'**이라고 이해하시면 됩니다.

# %%
message = [
    {
        "role":"user",
        "content":"나는 4박 5일간 기타큐슈로 여행을 갈 예정이야. 일정에 맞춰 스케줄을 짜줘."
    }
]

res = model.invoke(message)

# %%
print(res.content[0]['text'])
# Out:
# 기타큐슈는 4박 5일이면 여유롭게 도시 곳곳을 둘러보고, 근교인 **모지코, 시모노세키, 그리고 고쿠라**를 중심으로 알차게 즐길 수 있는 아주 좋은 일정입니다.
#
# 이동 동선과 관광지 특성을 고려해 추천 일정을 짜드릴게요.
#
# ---
#
# ### [기타큐슈 4박 5일 추천 일정]
#
# #### **1일차: 도착 및 고쿠라 시내 탐방**
# * **오전/오후:** 기타큐슈 공항 도착 후 리무진 버스로 고쿠라역 이동 (약 30~40분)
# * **오후:** **고쿠라성 & 가쓰야마 공원** 산책 (고쿠라의 상징)
# * **저녁:** **리버워크 기타큐슈** 쇼핑 및 저녁 식사, **탄가 시장**에서 레트로한 분위기 느끼기
# * **숙소:** 고쿠라역 근처 (교통의 요지라 이동이 편리함)
#
# #### **2일차: 모지코 & 시모노세키 (복고 감성 여행)**
# * **오전:** **모지코 레트로 지구** 이동. 큐슈 철도 기념관, 블루윙 모지(도개교) 구경
# * **점심:** 모지코의 명물 **'야키카레(구운 카레)'** 맛보기
# * **오후:** 연락선(배)을 타고 바다를 건너 **시모노세키(가라토 시장)**로 이동
# * **늦은 오후:** **아카마 신궁** 구경 및 시모노세키 해변 산책
# * **저녁:** 다시 배를 타고 모지코로 넘어와 야경 감상 후 고쿠라로 복귀
#
# #### **3일차: 자연과 힐링 (히라오다이 또는 사라쿠라야마)**
# * **오전:** 일본 3대 카르스트 지형인 **'히라오다이'** 트레킹 (자연 경관이 정말 아름답습니다)
# * **오후:** 고쿠라 시내로 돌아와 카페 투어 혹은 쇼핑
# * **저녁:** **사라쿠라야마 전망대** (케이블카 탑승). '신일본 3대 야경'으로 선정된 기타큐슈 최고의 야경 포인트입니다. (반드시 방문 추천!)
#
# #### **4일차: 선택적 근교 여행 (후쿠오카 당일치기 or 야와타)**
# * **옵션 A (쇼핑/미식):** 신칸센(15분)이나 특급열차(40분)를 타고 **후쿠오카(하카타/텐진)** 당일치기 여행.
# * **옵션 B (문화):** **'이노치노타비 박물관(생명과 여행 박물관)'** 관람 (아이와 함께라면 강력 추천, 볼거리가 매우 많습니다).
# * **저녁:** 마지막 밤을 즐기며 고쿠라역 근처 이자카야에서 나마비루(생맥주) 한 잔.
#
# #### **5일차: 여유로운 마무리 및 출국**
# * **오전:** 고쿠라역 주변에서 기념품 쇼핑 (명란젓, 도쿄 바나나 등)
# * **오후:** 공항 이동 및 귀국
#
# ---
#
# ### 💡 여행 꿀팁!
#
# 1.  **교통권:** 기타큐슈 내 이동은 **'기타큐슈 버스 1일 승차권'**이 유용할 수 있습니다. JR 노선을 많이 이용하신다면 **'JR 북큐슈 레일패스'**를 고려해보세요.
# 2.  **가라토 시장:** 2일차를 금/토/일로 맞추면 가라토 시장에서 신선한 초밥을 저렴하게 즐길 수 있는 '이키이키 바칸가이' 행사를 즐길 수 있습니다.
# 3.  **날씨:** 기타큐슈는 바닷가 근처라 바람이 불 수 있으니 얇은 겉옷을 챙기세요.
# 4.  **맛집:**
#     *   **고쿠라:** '테츠나베 교자' (철판 교자), '야키우동' (발상지).
#     *   **모지코:** 야키카레.
#
# **혹시 특별히 좋아하시는 취향(예: 쇼핑, 역사 탐방, 온천, 사진 촬영 등)이 있으신가요?** 말씀해 주시면 그에 맞춰 일정을 더 세밀하게 조정해 드릴게요!

# %%
from IPython.display import Markdown

Markdown(res.text)
# Out:
# 기타큐슈는 4박 5일이면 여유롭게 도시 곳곳을 둘러보고, 근교인 **모지코, 시모노세키, 그리고 고쿠라**를 중심으로 알차게 즐길 수 있는 아주 좋은 일정입니다.
#
# 이동 동선과 관광지 특성을 고려해 추천 일정을 짜드릴게요.
#
# ---
#
# ### [기타큐슈 4박 5일 추천 일정]
#
# #### **1일차: 도착 및 고쿠라 시내 탐방**
# * **오전/오후:** 기타큐슈 공항 도착 후 리무진 버스로 고쿠라역 이동 (약 30~40분)
# * **오후:** **고쿠라성 & 가쓰야마 공원** 산책 (고쿠라의 상징)
# * **저녁:** **리버워크 기타큐슈** 쇼핑 및 저녁 식사, **탄가 시장**에서 레트로한 분위기 느끼기
# * **숙소:** 고쿠라역 근처 (교통의 요지라 이동이 편리함)
#
# #### **2일차: 모지코 & 시모노세키 (복고 감성 여행)**
# * **오전:** **모지코 레트로 지구** 이동. 큐슈 철도 기념관, 블루윙 모지(도개교) 구경
# * **점심:** 모지코의 명물 **'야키카레(구운 카레)'** 맛보기
# * **오후:** 연락선(배)을 타고 바다를 건너 **시모노세키(가라토 시장)**로 이동
# * **늦은 오후:** **아카마 신궁** 구경 및 시모노세키 해변 산책
# * **저녁:** 다시 배를 타고 모지코로 넘어와 야경 감상 후 고쿠라로 복귀
#
# #### **3일차: 자연과 힐링 (히라오다이 또는 사라쿠라야마)**
# * **오전:** 일본 3대 카르스트 지형인 **'히라오다이'** 트레킹 (자연 경관이 정말 아름답습니다)
# * **오후:** 고쿠라 시내로 돌아와 카페 투어 혹은 쇼핑
# * **저녁:** **사라쿠라야마 전망대** (케이블카 탑승). '신일본 3대 야경'으로 선정된 기타큐슈 최고의 야경 포인트입니다. (반드시 방문 추천!)
#
# #### **4일차: 선택적 근교 여행 (후쿠오카 당일치기 or 야와타)**
# * **옵션 A (쇼핑/미식):** 신칸센(15분)이나 특급열차(40분)를 타고 **후쿠오카(하카타/텐진)** 당일치기 여행.
# * **옵션 B (문화):** **'이노치노타비 박물관(생명과 여행 박물관)'** 관람 (아이와 함께라면 강력 추천, 볼거리가 매우 많습니다).
# * **저녁:** 마지막 밤을 즐기며 고쿠라역 근처 이자카야에서 나마비루(생맥주) 한 잔.
#
# #### **5일차: 여유로운 마무리 및 출국**
# * **오전:** 고쿠라역 주변에서 기념품 쇼핑 (명란젓, 도쿄 바나나 등)
# * **오후:** 공항 이동 및 귀국
#
# ---
#
# ### 💡 여행 꿀팁!
#
# 1.  **교통권:** 기타큐슈 내 이동은 **'기타큐슈 버스 1일 승차권'**이 유용할 수 있습니다. JR 노선을 많이 이용하신다면 **'JR 북큐슈 레일패스'**를 고려해보세요.
# 2.  **가라토 시장:** 2일차를 금/토/일로 맞추면 가라토 시장에서 신선한 초밥을 저렴하게 즐길 수 있는 '이키이키 바칸가이' 행사를 즐길 수 있습니다.
# 3.  **날씨:** 기타큐슈는 바닷가 근처라 바람이 불 수 있으니 얇은 겉옷을 챙기세요.
# 4.  **맛집:**
#     *   **고쿠라:** '테츠나베 교자' (철판 교자), '야키우동' (발상지).
#     *   **모지코:** 야키카레.
#
# **혹시 특별히 좋아하시는 취향(예: 쇼핑, 역사 탐방, 온천, 사진 촬영 등)이 있으신가요?** 말씀해 주시면 그에 맞춰 일정을 더 세밀하게 조정해 드릴게요!

# %%
message = [
    ("user", "3박 4일간 대만 여행을 하려고 한다. 가면 좋을 관광지를 소개해줘.")
]
res = model.invoke(message)

# %%
Markdown(res.text)
# Out:
# 3박 4일 대만 여행은 주로 **'타이베이'를 중심으로 근교를 여행**하는 것이 가장 효율적입니다. 대중교통이 매우 잘 되어 있어 이동이 편리하죠. 여행 테마별로 핵심 관광지를 정리해 드릴게요.
#
# ---
#
# ### 1일차: 타이베이 시내 탐방 (도심 즐기기)
# *   **타이베이 101 타워:** 대만의 랜드마크입니다. 전망대에서 야경을 보거나, 지하의 '딘타이펑' 본점에서 식사를 추천합니다.
# *   **중정기념당:** 대만의 역사를 볼 수 있는 곳입니다. 매시 정각에 있는 근위병 교대식이 볼거리입니다.
# *   **용산사:** 타이베이에서 가장 오래된 사찰로, 밤에 방문하면 화려한 조명과 함께 현지인들의 기도하는 모습을 볼 수 있습니다.
# *   **시먼딩:** '타이베이의 명동'이라 불리는 곳입니다. 길거리 음식(지파이, 곱창국수 등)을 즐기고 쇼핑하기 좋습니다.
#
# ### 2일차: 예스진지 투어 (근교 핵심 코스)
# 대만 여행의 하이라이트입니다. 거리가 멀어 **일일 투어 버스**를 이용하는 것을 강력 추천합니다.
# *   **예(예류):** 기암괴석이 가득한 해안 지질 공원.
# *   **스(스펀):** 기찻길에서 소원을 적은 천등 날리기 체험.
# *   **진(진과스):** 황금 박물관과 광부 도시락 체험.
# *   **지(지우펀):** 애니메이션 '센과 치히로의 행방불명' 분위기가 나는 홍등 거리. 밤에 가는 것이 훨씬 예쁩니다.
#
# ### 3일차: 문화와 힐링 (여유 즐기기)
# *   **국립고궁박물원:** 세계 4대 박물관 중 하나로, 중국 고대 보물들을 감상할 수 있습니다.
# *   **단수이:** 영화 '말할 수 없는 비밀' 촬영지입니다. '홍마오청'과 '진리대학'을 둘러보고, '워런마터우'에서 석양을 보는 것이 필수 코스입니다.
# *   **스린 야시장 / 라오허제 야시장:** 타이베이 최대 규모의 야시장입니다. 큐브 스테이크, 왕자치즈감자 등 맛있는 음식이 가득합니다.
#
# ### 4일차: 마지막 쇼핑 및 공항 이동
# *   **화산 1914 창의문화원:** 옛 술 공장을 개조한 복합 문화 공간입니다. 아기자기한 소품샵과 카페가 많아 마지막 기념품을 사기에 좋습니다.
# *   **까르푸:** 대만 여행의 필수 쇼핑 코스(누가 크래커, 펑리수, 망고젤리 등)를 마무리하고 공항으로 이동합니다.
#
# ---
#
# ### 💡 여행 꿀팁
# 1.  **교통카드 (이지카드):** 편의점에서 쉽게 구매 가능합니다. 지하철(MRT), 버스, 편의점까지 어디서든 결제할 수 있어 필수입니다.
# 2.  **날씨:** 대만은 습하고 비가 자주 옵니다. 작은 우산이나 우비를 항상 챙기세요.
# 3.  **온천:** 시간적 여유가 된다면 '베이토우' 온천 마을에 들러 당일 온천을 즐기는 것도 아주 좋습니다.
# 4.  **숙소 위치:** 이동이 편리한 **'시먼딩'**이나 **'타이베이 메인역'** 근처에 잡는 것을 추천합니다.
#
# 어떤 스타일의 여행(미식 위주, 사진 찍기 위주, 휴식 위주 등)을 선호하시는지 알려주시면 더 구체적으로 일정을 조정해 드릴 수 있습니다!
