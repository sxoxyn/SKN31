# %% [markdown]
# # 데이터 불러오기

# %% [markdown]
# - 2022년 주유소들의 일자별 가격 데이터
# - https://www.opinet.co.kr/user/opdown/opDownload.do
#     - csv 파일로 다운 받고 read 시 인코딩 설정 필요
#     - 데이터 분석하고 인사이트를 얻을 때 뭘 얻고 싶은지 생각하는 것 중요~

# %%
# 상반기, 하반기 주유소 가격 데이터 조회

# %%
import pandas as pd

fh = pd.read_csv("data/2022년_서울_상반기_일별_가격.csv", index_col=0)
fh
# Out:
#               지역                  상호                    주소        기간      상표  \
# 번호
# A0006039  서울 강남구     (유)동하석유 힐탑셀프주유소        서울 강남구 논현로 640  20220101   SK에너지
# A0006039  서울 강남구     (유)동하석유 힐탑셀프주유소        서울 강남구 논현로 640  20220102   SK에너지
# A0006039  서울 강남구     (유)동하석유 힐탑셀프주유소        서울 강남구 논현로 640  20220103   SK에너지
# A0006039  서울 강남구     (유)동하석유 힐탑셀프주유소        서울 강남구 논현로 640  20220104   SK에너지
# A0006039  서울 강남구     (유)동하석유 힐탑셀프주유소        서울 강남구 논현로 640  20220105   SK에너지
# ...          ...                 ...                   ...       ...     ...
# A0009197  서울 중랑구  현대오일뱅크㈜직영 중랑교셀프주유소  서울 중랑구 망우로 229 (중화동)  20220507  현대오일뱅크
# A0009197  서울 중랑구  현대오일뱅크㈜직영 중랑교셀프주유소  서울 중랑구 망우로 229 (중화동)  20220508  현대오일뱅크
# A0009197  서울 중랑구  현대오일뱅크㈜직영 중랑교셀프주유소  서울 중랑구 망우로 229 (중화동)  20220509  현대오일뱅크
# A0009197  서울 중랑구  현대오일뱅크㈜직영 중랑교셀프주유소  서울 중랑구 망우로 229 (중화동)  20220510  현대오일뱅크
# A0009197  서울 중랑구  현대오일뱅크㈜직영 중랑교셀프주유소  서울 중랑구 망우로 229 (중화동)  20220511  현대오일뱅크
#
#          셀프여부  고급휘발유   휘발유    경유  실내등유
# ...

# %%
sh = pd.read_csv("data/2022년_서울_하반기_일별_가격.csv", index_col=0)
sh
# Out:
#               지역               상호                       주소        기간     상표  \
# 번호
# A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220701  SK에너지
# A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220702  SK에너지
# A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220703  SK에너지
# A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220704  SK에너지
# A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220705  SK에너지
# ...          ...              ...                      ...       ...    ...
# A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221227  GS칼텍스
# A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221228  GS칼텍스
# A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221229  GS칼텍스
# A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221230  GS칼텍스
# A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221231  GS칼텍스
#
#          셀프여부  고급휘발유   휘발유    경유  실내등유
# 번호
# ...

# %%
# 상반기, 하반기 DataFrame 합치기

# 1. 기본 합치기(행/열)
result = pd.concat([fh, sh])#, axis=1)
result
# Out:
#               지역               상호                       주소        기간     상표  \
# 번호
# A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220101  SK에너지
# A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220102  SK에너지
# A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220103  SK에너지
# A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220104  SK에너지
# A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220105  SK에너지
# ...          ...              ...                      ...       ...    ...
# A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221227  GS칼텍스
# A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221228  GS칼텍스
# A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221229  GS칼텍스
# A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221230  GS칼텍스
# A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221231  GS칼텍스
#
#          셀프여부  고급휘발유   휘발유    경유  실내등유
# 번호
# ...

# %%
# 2. dataframe 구분 위한 index 지정하며 합치기
result2 = pd.concat([fh, sh], keys=['상반기', '하반기'])
result2
# Out:
#                   지역               상호                       주소        기간  \
#     번호
# 상반기 A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220101
#     A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220102
#     A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220103
#     A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220104
#     A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220105
# ...              ...              ...                      ...       ...
# 하반기 A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221227
#     A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221228
#     A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221229
#     A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221230
#     A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221231
#
#                  상표 셀프여부  고급휘발유   휘발유    경유  실내등유
#     번호
# ...

# %%
# 3. 인덱스 확인 후 다중인덱스 단계별로 행 또는 열 조회
result2.index

result2.xs('A0006039', level=1, axis=0)
result2.xs("상반기", level=0, axis=0)
# Out:
#               지역                  상호                    주소        기간      상표  \
# 번호
# A0006039  서울 강남구     (유)동하석유 힐탑셀프주유소        서울 강남구 논현로 640  20220101   SK에너지
# A0006039  서울 강남구     (유)동하석유 힐탑셀프주유소        서울 강남구 논현로 640  20220102   SK에너지
# A0006039  서울 강남구     (유)동하석유 힐탑셀프주유소        서울 강남구 논현로 640  20220103   SK에너지
# A0006039  서울 강남구     (유)동하석유 힐탑셀프주유소        서울 강남구 논현로 640  20220104   SK에너지
# A0006039  서울 강남구     (유)동하석유 힐탑셀프주유소        서울 강남구 논현로 640  20220105   SK에너지
# ...          ...                 ...                   ...       ...     ...
# A0009197  서울 중랑구  현대오일뱅크㈜직영 중랑교셀프주유소  서울 중랑구 망우로 229 (중화동)  20220507  현대오일뱅크
# A0009197  서울 중랑구  현대오일뱅크㈜직영 중랑교셀프주유소  서울 중랑구 망우로 229 (중화동)  20220508  현대오일뱅크
# A0009197  서울 중랑구  현대오일뱅크㈜직영 중랑교셀프주유소  서울 중랑구 망우로 229 (중화동)  20220509  현대오일뱅크
# A0009197  서울 중랑구  현대오일뱅크㈜직영 중랑교셀프주유소  서울 중랑구 망우로 229 (중화동)  20220510  현대오일뱅크
# A0009197  서울 중랑구  현대오일뱅크㈜직영 중랑교셀프주유소  서울 중랑구 망우로 229 (중화동)  20220511  현대오일뱅크
#
#          셀프여부  고급휘발유   휘발유    경유  실내등유
# ...

# %%
# DataFrame 기본 정보 조회

# fh.info()
# sh.info()
result2.info()
# Out:
# <class 'pandas.DataFrame'>
# MultiIndex: 164482 entries, ('상반기', 'A0006039') to ('하반기', 'A0009138')
# Data columns (total 10 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   지역      164482 non-null  str
#  1   상호      164482 non-null  str
#  2   주소      164482 non-null  str
#  3   기간      164482 non-null  int64
#  4   상표      164482 non-null  str
#  5   셀프여부    164482 non-null  str
#  6   고급휘발유   164482 non-null  int64
#  7   휘발유     164482 non-null  int64
#  8   경유      164482 non-null  int64
#  9   실내등유    164482 non-null  int64
# dtypes: int64(5), str(5)
# memory usage: 13.0+ MB

# %%
# fh.shape
# sh.shape
result2.shape
# Out:
# (164482, 10)

# %%
# 상표 컬럼의 고유값 조회

# fh['상표'].unique()
# sh['상표'].unique()
result2['상표'].unique()
# Out:
# <StringArray>
# ['SK에너지', 'GS칼텍스', '현대오일뱅크', 'S-OIL', '알뜰주유소', '자가상표', '알뜰(ex)']
# Length: 7, dtype: str

# %%
# 지역 컬럼의 고유값 조회

# fh['지역'].unique()
# sh['지역'].unique()
result2['지역'].unique()
# Out:
# <StringArray>
# [ '서울 강남구',  '서울 강동구',  '서울 강북구',  '서울 강서구',  '서울 관악구',  '서울 광진구',  '서울 구로구',
#   '서울 금천구',  '서울 노원구',  '서울 도봉구', '서울 동대문구',  '서울 동작구',  '서울 마포구', '서울 서대문구',
#   '서울 서초구',  '서울 성동구',  '서울 성북구',  '서울 송파구',  '서울 양천구', '서울 영등포구',  '서울 용산구',
#   '서울 은평구',  '서울 종로구',   '서울 중구',  '서울 중랑구']
# Length: 25, dtype: str

# %% [markdown]
# > ### str accessor
# > - `Series.str.String메소드()`
# > - 문자열 타입 Series에 String 메소드들을 사용하여 일괄처리 할 수 있도록 한다.
# > - str accessor 메소드 : https://pandas.pydata.org/pandas-docs/stable/reference/series.html#api-series-str
#
# > ### datetime으로 변환
# > - `pd.to_datetime(변환할 Series, format="날짜형식")`
# > - x 또는 y 축이 날짜 일 경우 datetime 타입으로 처리하는 것이 좋다.
# > - format: 년월일의 형식을 strftime 형식문자열로 지정한다.
# >      - [strftime 형식](https://docs.python.org/3/library/datetime.html#strftime-and-strptime-format-codes)
# > - datetime을 변환하면 날짜만의 기능을 다룰 수 있다.
# >     - dt accessor를 이용해 datetime의 속성값들을(년, 월, 일 등) 추출할 수 있다.
# >     - https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.dt.html

# %%
# 지역 컬럼의 값을 이용하여 "구" 컬럼 생성 (지역에서 구만 추출해서 파생변수컬럼 생성해서 구별로로 집계를 할 수있도록 한다.)

result2['구'] = result2['지역'].str.split(expand=True)[1]
result2
# ex2 = result2['지역'].str.extract(r'서울\s+(\S+)')
# ex2
# ex3 = fresult2['지역'].str.slice(start=3)
# ex3
# Out:
#                   지역               상호                       주소        기간  \
#     번호
# 상반기 A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220101
#     A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220102
#     A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220103
#     A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220104
#     A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220105
# ...              ...              ...                      ...       ...
# 하반기 A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221227
#     A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221228
#     A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221229
#     A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221230
#     A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221231
#
#                  상표 셀프여부  고급휘발유   휘발유    경유  실내등유    구
#     번호
# ...

# %%
# 기간 컬럼을 datetime 타입으로 변경한다.

result2['기간'] = pd.to_datetime(result2['기간'], format="%Y%m%d")
result2
# Out:
#                   지역               상호                       주소         기간  \
#     번호
# 상반기 A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640 2022-01-01
#     A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640 2022-01-02
#     A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640 2022-01-03
#     A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640 2022-01-04
#     A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640 2022-01-05
# ...              ...              ...                      ...        ...
# 하반기 A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동) 2022-12-27
#     A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동) 2022-12-28
#     A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동) 2022-12-29
#     A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동) 2022-12-30
#     A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동) 2022-12-31
#
#                  상표 셀프여부  고급휘발유   휘발유    경유  실내등유    구
#     번호
# ...

# %%
# 기간 컬럼을 이용해 "월", "일", "요일" 컬럼 생성 (dt accessor 이용) (월, 일, 요일 별로 집계할 수있도록 한다.)

result2['월'] = result2['기간'].dt.month
result2
result2['일'] = result2['기간'].dt.day
result2
result2['요일'] = result2['기간'].dt.weekday
result2
# Out:
#                   지역               상호                       주소         기간  \
#     번호
# 상반기 A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640 2022-01-01
#     A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640 2022-01-02
#     A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640 2022-01-03
#     A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640 2022-01-04
#     A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640 2022-01-05
# ...              ...              ...                      ...        ...
# 하반기 A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동) 2022-12-27
#     A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동) 2022-12-28
#     A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동) 2022-12-29
#     A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동) 2022-12-30
#     A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동) 2022-12-31
#
#                  상표 셀프여부  고급휘발유   휘발유    경유  실내등유    구   월   일  요일
# ...

# %%
# 요일 - 0:월, 1:화, 2:수, 3:목, 4:금, 5:토, 6:일 로 변경

# 일괄처리 함수
import numpy as np

def convert_weekday(value):
    if pd.isna(value): # 결측치 처리
        return np.nan
    return "월화수목금토일"[int(value)]

result2['요일'] = result2['요일'].apply(convert_weekday)
result2

# lambda
# result2['요일'] = result2['요일'].apply(lambda x: "월화수목금토일"[int(x)] if pd.notna(x) else np.nan)
# Out:
#                   지역               상호                       주소         기간  \
#     번호
# 상반기 A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640 2022-01-01
#     A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640 2022-01-02
#     A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640 2022-01-03
#     A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640 2022-01-04
#     A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640 2022-01-05
# ...              ...              ...                      ...        ...
# 하반기 A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동) 2022-12-27
#     A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동) 2022-12-28
#     A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동) 2022-12-29
#     A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동) 2022-12-30
#     A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동) 2022-12-31
#
#                  상표 셀프여부  고급휘발유   휘발유    경유  실내등유    구   월   일 요일
# ...

# %%
# 휘발유 가격이 가장 비싼 5개 행 조회

result2.sort_values(by="휘발유", ascending=False).head()
# Out:
#                  지역     상호            주소         기간     상표 셀프여부  고급휘발유   휘발유  \
#     번호
# 상반기 A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2022-06-22  SK에너지   일반   3496  3096
#     A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2022-06-26  SK에너지   일반   3496  3096
#     A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2022-06-24  SK에너지   일반   3496  3096
#     A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2022-06-23  SK에너지   일반   3496  3096
#     A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2022-06-27  SK에너지   일반   3496  3096
#
#                 경유  실내등유   구  월   일 요일
#     번호
# 상반기 A0000767  3223  2719  중구  6  22  수
#     A0000767  3223  2719  중구  6  26  일
#     A0000767  3223  2719  중구  6  24  금
#     A0000767  3223  2719  중구  6  23  목
#     A0000767  3223  2719  중구  6  27  월

# %%
# 휘발유 가격이 가장 저렴한 5개 행 조회 (단 0원인 주유소 제외)

result2[result2['휘발유'] > 0].sort_values(by="휘발유").head()
# Out:
#                   지역               상호                      주소         기간  \
#     번호
# 하반기 A0000519  서울 강서구           화곡역주유소    서울 강서구 강서로 154 (화곡동) 2022-12-27
#     A0000549  서울 강서구  이케이에너지(주) 강서주유소    서울 강서구 화곡로 273 (화곡동) 2022-12-24
#     A0000549  서울 강서구  이케이에너지(주) 강서주유소    서울 강서구 화곡로 273 (화곡동) 2022-12-25
#     A0001005  서울 양천구            현대주유소  서울 양천구 남부순환로 372 (신월동) 2022-12-26
#     A0000549  서울 강서구  이케이에너지(주) 강서주유소    서울 강서구 화곡로 273 (화곡동) 2022-12-23
#
#                   상표 셀프여부  고급휘발유   휘발유    경유  실내등유    구   월   일 요일
#     번호
# 하반기 A0000519   알뜰주유소   셀프      0  1410  1660     0  강서구  12  27  화
#     A0000549  현대오일뱅크   셀프      0  1410  1660     0  강서구  12  24  토
#     A0000549  현대오일뱅크   셀프      0  1410  1660     0  강서구  12  25  일
#     A0001005   S-OIL   셀프      0  1410  1660     0  양천구  12  26  월
#     A0000549  현대오일뱅크   셀프      0  1410  1660     0  강서구  12  23  금

# %%
# 고급휘발유 가격이 가장 비싼 5개 행 조회

result2.sort_values(by="고급휘발유", ascending=False).head()
# Out:
#                  지역     상호            주소         기간     상표 셀프여부  고급휘발유   휘발유  \
#     번호
# 상반기 A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2022-06-27  SK에너지   일반   3496  3096
#     A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2022-06-26  SK에너지   일반   3496  3096
#     A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2022-06-25  SK에너지   일반   3496  3096
#     A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2022-06-24  SK에너지   일반   3496  3096
#     A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2022-06-23  SK에너지   일반   3496  3096
#
#                 경유  실내등유   구  월   일 요일
#     번호
# 상반기 A0000767  3223  2719  중구  6  27  월
#     A0000767  3223  2719  중구  6  26  일
#     A0000767  3223  2719  중구  6  25  토
#     A0000767  3223  2719  중구  6  24  금
#     A0000767  3223  2719  중구  6  23  목

# %%
# 고급휘발유 가격이 가장 저렴한 5개 행 조회 (단 0원인 주유소 제외)

result2[result2['고급휘발유'] > 0].sort_values(by="고급휘발유").head()
# Out:
#                   지역       상호                       주소         기간     상표 셀프여부  \
#     번호
# 하반기 A0000520  서울 강서구  하이웨이주유소  서울특별시 강서구 공항대로 432(화곡동) 2022-12-20  S-OIL   셀프
#     A0000520  서울 강서구  하이웨이주유소  서울특별시 강서구 공항대로 432(화곡동) 2022-12-21  S-OIL   셀프
#     A0000520  서울 강서구  하이웨이주유소  서울특별시 강서구 공항대로 432(화곡동) 2022-12-22  S-OIL   셀프
#     A0000520  서울 강서구  하이웨이주유소  서울특별시 강서구 공항대로 432(화곡동) 2022-12-23  S-OIL   셀프
#     A0000520  서울 강서구  하이웨이주유소  서울특별시 강서구 공항대로 432(화곡동) 2022-12-24  S-OIL   셀프
#
#               고급휘발유   휘발유    경유  실내등유    구   월   일 요일
#     번호
# 하반기 A0000520   1599  1527  1787     0  강서구  12  20  화
#     A0000520   1599  1499  1759     0  강서구  12  21  수
#     A0000520   1599  1499  1759     0  강서구  12  22  목
#     A0000520   1599  1499  1729     0  강서구  12  23  금
#     A0000520   1599  1499  1729     0  강서구  12  24  토

# %%
# 경유 가격이 가장 비싼 5개 행 조회

result2.sort_values(by="경유", ascending=False).head()
# Out:
#                  지역     상호            주소         기간     상표 셀프여부  고급휘발유   휘발유  \
#     번호
# 상반기 A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2022-06-29  SK에너지   일반   3481  3081
# 하반기 A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2022-07-01  SK에너지   일반   3481  3081
# 상반기 A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2022-06-28  SK에너지   일반   3481  3081
#     A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2022-06-30  SK에너지   일반   3481  3081
# 하반기 A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2022-07-04  SK에너지   일반   3481  3081
#
#                 경유  실내등유   구  월   일 요일
#     번호
# 상반기 A0000767  3230  2703  중구  6  29  수
# 하반기 A0000767  3230  2703  중구  7   1  금
# 상반기 A0000767  3230  2703  중구  6  28  화
#     A0000767  3230  2703  중구  6  30  목
# 하반기 A0000767  3230  2703  중구  7   4  월

# %%
# 경유 가격이 가장 저렴한 5개 행 조회 (단 0원인 주유소 제외)

result2[result2['경유'] > 0].sort_values(by="경유").head()
# Out:
#                   지역        상호                     주소         기간      상표 셀프여부  \
#     번호
# 상반기 A0011826  서울 서초구  만남의광장주유소   서울 서초구 양재대로12길 73-71 2022-01-16  알뜰(ex)   셀프
#     A0004657  서울 강서구    뉴신정주유소  서울 강서구 곰달래로 207 (화곡동) 2022-01-11   알뜰주유소   일반
#     A0004657  서울 강서구    뉴신정주유소  서울 강서구 곰달래로 207 (화곡동) 2022-01-12   알뜰주유소   일반
#     A0004657  서울 강서구    뉴신정주유소  서울 강서구 곰달래로 207 (화곡동) 2022-01-13   알뜰주유소   일반
#     A0000519  서울 강서구    화곡역주유소   서울 강서구 강서로 154 (화곡동) 2022-01-06   알뜰주유소   셀프
#
#               고급휘발유   휘발유    경유  실내등유    구  월   일 요일
#     번호
# 상반기 A0011826      0  1565  1367     0  서초구  1  16  일
#     A0004657      0  1547  1377     0  강서구  1  11  화
#     A0004657      0  1547  1377     0  강서구  1  12  수
#     A0004657      0  1547  1377     0  강서구  1  13  목
#     A0000519      0  1547  1377     0  강서구  1   6  목

# %%
# 상표별 휘발유 평균가격 조회

brand_avg = result2.groupby('상표')['휘발유'].mean().round(2)
brand_avg
# Out:
# 상표
# GS칼텍스     1904.90
# S-OIL     1859.28
# SK에너지     1908.90
# 알뜰(ex)    1759.88
# 알뜰주유소     1767.91
# 자가상표      1823.62
# 현대오일뱅크    1839.45
# Name: 휘발유, dtype: float64

# %%
# 상표별 휘발유 평균가격 시각화

import matplotlib.pyplot as plt

# 1. 데이터 준비 
brand_avg = result2.groupby('상표')['휘발유'].mean().round(2)

# 2. 그래프 그리기
plt.figure(figsize=(10, 6))
plt.bar(brand_avg.index, brand_avg.values)

plt.title('상표별 휘발유 평균 가격', fontsize=18)
for x, y in enumerate(brand_avg.values): # 막대 그래프 위 값 표시
    plt.text(x-0.3, y+10, str(y))

plt.xlabel('상표', fontsize=12)
plt.ylabel('평균 가격(원)', fontsize=12)
plt.xticks(rotation=45)

plt.ylim(0, 2200)

plt.show()

# %%
# 셀프주유소와 일반주유소 개수 확인

self_count = result2['셀프여부'].value_counts()
self_count
# Out:
# 셀프여부
# 셀프    92478
# 일반    72004
# Name: count, dtype: int64

# %%
# 셀프 여부에 따른 휘발유 평균 가격 비교 

self_yn = result2.groupby('셀프여부')['휘발유'].mean().round(2)
self_yn
# Out:
# 셀프여부
# 셀프    1818.22
# 일반    1953.87
# Name: 휘발유, dtype: float64

# %%
# 상표별 일반/셀프 주유소의 휘발유 가격 평균 비교

brand_self_avg = result2.groupby(['상표', '셀프여부'])['휘발유'].mean().round(2)
brand_self_avg
# Out:
# 상표      셀프여부
# GS칼텍스   셀프      1825.85
#         일반      2001.42
# S-OIL   셀프      1820.12
#         일반      1932.12
# SK에너지   셀프      1826.72
#         일반      2003.23
# 알뜰(ex)  셀프      1759.88
# 알뜰주유소   셀프      1754.26
#         일반      1796.20
# 자가상표    셀프      2017.00
#         일반      1821.77
# 현대오일뱅크  셀프      1807.27
#         일반      1877.61
# Name: 휘발유, dtype: float64

# %%
# 상표별 일반/셀프 주유소의 휘발유 가격 평균 비교 시각화

import matplotlib.pyplot as plt

# 1. 데이터 만들기
brand_self_pivot = result2.pivot_table(index='상표', columns='셀프여부', values='휘발유').round(2)

# 2. 그래프 그리기
brand_self_pivot.plot(kind='bar', figsize=(12, 8))

plt.title('상표별 셀프/일반 주유소 휘발유 가격 평균 비교', fontsize=18)

plt.xlabel('상표', fontsize=12)
plt.ylabel('평균 가격(원)', fontsize=12)
plt.xticks(rotation=45)
plt.legend(title='셀프여부', loc='upper right')

plt.ylim(0, 2300)

plt.show()

# %%
# 상표별 휘발유 가격의 분포를 boxplot으로 시각화

import matplotlib.pyplot as plt

# column: 데이터로 쓸 컬럼, by: 그룹을 나눌 기준 컬럼
result2.boxplot(column='휘발유', by='상표', figsize=(12, 8))

plt.suptitle('')
plt.xlabel('상표', fontsize=12)
plt.ylabel('가격(원)', fontsize=12)
plt.xticks(rotation=45)

plt.show()

# %%
# 상표별 일반/셀프 주유소의 휘발유 가격에 대한 분포 확인 - boxplot으로 시각화

# %%
# 구별 휘발유 가격의 평균

gu = result2.groupby('구')['휘발유'].mean().round()
gu
# Out:
# 구
# 강남구     2024.0
# 강동구     1911.0
# 강북구     1787.0
# 강서구     1829.0
# 관악구     1851.0
# 광진구     1818.0
# 구로구     1865.0
# 금천구     1799.0
# 노원구     1845.0
# 도봉구     1800.0
# 동대문구    1825.0
# 동작구     1837.0
# 마포구     1880.0
# 서대문구    1819.0
# 서초구     1902.0
# 성동구     1923.0
# 성북구     1805.0
# 송파구     1843.0
# 양천구     1800.0
# 영등포구    1864.0
# 용산구     2203.0
# 은평구     1822.0
# 종로구     2129.0
# 중구      2150.0
# 중랑구     1806.0
# Name: 휘발유, dtype: float64

# %%
# 평균 가격이 가장 높은 구의 상표별 휘발유 평균가격

gu_avg = result2.groupby(['상표', '구'])['휘발유'].mean().round(2)
gu_avg
# Out:
# 상표      구
# GS칼텍스   강남구    2096.48
#         강동구    1899.22
#         강북구    1792.97
#         강서구    1844.69
#         관악구    1872.75
#                 ...
# 현대오일뱅크  용산구    2013.06
#         은평구    1810.96
#         종로구    1928.50
#         중구     1927.89
#         중랑구    1800.70
# Name: 휘발유, Length: 110, dtype: float64

# %%
# 월 평균 휘발유 가격

month_avg = result2.groupby('월')['휘발유'].mean().round(2)
month_avg
# Out:
# 월
# 1     1704.98
# 2     1781.80
# 3     2007.94
# 4     2030.14
# 5     2027.26
# 6     2151.49
# 7     2082.67
# 8     1858.74
# 9     1799.55
# 10    1737.29
# 11    1715.45
# 12    1627.07
# Name: 휘발유, dtype: float64

# %%
# 각 구의 월별 평균 휘발유 가격 

month_avg = result2.groupby(['구', '월'])['휘발유'].mean().round(2)
month_avg
# Out:
# 구    월
# 강남구  1     1845.04
#      2     1914.71
#      3     2109.48
#      4     2138.08
#      5     2137.11
#             ...
# 중랑구  8     1773.06
#      9     1717.47
#      10    1654.12
#      11    1629.46
#      12    1566.59
# Name: 휘발유, Length: 300, dtype: float64

# %%
# 각 구의 월별 평균가격의 변화추이 시각화

import matplotlib.pyplot as plt

gu_month_pivot = result2.pivot_table(index='월', columns='구', values='휘발유', aggfunc='mean')

gu_month_pivot.plot(kind='line', figsize=(15, 8), marker='o')

plt.title('구별 월별 휘발유 평균 가격 추이', fontsize=18)
plt.xlabel('월', fontsize=12)
plt.ylabel('평균 가격(원)', fontsize=12)
plt.xticks(gu_month_pivot.index)

plt.legend(title='구', bbox_to_anchor=(1.02, 1), loc='upper left', ncol=2)

plt.show()

# %%
# 가장 휘발유가격이 비싼 주유소 상위 5 - (같은 주유소가 여러개 나오므로 가장 비싼 가격을 기준으로 집계)

exp_top5 = result2.groupby('상표')['휘발유'].max().sort_values(ascending=False).head()
exp_top5
# Out:
# 상표
# SK에너지     3096
# GS칼텍스     3050
# S-OIL     2595
# 현대오일뱅크    2568
# 알뜰주유소     2252
# Name: 휘발유, dtype: int64

# %%
# 가장 휘발유가격이 저렴한 주유소 상위 5 - (같은 주유소가 여러개 나오므로 가장 비싼 가격을 기준으로 집계)

cheap_top5 = result2.groupby('상표')['휘발유'].max().sort_values(ascending=False).head()
cheap_top5
# Out:
# 상표
# SK에너지     3096
# GS칼텍스     3050
# S-OIL     2595
# 현대오일뱅크    2568
# 알뜰주유소     2252
# Name: 휘발유, dtype: int64

# %%
result2
# Out:
#                   지역               상호                       주소         기간  \
#     번호
# 상반기 A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640 2022-01-01
#     A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640 2022-01-02
#     A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640 2022-01-03
#     A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640 2022-01-04
#     A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640 2022-01-05
# ...              ...              ...                      ...        ...
# 하반기 A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동) 2022-12-27
#     A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동) 2022-12-28
#     A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동) 2022-12-29
#     A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동) 2022-12-30
#     A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동) 2022-12-31
#
#                  상표 셀프여부  고급휘발유   휘발유    경유  실내등유    구   월   일 요일
# ...

# %%
# 휘발유 비싼 주유소의 상위 5개의 상호, 주소, 상표, 셀프여부,  조회 - 위에서 조회한 결과에 추가 정보(상표, 셀프여부 등) 조회 (중복제거-drop_duplicates)

exp_top5_info = result2.sort_values(by='휘발유', ascending=False) \
                       .drop_duplicates(subset=['상표', '주소']) \
                       .head(5)[['상호', '주소', '상표', '셀프여부', '휘발유']]

exp_top5_info
# Out:
#                   상호                       주소     상표 셀프여부   휘발유
#     번호
# 상반기 A0000767   서남주유소             서울 중구 통일로 30  SK에너지   일반  3096
#     A0000925   서계주유소    서울 용산구  청파로 367 (청파동)  GS칼텍스   일반  3050
#     A0009047   필동주유소     서울 중구 퇴계로 196 (필동2가)  GS칼텍스   일반  2789
#     A0000223  동자동주유소  서울 용산구 한강대로104길 6 (동자동)  SK에너지   일반  2690
#     A0000221   한석주유소           서울 용산구 이촌로 164  SK에너지   일반  2681

# %%
# 휘발유 저렴한 주유소의 상위 5개의 상호, 주소, 상표, 셀프여부,  조회 - 위에서 조회한 결과에 추가 정보(상표, 셀프여부 등) 조회 (중복제거-drop_duplicates)

cheap_top5_info = result2[result2['휘발유'] > 0] \
                       .sort_values(by='휘발유') \
                       .drop_duplicates(subset=['상표', '주소']) \
                       .head(5)[['상호', '주소', '상표', '셀프여부', '휘발유']]

cheap_top5_info
# Out:
#                            상호                      주소      상표 셀프여부   휘발유
#     번호
# 하반기 A0000519           화곡역주유소    서울 강서구 강서로 154 (화곡동)   알뜰주유소   셀프  1410
#     A0000549  이케이에너지(주) 강서주유소    서울 강서구 화곡로 273 (화곡동)  현대오일뱅크   셀프  1410
#     A0001005            현대주유소  서울 양천구 남부순환로 372 (신월동)   S-OIL   셀프  1410
#     A0004657           뉴신정주유소   서울 강서구 곰달래로 207 (화곡동)   알뜰주유소   일반  1415
#     A0000582            목화주유소   서울 강서구 국회대로 251 (화곡동)   알뜰주유소   셀프  1430

# %%
# 고급 휘발유를 가장 많이 파는 구 조회

premium = (result2[result2['고급휘발유'] > 0].groupby('구')['상표'].nunique().sort_values(ascending=False)).idxmax()
premium
# Out:
# '강남구'

# %%
###############################################################################
# 주유소 가격 데이터를 이용해서 알고 싶은 정보들을 추가 분석해 보세요.
###############################################################################
